# %% [markdown]
# # Multiplier TEST code

# %% [markdown]
# fixed number to stochastic conversion & multiply & stochastic to fixed number conversion

# %% [markdown]
# ## Import

# %%
import random, struct, math
import torch
import numpy as np
import torch.nn as nn 
import argparse
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Parser

# %%
parser = argparse.ArgumentParser(description='fixed_mac')
parser.add_argument('--full_bits', type=int, default=16, help='Number of Quantization Bits')
parser.add_argument('--frac_bits', type=int, default=8, help='Number of Quantization Bits')
parser.add_argument('--bBW', type=int, default=7, help='Number of bit width')
args = parser.parse_args(args=[])

# %% [markdown]
# ## Definition

# %% [markdown]
# ### int2bin : int number to binary number

# %%
def int2bin(iIn,iBW):
    iBW = iBW + 1
    if iIn >= 0:
        bOut = bin(iIn).replace('0b','').rjust(iBW,'0')
    else :
        bOut = bin(iIn & (pow(2,iBW)-1)).replace('0b','').rjust(iBW,'1')
    return bOut[1:]

# %% [markdown]
# ### XOR : xor gate with string

# %%
def XOR(iA,iB):
    if iA != iB :
        iOut = '1'
    else : 
        iOut = '0'
    return iOut

# %% [markdown]
# ### SNUM : sign number determination

# %%
def snum(a):
    if a >= 0 :
        return '0'
    else :
        return '1'

# %% [markdown]
# ## binInv : binary Inversion

# %%
def binInv(bIn):
    bOut = bin(int(bIn,2)^(pow(2,len(bIn))-1)).replace('0b','').rjust(len(bIn),'0')
    return bOut

# %% [markdown]
# ### fxp & flp2fix : floating number to fixed number conversion

# %%
class fxp:
    def __init__(self, bIn, iBWF):
        self.iFullBW = len(bIn)
        self.iIntgBW = self.iFullBW - iBWF
        self.bSign = bIn[0]
        self.bIntg = bIn[:self.iIntgBW]
        self.bFrac = bIn[self.iIntgBW:]
        self.fFull = 0
        try:
            for idx, bit in enumerate(bIn):
                if idx == 0:
                    self.fFull = self.fFull + int(bit,2) * -pow(2, self.iIntgBW - 1)
                else:
                    self.fFull = self.fFull + int(bit,2) * pow(2, self.iIntgBW - 1 - idx)
        except:
            print(bIn)
        self.dispFull = self.bIntg +"."+ self.bFrac 
        return

# %%
class flp2fix:
    def __init__(self, fIn, iBW, iBWF):
        self.fMin = - 2 ** (iBW - iBWF - 1)
        self.fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
        self.fResol = 2 ** -iBWF
        if fIn < self.fMin or fIn > self.fMax:
            print(f'({fIn}): Out of input range ({self.fMax}/{self.fMin}) during flp -> fix converting ')
        self.iBW = iBW
        self.iBWI = iBW - iBWF
        self.iBWF = iBWF

        self.iFLP2INT = abs(int(fIn * 2 ** iBWF))
        if fIn < 0:
            self.iFLP2INT = 2 ** (iBW-1) - self.iFLP2INT

        if fIn >= 0:
            self.bFull = bin(self.iFLP2INT)[2:].rjust(iBW, '0')
        else:
            self.bFull = '1'+bin(self.iFLP2INT)[2:].rjust(iBW-1, '0')
            if len(self.bFull) > iBW:
                self.bFull = '0' * iBW

        self.cssFxp = fxp(self.bFull, self.iBWF)
        self.bSign = self.cssFxp.bSign
        self.bIntg = self.cssFxp.bIntg
        self.bFrac = self.cssFxp.bFrac
        self.fFull = self.cssFxp.fFull
        return

# %%
def flp2fixTensor(fIn, iBW, iBWF):
    fMin = - 2 ** (iBW - iBWF - 1)
    fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
    fList = []
    for aTensor in fIn.view(-1):
        fList.append(flp2fix(aTensor, iBW, iBWF).fFull)
    return torch.tensor(fList).view(fIn.size())

# %% [markdown]
# ### LFSR : make pseudorandom number bitstream

# %%
class LFSR7:
    def Random(self):
        self.b0 = eval(f'str(random.randint(0,1))')
        self.b1 = eval(f'str(random.randint(0,1))')
        self.b2 = eval(f'str(random.randint(0,1))')
        self.b3 = eval(f'str(random.randint(0,1))')
        self.b4 = eval(f'str(random.randint(0,1))')
        self.b5 = eval(f'str(random.randint(0,1))')
        self.b6 = eval(f'str(random.randint(0,1))')
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6
    
    def Normal(self,stream):
        self.b0 = XOR(int(stream[5]),int(stream[6]))
        self.b1 = stream[0]
        self.b2 = stream[1]
        self.b3 = stream[2]
        self.b4 = stream[3]
        self.b5 = stream[4]
        self.b6 = stream[5]
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6
    
    def Allzero(self):
        self.b0 = '0'
        self.b1 = '0'
        self.b2 = '0'
        self.b3 = '0'
        self.b4 = '0'
        self.b5 = '0'
        self.b6 = '0'
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6

# %% [markdown]
# ### LFSRlist : make pseudorandom number bitstream with 2**bBW cycle

# %%
def LFSRlist7():
    lfsr = LFSR7()
    lfsrlist = []
    for k in range(2**(7)-1): #lfsr number generating
        if k == 0:
            lfsrlist.append(lfsr.Random())
        else :
            lfsrlist.append(lfsr.Normal(lfsrlist[k-1]))
        if (k == 2**(7)-2):
            lfsrlist.append(lfsr.Allzero())
    
    if (args.bBW) != args.frac_bits :
        if args.bBW < args.frac_bits :
            for i in range(len(lfsrlist)):
                lfsrlist[i] = lfsrlist[i] + (args.frac_bits-args.bBW)*'0'
        else :
            print("it can't work")
            return 0
    
    return lfsrlist

# %% [markdown]
# ### Comp : Comparator in SNG

# %%
def Comp(a,lfsr,snum):
    for com in range(0,len(a)):
        oA = '0'
        if a[com]!=lfsr[com]:
            if(int(a[com]) > int(lfsr[com])):
                oA = '1'
            break
    return XOR(oA,snum)

# %% [markdown]
# ### Perm : module for permutation SNG

# %%
def perm(a):
    al = len(a)
    blist = []
    if args.frac_bits == args.bBW : 
        for i in range(al) :
            blist.append(a[al-i-1])
    elif args.frac_bits > args.bBW :
        for i in range(al-(args.frac_bits-args.bBW)) :
            blist.append((a[al-(args.frac_bits-args.bBW)-i-1]))
    b = "".join(blist)
    b = b + ('0'*(args.frac_bits-args.bBW))
    return b

# %% [markdown]
# ### findMaxMin : find abs max value in act tensor

# %%
def findMaxMin(data):
    max = torch.max(data)
    min = torch.min(data)
    SF=torch.max(abs(max),abs(min)).item()
    return SF

# %% [markdown]
# ### SNG : stochastic number generator module

# %%
def SNG(iIN,lfsr):

    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    bFRAC = bIN[-(args.frac_bits):]
    if sNUM == 1 :
        bFRAC = bin(int(binInv(bFRAC),2)+1).replace('0b','').rjust(args.bBW,'0')
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        lNUM = lfsr[k]
        a = Comp(bFRAC,lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if bIN == args.full_bits*'0' :
        return '0'*(2**(args.bBW)+1)
    else :
        return sA

# %% [markdown]
# ### SNG_P : permutation stochastic number generator module

# %%
def SNG_P(iIN,lfsr):
    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    bFRAC = bIN[-(args.frac_bits):]
    if sNUM == 1 :
        bFRAC = bin(int(binInv(bFRAC),2)+1).replace('0b','').rjust(args.bBW,'0')
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating    
        lNUM = perm(lfsr[k])
        a = Comp(bFRAC,lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    
    if bIN == args.full_bits*'0' :
        return '0'*(2**(args.bBW)+1)
    else :
        return sA

# %% [markdown]
# ### SNGnumpy : SNG module with numpy

# %%
def SNGnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG(float(aNumpy),lfsr))
                     
    return np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### SNGpnumpy : permutation SNG module with numpy

# %%
def SNGpnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG_P(float(aNumpy),lfsr))
                     
    return  np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### CountOne : count 1 in stochastic number bit stream

# %%
def CountOne(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        n = 0
        for a in num:
            if a == '1' :
                n += 1
        if num[0] == '1' :
            nlist.append(n-1)
        else :
            nlist.append(n)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### defSign : sign determination in S2N

# %%
def defSign(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        if num[0] == '1' :
            nlist.append(-1)
        else :
            nlist.append(1)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### Multiplier

# %%
def mul(a,b):
    al = len(a)
    bl = len(b)
    
    outlist = []
    
    if al != bl :
        print("length of string is different")
        return 0
    
    outlist.append(XOR(a[0],b[0]))
    
    for i in range(al-1) :
        outlist.append(str(int(a[i+1]) & int(b[i+1])))
    
    #print(outlist)
    out = "".join(outlist)
    
    return out

# %%
def defSign1(nIn):
    if nIn[0] == '1' :
        return -1
    else :
        return 1

# %%
def CountOne1(nIn):
    n = 0
    for num in nIn:
        if num == '1' :
            n += 1
    if nIn[0] == '1' :
        return n-1
    else :
        return n

# %%
def S2None(sIn,SF):
    s = defSign(sIn)
    o = (CountOne(sIn)/(2**args.bBW))*SF*s
    return o

# %%
def mulNumpy(aIn,bIn,aSF,wSF):
    mList = []
    for i in range(aIn.shape[0]):
        for j in range(bIn.T.shape[1]):
            sum = 0
            for k in range(aIn.shape[1]):
                sum += S2None(mul((aIn[i][k].astype(str)),(bIn.T)[k][j].astype(str)),aSF*wSF)
            mList.append(sum)
    return torch.tensor(mList).view(aIn.shape[0],bIn.T.shape[1])

# %%
def FindError(a,b):
    error = 0
    for anum,bnum in zip(a.view(-1),b.view(-1)):
        e = (abs(bnum-anum)*100).item()
        error += e
    return error/(len(a.view(-1))+len(b.view(-1)))

# %% [markdown]
# # TEST : LFSR 7 bit

# %%
act = torch.rand((10,15))-torch.randint(5,(10,15))+torch.randint(5,(10,15))
wei = torch.rand((10,15))-torch.randint(5,(10,15))+torch.randint(5,(10,15))

# %%
act_f = flp2fixTensor(act,args.full_bits,args.frac_bits)
wei_f = flp2fixTensor(wei,args.full_bits,args.frac_bits)

# %% [markdown]
# ### number to stochastic conversion

# %%
aSF = findMaxMin(act_f)
wSF = findMaxMin(wei_f)

# %%
def N2S(act,wei,aSF,wSF):
    
    lfsrlist = LFSRlist7()
    
    a = SNGnumpy(act/aSF,lfsrlist)
    w = SNGpnumpy(wei/wSF,lfsrlist)
    
    return a,w

# %% [markdown]
# ### stochastic to number conversion

# %%
def S2N(a,w,aSF,wSF):
    
    sa = defSign(a)
    sw = defSign(w)

    ca = (CountOne(a)/(2**args.bBW)) * aSF *sa
    cw = (CountOne(w)/(2**args.bBW)) * wSF *sw

    return ca,cw

# %%
a,w = N2S(act,wei,aSF,wSF)

# %%
ca,cw = S2N(a,w,aSF,wSF)

# %%
def multest(aIn,wIn,aSF,wSF):
    mlist=[]
    out = 0
    for a,b in zip(aIn.reshape(-1),wIn.reshape(-1)) :
        out = mul(a,b)
        mlist.append(out)
    
    return np.array(mlist).reshape(aIn.shape)

# %%
c = multest(a,w,aSF,wSF)

# %%
print(wei_f[0][0])
# Out:
# tensor(2.9844)

# %%
print((wei_f[0][0])/wSF)
# Out:
# tensor(0.6388)

# %%
lfsr = LFSRlist7()

# %%
d = SNG_P(wei_f[0][0]/wSF,lfsr)

# %%
print(d)
# Out:
# 010010000101111001111010001001110111010101000000111111111111101111111111100011111110101110001011110000111111100111111111100100101

# %%
e = SNG(wei_f[0][0]/wSF,lfsr)

# %%
print(e)
# Out:
# 000100111101011110001000111011110101000000011111111111110111111111110001111111110111001010111000010111110011111111110100101001001

# %%
print(w[0][0])
# Out:
# 000111111101011100010111100001111111001111111111001001010010000101111001111010001001110111010101000000111111111111101111111111101

# %%
print(cw[0][0])
# Out:
# tensor(2.9929)

# %%
cc = flp2fixTensor(S2None(c,aSF*wSF),args.full_bits,args.frac_bits)

# %%
for i in range(10):
    for j in range(15):
        print(f'act value is            : {act_f[i][j]:^25}( --> {ca[i][j]})')
        print(f'wei value is            : {wei_f[i][j]:^25}( --> {cw[i][j]})')
        print(f'stochastic mul value is : {cc[i][j]:^25}( --> {ca[i][j] * cw[i][j]})')
        print(f'fixed mul value is      : {act_f[i][j]*wei_f[i][j]:^25}')
        print(f'------------------------------------------------------------------------------------------')
# Out:
# act value is            :        -1.94140625       ( --> -1.9376220703125)
# wei value is            :         2.984375         ( --> 2.992919921875)
# stochastic mul value is :        -5.5703125        ( --> -5.799147605895996)
# fixed mul value is      :     -5.79388427734375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.6015625        ( --> -0.59619140625)
# wei value is            :         2.0390625        ( --> 2.0439453125)
# stochastic mul value is :        -1.21484375       ( --> -1.2185826301574707)
# fixed mul value is      :     -1.22662353515625
# ------------------------------------------------------------------------------------------
# act value is            :          0.3125          ( --> 0.298095703125)
# wei value is            :        0.26171875        ( --> 0.2554931640625)
# stochastic mul value is :         0.171875         ( --> 0.07616141438484192)
# fixed mul value is      :      0.081787109375
# ------------------------------------------------------------------------------------------
# act value is            :         1.171875         ( --> 1.155120849609375)
# wei value is            :        -2.25390625       ( --> -2.2264404296875)
# stochastic mul value is :        -2.43359375       ( --> -2.571807861328125)
# fixed mul value is      :     -2.64129638671875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.6796875        ( --> -0.67071533203125)
# wei value is            :        0.29296875        ( --> 0.2919921875)
# stochastic mul value is :         -0.171875        ( --> -0.1958436369895935)
# fixed mul value is      :    -0.199127197265625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.9296875        ( --> -0.931549072265625)
# wei value is            :          4.1875          ( --> 4.1973876953125)
# stochastic mul value is :        -3.65234375       ( --> -3.9100725650787354)
# fixed mul value is      :      -3.89306640625
# ------------------------------------------------------------------------------------------
# act value is            :         2.1171875        ( --> 2.123931884765625)
# wei value is            :        -0.1171875        ( --> -0.1094970703125)
# stochastic mul value is :            0.0           ( --> -0.232564315199852)
# fixed mul value is      :     -0.24810791015625
# ------------------------------------------------------------------------------------------
# act value is            :        -3.72265625       ( --> -3.688934326171875)
# wei value is            :        -0.0546875        ( --> -0.0364990234375)
# stochastic mul value is :         0.171875         ( --> 0.13464249670505524)
# fixed mul value is      :     0.203582763671875
# ------------------------------------------------------------------------------------------
# act value is            :        1.97265625        ( --> 1.974884033203125)
# wei value is            :          0.03125         ( --> 0.0364990234375)
# stochastic mul value is :         0.171875         ( --> 0.07208134233951569)
# fixed mul value is      :      0.0616455078125
# ------------------------------------------------------------------------------------------
# act value is            :         4.2890625        ( --> 4.285125732421875)
# wei value is            :        0.51953125        ( --> 0.510986328125)
# stochastic mul value is :        2.43359375        ( --> 2.189640760421753)
# fixed mul value is      :     2.228302001953125
# ------------------------------------------------------------------------------------------
# act value is            :        2.91796875        ( --> 2.90643310546875)
# wei value is            :        -1.29296875       ( --> -1.2774658203125)
# stochastic mul value is :        -3.48046875       ( --> -3.7128689289093018)
# fixed mul value is      :    -3.7728424072265625
# ------------------------------------------------------------------------------------------
# act value is            :         0.5078125        ( --> 0.52166748046875)
# wei value is            :        -0.4296875        ( --> -0.4014892578125)
# stochastic mul value is :            0.0           ( --> -0.20944389700889587)
# fixed mul value is      :     -0.21820068359375
# ------------------------------------------------------------------------------------------
# act value is            :        1.62890625        ( --> 1.6395263671875)
# wei value is            :        4.45703125        ( --> 4.452880859375)
# stochastic mul value is :         7.484375         ( --> 7.3006157875061035)
# fixed mul value is      :    7.2600860595703125
# ------------------------------------------------------------------------------------------
# act value is            :          0.03125         ( --> 0.037261962890625)
# wei value is            :        0.16015625        ( --> 0.14599609375)
# stochastic mul value is :         0.171875         ( --> 0.0054401010274887085)
# fixed mul value is      :      0.0050048828125
# ------------------------------------------------------------------------------------------
# act value is            :         -1.09375         ( --> -1.080596923828125)
# wei value is            :        -2.0859375        ( --> -2.0804443359375)
# stochastic mul value is :         2.609375         ( --> 2.248121738433838)
# fixed mul value is      :      2.281494140625
# ------------------------------------------------------------------------------------------
# act value is            :        3.46484375        ( --> 3.465362548828125)
# wei value is            :        2.08203125        ( --> 2.0804443359375)
# stochastic mul value is :         7.484375         ( --> 7.209494113922119)
# fixed mul value is      :    7.2139129638671875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.25390625       ( --> -0.22357177734375)
# wei value is            :         0.5390625        ( --> 0.5474853515625)
# stochastic mul value is :            0.0           ( --> -0.12240227311849594)
# fixed mul value is      :    -0.136871337890625
# ------------------------------------------------------------------------------------------
# act value is            :        4.09765625        ( --> 4.09881591796875)
# wei value is            :           0.75           ( --> 0.7664794921875)
# stochastic mul value is :         3.3046875        ( --> 3.141658306121826)
# fixed mul value is      :       3.0732421875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.34765625       ( --> -0.335357666015625)
# wei value is            :        3.81640625        ( --> 3.8323974609375)
# stochastic mul value is :        -1.04296875       ( --> -1.2852238416671753)
# fixed mul value is      :    -1.3267974853515625
# ------------------------------------------------------------------------------------------
# act value is            :        -1.87890625       ( --> -1.86309814453125)
# wei value is            :        -0.02734375       ( --> -0.0)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :    0.0513763427734375
# ------------------------------------------------------------------------------------------
# act value is            :        1.88671875        ( --> 1.900360107421875)
# wei value is            :        0.32421875        ( --> 0.3284912109375)
# stochastic mul value is :         0.8671875        ( --> 0.6242516040802002)
# fixed mul value is      :    0.6117095947265625
# ------------------------------------------------------------------------------------------
# act value is            :         3.265625         ( --> 3.279052734375)
# wei value is            :         -2.84375         ( --> -2.8104248046875)
# stochastic mul value is :        -9.05078125       ( --> -9.215531349182129)
# fixed mul value is      :      -9.28662109375
# ------------------------------------------------------------------------------------------
# act value is            :        1.62109375        ( --> 1.6395263671875)
# wei value is            :        2.12890625        ( --> 2.116943359375)
# stochastic mul value is :        3.65234375        ( --> 3.4707844257354736)
# fixed mul value is      :    3.4511566162109375
# ------------------------------------------------------------------------------------------
# act value is            :         -0.46875         ( --> -0.4471435546875)
# wei value is            :        0.67578125        ( --> 0.6934814453125)
# stochastic mul value is :         -0.171875        ( --> -0.3100857734680176)
# fixed mul value is      :     -0.3167724609375
# ------------------------------------------------------------------------------------------
# act value is            :          0.1875          ( --> 0.186309814453125)
# wei value is            :         0.6015625        ( --> 0.6204833984375)
# stochastic mul value is :        0.34765625        ( --> 0.11560215055942535)
# fixed mul value is      :       0.11279296875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.74609375       ( --> -1.71405029296875)
# wei value is            :        1.39453125        ( --> 1.386962890625)
# stochastic mul value is :        -2.26171875       ( --> -2.377324104309082)
# fixed mul value is      :    -2.4349822998046875
# ------------------------------------------------------------------------------------------
# act value is            :          -1.125          ( --> -1.11785888671875)
# wei value is            :        -2.1015625        ( --> -2.0804443359375)
# stochastic mul value is :         2.609375         ( --> 2.325643301010132)
# fixed mul value is      :       2.3642578125
# ------------------------------------------------------------------------------------------
# act value is            :         0.7109375        ( --> 0.707977294921875)
# wei value is            :         0.5859375        ( --> 0.583984375)
# stochastic mul value is :        0.51953125        ( --> 0.41344767808914185)
# fixed mul value is      :     0.41656494140625
# ------------------------------------------------------------------------------------------
# act value is            :        1.69140625        ( --> 1.676788330078125)
# wei value is            :        1.16015625        ( --> 1.16796875)
# stochastic mul value is :         2.0859375        ( --> 1.958436369895935)
# fixed mul value is      :    1.9622955322265625
# ------------------------------------------------------------------------------------------
# act value is            :        0.59765625        ( --> 0.59619140625)
# wei value is            :        -0.6015625        ( --> -0.583984375)
# stochastic mul value is :        -0.34765625       ( --> -0.34816646575927734)
# fixed mul value is      :    -0.359527587890625
# ------------------------------------------------------------------------------------------
# act value is            :         -1.34375         ( --> -1.3414306640625)
# wei value is            :        1.33203125        ( --> 1.3504638671875)
# stochastic mul value is :        -1.73828125       ( --> -1.8115535974502563)
# fixed mul value is      :     -1.7899169921875
# ------------------------------------------------------------------------------------------
# act value is            :        -2.8828125        ( --> -2.869171142578125)
# wei value is            :        -0.66796875       ( --> -0.656982421875)
# stochastic mul value is :         2.0859375        ( --> 1.8849949836730957)
# fixed mul value is      :     1.925628662109375
# ------------------------------------------------------------------------------------------
# act value is            :         2.0859375        ( --> 2.086669921875)
# wei value is            :        -1.31640625       ( --> -1.31396484375)
# stochastic mul value is :         -2.609375        ( --> -2.7418107986450195)
# fixed mul value is      :    -2.745941162109375
# ------------------------------------------------------------------------------------------
# act value is            :        2.19140625        ( --> 2.198455810546875)
# wei value is            :        1.96484375        ( --> 1.970947265625)
# stochastic mul value is :         4.5234375        ( --> 4.333040237426758)
# fixed mul value is      :    4.3057708740234375
# ------------------------------------------------------------------------------------------
# act value is            :        2.72265625        ( --> 2.720123291015625)
# wei value is            :        -0.79296875       ( --> -0.7664794921875)
# stochastic mul value is :        -1.9140625        ( --> -2.084918737411499)
# fixed mul value is      :    -2.1589813232421875
# ------------------------------------------------------------------------------------------
# act value is            :        3.66796875        ( --> 3.688934326171875)
# wei value is            :         0.0078125        ( --> 0.0)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :     0.028656005859375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.55078125       ( --> -3.539886474609375)
# wei value is            :         1.8359375        ( --> 1.824951171875)
# stochastic mul value is :         -6.265625        ( --> -6.46012020111084)
# fixed mul value is      :    -6.519012451171875
# ------------------------------------------------------------------------------------------
# act value is            :        -2.99609375       ( --> -2.98095703125)
# wei value is            :        2.76171875        ( --> 2.77392578125)
# stochastic mul value is :        -8.1796875        ( --> -8.268953323364258)
# fixed mul value is      :    -8.274368286132812
# ------------------------------------------------------------------------------------------
# act value is            :        0.51171875        ( --> 0.52166748046875)
# wei value is            :           -3.25          ( --> -3.2484130859375)
# stochastic mul value is :        -1.56640625       ( --> -1.6945915222167969)
# fixed mul value is      :       -1.6630859375
# ------------------------------------------------------------------------------------------
# act value is            :        1.46484375        ( --> 1.453216552734375)
# wei value is            :        1.41796875        ( --> 1.4234619140625)
# stochastic mul value is :        2.26171875        ( --> 2.068598508834839)
# fixed mul value is      :    2.0771026611328125
# ------------------------------------------------------------------------------------------
# act value is            :        -2.6328125        ( --> -2.60833740234375)
# wei value is            :        -1.45703125       ( --> -1.4234619140625)
# stochastic mul value is :        4.00390625        ( --> 3.7128689289093018)
# fixed mul value is      :     3.836090087890625
# ------------------------------------------------------------------------------------------
# act value is            :          4.15625         ( --> 4.17333984375)
# wei value is            :        -0.5546875        ( --> -0.5474853515625)
# stochastic mul value is :        -2.26171875       ( --> -2.2848424911499023)
# fixed mul value is      :      -2.305419921875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.40234375       ( --> -0.37261962890625)
# wei value is            :        0.96484375        ( --> 0.9854736328125)
# stochastic mul value is :         -0.171875        ( --> -0.3672068119049072)
# fixed mul value is      :    -0.3881988525390625
# ------------------------------------------------------------------------------------------
# act value is            :        3.54296875        ( --> 3.539886474609375)
# wei value is            :        -3.28515625       ( --> -3.284912109375)
# stochastic mul value is :       -11.48828125       ( --> -11.628215789794922)
# fixed mul value is      :    -11.639205932617188
# ------------------------------------------------------------------------------------------
# act value is            :         1.2265625        ( --> 1.229644775390625)
# wei value is            :         2.2578125        ( --> 2.262939453125)
# stochastic mul value is :        2.95703125        ( --> 2.782611608505249)
# fixed mul value is      :     2.76934814453125
# ------------------------------------------------------------------------------------------
# act value is            :        0.25390625        ( --> 0.260833740234375)
# wei value is            :         1.3984375        ( --> 1.386962890625)
# stochastic mul value is :        0.51953125        ( --> 0.3617667257785797)
# fixed mul value is      :     0.355072021484375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.16015625       ( --> -0.1490478515625)
# wei value is            :        -2.71484375       ( --> -2.700927734375)
# stochastic mul value is :        0.51953125        ( --> 0.40256747603416443)
# fixed mul value is      :    0.4347991943359375
# ------------------------------------------------------------------------------------------
# act value is            :         0.8046875        ( --> 0.81976318359375)
# wei value is            :          0.8125          ( --> 0.802978515625)
# stochastic mul value is :         0.8671875        ( --> 0.6582522392272949)
# fixed mul value is      :       0.65380859375
# ------------------------------------------------------------------------------------------
# act value is            :         1.0234375        ( --> 1.0433349609375)
# wei value is            :        4.41015625        ( --> 4.4163818359375)
# stochastic mul value is :        4.87109375        ( --> 4.6077656745910645)
# fixed mul value is      :     4.513519287109375
# ------------------------------------------------------------------------------------------
# act value is            :         0.3515625        ( --> 0.37261962890625)
# wei value is            :        4.28515625        ( --> 4.2703857421875)
# stochastic mul value is :        1.73828125        ( --> 1.5912295579910278)
# fixed mul value is      :     1.506500244140625
# ------------------------------------------------------------------------------------------
# act value is            :         -2.15625         ( --> -2.123931884765625)
# wei value is            :        -2.8203125        ( --> -2.8104248046875)
# stochastic mul value is :         6.265625         ( --> 5.969151020050049)
# fixed mul value is      :      6.081298828125
# ------------------------------------------------------------------------------------------
# act value is            :         -0.890625        ( --> -0.857025146484375)
# wei value is            :        -0.79296875       ( --> -0.7664794921875)
# stochastic mul value is :         0.8671875        ( --> 0.6568921804428101)
# fixed mul value is      :     0.70623779296875
# ------------------------------------------------------------------------------------------
# act value is            :           -2.0           ( --> -1.974884033203125)
# wei value is            :        3.42578125        ( --> 3.430908203125)
# stochastic mul value is :        -6.61328125       ( --> -6.775645732879639)
# fixed mul value is      :        -6.8515625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.42578125       ( --> -0.409881591796875)
# wei value is            :        -0.59765625       ( --> -0.583984375)
# stochastic mul value is :        0.34765625        ( --> 0.23936444520950317)
# fixed mul value is      :    0.2544708251953125
# ------------------------------------------------------------------------------------------
# act value is            :        -3.8046875        ( --> -3.80072021484375)
# wei value is            :        2.88671875        ( --> 2.8834228515625)
# stochastic mul value is :       -10.79296875       ( --> -10.959083557128906)
# fixed mul value is      :    -10.983062744140625
# ------------------------------------------------------------------------------------------
# act value is            :         1.4140625        ( --> 1.41595458984375)
# wei value is            :        -1.83203125       ( --> -1.824951171875)
# stochastic mul value is :        -2.43359375       ( --> -2.58404803276062)
# fixed mul value is      :    -2.590606689453125
# ------------------------------------------------------------------------------------------
# act value is            :         0.484375         ( --> 0.484405517578125)
# wei value is            :        0.23828125        ( --> 0.2554931640625)
# stochastic mul value is :         0.171875         ( --> 0.12376229465007782)
# fixed mul value is      :     0.11541748046875
# ------------------------------------------------------------------------------------------
# act value is            :        0.26953125        ( --> 0.260833740234375)
# wei value is            :         1.140625         ( --> 1.1314697265625)
# stochastic mul value is :        0.34765625        ( --> 0.29512548446655273)
# fixed mul value is      :     0.30743408203125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.1640625        ( --> -0.1490478515625)
# wei value is            :        -0.19140625       ( --> -0.1824951171875)
# stochastic mul value is :         0.171875         ( --> 0.027200505137443542)
# fixed mul value is      :     0.031402587890625
# ------------------------------------------------------------------------------------------
# act value is            :         1.7109375        ( --> 1.71405029296875)
# wei value is            :          3.59375         ( --> 3.6134033203125)
# stochastic mul value is :          6.4375          ( --> 6.193554878234863)
# fixed mul value is      :      6.148681640625
# ------------------------------------------------------------------------------------------
# act value is            :         -0.90625         ( --> -0.894287109375)
# wei value is            :        1.81640625        ( --> 1.824951171875)
# stochastic mul value is :        -1.56640625       ( --> -1.6320302486419678)
# fixed mul value is      :     -1.6461181640625
# ------------------------------------------------------------------------------------------
# act value is            :        0.81640625        ( --> 0.81976318359375)
# wei value is            :         4.4296875        ( --> 4.4163818359375)
# stochastic mul value is :         3.828125         ( --> 3.620387315750122)
# fixed mul value is      :     3.616424560546875
# ------------------------------------------------------------------------------------------
# act value is            :         2.953125         ( --> 2.943695068359375)
# wei value is            :        0.68359375        ( --> 0.6934814453125)
# stochastic mul value is :        2.26171875        ( --> 2.0413978099823)
# fixed mul value is      :     2.01873779296875
# ------------------------------------------------------------------------------------------
# act value is            :         0.6171875        ( --> 0.633453369140625)
# wei value is            :           -0.75          ( --> -0.72998046875)
# stochastic mul value is :        -0.34765625       ( --> -0.4624086022377014)
# fixed mul value is      :       -0.462890625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.92578125       ( --> -0.894287109375)
# wei value is            :        2.34765625        ( --> 2.3359375)
# stochastic mul value is :        -2.0859375        ( --> -2.088998794555664)
# fixed mul value is      :    -2.1734161376953125
# ------------------------------------------------------------------------------------------
# act value is            :           -1.5           ( --> -1.490478515625)
# wei value is            :        -2.15234375       ( --> -2.1534423828125)
# stochastic mul value is :         3.3046875        ( --> 3.2096595764160156)
# fixed mul value is      :        3.228515625
# ------------------------------------------------------------------------------------------
# act value is            :        0.76171875        ( --> 0.782501220703125)
# wei value is            :        0.99609375        ( --> 0.9854736328125)
# stochastic mul value is :        1.04296875        ( --> 0.7711343169212341)
# fixed mul value is      :    0.7587432861328125
# ------------------------------------------------------------------------------------------
# act value is            :         1.6015625        ( --> 1.602264404296875)
# wei value is            :         1.4609375        ( --> 1.4599609375)
# stochastic mul value is :        2.43359375        ( --> 2.3392434120178223)
# fixed mul value is      :     2.33978271484375
# ------------------------------------------------------------------------------------------
# act value is            :        0.88671875        ( --> 0.894287109375)
# wei value is            :        -0.13671875       ( --> -0.1094970703125)
# stochastic mul value is :            0.0           ( --> -0.09792181849479675)
# fixed mul value is      :    -0.1212310791015625
# ------------------------------------------------------------------------------------------
# act value is            :        -1.7578125        ( --> -1.751312255859375)
# wei value is            :         3.7734375        ( --> 3.7593994140625)
# stochastic mul value is :          -6.4375         ( --> -6.5838823318481445)
# fixed mul value is      :     -6.63299560546875
# ------------------------------------------------------------------------------------------
# act value is            :         -1.140625        ( --> -1.11785888671875)
# wei value is            :        2.01953125        ( --> 2.0074462890625)
# stochastic mul value is :        -2.0859375        ( --> -2.244041681289673)
# fixed mul value is      :     -2.30352783203125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.29296875       ( --> -1.26690673828125)
# wei value is            :        3.08984375        ( --> 3.1024169921875)
# stochastic mul value is :         -3.828125        ( --> -3.9304730892181396)
# fixed mul value is      :    -3.9950714111328125
# ------------------------------------------------------------------------------------------
# act value is            :         2.2890625        ( --> 2.272979736328125)
# wei value is            :        -1.6484375        ( --> -1.6424560546875)
# stochastic mul value is :        -3.48046875       ( --> -3.733269214630127)
# fixed mul value is      :     -3.77337646484375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.3359375        ( --> -0.335357666015625)
# wei value is            :         -0.28125         ( --> -0.2554931640625)
# stochastic mul value is :         0.171875         ( --> 0.08568158745765686)
# fixed mul value is      :      0.094482421875
# ------------------------------------------------------------------------------------------
# act value is            :        0.19921875        ( --> 0.186309814453125)
# wei value is            :         2.4921875        ( --> 2.48193359375)
# stochastic mul value is :         0.6953125        ( --> 0.4624086022377014)
# fixed mul value is      :     0.496490478515625
# ------------------------------------------------------------------------------------------
# act value is            :        0.24609375        ( --> 0.260833740234375)
# wei value is            :        0.25390625        ( --> 0.2554931640625)
# stochastic mul value is :         0.171875         ( --> 0.06664124131202698)
# fixed mul value is      :    0.0624847412109375
# ------------------------------------------------------------------------------------------
# act value is            :        1.76171875        ( --> 1.751312255859375)
# wei value is            :        3.41015625        ( --> 3.3944091796875)
# stochastic mul value is :         6.265625         ( --> 5.9446702003479)
# fixed mul value is      :    6.0077362060546875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.2421875        ( --> -1.229644775390625)
# wei value is            :        1.64453125        ( --> 1.6424560546875)
# stochastic mul value is :        -1.9140625        ( --> -2.0196375846862793)
# fixed mul value is      :    -2.042816162109375
# ------------------------------------------------------------------------------------------
# act value is            :          -0.6875         ( --> -0.67071533203125)
# wei value is            :        -0.56640625       ( --> -0.5474853515625)
# stochastic mul value is :        0.51953125        ( --> 0.3672068119049072)
# fixed mul value is      :      0.389404296875
# ------------------------------------------------------------------------------------------
# act value is            :         3.7421875        ( --> 3.7261962890625)
# wei value is            :         0.734375         ( --> 0.72998046875)
# stochastic mul value is :        2.78515625        ( --> 2.720050573348999)
# fixed mul value is      :      2.7481689453125
# ------------------------------------------------------------------------------------------
# act value is            :           -0.75          ( --> -0.7452392578125)
# wei value is            :        -0.3046875        ( --> -0.2919921875)
# stochastic mul value is :        0.34765625        ( --> 0.21760404109954834)
# fixed mul value is      :        0.228515625
# ------------------------------------------------------------------------------------------
# act value is            :           3.25           ( --> 3.241790771484375)
# wei value is            :        -0.67578125       ( --> -0.656982421875)
# stochastic mul value is :        -1.9140625        ( --> -2.1297996044158936)
# fixed mul value is      :       -2.1962890625
# ------------------------------------------------------------------------------------------
# act value is            :        4.76953125        ( --> 0.0)
# wei value is            :        1.67578125        ( --> 1.678955078125)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :    7.9926910400390625
# ------------------------------------------------------------------------------------------
# act value is            :         -2.703125        ( --> -2.682861328125)
# wei value is            :          2.5625          ( --> 2.554931640625)
# stochastic mul value is :        -6.7890625        ( --> -6.854527473449707)
# fixed mul value is      :       -6.9267578125
# ------------------------------------------------------------------------------------------
# act value is            :         2.9140625        ( --> 2.90643310546875)
# wei value is            :        -0.37890625       ( --> -0.364990234375)
# stochastic mul value is :        -0.8671875        ( --> -1.0608197450637817)
# fixed mul value is      :    -1.104156494140625
# ------------------------------------------------------------------------------------------
# act value is            :         0.3984375        ( --> 0.409881591796875)
# wei value is            :         1.7578125        ( --> 1.751953125)
# stochastic mul value is :         0.8671875        ( --> 0.7180933356285095)
# fixed mul value is      :     0.70037841796875
# ------------------------------------------------------------------------------------------
# act value is            :         0.8515625        ( --> 0.857025146484375)
# wei value is            :        -1.74609375       ( --> -1.7154541015625)
# stochastic mul value is :        -1.21484375       ( --> -1.4701873064041138)
# fixed mul value is      :    -1.486907958984375
# ------------------------------------------------------------------------------------------
# act value is            :        0.18359375        ( --> 0.186309814453125)
# wei value is            :        -2.4453125        ( --> -2.4454345703125)
# stochastic mul value is :        -0.34765625       ( --> -0.45560845732688904)
# fixed mul value is      :    -0.448944091796875
# ------------------------------------------------------------------------------------------
# act value is            :        0.04296875        ( --> 0.037261962890625)
# wei value is            :         2.5546875        ( --> 2.554931640625)
# stochastic mul value is :         0.171875         ( --> 0.0952017679810524)
# fixed mul value is      :     0.109771728515625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.80859375       ( --> -0.782501220703125)
# wei value is            :        1.80078125        ( --> 1.7884521484375)
# stochastic mul value is :        -1.21484375       ( --> -1.3994660377502441)
# fixed mul value is      :    -1.4561004638671875
# ------------------------------------------------------------------------------------------
# act value is            :        4.05859375        ( --> 4.061553955078125)
# wei value is            :          -0.8125         ( --> -0.802978515625)
# stochastic mul value is :        -3.1328125        ( --> -3.261340618133545)
# fixed mul value is      :      -3.297607421875
# ------------------------------------------------------------------------------------------
# act value is            :        2.96484375        ( --> 2.98095703125)
# wei value is            :        -0.1171875        ( --> -0.1094970703125)
# stochastic mul value is :         -0.171875        ( --> -0.3264060616493225)
# fixed mul value is      :    -0.347442626953125
# ------------------------------------------------------------------------------------------
# act value is            :        1.25390625        ( --> 1.26690673828125)
# wei value is            :        1.16796875        ( --> 1.16796875)
# stochastic mul value is :        1.56640625        ( --> 1.4797074794769287)
# fixed mul value is      :    1.4645233154296875
# ------------------------------------------------------------------------------------------
# act value is            :        1.66796875        ( --> 1.676788330078125)
# wei value is            :        -0.63671875       ( --> -0.6204833984375)
# stochastic mul value is :        -0.8671875        ( --> -1.040419340133667)
# fixed mul value is      :    -1.0620269775390625
# ------------------------------------------------------------------------------------------
# act value is            :         0.7421875        ( --> 0.7452392578125)
# wei value is            :        -1.59765625       ( --> -1.5694580078125)
# stochastic mul value is :        -1.04296875       ( --> -1.1696217060089111)
# fixed mul value is      :    -1.185760498046875
# ------------------------------------------------------------------------------------------
# act value is            :          0.71875         ( --> 0.707977294921875)
# wei value is            :         -0.234375        ( --> -0.218994140625)
# stochastic mul value is :            0.0           ( --> -0.1550428867340088)
# fixed mul value is      :      -0.16845703125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.7890625        ( --> -0.782501220703125)
# wei value is            :        -0.10546875       ( --> -0.072998046875)
# stochastic mul value is :         0.171875         ( --> 0.05712106078863144)
# fixed mul value is      :     0.083221435546875
# ------------------------------------------------------------------------------------------
# act value is            :         -3.671875        ( --> -3.65167236328125)
# wei value is            :        2.66015625        ( --> 2.6644287109375)
# stochastic mul value is :        -9.57421875       ( --> -9.729620933532715)
# fixed mul value is      :     -9.76776123046875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.37890625       ( --> -0.37261962890625)
# wei value is            :          -2.375          ( --> -2.3724365234375)
# stochastic mul value is :        1.04296875        ( --> 0.8840163946151733)
# fixed mul value is      :       0.89990234375
# ------------------------------------------------------------------------------------------
# act value is            :         -0.59375         ( --> -0.558929443359375)
# wei value is            :          0.78125         ( --> 0.7664794921875)
# stochastic mul value is :         -0.171875        ( --> -0.4284079670906067)
# fixed mul value is      :       -0.4638671875
# ------------------------------------------------------------------------------------------
# act value is            :         3.171875         ( --> 3.167266845703125)
# wei value is            :         -3.09375         ( --> -3.06591796875)
# stochastic mul value is :        -9.3984375        ( --> -9.710579872131348)
# fixed mul value is      :      -9.81298828125
# ------------------------------------------------------------------------------------------
# act value is            :         -1.53125         ( --> -1.527740478515625)
# wei value is            :        2.67578125        ( --> 2.6644287109375)
# stochastic mul value is :         -3.828125        ( --> -4.070555686950684)
# fixed mul value is      :     -4.0972900390625
# ------------------------------------------------------------------------------------------
# act value is            :         -2.96875         ( --> -2.943695068359375)
# wei value is            :         -0.90625         ( --> -0.8759765625)
# stochastic mul value is :         2.609375         ( --> 2.5786077976226807)
# fixed mul value is      :       2.6904296875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.06640625       ( --> -0.037261962890625)
# wei value is            :        0.98828125        ( --> 0.9854736328125)
# stochastic mul value is :            0.0           ( --> -0.03672068193554878)
# fixed mul value is      :    -0.0656280517578125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.8671875        ( --> -0.857025146484375)
# wei value is            :        -2.0078125        ( --> -2.0074462890625)
# stochastic mul value is :         1.9140625        ( --> 1.720431923866272)
# fixed mul value is      :     1.74114990234375
# ------------------------------------------------------------------------------------------
# act value is            :        0.93359375        ( --> 0.931549072265625)
# wei value is            :         3.3359375        ( --> 3.3214111328125)
# stochastic mul value is :         3.3046875        ( --> 3.094057559967041)
# fixed mul value is      :     3.114410400390625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.8671875        ( --> -0.857025146484375)
# wei value is            :        1.73828125        ( --> 1.751953125)
# stochastic mul value is :         -1.390625        ( --> -1.5014679431915283)
# fixed mul value is      :    -1.507415771484375
# ------------------------------------------------------------------------------------------
# act value is            :        0.69921875        ( --> 0.707977294921875)
# wei value is            :        2.46484375        ( --> 2.48193359375)
# stochastic mul value is :         1.9140625        ( --> 1.7571526765823364)
# fixed mul value is      :    1.7234649658203125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.3828125        ( --> -0.37261962890625)
# wei value is            :        3.09765625        ( --> 3.1024169921875)
# stochastic mul value is :        -1.04296875       ( --> -1.1560214757919312)
# fixed mul value is      :    -1.185821533203125
# ------------------------------------------------------------------------------------------
# act value is            :          -0.875          ( --> -0.857025146484375)
# wei value is            :        2.20703125        ( --> 2.2264404296875)
# stochastic mul value is :        -1.73828125       ( --> -1.9081153869628906)
# fixed mul value is      :      -1.93115234375
# ------------------------------------------------------------------------------------------
# act value is            :        3.16796875        ( --> 3.167266845703125)
# wei value is            :            3.0           ( --> 2.992919921875)
# stochastic mul value is :        9.74609375        ( --> 9.479375839233398)
# fixed mul value is      :        9.50390625
# ------------------------------------------------------------------------------------------
# act value is            :        -2.3828125        ( --> -2.384765625)
# wei value is            :         3.5390625        ( --> 3.5404052734375)
# stochastic mul value is :        -8.35546875       ( --> -8.443037033081055)
# fixed mul value is      :     -8.43292236328125
# ------------------------------------------------------------------------------------------
# act value is            :           -3.25          ( --> -3.241790771484375)
# wei value is            :         -1.859375        ( --> -1.8614501953125)
# stochastic mul value is :         6.265625         ( --> 6.0344319343566895)
# fixed mul value is      :        6.04296875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.3671875        ( --> -0.335357666015625)
# wei value is            :           2.25           ( --> 2.262939453125)
# stochastic mul value is :        -0.51953125       ( --> -0.7588940858840942)
# fixed mul value is      :       -0.826171875
# ------------------------------------------------------------------------------------------
# act value is            :           2.625          ( --> 2.60833740234375)
# wei value is            :        0.07421875        ( --> 0.072998046875)
# stochastic mul value is :        0.34765625        ( --> 0.1904035359621048)
# fixed mul value is      :       0.19482421875
# ------------------------------------------------------------------------------------------
# act value is            :         1.4921875        ( --> 1.490478515625)
# wei value is            :        -0.5078125        ( --> -0.4744873046875)
# stochastic mul value is :        -0.51953125       ( --> -0.7072131633758545)
# fixed mul value is      :     -0.75775146484375
# ------------------------------------------------------------------------------------------
# act value is            :         4.7578125        ( --> 4.76953125)
# wei value is            :         0.4921875        ( --> 0.510986328125)
# stochastic mul value is :        2.43359375        ( --> 2.4371652603149414)
# fixed mul value is      :     2.34173583984375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.5546875        ( --> -2.5338134765625)
# wei value is            :         0.3203125        ( --> 0.3284912109375)
# stochastic mul value is :        -0.6953125        ( --> -0.8323354721069336)
# fixed mul value is      :     -0.81829833984375
# ------------------------------------------------------------------------------------------
# act value is            :        3.48828125        ( --> 3.50262451171875)
# wei value is            :        2.97265625        ( --> 2.992919921875)
# stochastic mul value is :        10.6171875        ( --> 10.483075141906738)
# fixed mul value is      :    10.369461059570312
# ------------------------------------------------------------------------------------------
# act value is            :        2.33203125        ( --> 2.347503662109375)
# wei value is            :         1.921875         ( --> 1.9344482421875)
# stochastic mul value is :        4.69921875        ( --> 4.54112434387207)
# fixed mul value is      :     4.48187255859375
# ------------------------------------------------------------------------------------------
# act value is            :          -0.4375         ( --> -0.409881591796875)
# wei value is            :         1.296875         ( --> 1.31396484375)
# stochastic mul value is :        -0.34765625       ( --> -0.538569986820221)
# fixed mul value is      :       -0.5673828125
# ------------------------------------------------------------------------------------------
# act value is            :         2.265625         ( --> 2.272979736328125)
# wei value is            :        -0.87109375       ( --> -0.8394775390625)
# stochastic mul value is :        -1.73828125       ( --> -1.9081153869628906)
# fixed mul value is      :     -1.97357177734375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.3671875        ( --> -2.347503662109375)
# wei value is            :         0.3828125        ( --> 0.4014892578125)
# stochastic mul value is :        -0.6953125        ( --> -0.9424974918365479)
# fixed mul value is      :     -0.90618896484375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.50390625       ( --> -2.496551513671875)
# wei value is            :        -2.26171875       ( --> -2.2264404296875)
# stochastic mul value is :         5.7421875        ( --> 5.558423042297363)
# fixed mul value is      :    5.6631317138671875
# ------------------------------------------------------------------------------------------
# act value is            :         -3.921875        ( --> -3.912506103515625)
# wei value is            :        0.98046875        ( --> 0.9854736328125)
# stochastic mul value is :        -3.65234375       ( --> -3.8556716442108154)
# fixed mul value is      :     -3.84527587890625
# ------------------------------------------------------------------------------------------
# act value is            :        -1.8515625        ( --> -1.825836181640625)
# wei value is            :          1.09375         ( --> 1.094970703125)
# stochastic mul value is :        -1.9140625        ( --> -1.9992371797561646)
# fixed mul value is      :      -2.025146484375
# ------------------------------------------------------------------------------------------
# act value is            :        -1.71484375       ( --> -1.71405029296875)
# wei value is            :        2.76953125        ( --> 2.77392578125)
# stochastic mul value is :        -4.5234375        ( --> -4.754648208618164)
# fixed mul value is      :    -4.7493133544921875
# ------------------------------------------------------------------------------------------
# act value is            :          -1.125          ( --> -1.11785888671875)
# wei value is            :         4.671875         ( --> 0.0)
# stochastic mul value is :            0.0           ( --> -0.0)
# fixed mul value is      :       -5.255859375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.72265625       ( --> -0.707977294921875)
# wei value is            :        -1.29296875       ( --> -1.2774658203125)
# stochastic mul value is :        1.04296875        ( --> 0.9044167995452881)
# fixed mul value is      :    0.9343719482421875
# ------------------------------------------------------------------------------------------
# act value is            :         0.015625         ( --> 0.0)
# wei value is            :        1.10546875        ( --> 1.094970703125)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :     0.01727294921875
# ------------------------------------------------------------------------------------------
# act value is            :        2.78515625        ( --> 2.794647216796875)
# wei value is            :        -1.83203125       ( --> -1.824951171875)
# stochastic mul value is :        -4.87109375       ( --> -5.100094795227051)
# fixed mul value is      :    -5.1024932861328125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.73828125       ( --> -0.707977294921875)
# wei value is            :        3.25390625        ( --> 3.2484130859375)
# stochastic mul value is :        -2.0859375        ( --> -2.299802780151367)
# fixed mul value is      :    -2.4022979736328125
# ------------------------------------------------------------------------------------------
# act value is            :        -3.67578125       ( --> -3.65167236328125)
# wei value is            :         -0.890625        ( --> -0.8759765625)
# stochastic mul value is :         3.3046875        ( --> 3.198779344558716)
# fixed mul value is      :     3.27374267578125
# ------------------------------------------------------------------------------------------
# act value is            :         3.2265625        ( --> 3.241790771484375)
# wei value is            :        1.74609375        ( --> 1.751953125)
# stochastic mul value is :         5.7421875        ( --> 5.679465293884277)
# fixed mul value is      :     5.633880615234375
# ------------------------------------------------------------------------------------------
# act value is            :         -2.78125         ( --> -2.75738525390625)
# wei value is            :         0.984375         ( --> 0.9854736328125)
# stochastic mul value is :        -2.43359375       ( --> -2.7173304557800293)
# fixed mul value is      :      -2.73779296875
# ------------------------------------------------------------------------------------------
# act value is            :        0.67578125        ( --> 0.67071533203125)
# wei value is            :        -0.59765625       ( --> -0.583984375)
# stochastic mul value is :        -0.34765625       ( --> -0.391687273979187)
# fixed mul value is      :    -0.4038848876953125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.9140625        ( --> -1.900360107421875)
# wei value is            :          0.3125          ( --> 0.3284912109375)
# stochastic mul value is :        -0.51953125       ( --> -0.6242516040802002)
# fixed mul value is      :      -0.59814453125
# ------------------------------------------------------------------------------------------
# act value is            :         1.7421875        ( --> 1.751312255859375)
# wei value is            :        2.96484375        ( --> 2.9564208984375)
# stochastic mul value is :        5.39453125        ( --> 5.177616119384766)
# fixed mul value is      :     5.165313720703125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.0703125        ( --> -0.037261962890625)
# wei value is            :        1.47265625        ( --> 1.4599609375)
# stochastic mul value is :            0.0           ( --> -0.054401010274887085)
# fixed mul value is      :    -0.103546142578125
# ------------------------------------------------------------------------------------------
# act value is            :        3.34765625        ( --> 3.35357666015625)
# wei value is            :         2.5234375        ( --> 2.5184326171875)
# stochastic mul value is :        8.52734375        ( --> 8.445756912231445)
# fixed mul value is      :     8.447601318359375
# ------------------------------------------------------------------------------------------
# act value is            :         -1.96875         ( --> -1.9376220703125)
# wei value is            :          1.0625          ( --> 1.0584716796875)
# stochastic mul value is :        -1.9140625        ( --> -2.0509181022644043)
# fixed mul value is      :       -2.091796875
# ------------------------------------------------------------------------------------------
# act value is            :        0.38671875        ( --> 0.37261962890625)
# wei value is            :        -0.93359375       ( --> -0.9124755859375)
# stochastic mul value is :         -0.171875        ( --> -0.3400063216686249)
# fixed mul value is      :    -0.3610382080078125
# ------------------------------------------------------------------------------------------
# act value is            :         3.3515625        ( --> 3.35357666015625)
# wei value is            :        1.21484375        ( --> 1.2044677734375)
# stochastic mul value is :        4.17578125        ( --> 4.039275169372559)
# fixed mul value is      :     4.071624755859375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.2421875        ( --> -0.22357177734375)
# wei value is            :         3.609375         ( --> 3.6134033203125)
# stochastic mul value is :        -0.6953125        ( --> -0.8078550100326538)
# fixed mul value is      :     -0.8741455078125
# ------------------------------------------------------------------------------------------
# act value is            :         0.6171875        ( --> 0.633453369140625)
# wei value is            :        1.73046875        ( --> 1.751953125)
# stochastic mul value is :        1.21484375        ( --> 1.1097805500030518)
# fixed mul value is      :     1.068023681640625
# ------------------------------------------------------------------------------------------
# act value is            :        1.18359375        ( --> 1.1923828125)
# wei value is            :          0.21875         ( --> 0.218994140625)
# stochastic mul value is :        0.34765625        ( --> 0.261124849319458)
# fixed mul value is      :      0.2589111328125
# ------------------------------------------------------------------------------------------
# act value is            :        1.22265625        ( --> 1.229644775390625)
# wei value is            :         -1.109375        ( --> -1.094970703125)
# stochastic mul value is :        -1.21484375       ( --> -1.3464250564575195)
# fixed mul value is      :     -1.35638427734375
# ------------------------------------------------------------------------------------------
# act value is            :        0.50390625        ( --> 0.52166748046875)
# wei value is            :         2.640625         ( --> 2.6279296875)
# stochastic mul value is :         1.390625         ( --> 1.3709053993225098)
# fixed mul value is      :     1.33062744140625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.6328125        ( --> -0.59619140625)
# wei value is            :         4.2578125        ( --> 4.2703857421875)
# stochastic mul value is :        -2.43359375       ( --> -2.5459673404693604)
# fixed mul value is      :     -2.69439697265625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.41796875       ( --> -0.409881591796875)
# wei value is            :        2.25390625        ( --> 2.262939453125)
# stochastic mul value is :        -0.6953125        ( --> -0.927537202835083)
# fixed mul value is      :    -0.9420623779296875
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## ERROR

# %%
def MSE(a,b):
    s = 0
    n = 0

    for i in range(100):
        for j in range(150):
            square = (((a[i][j])-b[i][j])**2).item()
            s += square
            n   += 1
    error = s/n
    return error

# %% [markdown]
# ## ERROR : 4bit LFSR

# %%
MSE(act_f*wei_f,cc)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-a16ace67035e> in <module>
# ----> 1 MSE(act_f*wei_f,cc)
#
# <ipython-input-47-111ebab47596> in MSE(a, b)
#       5     for i in range(100):
#       6         for j in range(150):
# ----> 7             square = (((a[i][j])-b[i][j])**2).item()
#       8             s += square
#       9             n   += 1
#
# IndexError: index 15 is out of bounds for dimension 0 with size 15
