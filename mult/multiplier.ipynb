# %% [markdown]
# # Multiplier TEST code

# %% [markdown]
# fixed number to stochastic conversion & multiply & stochastic to fixed number conversion

# %% [markdown]
# ## Import

# %%
import random, struct, math
import torch
import numpy as np
import torch.nn as nn 
import argparse
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Parser

# %%
parser = argparse.ArgumentParser(description='fixed_mac')
parser.add_argument('--full_bits', type=int, default=16, help='Number of Quantization Bits')
parser.add_argument('--frac_bits', type=int, default=8, help='Number of Quantization Bits')
parser.add_argument('--bBW', type=int, default=7, help='Number of bit width')
args = parser.parse_args(args=[])

# %% [markdown]
# ## Definition

# %% [markdown]
# ### int2bin : int number to binary number

# %%
def int2bin(iIn,iBW):
    iBW = iBW + 1
    if iIn >= 0:
        bOut = bin(iIn).replace('0b','').rjust(iBW,'0')
    else :
        bOut = bin(iIn & (pow(2,iBW)-1)).replace('0b','').rjust(iBW,'1')
    return bOut[1:]

# %% [markdown]
# ### XOR : xor gate with string

# %%
def XOR(iA,iB):
    if iA != iB :
        iOut = '1'
    else : 
        iOut = '0'
    return iOut

# %% [markdown]
# ### SNUM : sign number determination

# %%
def snum(a):
    if a >= 0 :
        return '0'
    else :
        return '1'

# %% [markdown]
# ## binInv : binary Inversion

# %%
def binInv(bIn):
    bOut = bin(int(bIn,2)^(pow(2,len(bIn))-1)).replace('0b','').rjust(len(bIn),'0')
    return bOut

# %% [markdown]
# ### fxp & flp2fix : floating number to fixed number conversion

# %%
class fxp:
    def __init__(self, bIn, iBWF):
        self.iFullBW = len(bIn)
        self.iIntgBW = self.iFullBW - iBWF
        self.bSign = bIn[0]
        self.bIntg = bIn[:self.iIntgBW]
        self.bFrac = bIn[self.iIntgBW:]
        self.fFull = 0
        try:
            for idx, bit in enumerate(bIn):
                if idx == 0:
                    self.fFull = self.fFull + int(bit,2) * -pow(2, self.iIntgBW - 1)
                else:
                    self.fFull = self.fFull + int(bit,2) * pow(2, self.iIntgBW - 1 - idx)
        except:
            print(bIn)
        self.dispFull = self.bIntg +"."+ self.bFrac 
        return

# %%
class flp2fix:
    def __init__(self, fIn, iBW, iBWF):
        self.fMin = - 2 ** (iBW - iBWF - 1)
        self.fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
        self.fResol = 2 ** -iBWF
        if fIn < self.fMin or fIn > self.fMax:
            print(f'({fIn}): Out of input range ({self.fMax}/{self.fMin}) during flp -> fix converting ')
        self.iBW = iBW
        self.iBWI = iBW - iBWF
        self.iBWF = iBWF

        self.iFLP2INT = abs(int(fIn * 2 ** iBWF))
        if fIn < 0:
            self.iFLP2INT = 2 ** (iBW-1) - self.iFLP2INT

        if fIn >= 0:
            self.bFull = bin(self.iFLP2INT)[2:].rjust(iBW, '0')
        else:
            self.bFull = '1'+bin(self.iFLP2INT)[2:].rjust(iBW-1, '0')
            if len(self.bFull) > iBW:
                self.bFull = '0' * iBW

        self.cssFxp = fxp(self.bFull, self.iBWF)
        self.bSign = self.cssFxp.bSign
        self.bIntg = self.cssFxp.bIntg
        self.bFrac = self.cssFxp.bFrac
        self.fFull = self.cssFxp.fFull
        return

# %%
def flp2fixTensor(fIn, iBW, iBWF):
    fMin = - 2 ** (iBW - iBWF - 1)
    fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
    fList = []
    for aTensor in fIn.view(-1):
        fList.append(flp2fix(aTensor, iBW, iBWF).fFull)
    return torch.tensor(fList).view(fIn.size())

# %% [markdown]
# ### LFSR : make pseudorandom number bitstream

# %%
class LFSR7:
    def Random(self):
        self.b0 = eval(f'str(random.randint(0,1))')
        self.b1 = eval(f'str(random.randint(0,1))')
        self.b2 = eval(f'str(random.randint(0,1))')
        self.b3 = eval(f'str(random.randint(0,1))')
        self.b4 = eval(f'str(random.randint(0,1))')
        self.b5 = eval(f'str(random.randint(0,1))')
        self.b6 = eval(f'str(random.randint(0,1))')
        if int(self.b0) + int(self.b1) + int(self.b2) + int(self.b3) + int(self.b4) + int(self.b5) + int(self.b6) == 0 :
            self.b0 = eval(f'str(random.randint(0,1))')
            self.b1 = eval(f'str(random.randint(0,1))')
            self.b2 = eval(f'str(random.randint(0,1))')
            self.b3 = eval(f'str(random.randint(0,1))')
            self.b4 = eval(f'str(random.randint(0,1))')
            self.b5 = eval(f'str(random.randint(0,1))')
            self.b6 = eval(f'str(random.randint(0,1))')
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6
    
    def Normal(self,stream):
        self.b0 = XOR(int(stream[5]),int(stream[6]))
        self.b1 = stream[0]
        self.b2 = stream[1]
        self.b3 = stream[2]
        self.b4 = stream[3]
        self.b5 = stream[4]
        self.b6 = stream[5]
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6
    
    def Allzero(self):
        self.b0 = '0'
        self.b1 = '0'
        self.b2 = '0'
        self.b3 = '0'
        self.b4 = '0'
        self.b5 = '0'
        self.b6 = '0'
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6

# %% [markdown]
# ### LFSRlist : make pseudorandom number bitstream with 2**bBW cycle

# %%
def LFSRlist7():
    lfsr = LFSR7()
    lfsrlist = []
    for k in range(2**(args.bBW)-1): #lfsr number generating
        if k == 0:
            lfsrlist.append(lfsr.Random())
        else :
            lfsrlist.append(lfsr.Normal(lfsrlist[k-1]))
        if (k == 2**(args.bBW)-2):
            lfsrlist.append(lfsr.Allzero())
    
    if (args.bBW) != args.frac_bits :
        if args.bBW < args.frac_bits :
            for i in range(len(lfsrlist)):
                lfsrlist[i] = lfsrlist[i] + (args.frac_bits-args.bBW)*'0'
        else :
            print("it can't work")
            return 0
    
    return lfsrlist

# %% [markdown]
# ### Comp : Comparator in SNG

# %%
def Comp(a,lfsr,snum):
    for com in range(0,len(a)):
        oA = '0'
        if a[com]!=lfsr[com]:
            if(int(a[com]) > int(lfsr[com])):
                oA = '1'
            break
    return XOR(oA,snum)

# %% [markdown]
# ### Perm : module for permutation SNG

# %%
def perm(a):
    al = len(a)
    blist = []
    if args.frac_bits == args.bBW : 
        for i in range(al) :
            blist.append(a[al-i-1])
    elif args.frac_bits > args.bBW :
        for i in range(al-(args.frac_bits-args.bBW)) :
            blist.append((a[al-(args.frac_bits-args.bBW)-i-1]))
    b = "".join(blist)
    b = b + ('0'*(args.frac_bits-args.bBW))
    return b

# %% [markdown]
# ### findMaxMin : find abs max value in act tensor

# %%
def findMaxMin(data):
    max = torch.max(data)
    min = torch.min(data)
    SF=torch.max(abs(max),abs(min)).item()
    return SF

# %% [markdown]
# ### SNG : stochastic number generator module

# %%
def SNG(iIN,lfsr):

    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    bFRAC = bIN[-(args.frac_bits):]
    if sNUM == 1 :
        bFRAC = bin(int(binInv(bFRAC),2)+1).replace('0b','').rjust(args.bBW,'0')
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        lNUM = lfsr[k]
        a = Comp(bFRAC,lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if bIN == args.full_bits*'0' :
        return '0'*(2**(args.bBW)+1)
    else :
        return sA

# %% [markdown]
# ### SNG_P : permutation stochastic number generator module

# %%
def SNG_P(iIN,lfsr):
    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    bFRAC = bIN[-(args.frac_bits):]
    if sNUM == 1 :
        bFRAC = bin(int(binInv(bFRAC),2)+1).replace('0b','').rjust(args.bBW,'0')
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating    
        lNUM = perm(lfsr[k])
        a = Comp(bFRAC,lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    
    if bIN == args.full_bits*'0' :
        return '0'*(2**(args.bBW)+1)
    else :
        return sA

# %% [markdown]
# ### SNGnumpy : SNG module with numpy

# %%
def SNGnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG(float(aNumpy),lfsr))
                     
    return np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### SNGpnumpy : permutation SNG module with numpy

# %%
def SNGpnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG_P(float(aNumpy),lfsr))
                     
    return  np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### CountOne : count 1 in stochastic number bit stream

# %%
def CountOne(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        n = 0
        for a in num:
            if a == '1' :
                n += 1
        if num[0] == '1' :
            nlist.append(n-1)
        else :
            nlist.append(n)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### defSign : sign determination in S2N

# %%
def defSign(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        if num[0] == '1' :
            nlist.append(-1)
        else :
            nlist.append(1)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### Multiplier

# %%
def mul(a,b):
    al = len(a)
    bl = len(b)
    
    outlist = []
    
    if al != bl :
        print("length of string is different")
        return 0
    
    outlist.append(XOR(a[0],b[0]))
    
    for i in range(al-1) :
        outlist.append(str(int(a[i+1]) & int(b[i+1])))
    
    #print(outlist)
    out = "".join(outlist)
    
    return out

# %%
def defSign1(nIn):
    if nIn[0] == '1' :
        return -1
    else :
        return 1

# %%
def CountOne1(nIn):
    n = 0
    for num in nIn:
        if num == '1' :
            n += 1
    if nIn[0] == '1' :
        return n-1
    else :
        return n

# %%
def S2None(sIn,SF):
    s = defSign(sIn)
    o = (CountOne(sIn)/(2**args.bBW))*SF*s
    return o

# %%
def mulNumpy(aIn,bIn,aSF,wSF):
    mList = []
    for i in range(aIn.shape[0]):
        for j in range(bIn.T.shape[1]):
            sum = 0
            for k in range(aIn.shape[1]):
                sum += S2None(mul((aIn[i][k].astype(str)),(bIn.T)[k][j].astype(str)),aSF*wSF)
            mList.append(sum)
    return torch.tensor(mList).view(aIn.shape[0],bIn.T.shape[1])

# %%
def FindError(a,b):
    elist = []
    for anum,bnum in zip(a.view(-1),b.view(-1)):
        e = (abs(bnum-anum)*100).item()
        elist.append(e)
    return torch.tensor(elist).reshape(a.size())

# %% [markdown]
# # TEST : LFSR 7 bit

# %%
act = torch.rand((10,15))-torch.randint(5,(10,15))+torch.randint(5,(10,15))
wei = torch.rand((10,15))-torch.randint(5,(10,15))+torch.randint(5,(10,15))

# %%
act_f = flp2fixTensor(act,args.full_bits,args.frac_bits)
wei_f = flp2fixTensor(wei,args.full_bits,args.frac_bits)

# %% [markdown]
# ### number to stochastic conversion

# %%
aSF = findMaxMin(act_f)
wSF = findMaxMin(wei_f)

# %%
def N2S(act,wei,aSF,wSF):
    
    lfsrlist = LFSRlist7()
    
    a = SNGnumpy(act/aSF,lfsrlist)
    w = SNGpnumpy(wei/wSF,lfsrlist)
    
    return a,w

# %% [markdown]
# ### stochastic to number conversion

# %%
def S2N(a,w,aSF,wSF):
    
    sa = defSign(a)
    sw = defSign(w)

    ca = (CountOne(a)/(2**args.bBW)) * aSF *sa
    cw = (CountOne(w)/(2**args.bBW)) * wSF *sw

    return ca,cw

# %%
a,w = N2S(act,wei,aSF,wSF)

# %%
ca,cw = S2N(a,w,aSF,wSF)

# %%
def multest(aIn,wIn,aSF,wSF):
    mlist=[]
    out = 0
    for a,b in zip(aIn.reshape(-1),wIn.reshape(-1)) :
        out = mul(a,b)
        mlist.append(out)
    
    return np.array(mlist).reshape(aIn.shape)

# %%
c = multest(a,w,aSF,wSF)

# %%
cc = flp2fixTensor(S2None(c,aSF*wSF),args.full_bits,args.frac_bits)

# %%
error = FindError(cc,act_f*wei_f)

# %%
print(f'error mean value is : {torch.mean(error)}')
print(f'------------------------------------------------------------------------------------------')
for i in range(10):
    for j in range(15):
        print(f'act value is            : {act_f[i][j]:^25}( --> {ca[i][j]})')
        print(f'wei value is            : {wei_f[i][j]:^25}( --> {cw[i][j]})')
        print(f'stochastic mul value is : {cc[i][j]:^25}( --> {ca[i][j] * cw[i][j]})')
        print(f'fixed mul value is      : {act_f[i][j]*wei_f[i][j]:^25}')
        print(f'error is                : {error[i][j]:^25}')
        print(f'------------------------------------------------------------------------------------------')
# Out:
# error mean value is : 26.57853126525879
# ------------------------------------------------------------------------------------------
# act value is            :         -3.34375         ( --> -3.34625244140625)
# wei value is            :        3.33203125        ( --> 3.32135009765625)
# stochastic mul value is :        -10.9140625       ( --> -11.114075660705566)
# fixed mul value is      :     -11.1414794921875
# error is                :      22.74169921875
# ------------------------------------------------------------------------------------------
# act value is            :        -3.4453125        ( --> -3.424072265625)
# wei value is            :         -3.421875        ( --> -3.424072265625)
# stochastic mul value is :         11.765625        ( --> 11.724270820617676)
# fixed mul value is      :     11.7894287109375
# error is                :       2.38037109375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.28515625       ( --> -2.25677490234375)
# wei value is            :        -2.42578125       ( --> -2.3968505859375)
# stochastic mul value is :        5.45703125        ( --> 5.409152030944824)
# fixed mul value is      :    5.5432891845703125
# error is                :     8.62579345703125
# ------------------------------------------------------------------------------------------
# act value is            :        -3.40234375       ( --> -3.385162353515625)
# wei value is            :        1.25390625        ( --> 1.26690673828125)
# stochastic mul value is :         -3.921875        ( --> -4.288684844970703)
# fixed mul value is      :    -4.2662200927734375
# error is                :     34.43450927734375
# ------------------------------------------------------------------------------------------
# act value is            :        1.68359375        ( --> 1.673126220703125)
# wei value is            :         3.2578125        ( --> 3.25286865234375)
# stochastic mul value is :           5.625          ( --> 5.442460060119629)
# fixed mul value is      :     5.484832763671875
# error is                :     14.0167236328125
# ------------------------------------------------------------------------------------------
# act value is            :        0.26953125        ( --> 0.272369384765625)
# wei value is            :        -0.9765625        ( --> -0.958740234375)
# stochastic mul value is :            0.0           ( --> -0.26113149523735046)
# fixed mul value is      :    -0.263214111328125
# error is                :     26.3214111328125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.8671875        ( --> -1.86767578125)
# wei value is            :        -0.17578125       ( --> -0.17120361328125)
# stochastic mul value is :         0.5078125        ( --> 0.31975284218788147)
# fixed mul value is      :     0.328216552734375
# error is                :     17.9595947265625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.2734375        ( --> -0.272369384765625)
# wei value is            :          1.1875          ( --> 1.19842529296875)
# stochastic mul value is :        -0.16796875       ( --> -0.3264143466949463)
# fixed mul value is      :      -0.32470703125
# error is                :       15.673828125
# ------------------------------------------------------------------------------------------
# act value is            :         1.2578125        ( --> 1.2451171875)
# wei value is            :         -0.828125        ( --> -0.82177734375)
# stochastic mul value is :        -1.01953125       ( --> -1.0232090950012207)
# fixed mul value is      :     -1.0416259765625
# error is                :       2.20947265625
# ------------------------------------------------------------------------------------------
# act value is            :        1.15234375        ( --> 1.16729736328125)
# wei value is            :         0.921875         ( --> 0.92449951171875)
# stochastic mul value is :        1.19140625        ( --> 1.0791658163070679)
# fixed mul value is      :     1.06231689453125
# error is                :      12.908935546875
# ------------------------------------------------------------------------------------------
# act value is            :        -2.33203125       ( --> -2.295684814453125)
# wei value is            :        -1.66796875       ( --> -1.6435546875)
# stochastic mul value is :         3.921875         ( --> 3.773083448410034)
# fixed mul value is      :    3.8897552490234375
# error is                :     3.21197509765625
# ------------------------------------------------------------------------------------------
# act value is            :        1.53515625        ( --> 1.556396484375)
# wei value is            :        -1.91796875       ( --> -1.91748046875)
# stochastic mul value is :        -2.8984375        ( --> -2.9843597412109375)
# fixed mul value is      :    -2.9443817138671875
# error is                :     4.59442138671875
# ------------------------------------------------------------------------------------------
# act value is            :        -2.78515625       ( --> -2.762603759765625)
# wei value is            :         -0.328125        ( --> -0.30816650390625)
# stochastic mul value is :        1.01953125        ( --> 0.851341962814331)
# fixed mul value is      :     0.91387939453125
# error is                :      10.565185546875
# ------------------------------------------------------------------------------------------
# act value is            :        1.92578125        ( --> 1.94549560546875)
# wei value is            :            2.0           ( --> 1.9859619140625)
# stochastic mul value is :         3.921875         ( --> 3.863680124282837)
# fixed mul value is      :         3.8515625
# error is                :          7.03125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.48828125       ( --> -0.4669189453125)
# wei value is            :        2.42578125        ( --> 2.43109130859375)
# stochastic mul value is :        -1.01953125       ( --> -1.135122537612915)
# fixed mul value is      :    -1.1844635009765625
# error is                :     16.49322509765625
# ------------------------------------------------------------------------------------------
# act value is            :         -1.96875         ( --> -1.94549560546875)
# wei value is            :        -1.44140625       ( --> -1.4381103515625)
# stochastic mul value is :         2.8984375        ( --> 2.797837257385254)
# fixed mul value is      :      2.8377685546875
# error is                :       6.06689453125
# ------------------------------------------------------------------------------------------
# act value is            :        2.62109375        ( --> 2.606964111328125)
# wei value is            :        0.50390625        ( --> 0.51361083984375)
# stochastic mul value is :          1.53125         ( --> 1.3389650583267212)
# fixed mul value is      :    1.3207855224609375
# error is                :     21.04644775390625
# ------------------------------------------------------------------------------------------
# act value is            :         1.1796875        ( --> 1.16729736328125)
# wei value is            :         -0.546875        ( --> -0.5478515625)
# stochastic mul value is :        -0.5078125        ( --> -0.6395056843757629)
# fixed mul value is      :     -0.6451416015625
# error is                :      13.73291015625
# ------------------------------------------------------------------------------------------
# act value is            :        -2.5546875        ( --> -2.529144287109375)
# wei value is            :          3.84375         ( --> 3.8349609375)
# stochastic mul value is :         -9.546875        ( --> -9.699169158935547)
# fixed mul value is      :      -9.819580078125
# error is                :       27.2705078125
# ------------------------------------------------------------------------------------------
# act value is            :         3.3359375        ( --> 3.34625244140625)
# wei value is            :         -3.140625        ( --> -3.11590576171875)
# stochastic mul value is :       -10.23046875       ( --> -10.426607131958008)
# fixed mul value is      :     -10.4769287109375
# error is                :      24.64599609375
# ------------------------------------------------------------------------------------------
# act value is            :         -3.09375         ( --> -3.073883056640625)
# wei value is            :         3.1484375        ( --> 3.150146484375)
# stochastic mul value is :         -9.546875        ( --> -9.683181762695312)
# fixed mul value is      :      -9.740478515625
# error is                :       19.3603515625
# ------------------------------------------------------------------------------------------
# act value is            :         0.8046875        ( --> 0.817108154296875)
# wei value is            :         -0.53125         ( --> -0.51361083984375)
# stochastic mul value is :        -0.16796875       ( --> -0.4196756184101105)
# fixed mul value is      :      -0.427490234375
# error is                :       25.9521484375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.69140625       ( --> -0.661468505859375)
# wei value is            :           2.75           ( --> 2.7392578125)
# stochastic mul value is :         -1.703125        ( --> -1.8119328022003174)
# fixed mul value is      :       -1.9013671875
# error is                :        19.82421875
# ------------------------------------------------------------------------------------------
# act value is            :          -1.4375         ( --> -1.439666748046875)
# wei value is            :        -0.8203125        ( --> -0.78753662109375)
# stochastic mul value is :        1.36328125        ( --> 1.1337902545928955)
# fixed mul value is      :       1.17919921875
# error is                :       18.408203125
# ------------------------------------------------------------------------------------------
# act value is            :         0.6484375        ( --> 0.661468505859375)
# wei value is            :        2.37109375        ( --> 2.36260986328125)
# stochastic mul value is :         1.703125         ( --> 1.5627920627593994)
# fixed mul value is      :     1.537506103515625
# error is                :     16.5618896484375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.1171875        ( --> -0.116729736328125)
# wei value is            :        2.40234375        ( --> 2.3968505859375)
# stochastic mul value is :        -0.16796875       ( --> -0.2797837257385254)
# fixed mul value is      :    -0.281524658203125
# error is                :     11.3555908203125
# ------------------------------------------------------------------------------------------
# act value is            :        1.91015625        ( --> 1.906585693359375)
# wei value is            :        -2.7578125        ( --> -2.7392578125)
# stochastic mul value is :        -5.11328125       ( --> -5.222629547119141)
# fixed mul value is      :    -5.267852783203125
# error is                :     15.4571533203125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.77734375       ( --> -1.750946044921875)
# wei value is            :        0.54296875        ( --> 0.5478515625)
# stochastic mul value is :        -0.8515625        ( --> -0.9592585563659668)
# fixed mul value is      :    -0.9650421142578125
# error is                :     11.34796142578125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.80859375       ( --> -0.7781982421875)
# wei value is            :         2.078125         ( --> 2.08868408203125)
# stochastic mul value is :         -1.53125         ( --> -1.6254103183746338)
# fixed mul value is      :     -1.68035888671875
# error is                :      14.910888671875
# ------------------------------------------------------------------------------------------
# act value is            :         2.828125         ( --> 2.840423583984375)
# wei value is            :        0.00390625        ( --> 0.0)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :     0.01104736328125
# error is                :      1.104736328125
# ------------------------------------------------------------------------------------------
# act value is            :         0.6640625        ( --> 0.661468505859375)
# wei value is            :        0.25390625        ( --> 0.23968505859375)
# stochastic mul value is :        0.33984375        ( --> 0.15854412317276)
# fixed mul value is      :     0.168609619140625
# error is                :     17.1234130859375
# ------------------------------------------------------------------------------------------
# act value is            :         0.953125         ( --> 0.933837890625)
# wei value is            :           3.125          ( --> 3.11590576171875)
# stochastic mul value is :        3.06640625        ( --> 2.9097509384155273)
# fixed mul value is      :        2.978515625
# error is                :         8.7890625
# ------------------------------------------------------------------------------------------
# act value is            :         0.5859375        ( --> 0.583648681640625)
# wei value is            :         3.9921875        ( --> 4.00616455078125)
# stochastic mul value is :         2.5546875        ( --> 2.3381927013397217)
# fixed mul value is      :     2.33917236328125
# error is                :      21.551513671875
# ------------------------------------------------------------------------------------------
# act value is            :         -0.15625         ( --> -0.1556396484375)
# wei value is            :        -2.90234375       ( --> -2.876220703125)
# stochastic mul value is :         0.5078125        ( --> 0.44765397906303406)
# fixed mul value is      :      0.4534912109375
# error is                :       5.43212890625
# ------------------------------------------------------------------------------------------
# act value is            :          0.78125         ( --> 0.7781982421875)
# wei value is            :        0.88671875        ( --> 0.8902587890625)
# stochastic mul value is :         0.8515625        ( --> 0.692797839641571)
# fixed mul value is      :      0.6927490234375
# error is                :      15.88134765625
# ------------------------------------------------------------------------------------------
# act value is            :        2.48828125        ( --> 2.490234375)
# wei value is            :        0.60546875        ( --> 0.6163330078125)
# stochastic mul value is :          1.53125         ( --> 1.534813642501831)
# fixed mul value is      :    1.5065765380859375
# error is                :     2.46734619140625
# ------------------------------------------------------------------------------------------
# act value is            :        2.93359375        ( --> 2.918243408203125)
# wei value is            :        3.02734375        ( --> 3.01318359375)
# stochastic mul value is :        9.03515625        ( --> 8.793203353881836)
# fixed mul value is      :     8.880996704101562
# error is                :     15.41595458984375
# ------------------------------------------------------------------------------------------
# act value is            :        0.94921875        ( --> 0.933837890625)
# wei value is            :        0.39453125        ( --> 0.410888671875)
# stochastic mul value is :         0.5078125        ( --> 0.38370341062545776)
# fixed mul value is      :    0.3744964599609375
# error is                :     13.33160400390625
# ------------------------------------------------------------------------------------------
# act value is            :        -2.5078125        ( --> -2.490234375)
# wei value is            :         0.671875         ( --> 0.684814453125)
# stochastic mul value is :         -1.703125        ( --> -1.7053484916687012)
# fixed mul value is      :     -1.6849365234375
# error is                :       1.81884765625
# ------------------------------------------------------------------------------------------
# act value is            :         0.6328125        ( --> 0.62255859375)
# wei value is            :        2.16015625        ( --> 2.15716552734375)
# stochastic mul value is :        1.36328125        ( --> 1.3429619073867798)
# fixed mul value is      :     1.366973876953125
# error is                :      0.3692626953125
# ------------------------------------------------------------------------------------------
# act value is            :        0.44140625        ( --> 0.428009033203125)
# wei value is            :         2.8828125        ( --> 2.876220703125)
# stochastic mul value is :          1.53125         ( --> 1.2310484647750854)
# fixed mul value is      :     1.272491455078125
# error is                :     25.8758544921875
# ------------------------------------------------------------------------------------------
# act value is            :        1.32421875        ( --> 1.32293701171875)
# wei value is            :          1.21875         ( --> 1.232666015625)
# stochastic mul value is :         1.703125         ( --> 1.630739450454712)
# fixed mul value is      :      1.6138916015625
# error is                :       8.92333984375
# ------------------------------------------------------------------------------------------
# act value is            :        0.87109375        ( --> 0.85601806640625)
# wei value is            :        0.91015625        ( --> 0.92449951171875)
# stochastic mul value is :        1.01953125        ( --> 0.7913882732391357)
# fixed mul value is      :    0.7928314208984375
# error is                :     22.66998291015625
# ------------------------------------------------------------------------------------------
# act value is            :         0.640625         ( --> 0.661468505859375)
# wei value is            :        0.76171875        ( --> 0.7532958984375)
# stochastic mul value is :         0.6796875        ( --> 0.4982815086841583)
# fixed mul value is      :     0.48797607421875
# error is                :      19.171142578125
# ------------------------------------------------------------------------------------------
# act value is            :         1.3515625        ( --> 1.361846923828125)
# wei value is            :        3.79296875        ( --> 3.80072021484375)
# stochastic mul value is :        5.28515625        ( --> 5.175999164581299)
# fixed mul value is      :     5.126434326171875
# error is                :     15.8721923828125
# ------------------------------------------------------------------------------------------
# act value is            :        3.60546875        ( --> 3.618621826171875)
# wei value is            :        -1.2109375        ( --> -1.19842529296875)
# stochastic mul value is :        -4.08984375       ( --> -4.336647987365723)
# fixed mul value is      :    -4.365997314453125
# error is                :     27.6153564453125
# ------------------------------------------------------------------------------------------
# act value is            :         2.7734375        ( --> 2.762603759765625)
# wei value is            :        2.45703125        ( --> 2.46533203125)
# stochastic mul value is :        6.98828125        ( --> 6.810735702514648)
# fixed mul value is      :     6.814422607421875
# error is                :     17.3858642578125
# ------------------------------------------------------------------------------------------
# act value is            :        -2.8203125        ( --> -2.801513671875)
# wei value is            :            1.0           ( --> 0.99298095703125)
# stochastic mul value is :        -2.5546875        ( --> -2.7818496227264404)
# fixed mul value is      :        -2.8203125
# error is                :          26.5625
# ------------------------------------------------------------------------------------------
# act value is            :         3.8984375        ( --> 3.8909912109375)
# wei value is            :           2.75           ( --> 2.7392578125)
# stochastic mul value is :        10.7421875        ( --> 10.658428192138672)
# fixed mul value is      :       10.720703125
# error is                :         2.1484375
# ------------------------------------------------------------------------------------------
# act value is            :        3.92578125        ( --> 3.929901123046875)
# wei value is            :         -2.53125         ( --> -2.49957275390625)
# stochastic mul value is :         -9.546875        ( --> -9.823073387145996)
# fixed mul value is      :     -9.9371337890625
# error is                :      39.02587890625
# ------------------------------------------------------------------------------------------
# act value is            :         0.4921875        ( --> 0.505828857421875)
# wei value is            :        0.44140625        ( --> 0.44512939453125)
# stochastic mul value is :        0.33984375        ( --> 0.22515928745269775)
# fixed mul value is      :     0.217254638671875
# error is                :     12.2589111328125
# ------------------------------------------------------------------------------------------
# act value is            :        -3.3359375        ( --> -3.307342529296875)
# wei value is            :        3.11328125        ( --> 3.11590576171875)
# stochastic mul value is :       -10.05859375       ( --> -10.305367469787598)
# fixed mul value is      :    -10.385711669921875
# error is                :     32.7117919921875
# ------------------------------------------------------------------------------------------
# act value is            :         4.4609375        ( --> 4.474639892578125)
# wei value is            :        1.20703125        ( --> 1.19842529296875)
# stochastic mul value is :        5.45703125        ( --> 5.362521648406982)
# fixed mul value is      :     5.384490966796875
# error is                :      7.2540283203125
# ------------------------------------------------------------------------------------------
# act value is            :         1.8828125        ( --> 1.86767578125)
# wei value is            :        -0.7421875        ( --> -0.71905517578125)
# stochastic mul value is :        -1.19140625       ( --> -1.3429619073867798)
# fixed mul value is      :     -1.39739990234375
# error is                :      20.599365234375
# ------------------------------------------------------------------------------------------
# act value is            :        1.25390625        ( --> 1.2451171875)
# wei value is            :        -0.48828125       ( --> -0.4793701171875)
# stochastic mul value is :        -0.5078125        ( --> -0.5968719720840454)
# fixed mul value is      :    -0.6122589111328125
# error is                :     10.44464111328125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.21484375       ( --> -1.206207275390625)
# wei value is            :        3.44140625        ( --> 3.45831298828125)
# stochastic mul value is :        -4.08984375       ( --> -4.17144250869751)
# fixed mul value is      :    -4.1807708740234375
# error is                :     9.09271240234375
# ------------------------------------------------------------------------------------------
# act value is            :         1.1328125        ( --> 1.128387451171875)
# wei value is            :         -2.546875        ( --> -2.5338134765625)
# stochastic mul value is :        -2.5546875        ( --> -2.8591232299804688)
# fixed mul value is      :     -2.8851318359375
# error is                :      33.04443359375
# ------------------------------------------------------------------------------------------
# act value is            :        -1.57421875       ( --> -1.556396484375)
# wei value is            :          4.28125         ( --> 4.28009033203125)
# stochastic mul value is :        -6.4765625        ( --> -6.66151762008667)
# fixed mul value is      :     -6.7396240234375
# error is                :      26.30615234375
# ------------------------------------------------------------------------------------------
# act value is            :        1.99609375        ( --> 1.984405517578125)
# wei value is            :         -1.796875        ( --> -1.780517578125)
# stochastic mul value is :        -3.23828125       ( --> -3.533268928527832)
# fixed mul value is      :     -3.58673095703125
# error is                :      34.844970703125
# ------------------------------------------------------------------------------------------
# act value is            :          -2.3125         ( --> -2.295684814453125)
# wei value is            :          0.84375         ( --> 0.85601806640625)
# stochastic mul value is :         -1.703125        ( --> -1.9651477336883545)
# fixed mul value is      :       -1.951171875
# error is                :        24.8046875
# ------------------------------------------------------------------------------------------
# act value is            :         1.703125         ( --> 1.7120361328125)
# wei value is            :         1.015625         ( --> 1.0272216796875)
# stochastic mul value is :           1.875          ( --> 1.7586406469345093)
# fixed mul value is      :      1.729736328125
# error is                :       14.5263671875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.24609375       ( --> -0.23345947265625)
# wei value is            :          0.59375         ( --> 0.58209228515625)
# stochastic mul value is :            0.0           ( --> -0.13589495420455933)
# fixed mul value is      :     -0.1461181640625
# error is                :      14.61181640625
# ------------------------------------------------------------------------------------------
# act value is            :         -3.921875        ( --> -3.8909912109375)
# wei value is            :        1.12109375        ( --> 1.12994384765625)
# stochastic mul value is :        -4.26171875       ( --> -4.396601676940918)
# fixed mul value is      :     -4.39678955078125
# error is                :      13.507080078125
# ------------------------------------------------------------------------------------------
# act value is            :        1.62890625        ( --> 1.63421630859375)
# wei value is            :        0.73046875        ( --> 0.71905517578125)
# stochastic mul value is :          1.53125         ( --> 1.1750917434692383)
# fixed mul value is      :    1.1898651123046875
# error is                :     34.13848876953125
# ------------------------------------------------------------------------------------------
# act value is            :        0.32421875        ( --> 0.311279296875)
# wei value is            :        1.47265625        ( --> 1.47235107421875)
# stochastic mul value is :         0.5078125        ( --> 0.45831239223480225)
# fixed mul value is      :    0.4774627685546875
# error is                :     3.03497314453125
# ------------------------------------------------------------------------------------------
# act value is            :        3.12109375        ( --> 3.11279296875)
# wei value is            :        -2.16796875       ( --> -2.15716552734375)
# stochastic mul value is :        -6.6484375        ( --> -6.714809894561768)
# fixed mul value is      :    -6.7664337158203125
# error is                :     11.79962158203125
# ------------------------------------------------------------------------------------------
# act value is            :        1.49609375        ( --> 1.47857666015625)
# wei value is            :        -0.1328125        ( --> -0.10272216796875)
# stochastic mul value is :            0.0           ( --> -0.151882603764534)
# fixed mul value is      :    -0.198699951171875
# error is                :     19.8699951171875
# ------------------------------------------------------------------------------------------
# act value is            :        4.44140625        ( --> 4.43572998046875)
# wei value is            :        -1.6484375        ( --> -1.6435546875)
# stochastic mul value is :        -7.16015625       ( --> -7.290364742279053)
# fixed mul value is      :    -7.321380615234375
# error is                :     16.1224365234375
# ------------------------------------------------------------------------------------------
# act value is            :         1.3359375        ( --> 1.32293701171875)
# wei value is            :        -0.71484375       ( --> -0.684814453125)
# stochastic mul value is :        -0.8515625        ( --> -0.9059664011001587)
# fixed mul value is      :    -0.954986572265625
# error is                :     10.3424072265625
# ------------------------------------------------------------------------------------------
# act value is            :          -1.1875         ( --> -1.16729736328125)
# wei value is            :         0.734375         ( --> 0.7532958984375)
# stochastic mul value is :        -0.6796875        ( --> -0.8793203234672546)
# fixed mul value is      :       -0.8720703125
# error is                :        19.23828125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.6953125        ( --> -0.661468505859375)
# wei value is            :         -1.296875        ( --> -1.26690673828125)
# stochastic mul value is :        1.01953125        ( --> 0.8380188941955566)
# fixed mul value is      :      0.9017333984375
# error is                :      11.77978515625
# ------------------------------------------------------------------------------------------
# act value is            :         0.2265625        ( --> 0.23345947265625)
# wei value is            :        -3.22265625       ( --> -3.2186279296875)
# stochastic mul value is :        -0.5078125        ( --> -0.751419186592102)
# fixed mul value is      :    -0.730133056640625
# error is                :     22.2320556640625
# ------------------------------------------------------------------------------------------
# act value is            :        3.23828125        ( --> 3.229522705078125)
# wei value is            :         0.1171875        ( --> 0.10272216796875)
# stochastic mul value is :         0.5078125        ( --> 0.3317435681819916)
# fixed mul value is      :     0.379486083984375
# error is                :     12.8326416015625
# ------------------------------------------------------------------------------------------
# act value is            :         3.3203125        ( --> 3.307342529296875)
# wei value is            :         -2.390625        ( --> -2.36260986328125)
# stochastic mul value is :           -7.5           ( --> -7.813960075378418)
# fixed mul value is      :     -7.9376220703125
# error is                :      43.76220703125
# ------------------------------------------------------------------------------------------
# act value is            :         -3.015625        ( --> -2.996063232421875)
# wei value is            :        4.23828125        ( --> 4.245849609375)
# stochastic mul value is :        -12.6171875       ( --> -12.720833778381348)
# fixed mul value is      :    -12.78106689453125
# error is                :      16.387939453125
# ------------------------------------------------------------------------------------------
# act value is            :        0.85546875        ( --> 0.85601806640625)
# wei value is            :        -1.20703125       ( --> -1.19842529296875)
# stochastic mul value is :        -0.8515625        ( --> -1.0258736610412598)
# fixed mul value is      :    -1.0325775146484375
# error is                :     18.10150146484375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.21484375       ( --> -3.19061279296875)
# wei value is            :        1.43359375        ( --> 1.4381103515625)
# stochastic mul value is :        -4.43359375       ( --> -4.58845329284668)
# fixed mul value is      :    -4.6087799072265625
# error is                :     17.51861572265625
# ------------------------------------------------------------------------------------------
# act value is            :        0.71484375        ( --> 0.70037841796875)
# wei value is            :         2.2890625        ( --> 2.29412841796875)
# stochastic mul value is :         1.703125         ( --> 1.6067579984664917)
# fixed mul value is      :     1.636322021484375
# error is                :      6.6802978515625
# ------------------------------------------------------------------------------------------
# act value is            :         2.3671875        ( --> 2.373504638671875)
# wei value is            :         -2.890625        ( --> -2.876220703125)
# stochastic mul value is :        -6.6484375        ( --> -6.826723098754883)
# fixed mul value is      :     -6.8426513671875
# error is                :      19.42138671875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.4921875        ( --> -0.4669189453125)
# wei value is            :         3.640625         ( --> 3.6295166015625)
# stochastic mul value is :         -1.53125         ( --> -1.6946901082992554)
# fixed mul value is      :     -1.7918701171875
# error is                :      26.06201171875
# ------------------------------------------------------------------------------------------
# act value is            :        0.37109375        ( --> 0.38909912109375)
# wei value is            :        3.58203125        ( --> 3.59527587890625)
# stochastic mul value is :          1.53125         ( --> 1.398918628692627)
# fixed mul value is      :    1.3292694091796875
# error is                :     20.19805908203125
# ------------------------------------------------------------------------------------------
# act value is            :        2.34765625        ( --> 2.3345947265625)
# wei value is            :        -3.3671875        ( --> -3.3555908203125)
# stochastic mul value is :         -7.671875        ( --> -7.833944797515869)
# fixed mul value is      :    -7.904998779296875
# error is                :     23.3123779296875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.21484375       ( --> -1.206207275390625)
# wei value is            :         -1.46875         ( --> -1.47235107421875)
# stochastic mul value is :           1.875          ( --> 1.7759605646133423)
# fixed mul value is      :      1.7843017578125
# error is                :       9.06982421875
# ------------------------------------------------------------------------------------------
# act value is            :         1.0078125        ( --> 1.01165771484375)
# wei value is            :        -1.4140625        ( --> -1.40386962890625)
# stochastic mul value is :        -1.19140625       ( --> -1.420235514640808)
# fixed mul value is      :     -1.42510986328125
# error is                :      23.370361328125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.5546875        ( --> -0.54473876953125)
# wei value is            :        0.02734375        ( --> 0.03424072265625)
# stochastic mul value is :            0.0           ( --> -0.01865224912762642)
# fixed mul value is      :    -0.015167236328125
# error is                :      1.5167236328125
# ------------------------------------------------------------------------------------------
# act value is            :         2.671875         ( --> 2.684783935546875)
# wei value is            :        -2.4453125        ( --> -2.43109130859375)
# stochastic mul value is :        -6.30859375       ( --> -6.5269551277160645)
# fixed mul value is      :     -6.5335693359375
# error is                :      22.49755859375
# ------------------------------------------------------------------------------------------
# act value is            :         0.8515625        ( --> 0.85601806640625)
# wei value is            :          -0.0625         ( --> -0.03424072265625)
# stochastic mul value is :            0.0           ( --> -0.0293106772005558)
# fixed mul value is      :      -0.05322265625
# error is                :        5.322265625
# ------------------------------------------------------------------------------------------
# act value is            :        2.71484375        ( --> 2.72369384765625)
# wei value is            :        1.35546875        ( --> 1.36962890625)
# stochastic mul value is :         3.921875         ( --> 3.730449914932251)
# fixed mul value is      :    3.6798858642578125
# error is                :     24.19891357421875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.76171875       ( --> -1.750946044921875)
# wei value is            :         1.828125         ( --> 1.81475830078125)
# stochastic mul value is :        -2.8984375        ( --> -3.177543878555298)
# fixed mul value is      :     -3.22064208984375
# error is                :      32.220458984375
# ------------------------------------------------------------------------------------------
# act value is            :         1.421875         ( --> 1.439666748046875)
# wei value is            :        -2.51953125       ( --> -2.49957275390625)
# stochastic mul value is :        -3.41015625       ( --> -3.5985517501831055)
# fixed mul value is      :     -3.58245849609375
# error is                :      17.230224609375
# ------------------------------------------------------------------------------------------
# act value is            :        0.61328125        ( --> 0.62255859375)
# wei value is            :         3.671875         ( --> 3.66375732421875)
# stochastic mul value is :        2.38671875        ( --> 2.2809035778045654)
# fixed mul value is      :     2.25189208984375
# error is                :      13.482666015625
# ------------------------------------------------------------------------------------------
# act value is            :        1.66796875        ( --> 1.673126220703125)
# wei value is            :        1.25390625        ( --> 1.26690673828125)
# stochastic mul value is :        2.38671875        ( --> 2.119694948196411)
# fixed mul value is      :    2.0914764404296875
# error is                :     29.52423095703125
# ------------------------------------------------------------------------------------------
# act value is            :        1.64453125        ( --> 1.63421630859375)
# wei value is            :          0.21875         ( --> 0.2054443359375)
# stochastic mul value is :         0.5078125        ( --> 0.33574047684669495)
# fixed mul value is      :      0.3597412109375
# error is                :      14.80712890625
# ------------------------------------------------------------------------------------------
# act value is            :         -0.734375        ( --> -0.70037841796875)
# wei value is            :         0.7109375        ( --> 0.71905517578125)
# stochastic mul value is :        -0.33984375       ( --> -0.5036107301712036)
# fixed mul value is      :     -0.5220947265625
# error is                :      18.22509765625
# ------------------------------------------------------------------------------------------
# act value is            :         1.046875         ( --> 1.050567626953125)
# wei value is            :        -0.44140625       ( --> -0.410888671875)
# stochastic mul value is :        -0.33984375       ( --> -0.4316663444042206)
# fixed mul value is      :     -0.46209716796875
# error is                :      12.225341796875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.64453125       ( --> -1.63421630859375)
# wei value is            :         2.9140625        ( --> 2.91046142578125)
# stochastic mul value is :        -4.6015625        ( --> -4.756323337554932)
# fixed mul value is      :    -4.792266845703125
# error is                :     19.0704345703125
# ------------------------------------------------------------------------------------------
# act value is            :         1.3828125        ( --> 1.4007568359375)
# wei value is            :           0.25           ( --> 0.23968505859375)
# stochastic mul value is :         0.5078125        ( --> 0.33574047684669495)
# fixed mul value is      :        0.345703125
# error is                :        16.2109375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.85546875       ( --> -0.85601806640625)
# wei value is            :        -0.07421875       ( --> -0.0684814453125)
# stochastic mul value is :        0.16796875        ( --> 0.0586213544011116)
# fixed mul value is      :    0.0634918212890625
# error is                :     10.44769287109375
# ------------------------------------------------------------------------------------------
# act value is            :        0.36328125        ( --> 0.350189208984375)
# wei value is            :         0.234375         ( --> 0.23968505859375)
# stochastic mul value is :        0.16796875        ( --> 0.08393511921167374)
# fixed mul value is      :     0.08514404296875
# error is                :      8.282470703125
# ------------------------------------------------------------------------------------------
# act value is            :         -0.640625        ( --> -0.62255859375)
# wei value is            :        -0.9296875        ( --> -0.92449951171875)
# stochastic mul value is :         0.6796875        ( --> 0.5755550861358643)
# fixed mul value is      :      0.5955810546875
# error is                :       8.41064453125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.74609375       ( --> -1.7120361328125)
# wei value is            :        2.09765625        ( --> 2.08868408203125)
# stochastic mul value is :        -3.41015625       ( --> -3.5759027004241943)
# fixed mul value is      :    -3.6627044677734375
# error is                :     25.25482177734375
# ------------------------------------------------------------------------------------------
# act value is            :        0.29296875        ( --> 0.311279296875)
# wei value is            :        -0.44921875       ( --> -0.44512939453125)
# stochastic mul value is :            0.0           ( --> -0.13855956494808197)
# fixed mul value is      :    -0.1316070556640625
# error is                :     13.16070556640625
# ------------------------------------------------------------------------------------------
# act value is            :          -3.375          ( --> -3.34625244140625)
# wei value is            :         1.7890625        ( --> 1.780517578125)
# stochastic mul value is :         -5.796875        ( --> -5.958061218261719)
# fixed mul value is      :       -6.0380859375
# error is                :        24.12109375
# ------------------------------------------------------------------------------------------
# act value is            :        -1.05859375       ( --> -1.050567626953125)
# wei value is            :        0.33203125        ( --> 0.3424072265625)
# stochastic mul value is :        -0.16796875       ( --> -0.35972195863723755)
# fixed mul value is      :    -0.3514862060546875
# error is                :     18.35174560546875
# ------------------------------------------------------------------------------------------
# act value is            :        0.41015625        ( --> 0.428009033203125)
# wei value is            :        -2.6953125        ( --> -2.6707763671875)
# stochastic mul value is :        -0.8515625        ( --> -1.1431163549423218)
# fixed mul value is      :    -1.105499267578125
# error is                :     25.3936767578125
# ------------------------------------------------------------------------------------------
# act value is            :        -3.94921875       ( --> -3.929901123046875)
# wei value is            :          0.78125         ( --> 0.78753662109375)
# stochastic mul value is :        -2.8984375        ( --> -3.0949411392211914)
# fixed mul value is      :     -3.0853271484375
# error is                :      18.68896484375
# ------------------------------------------------------------------------------------------
# act value is            :         2.515625         ( --> 2.529144287109375)
# wei value is            :        3.35546875        ( --> 3.3555908203125)
# stochastic mul value is :         8.5234375        ( --> 8.486773490905762)
# fixed mul value is      :     8.44110107421875
# error is                :      8.233642578125
# ------------------------------------------------------------------------------------------
# act value is            :        -3.91015625       ( --> -3.8909912109375)
# wei value is            :        1.24609375        ( --> 1.232666015625)
# stochastic mul value is :        -4.7734375        ( --> -4.796292781829834)
# fixed mul value is      :    -4.8724212646484375
# error is                :     9.89837646484375
# ------------------------------------------------------------------------------------------
# act value is            :        0.26953125        ( --> 0.272369384765625)
# wei value is            :        1.41015625        ( --> 1.40386962890625)
# stochastic mul value is :         0.5078125        ( --> 0.38237109780311584)
# fixed mul value is      :    0.3800811767578125
# error is                :     12.77313232421875
# ------------------------------------------------------------------------------------------
# act value is            :         -2.78125         ( --> -2.762603759765625)
# wei value is            :         1.6484375        ( --> 1.6435546875)
# stochastic mul value is :        -4.43359375       ( --> -4.54049015045166)
# fixed mul value is      :      -4.584716796875
# error is                :       15.1123046875
# ------------------------------------------------------------------------------------------
# act value is            :        1.08984375        ( --> 1.0894775390625)
# wei value is            :         0.9296875        ( --> 0.92449951171875)
# stochastic mul value is :        1.19140625        ( --> 1.0072214603424072)
# fixed mul value is      :     1.013214111328125
# error is                :     17.8192138671875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.5546875        ( --> -0.54473876953125)
# wei value is            :         3.5078125        ( --> 3.4925537109375)
# stochastic mul value is :         -1.703125        ( --> -1.9025293588638306)
# fixed mul value is      :     -1.94573974609375
# error is                :      24.261474609375
# ------------------------------------------------------------------------------------------
# act value is            :          1.78125         ( --> 1.78985595703125)
# wei value is            :         -1.671875        ( --> -1.6435546875)
# stochastic mul value is :        -2.8984375        ( --> -2.9417262077331543)
# fixed mul value is      :      -2.97802734375
# error is                :        7.958984375
# ------------------------------------------------------------------------------------------
# act value is            :        3.15234375        ( --> 3.151702880859375)
# wei value is            :          3.46875         ( --> 3.45831298828125)
# stochastic mul value is :        11.08203125       ( --> 10.899575233459473)
# fixed mul value is      :     10.9346923828125
# error is                :      14.73388671875
# ------------------------------------------------------------------------------------------
# act value is            :         3.359375         ( --> 3.34625244140625)
# wei value is            :            1.0           ( --> 0.99298095703125)
# stochastic mul value is :         3.578125         ( --> 3.3227648735046387)
# fixed mul value is      :         3.359375
# error is                :          21.875
# ------------------------------------------------------------------------------------------
# act value is            :          2.34375         ( --> 2.3345947265625)
# wei value is            :         -2.40625         ( --> -2.3968505859375)
# stochastic mul value is :        -5.45703125       ( --> -5.595674514770508)
# fixed mul value is      :       -5.6396484375
# error is                :        18.26171875
# ------------------------------------------------------------------------------------------
# act value is            :         2.703125         ( --> 2.72369384765625)
# wei value is            :         0.2890625        ( --> 0.27392578125)
# stochastic mul value is :         0.8515625        ( --> 0.7460899353027344)
# fixed mul value is      :      0.7813720703125
# error is                :       7.01904296875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.4609375        ( --> -0.428009033203125)
# wei value is            :         1.046875         ( --> 1.06146240234375)
# stochastic mul value is :        -0.16796875       ( --> -0.4543154835700989)
# fixed mul value is      :     -0.4825439453125
# error is                :      31.45751953125
# ------------------------------------------------------------------------------------------
# act value is            :          4.15625         ( --> 4.163360595703125)
# wei value is            :         1.515625         ( --> 1.506591796875)
# stochastic mul value is :         6.4765625        ( --> 6.27248477935791)
# fixed mul value is      :       6.29931640625
# error is                :       17.724609375
# ------------------------------------------------------------------------------------------
# act value is            :        1.59765625        ( --> 1.595306396484375)
# wei value is            :        -0.00390625       ( --> 0.0)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :    -0.0062408447265625
# error is                :     0.62408447265625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.44140625       ( --> -0.428009033203125)
# wei value is            :         0.9921875        ( --> 0.99298095703125)
# stochastic mul value is :        -0.16796875       ( --> -0.4250048100948334)
# fixed mul value is      :    -0.437957763671875
# error is                :     26.9989013671875
# ------------------------------------------------------------------------------------------
# act value is            :        -2.68359375       ( --> -2.684783935546875)
# wei value is            :        2.11328125        ( --> 2.1229248046875)
# stochastic mul value is :        -5.45703125       ( --> -5.699594497680664)
# fixed mul value is      :    -5.6711883544921875
# error is                :     21.41571044921875
# ------------------------------------------------------------------------------------------
# act value is            :        2.76953125        ( --> 2.762603759765625)
# wei value is            :        -1.85546875       ( --> -1.8489990234375)
# stochastic mul value is :        -4.9453125        ( --> -5.108051776885986)
# fixed mul value is      :    -5.1387786865234375
# error is                :     19.34661865234375
# ------------------------------------------------------------------------------------------
# act value is            :         -0.390625        ( --> -0.38909912109375)
# wei value is            :        -2.23828125       ( --> -2.22564697265625)
# stochastic mul value is :        1.01953125        ( --> 0.8659972548484802)
# fixed mul value is      :     0.87432861328125
# error is                :      14.520263671875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.48046875       ( --> -1.47857666015625)
# wei value is            :        -1.3828125        ( --> -1.36962890625)
# stochastic mul value is :        2.21484375        ( --> 2.02510142326355)
# fixed mul value is      :     2.047210693359375
# error is                :     16.7633056640625
# ------------------------------------------------------------------------------------------
# act value is            :        0.31640625        ( --> 0.311279296875)
# wei value is            :         0.0546875        ( --> 0.0684814453125)
# stochastic mul value is :        0.16796875        ( --> 0.021316856145858765)
# fixed mul value is      :     0.017303466796875
# error is                :     15.0665283203125
# ------------------------------------------------------------------------------------------
# act value is            :         1.6328125        ( --> 1.63421630859375)
# wei value is            :        2.95703125        ( --> 2.9447021484375)
# stochastic mul value is :        5.11328125        ( --> 4.812280178070068)
# fixed mul value is      :     4.828277587890625
# error is                :     28.5003662109375
# ------------------------------------------------------------------------------------------
# act value is            :         2.234375         ( --> 2.217864990234375)
# wei value is            :        0.12109375        ( --> 0.136962890625)
# stochastic mul value is :        0.33984375        ( --> 0.303765207529068)
# fixed mul value is      :     0.27056884765625
# error is                :      6.927490234375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.5078125        ( --> -0.505828857421875)
# wei value is            :        -0.25390625       ( --> -0.23968505859375)
# stochastic mul value is :        0.16796875        ( --> 0.12123961746692657)
# fixed mul value is      :     0.128936767578125
# error is                :      3.9031982421875
# ------------------------------------------------------------------------------------------
# act value is            :        2.94921875        ( --> 2.9571533203125)
# wei value is            :        4.36328125        ( --> 4.3828125)
# stochastic mul value is :        12.95703125       ( --> 12.960648536682129)
# fixed mul value is      :    12.868270874023438
# error is                :     8.87603759765625
# ------------------------------------------------------------------------------------------
# act value is            :         0.7109375        ( --> 0.70037841796875)
# wei value is            :        -0.87109375       ( --> -0.85601806640625)
# stochastic mul value is :        -0.5078125        ( --> -0.5995365977287292)
# fixed mul value is      :    -0.619293212890625
# error is                :     11.1480712890625
# ------------------------------------------------------------------------------------------
# act value is            :        1.57421875        ( --> 1.556396484375)
# wei value is            :        -1.26171875       ( --> -1.232666015625)
# stochastic mul value is :          -1.875          ( --> -1.9185171127319336)
# fixed mul value is      :    -1.9862213134765625
# error is                :     11.12213134765625
# ------------------------------------------------------------------------------------------
# act value is            :        3.08984375        ( --> 3.073883056640625)
# wei value is            :         3.6953125        ( --> 3.697998046875)
# stochastic mul value is :         11.59375         ( --> 11.367213249206543)
# fixed mul value is      :    11.417938232421875
# error is                :     17.5811767578125
# ------------------------------------------------------------------------------------------
# act value is            :        3.94140625        ( --> 3.929901123046875)
# wei value is            :         -0.265625        ( --> -0.23968505859375)
# stochastic mul value is :        -0.8515625        ( --> -0.941938579082489)
# fixed mul value is      :     -1.04693603515625
# error is                :      19.537353515625
# ------------------------------------------------------------------------------------------
# act value is            :        -2.37890625       ( --> -2.373504638671875)
# wei value is            :         0.046875         ( --> 0.03424072265625)
# stochastic mul value is :            0.0           ( --> -0.08127051591873169)
# fixed mul value is      :     -0.11151123046875
# error is                :      11.151123046875
# ------------------------------------------------------------------------------------------
# act value is            :         2.3515625        ( --> 2.3345947265625)
# wei value is            :        -0.25390625       ( --> -0.23968505859375)
# stochastic mul value is :        -0.33984375       ( --> -0.5595674514770508)
# fixed mul value is      :    -0.597076416015625
# error is                :     25.7232666015625
# ------------------------------------------------------------------------------------------
# act value is            :        4.76953125        ( --> 4.785919189453125)
# wei value is            :        0.91015625        ( --> 0.92449951171875)
# stochastic mul value is :         4.6015625        ( --> 4.424580097198486)
# fixed mul value is      :    4.3410186767578125
# error is                :     26.05438232421875
# ------------------------------------------------------------------------------------------
# act value is            :         -0.984375        ( --> -0.972747802734375)
# wei value is            :        2.11328125        ( --> 2.1229248046875)
# stochastic mul value is :          -1.875          ( --> -2.065070390701294)
# fixed mul value is      :     -2.08026123046875
# error is                :      20.526123046875
# ------------------------------------------------------------------------------------------
# act value is            :        4.98046875        ( --> 0.0)
# wei value is            :         -3.046875        ( --> -3.04742431640625)
# stochastic mul value is :            0.0           ( --> -0.0)
# fixed mul value is      :    -15.17486572265625
# error is                :     1517.486572265625
# ------------------------------------------------------------------------------------------
# act value is            :        -1.9765625        ( --> -1.94549560546875)
# wei value is            :          0.6875          ( --> 0.684814453125)
# stochastic mul value is :        -1.19140625       ( --> -1.332303524017334)
# fixed mul value is      :      -1.35888671875
# error is                :       16.748046875
# ------------------------------------------------------------------------------------------
# act value is            :         -0.15625         ( --> -0.1556396484375)
# wei value is            :         4.3828125        ( --> 0.0)
# stochastic mul value is :            0.0           ( --> -0.0)
# fixed mul value is      :      -0.684814453125
# error is                :       68.4814453125
# ------------------------------------------------------------------------------------------
# act value is            :         2.7109375        ( --> 2.72369384765625)
# wei value is            :        -2.22265625       ( --> -2.19140625)
# stochastic mul value is :        -5.96484375       ( --> -5.968719482421875)
# fixed mul value is      :    -6.025482177734375
# error is                :      6.0638427734375
# ------------------------------------------------------------------------------------------
# act value is            :        3.74609375        ( --> 3.7353515625)
# wei value is            :        -2.6328125        ( --> -2.602294921875)
# stochastic mul value is :         -9.71875         ( --> -9.720486640930176)
# fixed mul value is      :    -9.862762451171875
# error is                :     14.4012451171875
# ------------------------------------------------------------------------------------------
# act value is            :        3.18359375        ( --> 3.19061279296875)
# wei value is            :         -1.578125        ( --> -1.5750732421875)
# stochastic mul value is :        -4.7734375        ( --> -5.025448799133301)
# fixed mul value is      :     -5.02410888671875
# error is                :      25.067138671875
# ------------------------------------------------------------------------------------------
# act value is            :        3.44140625        ( --> 3.424072265625)
# wei value is            :        -1.1015625        ( --> -1.095703125)
# stochastic mul value is :           -3.75          ( --> -3.7517666816711426)
# fixed mul value is      :    -3.790924072265625
# error is                :      4.0924072265625
# ------------------------------------------------------------------------------------------
# act value is            :         0.9453125        ( --> 0.933837890625)
# wei value is            :           3.875          ( --> 3.86920166015625)
# stochastic mul value is :           3.75           ( --> 3.6132071018218994)
# fixed mul value is      :       3.6630859375
# error is                :        8.69140625
# ------------------------------------------------------------------------------------------
# act value is            :        -3.97265625       ( --> -3.96881103515625)
# wei value is            :        -0.61328125       ( --> -0.58209228515625)
# stochastic mul value is :        2.38671875        ( --> 2.3102142810821533)
# fixed mul value is      :    2.4363555908203125
# error is                :     4.96368408203125
# ------------------------------------------------------------------------------------------
# act value is            :        2.79296875        ( --> 2.801513671875)
# wei value is            :          2.15625         ( --> 2.15716552734375)
# stochastic mul value is :        6.13671875        ( --> 6.043328762054443)
# fixed mul value is      :      6.0223388671875
# error is                :      11.43798828125
# ------------------------------------------------------------------------------------------
# act value is            :        0.02734375        ( --> 0.038909912109375)
# wei value is            :         0.421875         ( --> 0.410888671875)
# stochastic mul value is :        0.16796875        ( --> 0.015987642109394073)
# fixed mul value is      :     0.01153564453125
# error is                :      15.643310546875
# ------------------------------------------------------------------------------------------
# act value is            :        2.48046875        ( --> 2.490234375)
# wei value is            :          0.71875         ( --> 0.71905517578125)
# stochastic mul value is :           1.875          ( --> 1.7906159162521362)
# fixed mul value is      :      1.7828369140625
# error is                :       9.21630859375
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## ERROR

# %%
def MSE(a,b):
    s = 0
    n = 0

    for i in range(10):
        for j in range(15):
            square = (((a[i][j])-b[i][j])**2).item()
            s += square
            n   += 1
    error = s/n
    return error

# %% [markdown]
# ## ERROR : 4bit LFSR

# %%
MSE(act_f*wei_f,cc)
# Out:
# 1.5714734817327312
