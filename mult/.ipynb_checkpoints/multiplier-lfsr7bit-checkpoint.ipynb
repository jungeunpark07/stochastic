# %% [markdown]
# # Multiplier TEST code

# %% [markdown]
# fixed number to stochastic conversion & multiply & stochastic to fixed number conversion

# %% [markdown]
# ## Import

# %%
import random, struct, math
import torch
import numpy as np
import torch.nn as nn 
import argparse
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Parser

# %%
parser = argparse.ArgumentParser(description='fixed_mac')
parser.add_argument('--full_bits', type=int, default=16, help='Number of Quantization Bits')
parser.add_argument('--frac_bits', type=int, default=8, help='Number of Quantization Bits')
parser.add_argument('--bBW', type=int, default=7, help='Number of bit width')
args = parser.parse_args(args=[])

# %% [markdown]
# ## Definition

# %% [markdown]
# ### int2bin : int number to binary number

# %%
def int2bin(iIn,iBW):
    iBW = iBW + 1
    if iIn >= 0:
        bOut = bin(iIn).replace('0b','').rjust(iBW,'0')
    else :
        bOut = bin(iIn & (pow(2,iBW)-1)).replace('0b','').rjust(iBW,'1')
    return bOut[1:]

# %% [markdown]
# ### XOR : xor gate with string

# %%
def XOR(iA,iB):
    if iA != iB :
        iOut = '1'
    else : 
        iOut = '0'
    return iOut

# %% [markdown]
# ### SNUM : sign number determination

# %%
def snum(a):
    if a >= 0 :
        return '0'
    else :
        return '1'

# %% [markdown]
# ## binInv : binary Inversion

# %%
def binInv(bIn):
    bOut = bin(int(bIn,2)^(pow(2,len(bIn))-1)).replace('0b','').rjust(len(bIn),'0')
    return bOut

# %% [markdown]
# ### fxp & flp2fix : floating number to fixed number conversion

# %%
class fxp:
    def __init__(self, bIn, iBWF):
        self.iFullBW = len(bIn)
        self.iIntgBW = self.iFullBW - iBWF
        self.bSign = bIn[0]
        self.bIntg = bIn[:self.iIntgBW]
        self.bFrac = bIn[self.iIntgBW:]
        self.fFull = 0
        try:
            for idx, bit in enumerate(bIn):
                if idx == 0:
                    self.fFull = self.fFull + int(bit,2) * -pow(2, self.iIntgBW - 1)
                else:
                    self.fFull = self.fFull + int(bit,2) * pow(2, self.iIntgBW - 1 - idx)
        except:
            print(bIn)
        self.dispFull = self.bIntg +"."+ self.bFrac 
        return

# %%
class flp2fix:
    def __init__(self, fIn, iBW, iBWF):
        self.fMin = - 2 ** (iBW - iBWF - 1)
        self.fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
        self.fResol = 2 ** -iBWF
        if fIn < self.fMin or fIn > self.fMax:
            print(f'({fIn}): Out of input range ({self.fMax}/{self.fMin}) during flp -> fix converting ')
        self.iBW = iBW
        self.iBWI = iBW - iBWF
        self.iBWF = iBWF

        self.iFLP2INT = abs(int(fIn * 2 ** iBWF))
        if fIn < 0:
            self.iFLP2INT = 2 ** (iBW-1) - self.iFLP2INT

        if fIn >= 0:
            self.bFull = bin(self.iFLP2INT)[2:].rjust(iBW, '0')
        else:
            self.bFull = '1'+bin(self.iFLP2INT)[2:].rjust(iBW-1, '0')
            if len(self.bFull) > iBW:
                self.bFull = '0' * iBW

        self.cssFxp = fxp(self.bFull, self.iBWF)
        self.bSign = self.cssFxp.bSign
        self.bIntg = self.cssFxp.bIntg
        self.bFrac = self.cssFxp.bFrac
        self.fFull = self.cssFxp.fFull
        return

# %%
def flp2fixTensor(fIn, iBW, iBWF):
    fMin = - 2 ** (iBW - iBWF - 1)
    fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
    fList = []
    for aTensor in fIn.view(-1):
        fList.append(flp2fix(aTensor, iBW, iBWF).fFull)
    return torch.tensor(fList).view(fIn.size())

# %% [markdown]
# ### LFSR : make pseudorandom number bitstream

# %%
class LFSR7:
    def Random(self):
        self.b0 = eval(f'str(random.randint(0,1))')
        self.b1 = eval(f'str(random.randint(0,1))')
        self.b2 = eval(f'str(random.randint(0,1))')
        self.b3 = eval(f'str(random.randint(0,1))')
        self.b4 = eval(f'str(random.randint(0,1))')
        self.b5 = eval(f'str(random.randint(0,1))')
        self.b6 = eval(f'str(random.randint(0,1))')
        if int(self.b0) + int(self.b1) + int(self.b2) + int(self.b3) + int(self.b4) + int(self.b5) + int(self.b6) == 0 :
            self.b0 = eval(f'str(random.randint(0,1))')
            self.b1 = eval(f'str(random.randint(0,1))')
            self.b2 = eval(f'str(random.randint(0,1))')
            self.b3 = eval(f'str(random.randint(0,1))')
            self.b4 = eval(f'str(random.randint(0,1))')
            self.b5 = eval(f'str(random.randint(0,1))')
            self.b6 = eval(f'str(random.randint(0,1))')
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6
    
    def Normal(self,stream):
        self.b0 = XOR(int(stream[5]),int(stream[6]))
        self.b1 = stream[0]
        self.b2 = stream[1]
        self.b3 = stream[2]
        self.b4 = stream[3]
        self.b5 = stream[4]
        self.b6 = stream[5]
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6
    
    def Allzero(self):
        self.b0 = '0'
        self.b1 = '0'
        self.b2 = '0'
        self.b3 = '0'
        self.b4 = '0'
        self.b5 = '0'
        self.b6 = '0'
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6

# %% [markdown]
# ### LFSRlist : make pseudorandom number bitstream with 2**bBW cycle

# %%
def LFSRlist7():
    lfsr = LFSR7()
    lfsrlist = []
    for k in range(2**(args.bBW)-1): #lfsr number generating
        if k == 0:
            lfsrlist.append(lfsr.Random())
        else :
            lfsrlist.append(lfsr.Normal(lfsrlist[k-1]))
        if (k == 2**(args.bBW)-2):
            lfsrlist.append(lfsr.Allzero())
    
    if (args.bBW) != args.frac_bits :
        if args.bBW < args.frac_bits :
            for i in range(len(lfsrlist)):
                lfsrlist[i] = lfsrlist[i] + (args.frac_bits-args.bBW)*'0'
        else :
            print("it can't work")
            return 0
    
    return lfsrlist

# %% [markdown]
# ### Comp : Comparator in SNG

# %%
def Comp(a,lfsr,snum):
    for com in range(0,len(a)):
        oA = '0'
        if a[com]!=lfsr[com]:
            if(int(a[com]) > int(lfsr[com])):
                oA = '1'
            break
    return XOR(oA,snum)

# %% [markdown]
# ### Perm : module for permutation SNG

# %%
def perm(a):
    al = len(a)
    blist = []
    if args.frac_bits == args.bBW : 
        for i in range(al) :
            blist.append(a[al-i-1])
    elif args.frac_bits > args.bBW :
        for i in range(al-(args.frac_bits-args.bBW)) :
            blist.append((a[al-(args.frac_bits-args.bBW)-i-1]))
    b = "".join(blist)
    b = b + ('0'*(args.frac_bits-args.bBW))
    return b

# %% [markdown]
# ### findMaxMin : find abs max value in act tensor

# %%
def findMaxMin(data):
    max = torch.max(data)
    min = torch.min(data)
    SF=torch.max(abs(max),abs(min)).item()
    return SF

# %% [markdown]
# ### SNG : stochastic number generator module

# %%
def SNG(iIN,lfsr):

    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    bFRAC = bIN[-(args.frac_bits):]
    if sNUM == 1 :
        bFRAC = bin(int(binInv(bFRAC),2)+1).replace('0b','').rjust(args.bBW,'0')
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        lNUM = lfsr[k]
        a = Comp(bFRAC,lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if bIN == args.full_bits*'0' :
        return '0'*(2**(args.bBW)+1)
    else :
        return sA

# %% [markdown]
# ### SNG_P : permutation stochastic number generator module

# %%
def SNG_P(iIN,lfsr):
    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    bFRAC = bIN[-(args.frac_bits):]
    if sNUM == 1 :
        bFRAC = bin(int(binInv(bFRAC),2)+1).replace('0b','').rjust(args.bBW,'0')
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating    
        lNUM = perm(lfsr[k])
        a = Comp(bFRAC,lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    
    if bIN == args.full_bits*'0' :
        return '0'*(2**(args.bBW)+1)
    else :
        return sA

# %% [markdown]
# ### SNGnumpy : SNG module with numpy

# %%
def SNGnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG(float(aNumpy),lfsr))
                     
    return np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### SNGpnumpy : permutation SNG module with numpy

# %%
def SNGpnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG_P(float(aNumpy),lfsr))
                     
    return  np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### CountOne : count 1 in stochastic number bit stream

# %%
def CountOne(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        n = 0
        for a in num:
            if a == '1' :
                n += 1
        if num[0] == '1' :
            nlist.append(n-1)
        else :
            nlist.append(n)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### defSign : sign determination in S2N

# %%
def defSign(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        if num[0] == '1' :
            nlist.append(-1)
        else :
            nlist.append(1)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### Multiplier

# %%
def mul(a,b):
    al = len(a)
    bl = len(b)
    
    outlist = []
    
    if al != bl :
        print("length of string is different")
        return 0
    
    outlist.append(XOR(a[0],b[0]))
    
    for i in range(al-1) :
        outlist.append(str(int(a[i+1]) & int(b[i+1])))
    
    #print(outlist)
    out = "".join(outlist)
    
    return out

# %%
def defSign1(nIn):
    if nIn[0] == '1' :
        return -1
    else :
        return 1

# %%
def CountOne1(nIn):
    n = 0
    for num in nIn:
        if num == '1' :
            n += 1
    if nIn[0] == '1' :
        return n-1
    else :
        return n

# %%
def S2None(sIn,SF):
    s = defSign(sIn)
    o = (CountOne(sIn)/(2**args.bBW))*SF*s
    return o

# %%
def mulNumpy(aIn,bIn,aSF,wSF):
    mList = []
    for i in range(aIn.shape[0]):
        for j in range(bIn.T.shape[1]):
            sum = 0
            for k in range(aIn.shape[1]):
                sum += S2None(mul((aIn[i][k].astype(str)),(bIn.T)[k][j].astype(str)),aSF*wSF)
            mList.append(sum)
    return torch.tensor(mList).view(aIn.shape[0],bIn.T.shape[1])

# %%
def FindError(a,b):
    elist = []
    for anum,bnum in zip(a.view(-1),b.view(-1)):
        e = (abs(bnum-anum)*100).item()
        elist.append(e)
    return torch.tensor(elist).reshape(a.size())

# %% [markdown]
# # TEST : LFSR 4 bit

# %%
act = torch.rand((10,15))-torch.randint(5,(10,15))+torch.randint(5,(10,15))
wei = torch.rand((10,15))-torch.randint(5,(10,15))+torch.randint(5,(10,15))

# %%
act_f = flp2fixTensor(act,args.full_bits,args.frac_bits)
wei_f = flp2fixTensor(wei,args.full_bits,args.frac_bits)

# %% [markdown]
# ### number to stochastic conversion

# %%
aSF = findMaxMin(act_f)
wSF = findMaxMin(wei_f)

# %%
def N2S(act,wei,aSF,wSF):
    
    lfsrlist = LFSRlist7()
    
    a = SNGnumpy(act/aSF,lfsrlist)
    w = SNGpnumpy(wei/wSF,lfsrlist)
    
    return a,w

# %%
def N2Sone(data,SF):
    lfsrlist = LFSRlist7()
    
    o = SNGnumpy(data/SF,lfsrlist)
    
    return o

# %% [markdown]
# ### stochastic to number conversion

# %%
def S2N(a,w,aSF,wSF):
    
    sa = defSign(a)
    sw = defSign(w)

    ca = (CountOne(a)/(2**args.bBW)) * aSF *sa
    cw = (CountOne(w)/(2**args.bBW)) * wSF *sw

    return ca,cw

# %%
a,w = N2S(act,wei,aSF,wSF)

# %%
ca,cw = S2N(a,w,aSF,wSF)

# %%
def multest(aIn,wIn,aSF,wSF):
    mlist=[]
    out = 0
    for a,b in zip(aIn.reshape(-1),wIn.reshape(-1)) :
        out = mul(a,b)
        mlist.append(out)
    
    return np.array(mlist).reshape(aIn.shape)

# %%
c = multest(a,w,aSF,wSF)

# %%
cc = flp2fixTensor(S2None(c,aSF*wSF),args.full_bits,args.frac_bits)

# %%
error = FindError(cc,act_f*wei_f)

# %%
print(f'error mean value is : {torch.mean(error)}')
print(f'------------------------------------------------------------------------------------------')
for i in range(10):
    for j in range(15):
        print(f'act value is            : {act_f[i][j]:^25}( --> {ca[i][j]})')
        print(f'wei value is            : {wei_f[i][j]:^25}( --> {cw[i][j]})')
        print(f'stochastic mul value is : {cc[i][j]:^25}( --> {ca[i][j] * cw[i][j]})')
        print(f'fixed mul value is      : {act_f[i][j]*wei_f[i][j]:^25}')
        print(f'error is                : {error[i][j]:^25}')
        print(f'------------------------------------------------------------------------------------------')
# Out:
# error mean value is : 22.189016342163086
# ------------------------------------------------------------------------------------------
# act value is            :        0.62109375        ( --> 0.6181640625)
# wei value is            :        -1.96484375       ( --> -1.95159912109375)
# stochastic mul value is :         -1.15625         ( --> -1.2064085006713867)
# fixed mul value is      :    -1.2203521728515625
# error is                :     6.41021728515625
# ------------------------------------------------------------------------------------------
# act value is            :         2.8671875        ( --> 2.8590087890625)
# wei value is            :        -1.37109375       ( --> -1.366119384765625)
# stochastic mul value is :        -3.6640625        ( --> -3.905747413635254)
# fixed mul value is      :    -3.931182861328125
# error is                :     26.7120361328125
# ------------------------------------------------------------------------------------------
# act value is            :        0.01171875        ( --> 0.0)
# wei value is            :         2.1796875        ( --> 2.185791015625)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :     0.025543212890625
# error is                :      2.5543212890625
# ------------------------------------------------------------------------------------------
# act value is            :        2.19921875        ( --> 2.20220947265625)
# wei value is            :        2.73828125        ( --> 2.73223876953125)
# stochastic mul value is :        6.17578125        ( --> 6.016962051391602)
# fixed mul value is      :    6.0220794677734375
# error is                :     15.37017822265625
# ------------------------------------------------------------------------------------------
# act value is            :        -2.39453125       ( --> -2.35675048828125)
# wei value is            :        1.85546875        ( --> 1.87353515625)
# stochastic mul value is :        -4.24609375       ( --> -4.415454864501953)
# fixed mul value is      :    -4.4429779052734375
# error is                :     19.68841552734375
# ------------------------------------------------------------------------------------------
# act value is            :        2.05859375        ( --> 2.04766845703125)
# wei value is            :         -1.109375        ( --> -1.0928955078125)
# stochastic mul value is :        -2.12109375       ( --> -2.2378876209259033)
# fixed mul value is      :     -2.28375244140625
# error is                :      16.265869140625
# ------------------------------------------------------------------------------------------
# act value is            :        -2.4765625        ( --> -2.47265625)
# wei value is            :        -1.4453125        ( --> -1.444183349609375)
# stochastic mul value is :         3.6640625        ( --> 3.5709691047668457)
# fixed mul value is      :     3.57940673828125
# error is                :      8.465576171875
# ------------------------------------------------------------------------------------------
# act value is            :         4.9453125        ( --> 0.0)
# wei value is            :         1.109375         ( --> 1.0928955078125)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :      5.4862060546875
# error is                :      548.62060546875
# ------------------------------------------------------------------------------------------
# act value is            :            0.5           ( --> 0.50225830078125)
# wei value is            :        -0.81640625       ( --> -0.7806396484375)
# stochastic mul value is :        -0.19140625       ( --> -0.39208275079727173)
# fixed mul value is      :       -0.408203125
# error is                :        21.6796875
# ------------------------------------------------------------------------------------------
# act value is            :        0.91015625        ( --> 0.92724609375)
# wei value is            :        1.95703125        ( --> 1.95159912109375)
# stochastic mul value is :         1.9296875        ( --> 1.8096126317977905)
# fixed mul value is      :    1.7812042236328125
# error is                :     14.84832763671875
# ------------------------------------------------------------------------------------------
# act value is            :        -2.68359375       ( --> -2.66583251953125)
# wei value is            :           0.625          ( --> 0.62451171875)
# stochastic mul value is :        -1.54296875       ( --> -1.6648436784744263)
# fixed mul value is      :      -1.67724609375
# error is                :       13.427734375
# ------------------------------------------------------------------------------------------
# act value is            :         -2.890625        ( --> -2.8590087890625)
# wei value is            :        2.12109375        ( --> 2.10772705078125)
# stochastic mul value is :        -5.7890625        ( --> -6.026010036468506)
# fixed mul value is      :     -6.13128662109375
# error is                :      34.222412109375
# ------------------------------------------------------------------------------------------
# act value is            :         0.0078125        ( --> 0.0)
# wei value is            :        2.01171875        ( --> 2.0296630859375)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :     0.015716552734375
# error is                :      1.5716552734375
# ------------------------------------------------------------------------------------------
# act value is            :        3.76171875        ( --> 3.74761962890625)
# wei value is            :          3.34375         ( --> 3.35675048828125)
# stochastic mul value is :        12.73828125       ( --> 12.579824447631836)
# fixed mul value is      :     12.5782470703125
# error is                :      16.00341796875
# ------------------------------------------------------------------------------------------
# act value is            :         4.7578125        ( --> 4.75213623046875)
# wei value is            :         1.4609375        ( --> 1.48321533203125)
# stochastic mul value is :         7.140625         ( --> 7.048441410064697)
# fixed mul value is      :     6.95086669921875
# error is                :      18.975830078125
# ------------------------------------------------------------------------------------------
# act value is            :          0.96875         ( --> 0.96588134765625)
# wei value is            :        2.37890625        ( --> 2.380950927734375)
# stochastic mul value is :         2.5078125        ( --> 2.299715995788574)
# fixed mul value is      :      2.3045654296875
# error is                :      20.32470703125
# ------------------------------------------------------------------------------------------
# act value is            :          -1.375          ( --> -1.35223388671875)
# wei value is            :         2.2890625        ( --> 2.302886962890625)
# stochastic mul value is :        -2.69921875       ( --> -3.114041805267334)
# fixed mul value is      :       -3.1474609375
# error is                :        44.82421875
# ------------------------------------------------------------------------------------------
# act value is            :          2.71875         ( --> 2.7044677734375)
# wei value is            :         0.9140625        ( --> 0.897735595703125)
# stochastic mul value is :        2.69921875        ( --> 2.4278969764709473)
# fixed mul value is      :      2.485107421875
# error is                :       21.4111328125
# ------------------------------------------------------------------------------------------
# act value is            :        3.03515625        ( --> 3.05218505859375)
# wei value is            :        -0.78515625       ( --> -0.7806396484375)
# stochastic mul value is :        -2.12109375       ( --> -2.3826565742492676)
# fixed mul value is      :    -2.3830718994140625
# error is                :     26.19781494140625
# ------------------------------------------------------------------------------------------
# act value is            :        0.06640625        ( --> 0.0772705078125)
# wei value is            :         -1.203125        ( --> -1.17095947265625)
# stochastic mul value is :            0.0           ( --> -0.09048063308000565)
# fixed mul value is      :     -0.07989501953125
# error is                :      7.989501953125
# ------------------------------------------------------------------------------------------
# act value is            :         3.2890625        ( --> 3.28399658203125)
# wei value is            :        -2.69140625       ( --> -2.6541748046875)
# stochastic mul value is :        -8.4921875        ( --> -8.716300964355469)
# fixed mul value is      :    -8.852203369140625
# error is                :     36.0015869140625
# ------------------------------------------------------------------------------------------
# act value is            :        2.67578125        ( --> 2.66583251953125)
# wei value is            :         1.6171875        ( --> 1.600311279296875)
# stochastic mul value is :        4.62890625        ( --> 4.266161918640137)
# fixed mul value is      :     4.327239990234375
# error is                :     30.1666259765625
# ------------------------------------------------------------------------------------------
# act value is            :         -3.296875        ( --> -3.28399658203125)
# wei value is            :        1.75390625        ( --> 1.756439208984375)
# stochastic mul value is :        -5.40234375       ( --> -5.7681403160095215)
# fixed mul value is      :     -5.78240966796875
# error is                :      38.006591796875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.33984375       ( --> -0.30908203125)
# wei value is            :        -1.9921875        ( --> -1.990631103515625)
# stochastic mul value is :        0.76953125        ( --> 0.6152682900428772)
# fixed mul value is      :     0.677032470703125
# error is                :      9.2498779296875
# ------------------------------------------------------------------------------------------
# act value is            :         1.359375         ( --> 1.35223388671875)
# wei value is            :        3.64453125        ( --> 3.629974365234375)
# stochastic mul value is :         5.2109375        ( --> 4.90857458114624)
# fixed mul value is      :     4.95428466796875
# error is                :      25.665283203125
# ------------------------------------------------------------------------------------------
# act value is            :         -1.53125         ( --> -1.50677490234375)
# wei value is            :         -0.515625        ( --> -0.507415771484375)
# stochastic mul value is :        0.96484375        ( --> 0.7645613551139832)
# fixed mul value is      :       0.78955078125
# error is                :       17.529296875
# ------------------------------------------------------------------------------------------
# act value is            :          3.65625         ( --> 3.67034912109375)
# wei value is            :           -0.75          ( --> -0.741607666015625)
# stochastic mul value is :        -2.5078125        ( --> -2.721959114074707)
# fixed mul value is      :        -2.7421875
# error is                :          23.4375
# ------------------------------------------------------------------------------------------
# act value is            :        1.44921875        ( --> 1.4681396484375)
# wei value is            :        -0.3515625        ( --> -0.351287841796875)
# stochastic mul value is :        -0.3828125        ( --> -0.5157396197319031)
# fixed mul value is      :    -0.509490966796875
# error is                :     12.6678466796875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.2578125        ( --> -0.2318115234375)
# wei value is            :         -0.359375        ( --> -0.351287841796875)
# stochastic mul value is :        0.19140625        ( --> 0.08143256604671478)
# fixed mul value is      :      0.0926513671875
# error is                :       9.87548828125
# ------------------------------------------------------------------------------------------
# act value is            :         0.0234375        ( --> 0.03863525390625)
# wei value is            :        1.85546875        ( --> 1.87353515625)
# stochastic mul value is :        0.19140625        ( --> 0.07238450646400452)
# fixed mul value is      :     0.043487548828125
# error is                :     14.7918701171875
# ------------------------------------------------------------------------------------------
# act value is            :        4.26953125        ( --> 4.28851318359375)
# wei value is            :         -2.796875        ( --> -2.771270751953125)
# stochastic mul value is :        -11.7734375       ( --> -11.884631156921387)
# fixed mul value is      :    -11.94134521484375
# error is                :      16.790771484375
# ------------------------------------------------------------------------------------------
# act value is            :         -0.578125        ( --> -0.57952880859375)
# wei value is            :        -2.21484375       ( --> -2.185791015625)
# stochastic mul value is :        1.34765625        ( --> 1.2667288780212402)
# fixed mul value is      :     1.28045654296875
# error is                :      6.719970703125
# ------------------------------------------------------------------------------------------
# act value is            :        -2.70703125       ( --> -2.7044677734375)
# wei value is            :        -0.92578125       ( --> -0.897735595703125)
# stochastic mul value is :        2.69921875        ( --> 2.4278969764709473)
# fixed mul value is      :    2.5061187744140625
# error is                :     19.30999755859375
# ------------------------------------------------------------------------------------------
# act value is            :        0.30859375        ( --> 0.30908203125)
# wei value is            :          0.78125         ( --> 0.7806396484375)
# stochastic mul value is :         0.3828125        ( --> 0.2412816882133484)
# fixed mul value is      :      0.2410888671875
# error is                :      14.17236328125
# ------------------------------------------------------------------------------------------
# act value is            :         2.1640625        ( --> 2.16357421875)
# wei value is            :         0.359375         ( --> 0.351287841796875)
# stochastic mul value is :        0.96484375        ( --> 0.7600373029708862)
# fixed mul value is      :      0.7777099609375
# error is                :      18.71337890625
# ------------------------------------------------------------------------------------------
# act value is            :        -3.9921875        ( --> -3.97943115234375)
# wei value is            :        -2.82421875       ( --> -2.810302734375)
# stochastic mul value is :        11.38671875       ( --> 11.183405876159668)
# fixed mul value is      :    11.274810791015625
# error is                :     11.1907958984375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.71484375       ( --> -3.708984375)
# wei value is            :        -1.30078125       ( --> -1.288055419921875)
# stochastic mul value is :        4.82421875        ( --> 4.777377605438232)
# fixed mul value is      :    4.8321990966796875
# error is                :     0.79803466796875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.52734375       ( --> -0.50225830078125)
# wei value is            :         1.3984375        ( --> 1.4051513671875)
# stochastic mul value is :         -0.578125        ( --> -0.7057489156723022)
# fixed mul value is      :    -0.737457275390625
# error is                :     15.9332275390625
# ------------------------------------------------------------------------------------------
# act value is            :         1.2265625        ( --> 1.236328125)
# wei value is            :        -1.12109375       ( --> -1.0928955078125)
# stochastic mul value is :        -1.34765625       ( --> -1.351177453994751)
# fixed mul value is      :    -1.375091552734375
# error is                :      2.7435302734375
# ------------------------------------------------------------------------------------------
# act value is            :        0.27734375        ( --> 0.27044677734375)
# wei value is            :        2.54296875        ( --> 2.537078857421875)
# stochastic mul value is :        0.96484375        ( --> 0.6861448287963867)
# fixed mul value is      :    0.7052764892578125
# error is                :     25.95672607421875
# ------------------------------------------------------------------------------------------
# act value is            :        1.10546875        ( --> 1.12042236328125)
# wei value is            :         3.640625         ( --> 3.629974365234375)
# stochastic mul value is :        4.24609375        ( --> 4.067104339599609)
# fixed mul value is      :     4.02459716796875
# error is                :      22.149658203125
# ------------------------------------------------------------------------------------------
# act value is            :          -1.1875         ( --> -1.1590576171875)
# wei value is            :        -2.70703125       ( --> -2.693206787109375)
# stochastic mul value is :          3.28125         ( --> 3.121581792831421)
# fixed mul value is      :      3.214599609375
# error is                :       6.6650390625
# ------------------------------------------------------------------------------------------
# act value is            :        0.57421875        ( --> 0.57952880859375)
# wei value is            :        2.07421875        ( --> 2.068695068359375)
# stochastic mul value is :        1.34765625        ( --> 1.1988683938980103)
# fixed mul value is      :    1.1910552978515625
# error is                :     15.66009521484375
# ------------------------------------------------------------------------------------------
# act value is            :         3.890625         ( --> 3.90216064453125)
# wei value is            :         -1.359375        ( --> -1.32708740234375)
# stochastic mul value is :         -5.015625        ( --> -5.178508281707764)
# fixed mul value is      :      -5.288818359375
# error is                :       27.3193359375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.81640625       ( --> -0.81134033203125)
# wei value is            :        -2.44921875       ( --> -2.41998291015625)
# stochastic mul value is :        2.12109375        ( --> 1.9634296894073486)
# fixed mul value is      :    1.9995574951171875
# error is                :     12.15362548828125
# ------------------------------------------------------------------------------------------
# act value is            :          -0.5625         ( --> -0.5408935546875)
# wei value is            :        2.68359375        ( --> 2.693206787109375)
# stochastic mul value is :        -1.34765625       ( --> -1.4567382335662842)
# fixed mul value is      :      -1.509521484375
# error is                :       16.1865234375
# ------------------------------------------------------------------------------------------
# act value is            :         3.9453125        ( --> 3.9407958984375)
# wei value is            :        -0.42578125       ( --> -0.39031982421875)
# stochastic mul value is :        -1.34765625       ( --> -1.5381708145141602)
# fixed mul value is      :    -1.679840087890625
# error is                :     33.2183837890625
# ------------------------------------------------------------------------------------------
# act value is            :         1.3515625        ( --> 1.35223388671875)
# wei value is            :        -0.3046875        ( --> -0.273223876953125)
# stochastic mul value is :        -0.19140625       ( --> -0.3694625794887543)
# fixed mul value is      :     -0.41180419921875
# error is                :      22.039794921875
# ------------------------------------------------------------------------------------------
# act value is            :        4.37890625        ( --> 4.36578369140625)
# wei value is            :        0.63671875        ( --> 0.62451171875)
# stochastic mul value is :        2.89453125        ( --> 2.726483106613159)
# fixed mul value is      :    2.7881317138671875
# error is                :     10.63995361328125
# ------------------------------------------------------------------------------------------
# act value is            :        1.34765625        ( --> 1.35223388671875)
# wei value is            :        -0.0703125        ( --> -0.039031982421875)
# stochastic mul value is :            0.0           ( --> -0.05278036743402481)
# fixed mul value is      :    -0.094757080078125
# error is                :      9.4757080078125
# ------------------------------------------------------------------------------------------
# act value is            :        -3.32421875       ( --> -3.3226318359375)
# wei value is            :         4.5546875        ( --> 4.566741943359375)
# stochastic mul value is :        -14.859375        ( --> -15.173602104187012)
# fixed mul value is      :    -15.140777587890625
# error is                :     28.1402587890625
# ------------------------------------------------------------------------------------------
# act value is            :          0.84375         ( --> 0.8499755859375)
# wei value is            :        0.49609375        ( --> 0.507415771484375)
# stochastic mul value is :         0.578125         ( --> 0.43129101395606995)
# fixed mul value is      :      0.4185791015625
# error is                :      15.95458984375
# ------------------------------------------------------------------------------------------
# act value is            :         0.1796875        ( --> 0.19317626953125)
# wei value is            :        1.24609375        ( --> 1.2490234375)
# stochastic mul value is :         0.3828125        ( --> 0.2412816882133484)
# fixed mul value is      :     0.223907470703125
# error is                :     15.8905029296875
# ------------------------------------------------------------------------------------------
# act value is            :         -0.890625        ( --> -0.88861083984375)
# wei value is            :         -2.59375         ( --> -2.57611083984375)
# stochastic mul value is :         2.5078125        ( --> 2.2891600131988525)
# fixed mul value is      :       2.31005859375
# error is                :       19.775390625
# ------------------------------------------------------------------------------------------
# act value is            :         1.1015625        ( --> 1.12042236328125)
# wei value is            :        0.96484375        ( --> 0.975799560546875)
# stochastic mul value is :        1.34765625        ( --> 1.093307614326477)
# fixed mul value is      :     1.062835693359375
# error is                :     28.4820556640625
# ------------------------------------------------------------------------------------------
# act value is            :        0.74609375        ( --> 0.73406982421875)
# wei value is            :         1.1640625        ( --> 1.17095947265625)
# stochastic mul value is :        0.96484375        ( --> 0.8595660328865051)
# fixed mul value is      :     0.868499755859375
# error is                :      9.6343994140625
# ------------------------------------------------------------------------------------------
# act value is            :         0.953125         ( --> 0.96588134765625)
# wei value is            :         -0.40625         ( --> -0.39031982421875)
# stochastic mul value is :        -0.19140625       ( --> -0.37700262665748596)
# fixed mul value is      :      -0.38720703125
# error is                :       19.580078125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.01953125       ( --> -1.0045166015625)
# wei value is            :        -1.44921875       ( --> -1.444183349609375)
# stochastic mul value is :         1.734375         ( --> 1.450706124305725)
# fixed mul value is      :    1.4775238037109375
# error is                :     25.68511962890625
# ------------------------------------------------------------------------------------------
# act value is            :         1.2890625        ( --> 1.27496337890625)
# wei value is            :         0.7265625        ( --> 0.741607666015625)
# stochastic mul value is :          1.15625         ( --> 0.9455226063728333)
# fixed mul value is      :     0.93658447265625
# error is                :      21.966552734375
# ------------------------------------------------------------------------------------------
# act value is            :        2.94140625        ( --> 2.936279296875)
# wei value is            :        3.86328125        ( --> 3.864166259765625)
# stochastic mul value is :         11.578125        ( --> 11.346271514892578)
# fixed mul value is      :    11.363479614257812
# error is                :     21.46453857421875
# ------------------------------------------------------------------------------------------
# act value is            :        1.76953125        ( --> 1.7772216796875)
# wei value is            :        0.59765625        ( --> 0.585479736328125)
# stochastic mul value is :          1.15625         ( --> 1.0405272245407104)
# fixed mul value is      :    1.0575714111328125
# error is                :     9.86785888671875
# ------------------------------------------------------------------------------------------
# act value is            :        1.73828125        ( --> 1.73858642578125)
# wei value is            :        0.30078125        ( --> 0.312255859375)
# stochastic mul value is :         0.578125         ( --> 0.5428838133811951)
# fixed mul value is      :    0.5228424072265625
# error is                :     5.52825927734375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.4296875        ( --> -3.39990234375)
# wei value is            :        -1.48828125       ( --> -1.48321533203125)
# stochastic mul value is :         5.2109375        ( --> 5.042787075042725)
# fixed mul value is      :     5.104339599609375
# error is                :     10.6597900390625
# ------------------------------------------------------------------------------------------
# act value is            :          2.5625          ( --> 2.5499267578125)
# wei value is            :        1.44140625        ( --> 1.444183349609375)
# stochastic mul value is :         3.859375         ( --> 3.6825618743896484)
# fixed mul value is      :      3.693603515625
# error is                :       16.5771484375
# ------------------------------------------------------------------------------------------
# act value is            :         -1.734375        ( --> -1.699951171875)
# wei value is            :        -2.5390625        ( --> -2.537078857421875)
# stochastic mul value is :          4.4375          ( --> 4.312910079956055)
# fixed mul value is      :      4.4036865234375
# error is                :       3.38134765625
# ------------------------------------------------------------------------------------------
# act value is            :        -1.54296875       ( --> -1.54541015625)
# wei value is            :        -0.24609375       ( --> -0.23419189453125)
# stochastic mul value is :         0.578125         ( --> 0.3619225323200226)
# fixed mul value is      :    0.3797149658203125
# error is                :     19.84100341796875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.34765625       ( --> -1.3135986328125)
# wei value is            :        1.63671875        ( --> 1.63934326171875)
# stochastic mul value is :        -1.9296875        ( --> -2.1534390449523926)
# fixed mul value is      :    -2.2057342529296875
# error is                :     27.60467529296875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.75390625       ( --> -0.73406982421875)
# wei value is            :        -0.1015625        ( --> -0.07806396484375)
# stochastic mul value is :        0.19140625        ( --> 0.05730440095067024)
# fixed mul value is      :     0.076568603515625
# error is                :     11.4837646484375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.0859375        ( --> -0.0772705078125)
# wei value is            :        0.73828125        ( --> 0.741607666015625)
# stochastic mul value is :            0.0           ( --> -0.05730440095067024)
# fixed mul value is      :    -0.063446044921875
# error is                :      6.3446044921875
# ------------------------------------------------------------------------------------------
# act value is            :        2.51171875        ( --> 2.51129150390625)
# wei value is            :        -2.2109375        ( --> -2.185791015625)
# stochastic mul value is :        -5.40234375       ( --> -5.489158630371094)
# fixed mul value is      :    -5.553253173828125
# error is                :     15.0909423828125
# ------------------------------------------------------------------------------------------
# act value is            :          4.6875          ( --> 4.67486572265625)
# wei value is            :        0.25390625        ( --> 0.273223876953125)
# stochastic mul value is :        1.34765625        ( --> 1.2772849798202515)
# fixed mul value is      :      1.190185546875
# error is                :       15.7470703125
# ------------------------------------------------------------------------------------------
# act value is            :        0.13671875        ( --> 0.154541015625)
# wei value is            :        1.94921875        ( --> 1.95159912109375)
# stochastic mul value is :         0.3828125        ( --> 0.3016021251678467)
# fixed mul value is      :    0.2664947509765625
# error is                :     11.63177490234375
# ------------------------------------------------------------------------------------------
# act value is            :         2.578125         ( --> 2.58856201171875)
# wei value is            :         4.5234375        ( --> 4.5277099609375)
# stochastic mul value is :        11.7734375        ( --> 11.720257759094238)
# fixed mul value is      :     11.6619873046875
# error is                :      11.14501953125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.98828125       ( --> -0.96588134765625)
# wei value is            :         1.9921875        ( --> 1.990631103515625)
# stochastic mul value is :         -1.734375        ( --> -1.9227133989334106)
# fixed mul value is      :    -1.968841552734375
# error is                :     23.4466552734375
# ------------------------------------------------------------------------------------------
# act value is            :        0.16796875        ( --> 0.154541015625)
# wei value is            :        2.14453125        ( --> 2.146759033203125)
# stochastic mul value is :         0.3828125        ( --> 0.33176231384277344)
# fixed mul value is      :    0.3602142333984375
# error is                :     2.25982666015625
# ------------------------------------------------------------------------------------------
# act value is            :         2.8515625        ( --> 2.8590087890625)
# wei value is            :         1.234375         ( --> 1.2490234375)
# stochastic mul value is :         3.6640625        ( --> 3.5709691047668457)
# fixed mul value is      :      3.5198974609375
# error is                :      14.41650390625
# ------------------------------------------------------------------------------------------
# act value is            :         1.203125         ( --> 1.19769287109375)
# wei value is            :         -1.734375        ( --> -1.7174072265625)
# stochastic mul value is :        -1.9296875        ( --> -2.0569264888763428)
# fixed mul value is      :      -2.086669921875
# error is                :       15.6982421875
# ------------------------------------------------------------------------------------------
# act value is            :        2.93359375        ( --> 2.936279296875)
# wei value is            :         1.5078125        ( --> 1.522247314453125)
# stochastic mul value is :        4.62890625        ( --> 4.469743251800537)
# fixed mul value is      :     4.423309326171875
# error is                :     20.5596923828125
# ------------------------------------------------------------------------------------------
# act value is            :        0.81640625        ( --> 0.81134033203125)
# wei value is            :        -3.07421875       ( --> -3.04449462890625)
# stochastic mul value is :        -2.12109375       ( --> -2.470121383666992)
# fixed mul value is      :    -2.5098114013671875
# error is                :     38.87176513671875
# ------------------------------------------------------------------------------------------
# act value is            :         0.8515625        ( --> 0.8499755859375)
# wei value is            :        1.94140625        ( --> 1.95159912109375)
# stochastic mul value is :         1.9296875        ( --> 1.6588115692138672)
# fixed mul value is      :     1.653228759765625
# error is                :     27.6458740234375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.01953125       ( --> -3.0135498046875)
# wei value is            :         3.765625         ( --> 3.7470703125)
# stochastic mul value is :        -11.1953125       ( --> -11.291982650756836)
# fixed mul value is      :    -11.37042236328125
# error is                :      17.510986328125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.3203125        ( --> -0.30908203125)
# wei value is            :        4.99609375        ( --> 0.0)
# stochastic mul value is :            0.0           ( --> -0.0)
# fixed mul value is      :    -1.600311279296875
# error is                :     160.0311279296875
# ------------------------------------------------------------------------------------------
# act value is            :         3.7578125        ( --> 3.74761962890625)
# wei value is            :         2.7578125        ( --> 2.771270751953125)
# stochastic mul value is :        10.61328125       ( --> 10.385668754577637)
# fixed mul value is      :     10.36334228515625
# error is                :      24.993896484375
# ------------------------------------------------------------------------------------------
# act value is            :         3.921875         ( --> 3.9407958984375)
# wei value is            :        -0.69140625       ( --> -0.663543701171875)
# stochastic mul value is :          -2.3125         ( --> -2.6148903369903564)
# fixed mul value is      :     -2.71160888671875
# error is                :      39.910888671875
# ------------------------------------------------------------------------------------------
# act value is            :        2.30859375        ( --> 2.318115234375)
# wei value is            :         0.9609375        ( --> 0.975799560546875)
# stochastic mul value is :         2.5078125        ( --> 2.2620158195495605)
# fixed mul value is      :     2.218414306640625
# error is                :     28.9398193359375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.6015625        ( --> -2.58856201171875)
# wei value is            :        1.50390625        ( --> 1.522247314453125)
# stochastic mul value is :        -3.6640625        ( --> -3.940431594848633)
# fixed mul value is      :    -3.912506103515625
# error is                :     24.8443603515625
# ------------------------------------------------------------------------------------------
# act value is            :        -3.12890625       ( --> -3.12945556640625)
# wei value is            :        -2.5859375        ( --> -2.57611083984375)
# stochastic mul value is :         8.296875         ( --> 8.061824798583984)
# fixed mul value is      :     8.091156005859375
# error is                :     20.5718994140625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.33984375       ( --> -0.30908203125)
# wei value is            :         4.3359375        ( --> 4.332550048828125)
# stochastic mul value is :         -1.15625         ( --> -1.3391133546829224)
# fixed mul value is      :    -1.473541259765625
# error is                :     31.7291259765625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.00390625       ( --> 0.0)
# wei value is            :        -1.81640625       ( --> -1.79547119140625)
# stochastic mul value is :            0.0           ( --> -0.0)
# fixed mul value is      :    0.0070953369140625
# error is                :     0.70953369140625
# ------------------------------------------------------------------------------------------
# act value is            :        2.82421875        ( --> 2.82037353515625)
# wei value is            :         0.171875         ( --> 0.1561279296875)
# stochastic mul value is :         0.578125         ( --> 0.4403390884399414)
# fixed mul value is      :     0.48541259765625
# error is                :      9.271240234375
# ------------------------------------------------------------------------------------------
# act value is            :        0.49609375        ( --> 0.50225830078125)
# wei value is            :        0.94921875        ( --> 0.936767578125)
# stochastic mul value is :         0.578125         ( --> 0.47049927711486816)
# fixed mul value is      :    0.4709014892578125
# error is                :     10.72235107421875
# ------------------------------------------------------------------------------------------
# act value is            :        0.52734375        ( --> 0.5408935546875)
# wei value is            :          2.15625         ( --> 2.146759033203125)
# stochastic mul value is :        1.34765625        ( --> 1.161168098449707)
# fixed mul value is      :      1.1370849609375
# error is                :      21.05712890625
# ------------------------------------------------------------------------------------------
# act value is            :         3.3203125        ( --> 3.3226318359375)
# wei value is            :         1.8984375        ( --> 1.912567138671875)
# stochastic mul value is :          6.5625          ( --> 6.3547563552856445)
# fixed mul value is      :     6.30340576171875
# error is                :      25.909423828125
# ------------------------------------------------------------------------------------------
# act value is            :        -2.36328125       ( --> -2.35675048828125)
# wei value is            :          1.1875          ( --> 1.17095947265625)
# stochastic mul value is :        -2.69921875       ( --> -2.7596592903137207)
# fixed mul value is      :      -2.806396484375
# error is                :       10.7177734375
# ------------------------------------------------------------------------------------------
# act value is            :        -1.4765625        ( --> -1.4681396484375)
# wei value is            :         -1.265625        ( --> -1.2490234375)
# stochastic mul value is :         1.9296875        ( --> 1.8337408304214478)
# fixed mul value is      :      1.8687744140625
# error is                :       6.09130859375
# ------------------------------------------------------------------------------------------
# act value is            :        3.37890625        ( --> 3.36126708984375)
# wei value is            :         4.890625         ( --> 4.878997802734375)
# stochastic mul value is :        16.59765625       ( --> 16.399614334106445)
# fixed mul value is      :     16.52496337890625
# error is                :      7.269287109375
# ------------------------------------------------------------------------------------------
# act value is            :           -2.5           ( --> -2.47265625)
# wei value is            :        1.12890625        ( --> 1.131927490234375)
# stochastic mul value is :        -2.69921875       ( --> -2.798867702484131)
# fixed mul value is      :       -2.822265625
# error is                :        12.3046875
# ------------------------------------------------------------------------------------------
# act value is            :        1.94921875        ( --> 1.97039794921875)
# wei value is            :         0.1171875        ( --> 0.117095947265625)
# stochastic mul value is :         0.3828125        ( --> 0.23072561621665955)
# fixed mul value is      :     0.228424072265625
# error is                :     15.4388427734375
# ------------------------------------------------------------------------------------------
# act value is            :        0.79296875        ( --> 0.81134033203125)
# wei value is            :         0.6484375        ( --> 0.663543701171875)
# stochastic mul value is :        0.76953125        ( --> 0.5383597612380981)
# fixed mul value is      :     0.514190673828125
# error is                :     25.5340576171875
# ------------------------------------------------------------------------------------------
# act value is            :         3.140625         ( --> 3.12945556640625)
# wei value is            :          2.1875          ( --> 2.185791015625)
# stochastic mul value is :         6.9453125        ( --> 6.840335845947266)
# fixed mul value is      :       6.8701171875
# error is                :        7.51953125
# ------------------------------------------------------------------------------------------
# act value is            :         -0.640625        ( --> -0.6181640625)
# wei value is            :         -1.953125        ( --> -1.95159912109375)
# stochastic mul value is :        1.34765625        ( --> 1.2064085006713867)
# fixed mul value is      :      1.251220703125
# error is                :       9.6435546875
# ------------------------------------------------------------------------------------------
# act value is            :          1.34375         ( --> 1.35223388671875)
# wei value is            :        3.79296875        ( --> 3.786102294921875)
# stochastic mul value is :        5.40234375        ( --> 5.119695663452148)
# fixed mul value is      :      5.0968017578125
# error is                :      30.55419921875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.4453125        ( --> -1.42950439453125)
# wei value is            :        -0.27734375       ( --> -0.273223876953125)
# stochastic mul value is :         0.578125         ( --> 0.39057472348213196)
# fixed mul value is      :     0.400848388671875
# error is                :     17.7276611328125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.3359375        ( --> -0.30908203125)
# wei value is            :        -0.6953125        ( --> -0.663543701171875)
# stochastic mul value is :         0.3828125        ( --> 0.20508943498134613)
# fixed mul value is      :     0.23358154296875
# error is                :      14.923095703125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.06640625       ( --> -0.03863525390625)
# wei value is            :          1.6875          ( --> 1.678375244140625)
# stochastic mul value is :            0.0           ( --> -0.06484445184469223)
# fixed mul value is      :      -0.112060546875
# error is                :       11.2060546875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.98046875       ( --> -1.97039794921875)
# wei value is            :         -0.46875         ( --> -0.4683837890625)
# stochastic mul value is :          1.15625         ( --> 0.9229024648666382)
# fixed mul value is      :      0.9283447265625
# error is                :      22.79052734375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.36328125       ( --> -0.34771728515625)
# wei value is            :         3.046875         ( --> 3.04449462890625)
# stochastic mul value is :        -0.76953125       ( --> -1.0586234331130981)
# fixed mul value is      :     -1.10687255859375
# error is                :      33.734130859375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.10546875       ( --> -0.0772705078125)
# wei value is            :           0.375          ( --> 0.39031982421875)
# stochastic mul value is :            0.0           ( --> -0.03016021102666855)
# fixed mul value is      :      -0.03955078125
# error is                :        3.955078125
# ------------------------------------------------------------------------------------------
# act value is            :         3.421875         ( --> 3.43853759765625)
# wei value is            :        0.57421875        ( --> 0.585479736328125)
# stochastic mul value is :          2.3125          ( --> 2.0131940841674805)
# fixed mul value is      :     1.96490478515625
# error is                :      34.759521484375
# ------------------------------------------------------------------------------------------
# act value is            :        0.19921875        ( --> 0.19317626953125)
# wei value is            :         2.9140625        ( --> 2.927398681640625)
# stochastic mul value is :        0.76953125        ( --> 0.5655039548873901)
# fixed mul value is      :     0.580535888671875
# error is                :     18.8995361328125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.3828125        ( --> -1.35223388671875)
# wei value is            :        1.74609375        ( --> 1.756439208984375)
# stochastic mul value is :        -2.12109375       ( --> -2.3751165866851807)
# fixed mul value is      :    -2.414520263671875
# error is                :     29.3426513671875
# ------------------------------------------------------------------------------------------
# act value is            :        1.45703125        ( --> 1.4681396484375)
# wei value is            :        1.40234375        ( --> 1.4051513671875)
# stochastic mul value is :          2.3125          ( --> 2.0629584789276123)
# fixed mul value is      :    2.0432586669921875
# error is                :     26.92413330078125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.41796875       ( --> -0.3863525390625)
# wei value is            :         2.8984375        ( --> 2.88836669921875)
# stochastic mul value is :        -0.96484375       ( --> -1.115927815437317)
# fixed mul value is      :    -1.211456298828125
# error is                :     24.6612548828125
# ------------------------------------------------------------------------------------------
# act value is            :         2.8984375        ( --> 2.89764404296875)
# wei value is            :        -3.06640625       ( --> -3.04449462890625)
# stochastic mul value is :        -8.4921875        ( --> -8.821861267089844)
# fixed mul value is      :    -8.887786865234375
# error is                :     39.5599365234375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.59765625       ( --> -3.59307861328125)
# wei value is            :         0.7890625        ( --> 0.7806396484375)
# stochastic mul value is :        -2.69921875       ( --> -2.8048996925354004)
# fixed mul value is      :    -2.838775634765625
# error is                :     13.9556884765625
# ------------------------------------------------------------------------------------------
# act value is            :         0.4609375        ( --> 0.463623046875)
# wei value is            :        -1.2734375        ( --> -1.2490234375)
# stochastic mul value is :         -0.578125        ( --> -0.5790760517120361)
# fixed mul value is      :     -0.58697509765625
# error is                :      0.885009765625
# ------------------------------------------------------------------------------------------
# act value is            :        1.86328125        ( --> 1.8544921875)
# wei value is            :        -3.7578125        ( --> -3.7470703125)
# stochastic mul value is :        -6.9453125        ( --> -6.948912620544434)
# fixed mul value is      :    -7.001861572265625
# error is                :      5.6549072265625
# ------------------------------------------------------------------------------------------
# act value is            :        0.70703125        ( --> 0.6954345703125)
# wei value is            :        2.30078125        ( --> 2.302886962890625)
# stochastic mul value is :         1.734375         ( --> 1.6015071868896484)
# fixed mul value is      :    1.6267242431640625
# error is                :     10.76507568359375
# ------------------------------------------------------------------------------------------
# act value is            :        -1.3984375        ( --> -1.390869140625)
# wei value is            :        1.21484375        ( --> 1.209991455078125)
# stochastic mul value is :        -1.54296875       ( --> -1.6829397678375244)
# fixed mul value is      :    -1.698883056640625
# error is                :     15.5914306640625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.08984375       ( --> -0.0772705078125)
# wei value is            :        -1.69921875       ( --> -1.678375244140625)
# stochastic mul value is :        0.19140625        ( --> 0.12968890368938446)
# fixed mul value is      :    0.1526641845703125
# error is                :     3.87420654296875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.7890625        ( --> -1.7772216796875)
# wei value is            :        1.40234375        ( --> 1.4051513671875)
# stochastic mul value is :          -2.3125         ( --> -2.497265577316284)
# fixed mul value is      :    -2.508880615234375
# error is                :     19.6380615234375
# ------------------------------------------------------------------------------------------
# act value is            :        1.98046875        ( --> 1.97039794921875)
# wei value is            :         -2.671875        ( --> -2.6541748046875)
# stochastic mul value is :         -5.015625        ( --> -5.229780673980713)
# fixed mul value is      :     -5.29156494140625
# error is                :      27.593994140625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.70703125       ( --> -0.6954345703125)
# wei value is            :        1.16015625        ( --> 1.17095947265625)
# stochastic mul value is :         -0.578125        ( --> -0.8143256902694702)
# fixed mul value is      :    -0.8202667236328125
# error is                :     24.21417236328125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.59765625       ( --> -1.58404541015625)
# wei value is            :        1.44921875        ( --> 1.444183349609375)
# stochastic mul value is :        -2.12109375       ( --> -2.287652015686035)
# fixed mul value is      :    -2.3153533935546875
# error is                :     19.42596435546875
# ------------------------------------------------------------------------------------------
# act value is            :         0.890625         ( --> 0.88861083984375)
# wei value is            :         2.140625         ( --> 2.146759033203125)
# stochastic mul value is :        2.12109375        ( --> 1.9076333045959473)
# fixed mul value is      :      1.906494140625
# error is                :       21.4599609375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.0078125        ( --> -2.009033203125)
# wei value is            :        3.55859375        ( --> 3.551910400390625)
# stochastic mul value is :        -6.9453125        ( --> -7.135905742645264)
# fixed mul value is      :    -7.144989013671875
# error is                :     19.9676513671875
# ------------------------------------------------------------------------------------------
# act value is            :         3.984375         ( --> 3.97943115234375)
# wei value is            :        1.17578125        ( --> 1.17095947265625)
# stochastic mul value is :        4.82421875        ( --> 4.659752368927002)
# fixed mul value is      :     4.68475341796875
# error is                :      13.946533203125
# ------------------------------------------------------------------------------------------
# act value is            :        0.26171875        ( --> 0.27044677734375)
# wei value is            :          1.53125         ( --> 1.522247314453125)
# stochastic mul value is :         0.578125         ( --> 0.41168686747550964)
# fixed mul value is      :      0.4007568359375
# error is                :      17.73681640625
# ------------------------------------------------------------------------------------------
# act value is            :        -3.39453125       ( --> -3.36126708984375)
# wei value is            :         -0.359375        ( --> -0.351287841796875)
# stochastic mul value is :        1.34765625        ( --> 1.180772304534912)
# fixed mul value is      :     1.21990966796875
# error is                :      12.774658203125
# ------------------------------------------------------------------------------------------
# act value is            :         0.171875         ( --> 0.154541015625)
# wei value is            :         0.0859375        ( --> 0.07806396484375)
# stochastic mul value is :        0.19140625        ( --> 0.01206408441066742)
# fixed mul value is      :      0.0147705078125
# error is                :      17.66357421875
# ------------------------------------------------------------------------------------------
# act value is            :          -3.6875         ( --> -3.67034912109375)
# wei value is            :        -3.93359375       ( --> -3.9031982421875)
# stochastic mul value is :        14.4765625        ( --> 14.32610034942627)
# fixed mul value is      :      14.505126953125
# error is                :       2.8564453125
# ------------------------------------------------------------------------------------------
# act value is            :        0.78515625        ( --> 0.772705078125)
# wei value is            :        1.33984375        ( --> 1.32708740234375)
# stochastic mul value is :          1.15625         ( --> 1.025447130203247)
# fixed mul value is      :    1.0519866943359375
# error is                :     10.42633056640625
# ------------------------------------------------------------------------------------------
# act value is            :        -1.64453125       ( --> -1.6226806640625)
# wei value is            :        -0.2109375        ( --> -0.195159912109375)
# stochastic mul value is :         0.578125         ( --> 0.31668221950531006)
# fixed mul value is      :     0.346893310546875
# error is                :     23.1231689453125
# ------------------------------------------------------------------------------------------
# act value is            :         1.921875         ( --> 1.9317626953125)
# wei value is            :        -1.4140625        ( --> -1.4051513671875)
# stochastic mul value is :        -2.5078125        ( --> -2.714418888092041)
# fixed mul value is      :     -2.7176513671875
# error is                :      20.98388671875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.54296875       ( --> -1.54541015625)
# wei value is            :         -0.65625         ( --> -0.62451171875)
# stochastic mul value is :        0.96484375        ( --> 0.9651267528533936)
# fixed mul value is      :      1.0125732421875
# error is                :       4.77294921875
# ------------------------------------------------------------------------------------------
# act value is            :         0.0546875        ( --> 0.03863525390625)
# wei value is            :        -1.7265625        ( --> -1.7174072265625)
# stochastic mul value is :            0.0           ( --> -0.0663524642586708)
# fixed mul value is      :     -0.09442138671875
# error is                :      9.442138671875
# ------------------------------------------------------------------------------------------
# act value is            :        3.07421875        ( --> 3.0908203125)
# wei value is            :        -1.23046875       ( --> -1.209991455078125)
# stochastic mul value is :        -3.6640625        ( --> -3.739866256713867)
# fixed mul value is      :    -3.7827301025390625
# error is                :     11.86676025390625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.88671875       ( --> -0.88861083984375)
# wei value is            :           1.125          ( --> 1.131927490234375)
# stochastic mul value is :        -0.76953125       ( --> -1.0058430433273315)
# fixed mul value is      :      -0.99755859375
# error is                :       22.802734375
# ------------------------------------------------------------------------------------------
# act value is            :         -0.796875        ( --> -0.772705078125)
# wei value is            :        -1.44921875       ( --> -1.444183349609375)
# stochastic mul value is :        1.34765625        ( --> 1.115927815437317)
# fixed mul value is      :     1.15484619140625
# error is                :      19.281005859375
# ------------------------------------------------------------------------------------------
# act value is            :        0.47265625        ( --> 0.463623046875)
# wei value is            :        3.70703125        ( --> 3.708038330078125)
# stochastic mul value is :         1.734375         ( --> 1.7191320657730103)
# fixed mul value is      :    1.7521514892578125
# error is                :     1.77764892578125
# ------------------------------------------------------------------------------------------
# act value is            :        2.33203125        ( --> 2.318115234375)
# wei value is            :         0.265625         ( --> 0.273223876953125)
# stochastic mul value is :        0.76953125        ( --> 0.6333644390106201)
# fixed mul value is      :     0.61944580078125
# error is                :      15.008544921875
# ------------------------------------------------------------------------------------------
# act value is            :          2.5625          ( --> 2.5499267578125)
# wei value is            :        1.16796875        ( --> 1.17095947265625)
# stochastic mul value is :         3.0859375        ( --> 2.985860824584961)
# fixed mul value is      :      2.992919921875
# error is                :       9.3017578125
# ------------------------------------------------------------------------------------------
# act value is            :         1.6796875        ( --> 1.699951171875)
# wei value is            :         -1.34375         ( --> -1.32708740234375)
# stochastic mul value is :        -2.12109375       ( --> -2.255983829498291)
# fixed mul value is      :      -2.257080078125
# error is                :       13.5986328125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.98828125       ( --> -0.96588134765625)
# wei value is            :        4.08203125        ( --> 4.098358154296875)
# stochastic mul value is :        -3.6640625        ( --> -3.9585278034210205)
# fixed mul value is      :    -4.0341949462890625
# error is                :     37.01324462890625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.90234375       ( --> -0.88861083984375)
# wei value is            :        -0.42578125       ( --> -0.39031982421875)
# stochastic mul value is :         0.578125         ( --> 0.3468424379825592)
# fixed mul value is      :    0.3842010498046875
# error is                :     19.39239501953125
# ------------------------------------------------------------------------------------------
# act value is            :         -1.046875        ( --> -1.04315185546875)
# wei value is            :        -0.76171875       ( --> -0.741607666015625)
# stochastic mul value is :        0.96484375        ( --> 0.7736093997955322)
# fixed mul value is      :     0.79742431640625
# error is                :      16.741943359375
# ------------------------------------------------------------------------------------------
# act value is            :          1.4375          ( --> 1.42950439453125)
# wei value is            :        -2.9296875        ( --> -2.927398681640625)
# stochastic mul value is :         -3.859375        ( --> -4.184729099273682)
# fixed mul value is      :      -4.21142578125
# error is                :       35.205078125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.79296875       ( --> -0.772705078125)
# wei value is            :        0.87109375        ( --> 0.85870361328125)
# stochastic mul value is :        -0.3828125        ( --> -0.6635246276855469)
# fixed mul value is      :    -0.6907501220703125
# error is                :     30.79376220703125
# ------------------------------------------------------------------------------------------
# act value is            :         0.296875         ( --> 0.30908203125)
# wei value is            :        1.45703125        ( --> 1.444183349609375)
# stochastic mul value is :         0.578125         ( --> 0.4463711380958557)
# fixed mul value is      :     0.43255615234375
# error is                :      14.556884765625
# ------------------------------------------------------------------------------------------
# act value is            :         2.5390625        ( --> 2.5499267578125)
# wei value is            :        3.80078125        ( --> 3.786102294921875)
# stochastic mul value is :          9.84375         ( --> 9.65428352355957)
# fixed mul value is      :     9.650421142578125
# error is                :     19.3328857421875
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## ERROR

# %%
def MSE(a,b):
    s = 0
    n = 0

    for i in range(10):
        for j in range(15):
            square = (((a[i][j])-b[i][j])**2).item()
            s += square
            n   += 1
    error = s/n
    return error

# %% [markdown]
# ## ERROR : 7bit LFSR

# %%
MSE(act_f*wei_f,cc)
# Out:
# 0.2573740140131364
