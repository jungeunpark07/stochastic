# %% [markdown]
# # Multiplier TEST code

# %% [markdown]
# fixed number to stochastic conversion & multiply & stochastic to fixed number conversion

# %% [markdown]
# ## Import

# %%
import random, struct, math
import torch
import numpy as np
import torch.nn as nn 
import argparse
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Parser

# %%
parser = argparse.ArgumentParser(description='fixed_mac')
parser.add_argument('--full_bits', type=int, default=16, help='Number of Quantization Bits')
parser.add_argument('--frac_bits', type=int, default=8, help='Number of Quantization Bits')
parser.add_argument('--bBW', type=int, default=6, help='Number of bit width')
args = parser.parse_args(args=[])

# %% [markdown]
# ## Definition

# %% [markdown]
# ### int2bin : int number to binary number

# %%
def int2bin(iIn,iBW):
    iBW = iBW + 1
    if iIn >= 0:
        bOut = bin(iIn).replace('0b','').rjust(iBW,'0')
    else :
        bOut = bin(iIn & (pow(2,iBW)-1)).replace('0b','').rjust(iBW,'1')
    return bOut[1:]

# %% [markdown]
# ### XOR : xor gate with string

# %%
def XOR(iA,iB):
    if iA != iB :
        iOut = '1'
    else : 
        iOut = '0'
    return iOut

# %% [markdown]
# ### SNUM : sign number determination

# %%
def snum(a):
    if a >= 0 :
        return '0'
    else :
        return '1'

# %% [markdown]
# ## bInv : Binary Inversion

# %%
def binInv(bIn):
    bOut = bin(int(bIn,2)^(pow(2,len(bIn))-1)).replace('0b','').rjust(len(bIn),'0')
    return bOut

# %% [markdown]
# ### fxp & flp2fix : floating number to fixed number conversion

# %%
class fxp:
    def __init__(self, bIn, iBWF):
        self.iFullBW = len(bIn)
        self.iIntgBW = self.iFullBW - iBWF
        self.bSign = bIn[0]
        self.bIntg = bIn[:self.iIntgBW]
        self.bFrac = bIn[self.iIntgBW:]
        self.fFull = 0
        try:
            for idx, bit in enumerate(bIn):
                if idx == 0:
                    self.fFull = self.fFull + int(bit,2) * -pow(2, self.iIntgBW - 1)
                else:
                    self.fFull = self.fFull + int(bit,2) * pow(2, self.iIntgBW - 1 - idx)
        except:
            print(bIn)
        self.dispFull = self.bIntg +"."+ self.bFrac 
        return

# %%
class flp2fix:
    def __init__(self, fIn, iBW, iBWF):
        self.fMin = - 2 ** (iBW - iBWF - 1)
        self.fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
        self.fResol = 2 ** -iBWF
        if fIn < self.fMin or fIn > self.fMax:
            print(f'({fIn}): Out of input range ({self.fMax}/{self.fMin}) during flp -> fix converting ')
        self.iBW = iBW
        self.iBWI = iBW - iBWF
        self.iBWF = iBWF

        self.iFLP2INT = abs(int(fIn * 2 ** iBWF))
        if fIn < 0:
            self.iFLP2INT = 2 ** (iBW-1) - self.iFLP2INT

        if fIn >= 0:
            self.bFull = bin(self.iFLP2INT)[2:].rjust(iBW, '0')
        else:
            self.bFull = '1'+bin(self.iFLP2INT)[2:].rjust(iBW-1, '0')
            if len(self.bFull) > iBW:
                self.bFull = '0' * iBW

        self.cssFxp = fxp(self.bFull, self.iBWF)
        self.bSign = self.cssFxp.bSign
        self.bIntg = self.cssFxp.bIntg
        self.bFrac = self.cssFxp.bFrac
        self.fFull = self.cssFxp.fFull
        return

# %%
def flp2fixTensor(fIn, iBW, iBWF):
    fMin = - 2 ** (iBW - iBWF - 1)
    fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
    fList = []
    for aTensor in fIn.view(-1):
        fList.append(flp2fix(aTensor, iBW, iBWF).fFull)
    return torch.tensor(fList).view(fIn.size())

# %% [markdown]
# ### LFSR : make pseudorandom number bitstream

# %%
class LFSR6:
    def Random(self):
        self.b0 = eval(f'str(random.randint(0,1))')
        self.b1 = eval(f'str(random.randint(0,1))')
        self.b2 = eval(f'str(random.randint(0,1))')
        self.b3 = eval(f'str(random.randint(0,1))')
        self.b4 = eval(f'str(random.randint(0,1))')
        self.b5 = eval(f'str(random.randint(0,1))')
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5
    
    def Normal(self,stream):
        self.b0 = XOR(int(stream[4]),int(stream[5]))
        self.b1 = stream[0]
        self.b2 = stream[1]
        self.b3 = stream[2]
        self.b4 = stream[3]
        self.b5 = stream[4]
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5
    
    def Allzero(self):
        self.b0 = '0'
        self.b1 = '0'
        self.b2 = '0'
        self.b3 = '0'
        self.b4 = '0'
        self.b5 = '0'
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5

# %%
def LFSRlist6():
    lfsr = LFSR6()
    lfsrlist = []
    for k in range(2**(args.bBW)-1): #lfsr number generating
        if k == 0:
            lfsrlist.append(lfsr.Random())
        else :
            lfsrlist.append(lfsr.Normal(lfsrlist[k-1]))
        if (k == 2**(args.bBW)-2):
            lfsrlist.append(lfsr.Allzero())
    
    if (args.bBW) != args.frac_bits :
        if args.bBW < args.frac_bits :
            for i in range(len(lfsrlist)):
                lfsrlist[i] = lfsrlist[i] + (args.frac_bits-args.bBW)*'0'
        else :
            print("it can't work")
            return 0
    
    return lfsrlist

# %% [markdown]
# ### LFSRlist : make pseudorandom number bitstream with 2**bBW cycle

# %%
class LFSR6:
    def Random(self):
        self.b0 = eval(f'str(random.randint(0,1))')
        self.b1 = eval(f'str(random.randint(0,1))')
        self.b2 = eval(f'str(random.randint(0,1))')
        self.b3 = eval(f'str(random.randint(0,1))')
        self.b4 = eval(f'str(random.randint(0,1))')
        self.b5 = eval(f'str(random.randint(0,1))')
        if int(self.b0) + int(self.b1) + int(self.b2) + int(self.b3) + int(self.b4) + int(self.b5 ) == 0 :
            self.b0 = eval(f'str(random.randint(0,1))')
            self.b1 = eval(f'str(random.randint(0,1))')
            self.b2 = eval(f'str(random.randint(0,1))')
            self.b3 = eval(f'str(random.randint(0,1))')
            self.b4 = eval(f'str(random.randint(0,1))')
            self.b5 = eval(f'str(random.randint(0,1))') 
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5
    
    def Normal(self,stream):
        self.b0 = XOR(int(stream[4]),int(stream[5]))
        self.b1 = stream[0]
        self.b2 = stream[1]
        self.b3 = stream[2]
        self.b4 = stream[3]
        self.b5 = stream[4]
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5
    
    def Allzero(self):
        self.b0 = '0'
        self.b1 = '0'
        self.b2 = '0'
        self.b3 = '0'
        self.b4 = '0'
        self.b5 = '0'
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5

# %% [markdown]
# ### Comp : Comparator in SNG

# %%
def Comp(a,lfsr,snum):
    for com in range(0,len(a)):
        oA = '0'
        if a[com]!=lfsr[com]:
            if(int(a[com]) > int(lfsr[com])):
                oA = '1'
            break
    return XOR(oA,snum)

# %% [markdown]
# ### Perm : module for permutation SNG

# %%
def perm(a):
    al = len(a)
    blist = []
    if args.frac_bits == args.bBW : 
        for i in range(al) :
            blist.append(a[al-i-1])
    elif args.frac_bits > args.bBW :
        for i in range(al-(args.frac_bits-args.bBW)) :
            blist.append((a[al-(args.frac_bits-args.bBW)-i-1]))
    b = "".join(blist)
    b = b + ('0'*(args.frac_bits-args.bBW))
    return b

# %% [markdown]
# ### findMaxMin : find abs max value in act tensor

# %%
def findMaxMin(data):
    max = torch.max(data)
    min = torch.min(data)
    SF=torch.max(abs(max),abs(min)).item()
    return SF

# %% [markdown]
# ### SNG : stochastic number generator module

# %%
def SNG(iIN,lfsr):

    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    bFRAC = bIN[-(args.frac_bits):]
    if sNUM == 1 :
        bFRAC = bin(int(binInv(bFRAC),2)+1).replace('0b','').rjust(args.bBW,'0')
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        lNUM = lfsr[k]
        a = Comp(bFRAC,lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if bIN == '0'*args.full_bits :
        return "0"*((2**(args.bBW))+1)
    else :
        return sA

# %% [markdown]
# ### SNG_P : permutation stochastic number generator module

# %%
def SNG_P(iIN,lfsr):
    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    bFRAC = bIN[-(args.frac_bits):]
    if sNUM == 1 :
        bFRAC = bin(int(binInv(bFRAC),2)+1).replace('0b','').rjust(args.bBW,'0')
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        if (args.bBW == args.frac_bits) :    
            lNUM = perm(lfsr[k])
        elif (args.bBW < args.frac_bits) :
            lNUM = perm(lfsr[k][:args.bBW])+(args.frac_bits-args.bBW)*"0"
        a = Comp(bFRAC,lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if bIN == '0'*args.full_bits :
         return "0"*((2**(args.bBW))+1)
    else :
        return sA

# %% [markdown]
# ### SNGnumpy : SNG module with numpy

# %%
def SNGnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG(float(aNumpy),lfsr))
                     
    return np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### SNGpnumpy : permutation SNG module with numpy

# %%
def SNGpnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG_P(float(aNumpy),lfsr))
                     
    return  np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### CountOne : count 1 in stochastic number bit stream

# %%
def CountOne(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        n = 0
        for a in num:
            if a == '1' :
                n += 1
        if num[0] == '1' :
            nlist.append(n-1)
        else :
            nlist.append(n)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### defSign : sign determination in S2N

# %%
def defSign(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        if num[0] == '1' :
            nlist.append(-1)
        else :
            nlist.append(1)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### Multiplier

# %%
def mul(a,b):
    al = len(a)
    bl = len(b)
    
    outlist = []
    
    if al != bl :
        print("length of string is different")
        return 0
    
    outlist.append(XOR(a[0],b[0]))
    
    for i in range(al-1) :
        outlist.append(str(int(a[i+1]) & int(b[i+1])))
    
    #print(outlist)
    out = "".join(outlist)
    
    return out

# %%
def defSign1(nIn):
    if nIn[0] == '1' :
        return -1
    else :
        return 1

# %%
def CountOne1(nIn):
    n = 0
    for num in nIn:
        if num == '1' :
            n += 1
    if nIn[0] == '1' :
        return n-1
    else :
        return n

# %%
def S2None(sIn,SF):
    s = defSign(sIn)
    o = (CountOne(sIn)/(2**args.bBW))*SF*s
    return o

# %%
def mulNumpy(aIn,bIn,aSF,wSF):
    mList = []
    for i in range(aIn.shape[0]):
        for j in range(bIn.T.shape[1]):
            sum = 0
            for k in range(aIn.shape[1]):
                sum += S2None(mul((aIn[i][k].astype(str)),(bIn.T)[k][j].astype(str)),aSF*wSF)
            mList.append(sum)
    return torch.tensor(mList).view(aIn.shape[0],bIn.T.shape[1])

# %%
def FindError(a,b):
    elist = []
    for anum,bnum in zip(a.view(-1),b.view(-1)):
        e = (abs(bnum-anum)*100).item()
        elist.append(e)
    return torch.tensor(elist).reshape(a.size())

# %% [markdown]
# # TEST : LFSR 6 bit

# %%
act = torch.rand((10,15))-torch.randint(5,(10,15))+torch.randint(5,(10,15))
wei = torch.rand((10,15))-torch.randint(5,(10,15))+torch.randint(5,(10,15))

# %%
act_f = flp2fixTensor(act,args.full_bits,args.frac_bits)
wei_f = flp2fixTensor(wei,args.full_bits,args.frac_bits)

# %% [markdown]
# ### number to stochastic conversion

# %%
aSF = findMaxMin(act_f)
wSF = findMaxMin(wei_f)

# %%
def N2S(act,wei,aSF,wSF):
    
    lfsrlist = LFSRlist6()
    
    a = SNGnumpy(act/aSF,lfsrlist)
    w = SNGpnumpy(wei/wSF,lfsrlist)
    
    return a,w

# %%
def N2Sone(data,SF):
    lfsrlist = LFSRlist6()
    
    o = SNGnumpy(data/SF,lfsrlist)
    
    return o

# %% [markdown]
# ### stochastic to number conversion

# %%
def S2N(a,w,aSF,wSF):
    
    sa = defSign(a)
    sw = defSign(w)

    ca = (CountOne(a)/(2**args.bBW)) * aSF *sa
    cw = (CountOne(w)/(2**args.bBW)) * wSF *sw

    return ca,cw

# %%
a,w = N2S(act,wei,aSF,wSF)

# %%
ca,cw = S2N(a,w,aSF,wSF)

# %%
def multest(aIn,wIn,aSF,wSF):
    mlist=[]
    out = 0
    for a,b in zip(aIn.reshape(-1),wIn.reshape(-1)) :
        out = mul(a,b)
        mlist.append(out)
    
    return np.array(mlist).reshape(aIn.shape)

# %%
c = multest(a,w,aSF,wSF)

# %%
cc = flp2fixTensor(S2None(c,aSF*wSF),args.full_bits,args.frac_bits)

# %%
print(aSF,wSF)
# Out:
# 4.9921875 4.546875

# %%
error = FindError(cc,act_f*wei_f)

# %%
print(f'error mean value is : {torch.mean(error)}')
print(f'------------------------------------------------------------------------------------------')
for i in range(10):
    for j in range(15):
        print(f'act value is            : {act_f[i][j]:^25}( --> {ca[i][j]})')
        print(f'wei value is            : {wei_f[i][j]:^25}( --> {cw[i][j]})')
        print(f'stochastic mul value is : {cc[i][j]:^25}( --> {ca[i][j] * cw[i][j]})')
        print(f'fixed mul value is      : {act_f[i][j]*wei_f[i][j]:^25}')
        print(f'error is                : {error[i][j]:^25}')
        print(f'------------------------------------------------------------------------------------------')
# Out:
# error mean value is : 87.4292984008789
# ------------------------------------------------------------------------------------------
# act value is            :        1.53515625        ( --> 1.56005859375)
# wei value is            :        0.03515625        ( --> 0.2841796875)
# stochastic mul value is :        1.41796875        ( --> 0.44333696365356445)
# fixed mul value is      :    0.0539703369140625
# error is                :    136.39984130859375
# ------------------------------------------------------------------------------------------
# act value is            :          -0.4375         ( --> -0.3900146484375)
# wei value is            :          0.46875         ( --> 0.568359375)
# stochastic mul value is :            0.0           ( --> -0.22166848182678223)
# fixed mul value is      :       -0.205078125
# error is                :        20.5078125
# ------------------------------------------------------------------------------------------
# act value is            :        0.33984375        ( --> 0.3900146484375)
# wei value is            :        -3.30078125       ( --> -3.1259765625)
# stochastic mul value is :        -0.3515625        ( --> -1.2191766500473022)
# fixed mul value is      :    -1.1217498779296875
# error is                :     77.01873779296875
# ------------------------------------------------------------------------------------------
# act value is            :         2.203125         ( --> 2.18408203125)
# wei value is            :         -0.28125         ( --> -0.0)
# stochastic mul value is :            0.0           ( --> -0.0)
# fixed mul value is      :      -0.61962890625
# error is                :       61.962890625
# ------------------------------------------------------------------------------------------
# act value is            :        2.20703125        ( --> 2.2620849609375)
# wei value is            :         -1.96875         ( --> -1.705078125)
# stochastic mul value is :        -3.19140625       ( --> -3.8570315837860107)
# fixed mul value is      :     -4.3450927734375
# error is                :      115.36865234375
# ------------------------------------------------------------------------------------------
# act value is            :        2.78515625        ( --> 2.80810546875)
# wei value is            :         1.1796875        ( --> 1.4208984375)
# stochastic mul value is :         5.671875         ( --> 3.99003267288208)
# fixed mul value is      :     3.285614013671875
# error is                :     238.6260986328125
# ------------------------------------------------------------------------------------------
# act value is            :        2.44921875        ( --> 2.49609375)
# wei value is            :         -1.03125         ( --> -0.8525390625)
# stochastic mul value is :        -1.41796875       ( --> -2.1280174255371094)
# fixed mul value is      :     -2.5257568359375
# error is                :      110.77880859375
# ------------------------------------------------------------------------------------------
# act value is            :        0.93359375        ( --> 0.93603515625)
# wei value is            :        0.48046875        ( --> 0.568359375)
# stochastic mul value is :        1.41796875        ( --> 0.5320043563842773)
# fixed mul value is      :    0.4485626220703125
# error is                :     96.94061279296875
# ------------------------------------------------------------------------------------------
# act value is            :        4.37890625        ( --> 4.3681640625)
# wei value is            :        0.26953125        ( --> 0.2841796875)
# stochastic mul value is :        1.41796875        ( --> 1.2413434982299805)
# fixed mul value is      :    1.1802520751953125
# error is                :     23.77166748046875
# ------------------------------------------------------------------------------------------
# act value is            :        4.67578125        ( --> 4.68017578125)
# wei value is            :        1.81640625        ( --> 1.9892578125)
# stochastic mul value is :         9.9296875        ( --> 9.310075759887695)
# fixed mul value is      :     8.493118286132812
# error is                :    143.65692138671875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.36328125       ( --> -1.3260498046875)
# wei value is            :        -1.51171875       ( --> -1.4208984375)
# stochastic mul value is :        3.19140625        ( --> 1.884182095527649)
# fixed mul value is      :    2.0608978271484375
# error is                :    113.05084228515625
# ------------------------------------------------------------------------------------------
# act value is            :        1.98828125        ( --> 2.028076171875)
# wei value is            :        1.94921875        ( --> 1.9892578125)
# stochastic mul value is :        4.96484375        ( --> 4.034366607666016)
# fixed mul value is      :    3.8755950927734375
# error is                :    108.92486572265625
# ------------------------------------------------------------------------------------------
# act value is            :        0.31640625        ( --> 0.31201171875)
# wei value is            :        -0.3203125        ( --> -0.2841796875)
# stochastic mul value is :            0.0           ( --> -0.08866739273071289)
# fixed mul value is      :    -0.101348876953125
# error is                :     10.1348876953125
# ------------------------------------------------------------------------------------------
# act value is            :        3.03515625        ( --> 3.0421142578125)
# wei value is            :        2.43359375        ( --> 2.5576171875)
# stochastic mul value is :        8.51171875        ( --> 7.780563831329346)
# fixed mul value is      :    7.3863372802734375
# error is                :    112.53814697265625
# ------------------------------------------------------------------------------------------
# act value is            :        4.11328125        ( --> 4.1341552734375)
# wei value is            :        -1.51171875       ( --> -1.4208984375)
# stochastic mul value is :         -4.609375        ( --> -5.8742146492004395)
# fixed mul value is      :    -6.2181243896484375
# error is                :    160.87493896484375
# ------------------------------------------------------------------------------------------
# act value is            :         1.109375         ( --> 1.1700439453125)
# wei value is            :        -1.20703125       ( --> -1.13671875)
# stochastic mul value is :          -1.0625         ( --> -1.3300108909606934)
# fixed mul value is      :     -1.33905029296875
# error is                :      27.655029296875
# ------------------------------------------------------------------------------------------
# act value is            :        1.29296875        ( --> 1.3260498046875)
# wei value is            :        2.41015625        ( --> 2.5576171875)
# stochastic mul value is :         4.609375         ( --> 3.3915276527404785)
# fixed mul value is      :    3.1162567138671875
# error is                :    149.31182861328125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.9140625        ( --> -1.8720703125)
# wei value is            :         3.328125         ( --> 3.41015625)
# stochastic mul value is :         -5.671875        ( --> -6.384052276611328)
# fixed mul value is      :     -6.3702392578125
# error is                :      69.83642578125
# ------------------------------------------------------------------------------------------
# act value is            :        3.17578125        ( --> 3.1981201171875)
# wei value is            :        -2.93359375       ( --> -2.841796875)
# stochastic mul value is :        -8.51171875       ( --> -9.088407516479492)
# fixed mul value is      :    -9.316452026367188
# error is                :     80.47332763671875
# ------------------------------------------------------------------------------------------
# act value is            :        0.08203125        ( --> 0.0780029296875)
# wei value is            :        2.26171875        ( --> 2.2734375)
# stochastic mul value is :         0.3515625        ( --> 0.17733478546142578)
# fixed mul value is      :    0.1855316162109375
# error is                :     16.60308837890625
# ------------------------------------------------------------------------------------------
# act value is            :        -1.26171875       ( --> -1.248046875)
# wei value is            :          0.9375          ( --> 1.13671875)
# stochastic mul value is :        -1.41796875       ( --> -1.4186782836914062)
# fixed mul value is      :      -1.182861328125
# error is                :       23.5107421875
# ------------------------------------------------------------------------------------------
# act value is            :         -0.09375         ( --> -0.0780029296875)
# wei value is            :        2.14453125        ( --> 2.2734375)
# stochastic mul value is :            0.0           ( --> -0.17733478546142578)
# fixed mul value is      :     -0.2010498046875
# error is                :      20.10498046875
# ------------------------------------------------------------------------------------------
# act value is            :        0.90234375        ( --> 0.93603515625)
# wei value is            :         -0.953125        ( --> -0.8525390625)
# stochastic mul value is :            0.0           ( --> -0.798006534576416)
# fixed mul value is      :     -0.86004638671875
# error is                :      86.004638671875
# ------------------------------------------------------------------------------------------
# act value is            :           -1.0           ( --> -0.93603515625)
# wei value is            :         1.1796875        ( --> 1.4208984375)
# stochastic mul value is :            0.0           ( --> -1.3300108909606934)
# fixed mul value is      :        -1.1796875
# error is                :         117.96875
# ------------------------------------------------------------------------------------------
# act value is            :         -1.140625        ( --> -1.092041015625)
# wei value is            :         2.484375         ( --> 2.5576171875)
# stochastic mul value is :          -2.125          ( --> -2.793022871017456)
# fixed mul value is      :      -2.833740234375
# error is                :       70.8740234375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.1796875        ( --> -2.1060791015625)
# wei value is            :        0.62890625        ( --> 0.8525390625)
# stochastic mul value is :            0.0           ( --> -1.795514702796936)
# fixed mul value is      :    -1.370819091796875
# error is                :     137.0819091796875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.70703125       ( --> -1.6380615234375)
# wei value is            :         -1.84375         ( --> -1.705078125)
# stochastic mul value is :        4.25390625        ( --> 2.793022871017456)
# fixed mul value is      :      3.1473388671875
# error is                :      110.65673828125
# ------------------------------------------------------------------------------------------
# act value is            :         2.9609375        ( --> 2.964111328125)
# wei value is            :        -2.8515625        ( --> -2.841796875)
# stochastic mul value is :        -7.80078125       ( --> -8.423402786254883)
# fixed mul value is      :     -8.44329833984375
# error is                :      64.251708984375
# ------------------------------------------------------------------------------------------
# act value is            :         -3.484375        ( --> -3.43212890625)
# wei value is            :        3.33203125        ( --> 3.41015625)
# stochastic mul value is :       -11.34765625       ( --> -11.704095840454102)
# fixed mul value is      :    -11.61004638671875
# error is                :      26.239013671875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.55859375       ( --> -0.5460205078125)
# wei value is            :         1.984375         ( --> 1.9892578125)
# stochastic mul value is :            0.0           ( --> -1.086175560951233)
# fixed mul value is      :     -1.10845947265625
# error is                :     110.845947265625
# ------------------------------------------------------------------------------------------
# act value is            :        0.37890625        ( --> 0.3900146484375)
# wei value is            :        1.32421875        ( --> 1.4208984375)
# stochastic mul value is :        1.41796875        ( --> 0.5541712045669556)
# fixed mul value is      :    0.5017547607421875
# error is                :     91.62139892578125
# ------------------------------------------------------------------------------------------
# act value is            :        3.77734375        ( --> 3.8221435546875)
# wei value is            :         2.2421875        ( --> 2.2734375)
# stochastic mul value is :        8.86328125        ( --> 8.689404487609863)
# fixed mul value is      :     8.469512939453125
# error is                :     39.3768310546875
# ------------------------------------------------------------------------------------------
# act value is            :        1.75390625        ( --> 1.7940673828125)
# wei value is            :          0.4375          ( --> 0.568359375)
# stochastic mul value is :        1.41796875        ( --> 1.0196750164031982)
# fixed mul value is      :      0.767333984375
# error is                :       65.0634765625
# ------------------------------------------------------------------------------------------
# act value is            :          1.21875         ( --> 1.248046875)
# wei value is            :         2.078125         ( --> 2.2734375)
# stochastic mul value is :         2.8359375        ( --> 2.8373565673828125)
# fixed mul value is      :       2.53271484375
# error is                :       30.322265625
# ------------------------------------------------------------------------------------------
# act value is            :          -2.375          ( --> -2.340087890625)
# wei value is            :        -0.44140625       ( --> -0.2841796875)
# stochastic mul value is :        1.41796875        ( --> 0.6650054454803467)
# fixed mul value is      :       1.04833984375
# error is                :       36.962890625
# ------------------------------------------------------------------------------------------
# act value is            :          3.78125         ( --> 3.8221435546875)
# wei value is            :           0.125          ( --> 0.2841796875)
# stochastic mul value is :        1.41796875        ( --> 1.086175560951233)
# fixed mul value is      :        0.47265625
# error is                :         94.53125
# ------------------------------------------------------------------------------------------
# act value is            :         1.9140625        ( --> 1.9500732421875)
# wei value is            :         -2.90625         ( --> -2.841796875)
# stochastic mul value is :         -4.609375        ( --> -5.541711807250977)
# fixed mul value is      :      -5.562744140625
# error is                :       95.3369140625
# ------------------------------------------------------------------------------------------
# act value is            :         1.296875         ( --> 1.3260498046875)
# wei value is            :         0.1484375        ( --> 0.2841796875)
# stochastic mul value is :        1.41796875        ( --> 0.3768364191055298)
# fixed mul value is      :      0.1925048828125
# error is                :      122.54638671875
# ------------------------------------------------------------------------------------------
# act value is            :        1.57421875        ( --> 1.56005859375)
# wei value is            :         0.328125         ( --> 0.568359375)
# stochastic mul value is :        1.41796875        ( --> 0.8866739273071289)
# fixed mul value is      :     0.51654052734375
# error is                :      90.142822265625
# ------------------------------------------------------------------------------------------
# act value is            :        3.80078125        ( --> 3.8221435546875)
# wei value is            :         -2.78125         ( --> -2.5576171875)
# stochastic mul value is :        -8.51171875       ( --> -9.775580406188965)
# fixed mul value is      :     -10.5709228515625
# error is                :      205.92041015625
# ------------------------------------------------------------------------------------------
# act value is            :         3.2109375        ( --> 3.1981201171875)
# wei value is            :        3.33984375        ( --> 3.41015625)
# stochastic mul value is :         11.703125        ( --> 10.906089782714844)
# fixed mul value is      :    10.724029541015625
# error is                :     97.9095458984375
# ------------------------------------------------------------------------------------------
# act value is            :         0.390625         ( --> 0.3900146484375)
# wei value is            :         -0.671875        ( --> -0.568359375)
# stochastic mul value is :            0.0           ( --> -0.22166848182678223)
# fixed mul value is      :      -0.262451171875
# error is                :       26.2451171875
# ------------------------------------------------------------------------------------------
# act value is            :        0.01171875        ( --> 0.0)
# wei value is            :         0.4609375        ( --> 0.568359375)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :     0.005401611328125
# error is                :      0.5401611328125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.6015625        ( --> -0.5460205078125)
# wei value is            :         1.7734375        ( --> 1.9892578125)
# stochastic mul value is :            0.0           ( --> -1.086175560951233)
# fixed mul value is      :     -1.06683349609375
# error is                :     106.683349609375
# ------------------------------------------------------------------------------------------
# act value is            :         -1.421875        ( --> -1.404052734375)
# wei value is            :        -1.25390625       ( --> -1.13671875)
# stochastic mul value is :           2.125          ( --> 1.596013069152832)
# fixed mul value is      :     1.78289794921875
# error is                :      34.210205078125
# ------------------------------------------------------------------------------------------
# act value is            :        3.76953125        ( --> 3.8221435546875)
# wei value is            :        -1.44921875       ( --> -1.4208984375)
# stochastic mul value is :        -4.25390625       ( --> -5.430877685546875)
# fixed mul value is      :    -5.4628753662109375
# error is                :    120.89691162109375
# ------------------------------------------------------------------------------------------
# act value is            :          -2.875          ( --> -2.80810546875)
# wei value is            :        -0.56640625       ( --> -0.2841796875)
# stochastic mul value is :        1.41796875        ( --> 0.798006534576416)
# fixed mul value is      :       1.62841796875
# error is                :       21.044921875
# ------------------------------------------------------------------------------------------
# act value is            :          2.3125          ( --> 2.340087890625)
# wei value is            :          1.34375         ( --> 1.4208984375)
# stochastic mul value is :        4.25390625        ( --> 3.3250272274017334)
# fixed mul value is      :        3.107421875
# error is                :        114.6484375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.6171875        ( --> -3.588134765625)
# wei value is            :        0.24609375        ( --> 0.2841796875)
# stochastic mul value is :            0.0           ( --> -1.0196750164031982)
# fixed mul value is      :    -0.890167236328125
# error is                :     89.0167236328125
# ------------------------------------------------------------------------------------------
# act value is            :        -2.8671875        ( --> -2.80810546875)
# wei value is            :        4.44140625        ( --> 4.546875)
# stochastic mul value is :        -12.765625        ( --> -12.768104553222656)
# fixed mul value is      :    -12.734344482421875
# error is                :      3.1280517578125
# ------------------------------------------------------------------------------------------
# act value is            :         4.4140625        ( --> 4.4461669921875)
# wei value is            :         3.734375         ( --> 3.978515625)
# stochastic mul value is :         18.796875        ( --> 17.689144134521484)
# fixed mul value is      :     16.4837646484375
# error is                :      231.31103515625
# ------------------------------------------------------------------------------------------
# act value is            :        1.33203125        ( --> 1.3260498046875)
# wei value is            :        2.16015625        ( --> 2.2734375)
# stochastic mul value is :        3.19140625        ( --> 3.0146913528442383)
# fixed mul value is      :    2.8773956298828125
# error is                :     31.40106201171875
# ------------------------------------------------------------------------------------------
# act value is            :         -0.21875         ( --> -0.156005859375)
# wei value is            :        -2.36328125       ( --> -2.2734375)
# stochastic mul value is :        0.70703125        ( --> 0.35466957092285156)
# fixed mul value is      :      0.5169677734375
# error is                :      19.00634765625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.91796875       ( --> -0.8580322265625)
# wei value is            :        3.51953125        ( --> 3.6943359375)
# stochastic mul value is :        -2.48046875       ( --> -3.1698594093322754)
# fixed mul value is      :    -3.2308197021484375
# error is                :     75.03509521484375
# ------------------------------------------------------------------------------------------
# act value is            :        1.63671875        ( --> 1.6380615234375)
# wei value is            :         2.3671875        ( --> 2.5576171875)
# stochastic mul value is :         5.671875         ( --> 4.1895341873168945)
# fixed mul value is      :     3.874420166015625
# error is                :     179.7454833984375
# ------------------------------------------------------------------------------------------
# act value is            :        4.94921875        ( --> 4.9921875)
# wei value is            :         2.484375         ( --> 2.5576171875)
# stochastic mul value is :         12.765625        ( --> 12.768104553222656)
# fixed mul value is      :     12.29571533203125
# error is                :      46.990966796875
# ------------------------------------------------------------------------------------------
# act value is            :        -2.16796875       ( --> -2.1060791015625)
# wei value is            :         2.140625         ( --> 2.2734375)
# stochastic mul value is :        -4.25390625       ( --> -4.788039207458496)
# fixed mul value is      :     -4.64080810546875
# error is                :      38.690185546875
# ------------------------------------------------------------------------------------------
# act value is            :          -2.6875         ( --> -2.652099609375)
# wei value is            :          0.96875         ( --> 1.13671875)
# stochastic mul value is :        -2.8359375        ( --> -3.0146913528442383)
# fixed mul value is      :       -2.603515625
# error is                :        23.2421875
# ------------------------------------------------------------------------------------------
# act value is            :           0.625          ( --> 0.6240234375)
# wei value is            :        -0.8515625        ( --> -0.8525390625)
# stochastic mul value is :            0.0           ( --> -0.5320043563842773)
# fixed mul value is      :       -0.5322265625
# error is                :        53.22265625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.3203125        ( --> -0.31201171875)
# wei value is            :        -0.1953125        ( --> -0.0)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :     0.06256103515625
# error is                :      6.256103515625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.71484375       ( --> -0.7020263671875)
# wei value is            :        4.39453125        ( --> 4.546875)
# stochastic mul value is :        -3.19140625       ( --> -3.192026138305664)
# fixed mul value is      :    -3.1414031982421875
# error is                :     5.00030517578125
# ------------------------------------------------------------------------------------------
# act value is            :        0.41796875        ( --> 0.468017578125)
# wei value is            :        2.41015625        ( --> 2.5576171875)
# stochastic mul value is :           2.125          ( --> 1.197009801864624)
# fixed mul value is      :    1.0073699951171875
# error is                :    111.76300048828125
# ------------------------------------------------------------------------------------------
# act value is            :          3.28125         ( --> 3.276123046875)
# wei value is            :         -1.59375         ( --> -1.4208984375)
# stochastic mul value is :        -2.8359375        ( --> -4.655037879943848)
# fixed mul value is      :       -5.2294921875
# error is                :       239.35546875
# ------------------------------------------------------------------------------------------
# act value is            :        0.63671875        ( --> 0.6240234375)
# wei value is            :        -1.5078125        ( --> -1.4208984375)
# stochastic mul value is :            0.0           ( --> -0.8866739273071289)
# fixed mul value is      :    -0.960052490234375
# error is                :     96.0052490234375
# ------------------------------------------------------------------------------------------
# act value is            :         2.9921875        ( --> 3.0421142578125)
# wei value is            :        1.69140625        ( --> 1.705078125)
# stochastic mul value is :         5.671875         ( --> 5.187042236328125)
# fixed mul value is      :     5.061004638671875
# error is                :     61.0870361328125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.88671875       ( --> -1.8720703125)
# wei value is            :         4.015625         ( --> 4.2626953125)
# stochastic mul value is :        -7.08984375       ( --> -7.98006534576416)
# fixed mul value is      :     -7.57635498046875
# error is                :      48.651123046875
# ------------------------------------------------------------------------------------------
# act value is            :        1.76953125        ( --> 1.7940673828125)
# wei value is            :         3.9453125        ( --> 3.978515625)
# stochastic mul value is :          8.15625         ( --> 7.137724876403809)
# fixed mul value is      :     6.981353759765625
# error is                :     117.4896240234375
# ------------------------------------------------------------------------------------------
# act value is            :          -3.1875         ( --> -3.1201171875)
# wei value is            :         0.6171875        ( --> 0.8525390625)
# stochastic mul value is :        -1.41796875       ( --> -2.6600217819213867)
# fixed mul value is      :      -1.96728515625
# error is                :       54.931640625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.20703125       ( --> -0.156005859375)
# wei value is            :          -2.6875         ( --> -2.5576171875)
# stochastic mul value is :        0.70703125        ( --> 0.399003267288208)
# fixed mul value is      :      0.556396484375
# error is                :       15.0634765625
# ------------------------------------------------------------------------------------------
# act value is            :        3.27734375        ( --> 3.276123046875)
# wei value is            :        -1.71484375       ( --> -1.705078125)
# stochastic mul value is :        -4.25390625       ( --> -5.586045742034912)
# fixed mul value is      :    -5.6201324462890625
# error is                :    136.62261962890625
# ------------------------------------------------------------------------------------------
# act value is            :            0.5           ( --> 0.5460205078125)
# wei value is            :        2.37890625        ( --> 2.5576171875)
# stochastic mul value is :        2.48046875        ( --> 1.396511435508728)
# fixed mul value is      :        1.189453125
# error is                :        129.1015625
# ------------------------------------------------------------------------------------------
# act value is            :        0.98046875        ( --> 1.0140380859375)
# wei value is            :        -1.1640625        ( --> -1.13671875)
# stochastic mul value is :        -0.3515625        ( --> -1.1526761054992676)
# fixed mul value is      :    -1.141326904296875
# error is                :     78.9764404296875
# ------------------------------------------------------------------------------------------
# act value is            :         -1.703125        ( --> -1.6380615234375)
# wei value is            :         3.734375         ( --> 3.978515625)
# stochastic mul value is :        -6.02734375       ( --> -6.517053604125977)
# fixed mul value is      :      -6.360107421875
# error is                :       33.2763671875
# ------------------------------------------------------------------------------------------
# act value is            :        1.95703125        ( --> 1.9500732421875)
# wei value is            :        2.76953125        ( --> 2.841796875)
# stochastic mul value is :        6.02734375        ( --> 5.541711807250977)
# fixed mul value is      :    5.4200592041015625
# error is                :     60.72845458984375
# ------------------------------------------------------------------------------------------
# act value is            :         1.8671875        ( --> 1.8720703125)
# wei value is            :        -0.72265625       ( --> -0.568359375)
# stochastic mul value is :            0.0           ( --> -1.0640087127685547)
# fixed mul value is      :    -1.349334716796875
# error is                :     134.9334716796875
# ------------------------------------------------------------------------------------------
# act value is            :        2.05859375        ( --> 2.1060791015625)
# wei value is            :        -1.47265625       ( --> -1.4208984375)
# stochastic mul value is :        -1.41796875       ( --> -2.9925246238708496)
# fixed mul value is      :    -3.0316009521484375
# error is                :    161.36322021484375
# ------------------------------------------------------------------------------------------
# act value is            :         4.296875         ( --> 4.2901611328125)
# wei value is            :        -0.2109375        ( --> -0.0)
# stochastic mul value is :            0.0           ( --> -0.0)
# fixed mul value is      :     -0.9063720703125
# error is                :      90.63720703125
# ------------------------------------------------------------------------------------------
# act value is            :         -3.53125         ( --> -3.5101318359375)
# wei value is            :        0.19921875        ( --> 0.2841796875)
# stochastic mul value is :            0.0           ( --> -0.99750816822052)
# fixed mul value is      :     -0.7034912109375
# error is                :      70.34912109375
# ------------------------------------------------------------------------------------------
# act value is            :        0.61328125        ( --> 0.6240234375)
# wei value is            :        0.19921875        ( --> 0.2841796875)
# stochastic mul value is :        1.41796875        ( --> 0.17733478546142578)
# fixed mul value is      :    0.1221771240234375
# error is                :    129.57916259765625
# ------------------------------------------------------------------------------------------
# act value is            :        2.25390625        ( --> 2.2620849609375)
# wei value is            :         0.984375         ( --> 1.13671875)
# stochastic mul value is :         2.8359375        ( --> 2.571354389190674)
# fixed mul value is      :     2.21868896484375
# error is                :      61.724853515625
# ------------------------------------------------------------------------------------------
# act value is            :        0.37109375        ( --> 0.3900146484375)
# wei value is            :         0.5078125        ( --> 0.568359375)
# stochastic mul value is :        1.41796875        ( --> 0.22166848182678223)
# fixed mul value is      :     0.188446044921875
# error is                :     122.9522705078125
# ------------------------------------------------------------------------------------------
# act value is            :        1.59765625        ( --> 1.6380615234375)
# wei value is            :         0.8828125        ( --> 1.13671875)
# stochastic mul value is :         2.8359375        ( --> 1.8620152473449707)
# fixed mul value is      :     1.410430908203125
# error is                :     142.5506591796875
# ------------------------------------------------------------------------------------------
# act value is            :         1.6640625        ( --> 1.716064453125)
# wei value is            :        -0.9609375        ( --> -0.8525390625)
# stochastic mul value is :            0.0           ( --> -1.4630119800567627)
# fixed mul value is      :     -1.59906005859375
# error is                :     159.906005859375
# ------------------------------------------------------------------------------------------
# act value is            :         -2.984375        ( --> -2.964111328125)
# wei value is            :        -1.42578125       ( --> -1.4208984375)
# stochastic mul value is :         5.671875         ( --> 4.211701393127441)
# fixed mul value is      :     4.25506591796875
# error is                :     141.680908203125
# ------------------------------------------------------------------------------------------
# act value is            :         -2.515625        ( --> -2.49609375)
# wei value is            :         2.421875         ( --> 2.5576171875)
# stochastic mul value is :         -5.671875        ( --> -6.384052276611328)
# fixed mul value is      :      -6.092529296875
# error is                :       42.0654296875
# ------------------------------------------------------------------------------------------
# act value is            :        0.57421875        ( --> 0.6240234375)
# wei value is            :         -1.359375        ( --> -1.13671875)
# stochastic mul value is :            0.0           ( --> -0.7093391418457031)
# fixed mul value is      :     -0.78057861328125
# error is                :      78.057861328125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.2109375        ( --> -0.156005859375)
# wei value is            :         0.8359375        ( --> 0.8525390625)
# stochastic mul value is :            0.0           ( --> -0.13300108909606934)
# fixed mul value is      :     -0.17633056640625
# error is                :      17.633056640625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.61328125       ( --> -0.5460205078125)
# wei value is            :         0.1953125        ( --> 0.2841796875)
# stochastic mul value is :            0.0           ( --> -0.15516793727874756)
# fixed mul value is      :    -0.119781494140625
# error is                :     11.9781494140625
# ------------------------------------------------------------------------------------------
# act value is            :        3.83203125        ( --> 3.8221435546875)
# wei value is            :        1.60546875        ( --> 1.705078125)
# stochastic mul value is :         7.4453125        ( --> 6.517053604125977)
# fixed mul value is      :    6.1522064208984375
# error is                :    129.31060791015625
# ------------------------------------------------------------------------------------------
# act value is            :        -3.54296875       ( --> -3.5101318359375)
# wei value is            :          0.96875         ( --> 1.13671875)
# stochastic mul value is :        -3.19140625       ( --> -3.99003267288208)
# fixed mul value is      :     -3.4322509765625
# error is                :      24.08447265625
# ------------------------------------------------------------------------------------------
# act value is            :        2.12890625        ( --> 2.18408203125)
# wei value is            :          0.6875          ( --> 0.8525390625)
# stochastic mul value is :         2.8359375        ( --> 1.8620152473449707)
# fixed mul value is      :      1.463623046875
# error is                :      137.2314453125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.6171875        ( --> -0.5460205078125)
# wei value is            :        -0.7421875        ( --> -0.568359375)
# stochastic mul value is :        1.41796875        ( --> 0.3103358745574951)
# fixed mul value is      :     0.45806884765625
# error is                :      95.989990234375
# ------------------------------------------------------------------------------------------
# act value is            :           -1.5           ( --> -1.4820556640625)
# wei value is            :         2.734375         ( --> 2.841796875)
# stochastic mul value is :        -2.8359375        ( --> -4.211701393127441)
# fixed mul value is      :        -4.1015625
# error is                :         126.5625
# ------------------------------------------------------------------------------------------
# act value is            :        0.05859375        ( --> 0.0780029296875)
# wei value is            :         0.3984375        ( --> 0.568359375)
# stochastic mul value is :         0.3515625        ( --> 0.044333696365356445)
# fixed mul value is      :     0.023345947265625
# error is                :     32.8216552734375
# ------------------------------------------------------------------------------------------
# act value is            :        0.79296875        ( --> 0.780029296875)
# wei value is            :         1.203125         ( --> 1.4208984375)
# stochastic mul value is :           2.125          ( --> 1.1083424091339111)
# fixed mul value is      :     0.95404052734375
# error is                :     117.095947265625
# ------------------------------------------------------------------------------------------
# act value is            :          4.28125         ( --> 4.2901611328125)
# wei value is            :         1.8515625        ( --> 1.9892578125)
# stochastic mul value is :         9.9296875        ( --> 8.534236907958984)
# fixed mul value is      :      7.927001953125
# error is                :      200.2685546875
# ------------------------------------------------------------------------------------------
# act value is            :         0.9765625        ( --> 1.0140380859375)
# wei value is            :          -2.9375         ( --> -2.841796875)
# stochastic mul value is :        -1.76953125       ( --> -2.881690263748169)
# fixed mul value is      :      -2.86865234375
# error is                :       109.912109375
# ------------------------------------------------------------------------------------------
# act value is            :         0.0078125        ( --> 0.0)
# wei value is            :        1.04296875        ( --> 1.13671875)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :     0.008148193359375
# error is                :      0.8148193359375
# ------------------------------------------------------------------------------------------
# act value is            :          2.28125         ( --> 2.340087890625)
# wei value is            :         1.546875         ( --> 1.705078125)
# stochastic mul value is :        4.25390625        ( --> 3.99003267288208)
# fixed mul value is      :       3.52880859375
# error is                :       72.509765625
# ------------------------------------------------------------------------------------------
# act value is            :        -3.83203125       ( --> -3.8221435546875)
# wei value is            :        -0.69921875       ( --> -0.568359375)
# stochastic mul value is :         2.8359375        ( --> 2.172351121902466)
# fixed mul value is      :    2.6794281005859375
# error is                :     15.65093994140625
# ------------------------------------------------------------------------------------------
# act value is            :        4.45703125        ( --> 4.4461669921875)
# wei value is            :        1.01953125        ( --> 1.13671875)
# stochastic mul value is :         5.671875         ( --> 5.054041385650635)
# fixed mul value is      :    4.5440826416015625
# error is                :    112.77923583984375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.37109375       ( --> -3.3541259765625)
# wei value is            :        0.05859375        ( --> 0.2841796875)
# stochastic mul value is :            0.0           ( --> -0.9531744718551636)
# fixed mul value is      :    -0.1975250244140625
# error is                :     19.75250244140625
# ------------------------------------------------------------------------------------------
# act value is            :        1.35546875        ( --> 1.404052734375)
# wei value is            :        1.80859375        ( --> 1.9892578125)
# stochastic mul value is :        3.54296875        ( --> 2.793022871017456)
# fixed mul value is      :    2.4514923095703125
# error is                :    109.14764404296875
# ------------------------------------------------------------------------------------------
# act value is            :         1.0078125        ( --> 1.0140380859375)
# wei value is            :        3.82421875        ( --> 3.978515625)
# stochastic mul value is :         4.609375         ( --> 4.034366607666016)
# fixed mul value is      :     3.854095458984375
# error is                :     75.5279541015625
# ------------------------------------------------------------------------------------------
# act value is            :          -0.875          ( --> -0.8580322265625)
# wei value is            :        -1.47265625       ( --> -1.4208984375)
# stochastic mul value is :        2.48046875        ( --> 1.2191766500473022)
# fixed mul value is      :       1.28857421875
# error is                :       119.189453125
# ------------------------------------------------------------------------------------------
# act value is            :        0.53515625        ( --> 0.5460205078125)
# wei value is            :        -2.28515625       ( --> -2.2734375)
# stochastic mul value is :          -1.0625         ( --> -1.2413434982299805)
# fixed mul value is      :    -1.2229156494140625
# error is                :     16.04156494140625
# ------------------------------------------------------------------------------------------
# act value is            :         1.6484375        ( --> 1.6380615234375)
# wei value is            :        3.99609375        ( --> 4.2626953125)
# stochastic mul value is :         7.4453125        ( --> 6.98255729675293)
# fixed mul value is      :     6.587310791015625
# error is                :     85.8001708984375
# ------------------------------------------------------------------------------------------
# act value is            :        0.61328125        ( --> 0.6240234375)
# wei value is            :        1.71484375        ( --> 1.705078125)
# stochastic mul value is :        1.41796875        ( --> 1.0640087127685547)
# fixed mul value is      :    1.0516815185546875
# error is                :     36.62872314453125
# ------------------------------------------------------------------------------------------
# act value is            :         2.2578125        ( --> 2.2620849609375)
# wei value is            :        0.77734375        ( --> 0.8525390625)
# stochastic mul value is :         2.8359375        ( --> 1.9285157918930054)
# fixed mul value is      :     1.755096435546875
# error is                :     108.0841064453125
# ------------------------------------------------------------------------------------------
# act value is            :          1.21875         ( --> 1.248046875)
# wei value is            :        0.23828125        ( --> 0.2841796875)
# stochastic mul value is :        1.41796875        ( --> 0.35466957092285156)
# fixed mul value is      :      0.2904052734375
# error is                :      112.75634765625
# ------------------------------------------------------------------------------------------
# act value is            :          0.09375         ( --> 0.156005859375)
# wei value is            :        -0.0703125        ( --> -0.0)
# stochastic mul value is :            0.0           ( --> -0.0)
# fixed mul value is      :      -0.006591796875
# error is                :       0.6591796875
# ------------------------------------------------------------------------------------------
# act value is            :        -2.9453125        ( --> -2.8861083984375)
# wei value is            :         2.890625         ( --> 3.1259765625)
# stochastic mul value is :        -7.4453125        ( --> -9.021906852722168)
# fixed mul value is      :     -8.5137939453125
# error is                :      106.84814453125
# ------------------------------------------------------------------------------------------
# act value is            :        2.81640625        ( --> 2.80810546875)
# wei value is            :        -2.6953125        ( --> -2.5576171875)
# stochastic mul value is :         -5.671875        ( --> -7.182058811187744)
# fixed mul value is      :    -7.591094970703125
# error is                :     191.9219970703125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.65234375       ( --> -1.6380615234375)
# wei value is            :        0.16796875        ( --> 0.2841796875)
# stochastic mul value is :            0.0           ( --> -0.4655038118362427)
# fixed mul value is      :    -0.2775421142578125
# error is                :     27.75421142578125
# ------------------------------------------------------------------------------------------
# act value is            :        -2.86328125       ( --> -2.80810546875)
# wei value is            :         4.546875         ( --> 0.0)
# stochastic mul value is :            0.0           ( --> -0.0)
# fixed mul value is      :    -13.01898193359375
# error is                :     1301.898193359375
# ------------------------------------------------------------------------------------------
# act value is            :         0.328125         ( --> 0.31201171875)
# wei value is            :         3.796875         ( --> 3.978515625)
# stochastic mul value is :        1.41796875        ( --> 1.2413434982299805)
# fixed mul value is      :      1.245849609375
# error is                :       17.2119140625
# ------------------------------------------------------------------------------------------
# act value is            :        2.12890625        ( --> 2.18408203125)
# wei value is            :        1.25390625        ( --> 1.4208984375)
# stochastic mul value is :        4.25390625        ( --> 3.103358745574951)
# fixed mul value is      :    2.6694488525390625
# error is                :    158.44573974609375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.1328125        ( --> -0.0780029296875)
# wei value is            :        0.41796875        ( --> 0.568359375)
# stochastic mul value is :            0.0           ( --> -0.044333696365356445)
# fixed mul value is      :    -0.055511474609375
# error is                :      5.5511474609375
# ------------------------------------------------------------------------------------------
# act value is            :          3.0625          ( --> 3.1201171875)
# wei value is            :        0.84765625        ( --> 0.8525390625)
# stochastic mul value is :        4.25390625        ( --> 2.6600217819213867)
# fixed mul value is      :      2.595947265625
# error is                :      165.7958984375
# ------------------------------------------------------------------------------------------
# act value is            :        1.23046875        ( --> 1.248046875)
# wei value is            :        -1.13671875       ( --> -1.13671875)
# stochastic mul value is :        -1.41796875       ( --> -1.4186782836914062)
# fixed mul value is      :    -1.3986968994140625
# error is                :     1.92718505859375
# ------------------------------------------------------------------------------------------
# act value is            :          0.21875         ( --> 0.2340087890625)
# wei value is            :        1.95703125        ( --> 1.9892578125)
# stochastic mul value is :          1.0625          ( --> 0.4655038118362427)
# fixed mul value is      :      0.4281005859375
# error is                :      63.43994140625
# ------------------------------------------------------------------------------------------
# act value is            :        1.11328125        ( --> 1.1700439453125)
# wei value is            :        -2.78515625       ( --> -2.5576171875)
# stochastic mul value is :        -2.48046875       ( --> -2.9925246238708496)
# fixed mul value is      :    -3.1006622314453125
# error is                :     62.01934814453125
# ------------------------------------------------------------------------------------------
# act value is            :        1.94140625        ( --> 1.9500732421875)
# wei value is            :         0.4921875        ( --> 0.568359375)
# stochastic mul value is :        1.41796875        ( --> 1.1083424091339111)
# fixed mul value is      :     0.955535888671875
# error is                :     46.2432861328125
# ------------------------------------------------------------------------------------------
# act value is            :        2.76953125        ( --> 2.80810546875)
# wei value is            :        0.17578125        ( --> 0.2841796875)
# stochastic mul value is :        1.41796875        ( --> 0.798006534576416)
# fixed mul value is      :    0.4868316650390625
# error is                :     93.11370849609375
# ------------------------------------------------------------------------------------------
# act value is            :         2.6953125        ( --> 2.7301025390625)
# wei value is            :         1.734375         ( --> 1.9892578125)
# stochastic mul value is :        6.73828125        ( --> 5.430877685546875)
# fixed mul value is      :      4.6746826171875
# error is                :      206.35986328125
# ------------------------------------------------------------------------------------------
# act value is            :        2.29296875        ( --> 2.340087890625)
# wei value is            :        -2.83984375       ( --> -2.5576171875)
# stochastic mul value is :        -4.96484375       ( --> -5.985049247741699)
# fixed mul value is      :    -6.5116729736328125
# error is                :    154.68292236328125
# ------------------------------------------------------------------------------------------
# act value is            :          0.5625          ( --> 0.6240234375)
# wei value is            :        -0.73828125       ( --> -0.568359375)
# stochastic mul value is :            0.0           ( --> -0.35466957092285156)
# fixed mul value is      :      -0.415283203125
# error is                :       41.5283203125
# ------------------------------------------------------------------------------------------
# act value is            :        0.01953125        ( --> 0.0780029296875)
# wei value is            :         -1.328125        ( --> -1.13671875)
# stochastic mul value is :            0.0           ( --> -0.08866739273071289)
# fixed mul value is      :     -0.02593994140625
# error is                :      2.593994140625
# ------------------------------------------------------------------------------------------
# act value is            :        -2.35546875       ( --> -2.340087890625)
# wei value is            :        -1.30859375       ( --> -1.13671875)
# stochastic mul value is :         2.8359375        ( --> 2.6600217819213867)
# fixed mul value is      :    3.0823516845703125
# error is                :     24.64141845703125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.30078125       ( --> -1.248046875)
# wei value is            :        0.25390625        ( --> 0.2841796875)
# stochastic mul value is :            0.0           ( --> -0.35466957092285156)
# fixed mul value is      :    -0.3302764892578125
# error is                :     33.02764892578125
# ------------------------------------------------------------------------------------------
# act value is            :        -3.01953125       ( --> -2.964111328125)
# wei value is            :        -0.92578125       ( --> -0.8525390625)
# stochastic mul value is :        4.25390625        ( --> 2.5270206928253174)
# fixed mul value is      :    2.7954254150390625
# error is                :    145.84808349609375
# ------------------------------------------------------------------------------------------
# act value is            :        3.06640625        ( --> 3.1201171875)
# wei value is            :        1.37890625        ( --> 1.4208984375)
# stochastic mul value is :         5.671875         ( --> 4.4333696365356445)
# fixed mul value is      :    4.2282867431640625
# error is                :    144.35882568359375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.49609375       ( --> -2.49609375)
# wei value is            :        -0.75390625       ( --> -0.568359375)
# stochastic mul value is :        1.41796875        ( --> 1.4186782836914062)
# fixed mul value is      :    1.8818206787109375
# error is                :     46.38519287109375
# ------------------------------------------------------------------------------------------
# act value is            :        2.79296875        ( --> 2.80810546875)
# wei value is            :         3.359375         ( --> 3.41015625)
# stochastic mul value is :         9.9296875        ( --> 9.576078414916992)
# fixed mul value is      :     9.38262939453125
# error is                :      54.705810546875
# ------------------------------------------------------------------------------------------
# act value is            :         0.5859375        ( --> 0.6240234375)
# wei value is            :         1.671875         ( --> 1.705078125)
# stochastic mul value is :        1.41796875        ( --> 1.0640087127685547)
# fixed mul value is      :      0.9796142578125
# error is                :      43.83544921875
# ------------------------------------------------------------------------------------------
# act value is            :         -0.078125        ( --> -0.0780029296875)
# wei value is            :        -1.85546875       ( --> -1.705078125)
# stochastic mul value is :         0.3515625        ( --> 0.13300108909606934)
# fixed mul value is      :     0.14495849609375
# error is                :      20.660400390625
# ------------------------------------------------------------------------------------------
# act value is            :         0.3515625        ( --> 0.3900146484375)
# wei value is            :        -0.8671875        ( --> -0.8525390625)
# stochastic mul value is :            0.0           ( --> -0.33250272274017334)
# fixed mul value is      :     -0.30487060546875
# error is                :      30.487060546875
# ------------------------------------------------------------------------------------------
# act value is            :        -3.3359375        ( --> -3.276123046875)
# wei value is            :        -0.8515625        ( --> -0.568359375)
# stochastic mul value is :         2.8359375        ( --> 1.8620152473449707)
# fixed mul value is      :     2.84075927734375
# error is                :      0.482177734375
# ------------------------------------------------------------------------------------------
# act value is            :         4.9921875        ( --> 0.0)
# wei value is            :          0.03125         ( --> 0.2841796875)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :      0.156005859375
# error is                :       15.6005859375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.0546875        ( --> -2.028076171875)
# wei value is            :        -1.1015625        ( --> -0.8525390625)
# stochastic mul value is :         2.8359375        ( --> 1.7290141582489014)
# fixed mul value is      :     2.26336669921875
# error is                :      57.257080078125
# ------------------------------------------------------------------------------------------
# act value is            :         -2.546875        ( --> -2.49609375)
# wei value is            :         -0.046875        ( --> -0.0)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :      0.119384765625
# error is                :       11.9384765625
# ------------------------------------------------------------------------------------------
# act value is            :        -2.08203125       ( --> -2.028076171875)
# wei value is            :        1.62109375        ( --> 1.705078125)
# stochastic mul value is :        -2.8359375        ( --> -3.4580283164978027)
# fixed mul value is      :    -3.3751678466796875
# error is                :     53.92303466796875
# ------------------------------------------------------------------------------------------
# act value is            :        -2.8828125        ( --> -2.80810546875)
# wei value is            :          2.03125         ( --> 2.2734375)
# stochastic mul value is :         -5.671875        ( --> -6.384052276611328)
# fixed mul value is      :      -5.855712890625
# error is                :       18.3837890625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.47265625       ( --> -0.468017578125)
# wei value is            :        1.39453125        ( --> 1.4208984375)
# stochastic mul value is :            0.0           ( --> -0.6650054454803467)
# fixed mul value is      :    -0.6591339111328125
# error is                :     65.91339111328125
# ------------------------------------------------------------------------------------------
# act value is            :        -2.45703125       ( --> -2.4180908203125)
# wei value is            :        1.76171875        ( --> 1.9892578125)
# stochastic mul value is :        -3.8984375        ( --> -4.810205936431885)
# fixed mul value is      :    -4.3285980224609375
# error is                :     43.01605224609375
# ------------------------------------------------------------------------------------------
# act value is            :        -1.4453125        ( --> -1.404052734375)
# wei value is            :        0.76953125        ( --> 0.8525390625)
# stochastic mul value is :            0.0           ( --> -1.197009801864624)
# fixed mul value is      :    -1.112213134765625
# error is                :     111.2213134765625
# ------------------------------------------------------------------------------------------
# act value is            :         -0.140625        ( --> -0.0780029296875)
# wei value is            :        -0.26953125       ( --> -0.0)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :     0.03790283203125
# error is                :      3.790283203125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.6484375        ( --> -0.6240234375)
# wei value is            :        -0.80859375       ( --> -0.568359375)
# stochastic mul value is :        1.41796875        ( --> 0.35466957092285156)
# fixed mul value is      :     0.524322509765625
# error is                :     89.3646240234375
# ------------------------------------------------------------------------------------------
# act value is            :        1.44921875        ( --> 1.4820556640625)
# wei value is            :        -0.6796875        ( --> -0.568359375)
# stochastic mul value is :            0.0           ( --> -0.8423402309417725)
# fixed mul value is      :    -0.985015869140625
# error is                :     98.5015869140625
# ------------------------------------------------------------------------------------------
# act value is            :        0.48828125        ( --> 0.5460205078125)
# wei value is            :         0.6796875        ( --> 0.8525390625)
# stochastic mul value is :        1.41796875        ( --> 0.4655038118362427)
# fixed mul value is      :     0.331878662109375
# error is                :     108.6090087890625
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## ERROR

# %%
def MSE(a,b):
    s = 0
    n = 0

    for i in range(10):
        for j in range(15):
            square = (((a[i][j])-b[i][j])**2).item()
            s += square
            n   += 1
    error = s/n
    return error

# %% [markdown]
# ## ERROR : 6bit LFSR

# %%
MSE(act_f*wei_f,cc)
# Out:
# 2.0622238003245243
