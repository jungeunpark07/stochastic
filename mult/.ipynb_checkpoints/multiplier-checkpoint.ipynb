# %% [markdown]
# # Multiplier TEST code

# %% [markdown]
# fixed number to stochastic conversion & multiply & stochastic to fixed number conversion

# %% [markdown]
# ## Import

# %%
import random, struct, math
import torch
import numpy as np
import torch.nn as nn 
import argparse
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Parser

# %%
parser = argparse.ArgumentParser(description='fixed_mac')
parser.add_argument('--full_bits', type=int, default=16, help='Number of Quantization Bits')
parser.add_argument('--frac_bits', type=int, default=8, help='Number of Quantization Bits')
parser.add_argument('--bBW', type=int, default=7, help='Number of bit width')
args = parser.parse_args(args=[])

# %% [markdown]
# ## Definition

# %% [markdown]
# ### int2bin : int number to binary number

# %%
def int2bin(iIn,iBW):
    iBW = iBW + 1
    if iIn >= 0:
        bOut = bin(iIn).replace('0b','').rjust(iBW,'0')
    else :
        bOut = bin(iIn & (pow(2,iBW)-1)).replace('0b','').rjust(iBW,'1')
    return bOut[1:]

# %% [markdown]
# ### XOR : xor gate with string

# %%
def XOR(iA,iB):
    if iA != iB :
        iOut = '1'
    else : 
        iOut = '0'
    return iOut

# %% [markdown]
# ### SNUM : sign number determination

# %%
def snum(a):
    if a >= 0 :
        return '0'
    else :
        return '1'

# %% [markdown]
# ## binInv : binary Inversion

# %%
def binInv(bIn):
    bOut = bin(int(bIn,2)^(pow(2,len(bIn))-1)).replace('0b','').rjust(len(bIn),'0')
    return bOut

# %% [markdown]
# ### fxp & flp2fix : floating number to fixed number conversion

# %%
class fxp:
    def __init__(self, bIn, iBWF):
        self.iFullBW = len(bIn)
        self.iIntgBW = self.iFullBW - iBWF
        self.bSign = bIn[0]
        self.bIntg = bIn[:self.iIntgBW]
        self.bFrac = bIn[self.iIntgBW:]
        self.fFull = 0
        try:
            for idx, bit in enumerate(bIn):
                if idx == 0:
                    self.fFull = self.fFull + int(bit,2) * -pow(2, self.iIntgBW - 1)
                else:
                    self.fFull = self.fFull + int(bit,2) * pow(2, self.iIntgBW - 1 - idx)
        except:
            print(bIn)
        self.dispFull = self.bIntg +"."+ self.bFrac 
        return

# %%
class flp2fix:
    def __init__(self, fIn, iBW, iBWF):
        self.fMin = - 2 ** (iBW - iBWF - 1)
        self.fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
        self.fResol = 2 ** -iBWF
        if fIn < self.fMin or fIn > self.fMax:
            print(f'({fIn}): Out of input range ({self.fMax}/{self.fMin}) during flp -> fix converting ')
        self.iBW = iBW
        self.iBWI = iBW - iBWF
        self.iBWF = iBWF

        self.iFLP2INT = abs(int(fIn * 2 ** iBWF))
        if fIn < 0:
            self.iFLP2INT = 2 ** (iBW-1) - self.iFLP2INT

        if fIn >= 0:
            self.bFull = bin(self.iFLP2INT)[2:].rjust(iBW, '0')
        else:
            self.bFull = '1'+bin(self.iFLP2INT)[2:].rjust(iBW-1, '0')
            if len(self.bFull) > iBW:
                self.bFull = '0' * iBW

        self.cssFxp = fxp(self.bFull, self.iBWF)
        self.bSign = self.cssFxp.bSign
        self.bIntg = self.cssFxp.bIntg
        self.bFrac = self.cssFxp.bFrac
        self.fFull = self.cssFxp.fFull
        return

# %%
def flp2fixTensor(fIn, iBW, iBWF):
    fMin = - 2 ** (iBW - iBWF - 1)
    fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
    fList = []
    for aTensor in fIn.view(-1):
        fList.append(flp2fix(aTensor, iBW, iBWF).fFull)
    return torch.tensor(fList).view(fIn.size())

# %% [markdown]
# ### LFSR : make pseudorandom number bitstream

# %%
class LFSR7:
    def Random(self):
        self.b0 = eval(f'str(random.randint(0,1))')
        self.b1 = eval(f'str(random.randint(0,1))')
        self.b2 = eval(f'str(random.randint(0,1))')
        self.b3 = eval(f'str(random.randint(0,1))')
        self.b4 = eval(f'str(random.randint(0,1))')
        self.b5 = eval(f'str(random.randint(0,1))')
        self.b6 = eval(f'str(random.randint(0,1))')
        if int(self.b0) + int(self.b1) + int(self.b2) + int(self.b3) + int(self.b4) + int(self.b5) + int(self.b6) == 0 :
            self.b0 = eval(f'str(random.randint(0,1))')
            self.b1 = eval(f'str(random.randint(0,1))')
            self.b2 = eval(f'str(random.randint(0,1))')
            self.b3 = eval(f'str(random.randint(0,1))')
            self.b4 = eval(f'str(random.randint(0,1))')
            self.b5 = eval(f'str(random.randint(0,1))')
            self.b6 = eval(f'str(random.randint(0,1))')
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6
    
    def Normal(self,stream):
        self.b0 = XOR(int(stream[5]),int(stream[6]))
        self.b1 = stream[0]
        self.b2 = stream[1]
        self.b3 = stream[2]
        self.b4 = stream[3]
        self.b5 = stream[4]
        self.b6 = stream[5]
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6
    
    def Allzero(self):
        self.b0 = '0'
        self.b1 = '0'
        self.b2 = '0'
        self.b3 = '0'
        self.b4 = '0'
        self.b5 = '0'
        self.b6 = '0'
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5 + self.b6

# %% [markdown]
# ### LFSRlist : make pseudorandom number bitstream with 2**bBW cycle

# %%
def LFSRlist7():
    lfsr = LFSR7()
    lfsrlist = []
    for k in range(2**(args.bBW)-1): #lfsr number generating
        if k == 0:
            lfsrlist.append(lfsr.Random())
        else :
            lfsrlist.append(lfsr.Normal(lfsrlist[k-1]))
        if (k == 2**(args.bBW)-2):
            lfsrlist.append(lfsr.Allzero())
    
    if (args.bBW) != args.frac_bits :
        if args.bBW < args.frac_bits :
            for i in range(len(lfsrlist)):
                lfsrlist[i] = lfsrlist[i] + (args.frac_bits-args.bBW)*'0'
        else :
            print("it can't work")
            return 0
    
    return lfsrlist

# %% [markdown]
# ### Comp : Comparator in SNG

# %%
def Comp(a,lfsr,snum):
    for com in range(0,len(a)):
        oA = '0'
        if a[com]!=lfsr[com]:
            if(int(a[com]) > int(lfsr[com])):
                oA = '1'
            break
    return XOR(oA,snum)

# %% [markdown]
# ### Perm : module for permutation SNG

# %%
def perm(a):
    al = len(a)
    blist = []
    if args.frac_bits == args.bBW : 
        for i in range(al) :
            blist.append(a[al-i-1])
    elif args.frac_bits > args.bBW :
        for i in range(al-(args.frac_bits-args.bBW)) :
            blist.append((a[al-(args.frac_bits-args.bBW)-i-1]))
    b = "".join(blist)
    b = b + ('0'*(args.frac_bits-args.bBW))
    return b

# %% [markdown]
# ### findMaxMin : find abs max value in act tensor

# %%
def findMaxMin(data):
    max = torch.max(data)
    min = torch.min(data)
    SF=torch.max(abs(max),abs(min)).item()
    return SF

# %% [markdown]
# ### SNG : stochastic number generator module

# %%
def SNG(iIN,lfsr):

    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    bFRAC = bIN[-(args.frac_bits):]
    if sNUM == 1 :
        bFRAC = bin(int(binInv(bFRAC),2)+1).replace('0b','').rjust(args.bBW,'0')
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        lNUM = lfsr[k]
        a = Comp(bFRAC,lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if bIN == args.full_bits*'0' :
        return '0'*(2**(args.bBW)+1)
    else :
        return sA

# %% [markdown]
# ### SNG_P : permutation stochastic number generator module

# %%
def SNG_P(iIN,lfsr):
    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    bFRAC = bIN[-(args.frac_bits):]
    if sNUM == 1 :
        bFRAC = bin(int(binInv(bFRAC),2)+1).replace('0b','').rjust(args.bBW,'0')
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating    
        lNUM = perm(lfsr[k])
        a = Comp(bFRAC,lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    
    if bIN == args.full_bits*'0' :
        return '0'*(2**(args.bBW)+1)
    else :
        return sA

# %% [markdown]
# ### SNGnumpy : SNG module with numpy

# %%
def SNGnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG(float(aNumpy),lfsr))
                     
    return np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### SNGpnumpy : permutation SNG module with numpy

# %%
def SNGpnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG_P(float(aNumpy),lfsr))
                     
    return  np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### CountOne : count 1 in stochastic number bit stream

# %%
def CountOne(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        n = 0
        for a in num:
            if a == '1' :
                n += 1
        if num[0] == '1' :
            nlist.append(n-1)
        else :
            nlist.append(n)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### defSign : sign determination in S2N

# %%
def defSign(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        if num[0] == '1' :
            nlist.append(-1)
        else :
            nlist.append(1)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### Multiplier

# %%
def mul(a,b):
    al = len(a)
    bl = len(b)
    
    outlist = []
    
    if al != bl :
        print("length of string is different")
        return 0
    
    outlist.append(XOR(a[0],b[0]))
    
    for i in range(al-1) :
        outlist.append(str(int(a[i+1]) & int(b[i+1])))
    
    #print(outlist)
    out = "".join(outlist)
    
    return out

# %%
def defSign1(nIn):
    if nIn[0] == '1' :
        return -1
    else :
        return 1

# %%
def CountOne1(nIn):
    n = 0
    for num in nIn:
        if num == '1' :
            n += 1
    if nIn[0] == '1' :
        return n-1
    else :
        return n

# %%
def S2None(sIn,SF):
    s = defSign(sIn)
    o = (CountOne(sIn)/(2**args.bBW))*SF*s
    return o

# %%
def mulNumpy(aIn,bIn,aSF,wSF):
    mList = []
    for i in range(aIn.shape[0]):
        for j in range(bIn.T.shape[1]):
            sum = 0
            for k in range(aIn.shape[1]):
                sum += S2None(mul((aIn[i][k].astype(str)),(bIn.T)[k][j].astype(str)),aSF*wSF)
            mList.append(sum)
    return torch.tensor(mList).view(aIn.shape[0],bIn.T.shape[1])

# %%
def FindError(a,b):
    elist = []
    for anum,bnum in zip(a.view(-1),b.view(-1)):
        e = (abs(bnum-anum)*100).item()
        elist.append(e)
    return torch.tensor(elist).reshape(a.size())

# %% [markdown]
# # TEST : LFSR 7 bit

# %%
act = torch.rand((10,15))-torch.randint(5,(10,15))+torch.randint(5,(10,15))
wei = torch.rand((10,15))-torch.randint(5,(10,15))+torch.randint(5,(10,15))

# %%
act_f = flp2fixTensor(act,args.full_bits,args.frac_bits)
wei_f = flp2fixTensor(wei,args.full_bits,args.frac_bits)

# %% [markdown]
# ### number to stochastic conversion

# %%
aSF = findMaxMin(act_f)
wSF = findMaxMin(wei_f)

# %%
def N2S(act,wei,aSF,wSF):
    
    lfsrlist = LFSRlist7()
    
    a = SNGnumpy(act/aSF,lfsrlist)
    w = SNGpnumpy(wei/wSF,lfsrlist)
    
    return a,w

# %% [markdown]
# ### stochastic to number conversion

# %%
def S2N(a,w,aSF,wSF):
    
    sa = defSign(a)
    sw = defSign(w)

    ca = (CountOne(a)/(2**args.bBW)) * aSF *sa
    cw = (CountOne(w)/(2**args.bBW)) * wSF *sw

    return ca,cw

# %%
a,w = N2S(act,wei,aSF,wSF)

# %%
ca,cw = S2N(a,w,aSF,wSF)

# %%
def multest(aIn,wIn,aSF,wSF):
    mlist=[]
    out = 0
    for a,b in zip(aIn.reshape(-1),wIn.reshape(-1)) :
        out = mul(a,b)
        mlist.append(out)
    
    return np.array(mlist).reshape(aIn.shape)

# %%
c = multest(a,w,aSF,wSF)

# %%
cc = flp2fixTensor(S2None(c,aSF*wSF),args.full_bits,args.frac_bits)

# %%
error = FindError(cc,act_f*wei_f)

# %%
print(f'error mean value is : {torch.mean(error)}')
print(f'------------------------------------------------------------------------------------------')
for i in range(10):
    for j in range(15):
        print(f'act value is            : {act_f[i][j]:^25}( --> {ca[i][j]})')
        print(f'wei value is            : {wei_f[i][j]:^25}( --> {cw[i][j]})')
        print(f'stochastic mul value is : {cc[i][j]:^25}( --> {ca[i][j] * cw[i][j]})')
        print(f'fixed mul value is      : {act_f[i][j]*wei_f[i][j]:^25}')
        print(f'error is                : {error[i][j]:^25}')
        print(f'------------------------------------------------------------------------------------------')
# Out:
# error mean value is : 20.02610206604004
# ------------------------------------------------------------------------------------------
# act value is            :         1.171875         ( --> 1.1663818359375)
# wei value is            :         -2.890625        ( --> -2.8773193359375)
# stochastic mul value is :        -3.1796875        ( --> -3.356053113937378)
# fixed mul value is      :      -3.387451171875
# error is                :       20.7763671875
# ------------------------------------------------------------------------------------------
# act value is            :        4.69921875        ( --> 4.70440673828125)
# wei value is            :         -1.453125        ( --> -1.4564208984375)
# stochastic mul value is :        -6.71484375       ( --> -6.851596355438232)
# fixed mul value is      :     -6.82855224609375
# error is                :      11.370849609375
# ------------------------------------------------------------------------------------------
# act value is            :         -1.984375        ( --> -1.98284912109375)
# wei value is            :        4.42578125        ( --> 4.4403076171875)
# stochastic mul value is :        -8.66015625       ( --> -8.804460525512695)
# fixed mul value is      :     -8.78240966796875
# error is                :      12.225341796875
# ------------------------------------------------------------------------------------------
# act value is            :          -0.875          ( --> -0.8553466796875)
# wei value is            :        -0.11328125       ( --> -0.1065673828125)
# stochastic mul value is :        0.17578125        ( --> 0.09115205705165863)
# fixed mul value is      :       0.09912109375
# error is                :        7.666015625
# ------------------------------------------------------------------------------------------
# act value is            :        -1.6640625        ( --> -1.6329345703125)
# wei value is            :         3.8671875        ( --> 3.8719482421875)
# stochastic mul value is :        -6.0078125        ( --> -6.322638034820557)
# fixed mul value is      :     -6.43524169921875
# error is                :      42.742919921875
# ------------------------------------------------------------------------------------------
# act value is            :          0.28125         ( --> 0.27215576171875)
# wei value is            :        0.15234375        ( --> 0.14208984375)
# stochastic mul value is :        0.17578125        ( --> 0.03867056965827942)
# fixed mul value is      :      0.0428466796875
# error is                :      13.29345703125
# ------------------------------------------------------------------------------------------
# act value is            :        2.51953125        ( --> 2.52716064453125)
# wei value is            :        0.51953125        ( --> 0.5328369140625)
# stochastic mul value is :        1.58984375        ( --> 1.346564531326294)
# fixed mul value is      :    1.3089752197265625
# error is                :     28.08685302734375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.84765625       ( --> -0.81646728515625)
# wei value is            :        0.03515625        ( --> 0.0355224609375)
# stochastic mul value is :            0.0           ( --> -0.029002927243709564)
# fixed mul value is      :    -0.0298004150390625
# error is                :     2.98004150390625
# ------------------------------------------------------------------------------------------
# act value is            :         1.4609375        ( --> 1.4774169921875)
# wei value is            :        -0.03515625       ( --> -0.0355224609375)
# stochastic mul value is :            0.0           ( --> -0.05248148739337921)
# fixed mul value is      :    -0.051361083984375
# error is                :      5.1361083984375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.22265625       ( --> -2.21612548828125)
# wei value is            :        -2.16015625       ( --> -2.13134765625)
# stochastic mul value is :        4.94921875        ( --> 4.723333835601807)
# fixed mul value is      :    4.8012847900390625
# error is                :     14.79339599609375
# ------------------------------------------------------------------------------------------
# act value is            :        -1.69921875       ( --> -1.67181396484375)
# wei value is            :        0.29296875        ( --> 0.2841796875)
# stochastic mul value is :        -0.3515625        ( --> -0.47509557008743286)
# fixed mul value is      :    -0.4978179931640625
# error is                :     14.62554931640625
# ------------------------------------------------------------------------------------------
# act value is            :         1.0078125        ( --> 1.0108642578125)
# wei value is            :        2.31640625        ( --> 2.3089599609375)
# stochastic mul value is :        2.47265625        ( --> 2.334045171737671)
# fixed mul value is      :     2.334503173828125
# error is                :     13.8153076171875
# ------------------------------------------------------------------------------------------
# act value is            :         -1.53125         ( --> -1.51629638671875)
# wei value is            :         0.2578125        ( --> 0.2486572265625)
# stochastic mul value is :        -0.17578125       ( --> -0.37703806161880493)
# fixed mul value is      :      -0.394775390625
# error is                :       21.8994140625
# ------------------------------------------------------------------------------------------
# act value is            :        0.48046875        ( --> 0.466552734375)
# wei value is            :        3.28515625        ( --> 3.26806640625)
# stochastic mul value is :        1.58984375        ( --> 1.524725317955017)
# fixed mul value is      :    1.5784149169921875
# error is                :     1.14288330078125
# ------------------------------------------------------------------------------------------
# act value is            :         1.1015625        ( --> 1.088623046875)
# wei value is            :        0.24609375        ( --> 0.2486572265625)
# stochastic mul value is :         0.3515625        ( --> 0.27069398760795593)
# fixed mul value is      :     0.271087646484375
# error is                :      8.0474853515625
# ------------------------------------------------------------------------------------------
# act value is            :         1.1328125        ( --> 1.12750244140625)
# wei value is            :           0.25           ( --> 0.2486572265625)
# stochastic mul value is :         0.3515625        ( --> 0.2803616225719452)
# fixed mul value is      :        0.283203125
# error is                :         6.8359375
# ------------------------------------------------------------------------------------------
# act value is            :          3.40625         ( --> 3.42138671875)
# wei value is            :        1.93359375        ( --> 1.9537353515625)
# stochastic mul value is :         6.890625         ( --> 6.684484004974365)
# fixed mul value is      :      6.5863037109375
# error is                :      30.43212890625
# ------------------------------------------------------------------------------------------
# act value is            :         -0.484375        ( --> -0.466552734375)
# wei value is            :        0.30078125        ( --> 0.3197021484375)
# stochastic mul value is :            0.0           ( --> -0.14915791153907776)
# fixed mul value is      :     -0.14569091796875
# error is                :      14.569091796875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.3203125        ( --> -0.31103515625)
# wei value is            :        1.73046875        ( --> 1.7406005859375)
# stochastic mul value is :        -0.52734375       ( --> -0.5413879752159119)
# fixed mul value is      :    -0.554290771484375
# error is                :      2.6947021484375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.97265625       ( --> -3.9656982421875)
# wei value is            :        -1.87109375       ( --> -1.84716796875)
# stochastic mul value is :         7.421875         ( --> 7.325310707092285)
# fixed mul value is      :    7.4332122802734375
# error is                :     1.13372802734375
# ------------------------------------------------------------------------------------------
# act value is            :         0.1171875        ( --> 0.11663818359375)
# wei value is            :        1.91015625        ( --> 1.918212890625)
# stochastic mul value is :         0.3515625        ( --> 0.22373686730861664)
# fixed mul value is      :     0.223846435546875
# error is                :     12.7716064453125
# ------------------------------------------------------------------------------------------
# act value is            :         1.859375         ( --> 1.8662109375)
# wei value is            :         0.6484375        ( --> 0.639404296875)
# stochastic mul value is :         1.234375         ( --> 1.193263292312622)
# fixed mul value is      :      1.2056884765625
# error is                :       2.86865234375
# ------------------------------------------------------------------------------------------
# act value is            :         0.765625         ( --> 0.777587890625)
# wei value is            :        -0.3828125        ( --> -0.355224609375)
# stochastic mul value is :        -0.17578125       ( --> -0.27621835470199585)
# fixed mul value is      :     -0.2930908203125
# error is                :      11.73095703125
# ------------------------------------------------------------------------------------------
# act value is            :        0.25390625        ( --> 0.27215576171875)
# wei value is            :         2.5078125        ( --> 2.5220947265625)
# stochastic mul value is :         0.8828125        ( --> 0.6864026188850403)
# fixed mul value is      :     0.636749267578125
# error is                :     24.6063232421875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.33984375       ( --> -1.3218994140625)
# wei value is            :         -1.640625        ( --> -1.634033203125)
# stochastic mul value is :         2.296875         ( --> 2.160027503967285)
# fixed mul value is      :     2.19818115234375
# error is                :      9.869384765625
# ------------------------------------------------------------------------------------------
# act value is            :        3.18359375        ( --> 3.1881103515625)
# wei value is            :        3.92578125        ( --> 3.9429931640625)
# stochastic mul value is :        12.7265625        ( --> 12.570697784423828)
# fixed mul value is      :    12.498092651367188
# error is                :     22.84698486328125
# ------------------------------------------------------------------------------------------
# act value is            :         -3.671875        ( --> -3.6546630859375)
# wei value is            :         -0.453125        ( --> -0.42626953125)
# stochastic mul value is :        1.58984375        ( --> 1.5578715801239014)
# fixed mul value is      :      1.663818359375
# error is                :       7.3974609375
# ------------------------------------------------------------------------------------------
# act value is            :        -0.7734375        ( --> -0.73870849609375)
# wei value is            :         -2.703125        ( --> -2.69970703125)
# stochastic mul value is :         2.296875         ( --> 1.9942965507507324)
# fixed mul value is      :      2.0906982421875
# error is                :      20.61767578125
# ------------------------------------------------------------------------------------------
# act value is            :        0.18359375        ( --> 0.19439697265625)
# wei value is            :         0.3515625        ( --> 0.355224609375)
# stochastic mul value is :        0.17578125        ( --> 0.06905458867549896)
# fixed mul value is      :     0.064544677734375
# error is                :     11.1236572265625
# ------------------------------------------------------------------------------------------
# act value is            :        -1.33203125       ( --> -1.3218994140625)
# wei value is            :          0.1875          ( --> 0.1776123046875)
# stochastic mul value is :        -0.17578125       ( --> -0.23478560149669647)
# fixed mul value is      :      -0.249755859375
# error is                :       7.3974609375
# ------------------------------------------------------------------------------------------
# act value is            :          0.9375          ( --> 0.93310546875)
# wei value is            :        1.76953125        ( --> 1.776123046875)
# stochastic mul value is :         1.765625         ( --> 1.657310128211975)
# fixed mul value is      :      1.658935546875
# error is                :       10.6689453125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.8828125        ( --> -0.8553466796875)
# wei value is            :         1.7265625        ( --> 1.7406005859375)
# stochastic mul value is :        -1.4140625        ( --> -1.4888169765472412)
# fixed mul value is      :     -1.52423095703125
# error is                :      11.016845703125
# ------------------------------------------------------------------------------------------
# act value is            :        0.05859375        ( --> 0.0777587890625)
# wei value is            :         0.2265625        ( --> 0.213134765625)
# stochastic mul value is :        0.17578125        ( --> 0.01657310128211975)
# fixed mul value is      :     0.013275146484375
# error is                :     16.2506103515625
# ------------------------------------------------------------------------------------------
# act value is            :         4.9765625        ( --> 0.0)
# wei value is            :        -0.32421875       ( --> -0.3197021484375)
# stochastic mul value is :            0.0           ( --> -0.0)
# fixed mul value is      :    -1.613494873046875
# error is                :     161.3494873046875
# ------------------------------------------------------------------------------------------
# act value is            :         4.8359375        ( --> 4.821044921875)
# wei value is            :          1.34375         ( --> 1.349853515625)
# stochastic mul value is :         6.5390625        ( --> 6.507704257965088)
# fixed mul value is      :      6.498291015625
# error is                :       4.0771484375
# ------------------------------------------------------------------------------------------
# act value is            :        4.22265625        ( --> 4.23785400390625)
# wei value is            :         1.078125         ( --> 1.065673828125)
# stochastic mul value is :        4.76953125        ( --> 4.516170024871826)
# fixed mul value is      :     4.55255126953125
# error is                :      21.697998046875
# ------------------------------------------------------------------------------------------
# act value is            :        1.69140625        ( --> 1.710693359375)
# wei value is            :         1.359375         ( --> 1.349853515625)
# stochastic mul value is :        2.47265625        ( --> 2.30918550491333)
# fixed mul value is      :     2.29925537109375
# error is                :      17.340087890625
# ------------------------------------------------------------------------------------------
# act value is            :        2.66796875        ( --> 2.68267822265625)
# wei value is            :        -2.04296875       ( --> -2.0247802734375)
# stochastic mul value is :          -5.125          ( --> -5.431833744049072)
# fixed mul value is      :    -5.4505767822265625
# error is                :     32.55767822265625
# ------------------------------------------------------------------------------------------
# act value is            :        -2.7890625        ( --> -2.76043701171875)
# wei value is            :        1.58984375        ( --> 1.5985107421875)
# stochastic mul value is :          -4.0625         ( --> -4.412588119506836)
# fixed mul value is      :    -4.434173583984375
# error is                :     37.1673583984375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.2890625        ( --> -2.2550048828125)
# wei value is            :         1.0703125        ( --> 1.065673828125)
# stochastic mul value is :         -2.296875        ( --> -2.403099775314331)
# fixed mul value is      :     -2.45001220703125
# error is                :      15.313720703125
# ------------------------------------------------------------------------------------------
# act value is            :        -2.95703125       ( --> -2.954833984375)
# wei value is            :        1.67578125        ( --> 1.6695556640625)
# stochastic mul value is :        -4.76953125       ( --> -4.933259963989258)
# fixed mul value is      :    -4.9553375244140625
# error is                :     18.58062744140625
# ------------------------------------------------------------------------------------------
# act value is            :         4.671875         ( --> 4.66552734375)
# wei value is            :        0.73046875        ( --> 0.7459716796875)
# stochastic mul value is :        3.53515625        ( --> 3.480351209640503)
# fixed mul value is      :     3.41265869140625
# error is                :      12.249755859375
# ------------------------------------------------------------------------------------------
# act value is            :        0.50390625        ( --> 0.50543212890625)
# wei value is            :        -2.7890625        ( --> -2.770751953125)
# stochastic mul value is :        -1.05859375       ( --> -1.4004271030426025)
# fixed mul value is      :    -1.405426025390625
# error is                :     34.6832275390625
# ------------------------------------------------------------------------------------------
# act value is            :         -1.203125        ( --> -1.1663818359375)
# wei value is            :        2.16796875        ( --> 2.1668701171875)
# stochastic mul value is :        -2.47265625       ( --> -2.527397871017456)
# fixed mul value is      :     -2.60833740234375
# error is                :      13.568115234375
# ------------------------------------------------------------------------------------------
# act value is            :           -3.5           ( --> -3.4991455078125)
# wei value is            :        0.87109375        ( --> 0.8880615234375)
# stochastic mul value is :         -2.828125        ( --> -3.1074564456939697)
# fixed mul value is      :       -3.048828125
# error is                :        22.0703125
# ------------------------------------------------------------------------------------------
# act value is            :           -1.25          ( --> -1.244140625)
# wei value is            :        -1.16796875       ( --> -1.13671875)
# stochastic mul value is :         1.4140625        ( --> 1.4142379760742188)
# fixed mul value is      :       1.4599609375
# error is                :        4.58984375
# ------------------------------------------------------------------------------------------
# act value is            :          2.0625          ( --> 2.06060791015625)
# wei value is            :         -3.03125         ( --> -3.0194091796875)
# stochastic mul value is :        -5.83203125       ( --> -6.221818447113037)
# fixed mul value is      :       -6.251953125
# error is                :        41.9921875
# ------------------------------------------------------------------------------------------
# act value is            :         -1.84375         ( --> -1.82733154296875)
# wei value is            :        1.52734375        ( --> 1.5274658203125)
# stochastic mul value is :        -2.47265625       ( --> -2.791186571121216)
# fixed mul value is      :     -2.8160400390625
# error is                :      34.33837890625
# ------------------------------------------------------------------------------------------
# act value is            :        0.88671875        ( --> 0.89422607421875)
# wei value is            :           0.875          ( --> 0.8880615234375)
# stochastic mul value is :        1.05859375        ( --> 0.7941277623176575)
# fixed mul value is      :       0.77587890625
# error is                :       28.271484375
# ------------------------------------------------------------------------------------------
# act value is            :        2.58984375        ( --> 2.60491943359375)
# wei value is            :         2.640625         ( --> 2.628662109375)
# stochastic mul value is :         7.0703125        ( --> 6.8474531173706055)
# fixed mul value is      :     6.83880615234375
# error is                :      23.150634765625
# ------------------------------------------------------------------------------------------
# act value is            :        3.22265625        ( --> 3.22698974609375)
# wei value is            :        2.97265625        ( --> 2.98388671875)
# stochastic mul value is :         9.8984375        ( --> 9.628972053527832)
# fixed mul value is      :     9.579849243164062
# error is                :     31.85882568359375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.3203125        ( --> -3.30474853515625)
# wei value is            :         0.9296875        ( --> 0.923583984375)
# stochastic mul value is :         -2.828125        ( --> -3.052212715148926)
# fixed mul value is      :     -3.08685302734375
# error is                :      25.872802734375
# ------------------------------------------------------------------------------------------
# act value is            :         1.5859375        ( --> 1.59405517578125)
# wei value is            :        3.38671875        ( --> 3.3746337890625)
# stochastic mul value is :         5.4765625        ( --> 5.379352569580078)
# fixed mul value is      :     5.371124267578125
# error is                :     10.5438232421875
# ------------------------------------------------------------------------------------------
# act value is            :        -2.37890625       ( --> -2.37164306640625)
# wei value is            :        3.05859375        ( --> 3.054931640625)
# stochastic mul value is :        -7.0703125        ( --> -7.2452073097229)
# fixed mul value is      :    -7.2761077880859375
# error is                :     20.57952880859375
# ------------------------------------------------------------------------------------------
# act value is            :        1.20703125        ( --> 1.20526123046875)
# wei value is            :         0.0390625        ( --> 0.0355224609375)
# stochastic mul value is :        0.17578125        ( --> 0.04281384497880936)
# fixed mul value is      :     0.047149658203125
# error is                :     12.8631591796875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.08203125       ( --> -0.0777587890625)
# wei value is            :         1.2890625        ( --> 1.27880859375)
# stochastic mul value is :            0.0           ( --> -0.0994386076927185)
# fixed mul value is      :    -0.105743408203125
# error is                :     10.5743408203125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.47265625       ( --> -1.43853759765625)
# wei value is            :        -1.39453125       ( --> -1.3853759765625)
# stochastic mul value is :         2.296875         ( --> 1.992915391921997)
# fixed mul value is      :    2.0536651611328125
# error is                :     24.32098388671875
# ------------------------------------------------------------------------------------------
# act value is            :        4.80859375        ( --> 4.821044921875)
# wei value is            :         -1.40625         ( --> -1.3853759765625)
# stochastic mul value is :        -6.5390625        ( --> -6.678959846496582)
# fixed mul value is      :     -6.7620849609375
# error is                :      22.30224609375
# ------------------------------------------------------------------------------------------
# act value is            :        0.97265625        ( --> 0.97198486328125)
# wei value is            :         3.9921875        ( --> 3.978515625)
# stochastic mul value is :        3.88671875        ( --> 3.8670568466186523)
# fixed mul value is      :     3.883026123046875
# error is                :      0.3692626953125
# ------------------------------------------------------------------------------------------
# act value is            :         0.5234375        ( --> 0.5443115234375)
# wei value is            :        -3.8515625        ( --> -3.83642578125)
# stochastic mul value is :        -1.94140625       ( --> -2.0882108211517334)
# fixed mul value is      :     -2.01605224609375
# error is                :      7.464599609375
# ------------------------------------------------------------------------------------------
# act value is            :        1.41796875        ( --> 1.399658203125)
# wei value is            :         1.3515625        ( --> 1.349853515625)
# stochastic mul value is :        2.12109375        ( --> 1.8893334865570068)
# fixed mul value is      :     1.916473388671875
# error is                :     20.4620361328125
# ------------------------------------------------------------------------------------------
# act value is            :        0.69140625        ( --> 0.6998291015625)
# wei value is            :        -2.43359375       ( --> -2.41552734375)
# stochastic mul value is :        -1.58984375       ( --> -1.6904563903808594)
# fixed mul value is      :    -1.6826019287109375
# error is                :     9.27581787109375
# ------------------------------------------------------------------------------------------
# act value is            :        1.83203125        ( --> 1.82733154296875)
# wei value is            :         1.734375         ( --> 1.7406005859375)
# stochastic mul value is :        3.35546875        ( --> 3.180654287338257)
# fixed mul value is      :     3.17742919921875
# error is                :      17.803955078125
# ------------------------------------------------------------------------------------------
# act value is            :          3.5625          ( --> 3.576904296875)
# wei value is            :        -2.5234375        ( --> -2.5220947265625)
# stochastic mul value is :        -8.8359375        ( --> -9.021291732788086)
# fixed mul value is      :      -8.98974609375
# error is                :       15.380859375
# ------------------------------------------------------------------------------------------
# act value is            :        -1.6640625        ( --> -1.6329345703125)
# wei value is            :         0.2890625        ( --> 0.2841796875)
# stochastic mul value is :        -0.3515625        ( --> -0.464046835899353)
# fixed mul value is      :     -0.48101806640625
# error is                :      12.945556640625
# ------------------------------------------------------------------------------------------
# act value is            :        2.80859375        ( --> 2.79931640625)
# wei value is            :         2.1484375        ( --> 2.1668701171875)
# stochastic mul value is :        6.18359375        ( --> 6.0657548904418945)
# fixed mul value is      :     6.034088134765625
# error is                :     14.9505615234375
# ------------------------------------------------------------------------------------------
# act value is            :        0.83984375        ( --> 0.8553466796875)
# wei value is            :         2.0234375        ( --> 2.0247802734375)
# stochastic mul value is :        1.94140625        ( --> 1.7318891286849976)
# fixed mul value is      :     1.699371337890625
# error is                :     24.2034912109375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.92578125       ( --> -2.91595458984375)
# wei value is            :        -0.98828125       ( --> -0.9591064453125)
# stochastic mul value is :        3.00390625        ( --> 2.796710729598999)
# fixed mul value is      :    2.8914947509765625
# error is                :     11.24114990234375
# ------------------------------------------------------------------------------------------
# act value is            :         2.0546875        ( --> 2.06060791015625)
# wei value is            :        -2.8828125        ( --> -2.8773193359375)
# stochastic mul value is :         -5.65625         ( --> -5.929027080535889)
# fixed mul value is      :     -5.92327880859375
# error is                :      26.702880859375
# ------------------------------------------------------------------------------------------
# act value is            :        1.30078125        ( --> 1.3218994140625)
# wei value is            :        2.04296875        ( --> 2.060302734375)
# stochastic mul value is :         2.828125         ( --> 2.723512887954712)
# fixed mul value is      :    2.6574554443359375
# error is                :     17.06695556640625
# ------------------------------------------------------------------------------------------
# act value is            :         1.4609375        ( --> 1.4774169921875)
# wei value is            :         -0.671875        ( --> -0.639404296875)
# stochastic mul value is :        -0.70703125       ( --> -0.9446667432785034)
# fixed mul value is      :     -0.9815673828125
# error is                :      27.45361328125
# ------------------------------------------------------------------------------------------
# act value is            :          3.1875          ( --> 3.1881103515625)
# wei value is            :         3.765625         ( --> 3.765380859375)
# stochastic mul value is :        12.1953125        ( --> 12.004449844360352)
# fixed mul value is      :       12.0029296875
# error is                :        19.23828125
# ------------------------------------------------------------------------------------------
# act value is            :           -2.75          ( --> -2.7215576171875)
# wei value is            :        1.38671875        ( --> 1.3853759765625)
# stochastic mul value is :        -3.53515625       ( --> -3.7703804969787598)
# fixed mul value is      :       -3.8134765625
# error is                :        27.83203125
# ------------------------------------------------------------------------------------------
# act value is            :        4.78515625        ( --> 4.78216552734375)
# wei value is            :        -1.5234375        ( --> -1.491943359375)
# stochastic mul value is :         -6.890625        ( --> -7.134720325469971)
# fixed mul value is      :    -7.289886474609375
# error is                :     39.9261474609375
# ------------------------------------------------------------------------------------------
# act value is            :         0.0546875        ( --> 0.03887939453125)
# wei value is            :         1.9296875        ( --> 1.918212890625)
# stochastic mul value is :        0.17578125        ( --> 0.07457895576953888)
# fixed mul value is      :     0.10552978515625
# error is                :      7.025146484375
# ------------------------------------------------------------------------------------------
# act value is            :         1.8203125        ( --> 1.82733154296875)
# wei value is            :         2.890625         ( --> 2.8773193359375)
# stochastic mul value is :         5.4765625        ( --> 5.257816314697266)
# fixed mul value is      :      5.2618408203125
# error is                :      21.47216796875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.32421875       ( --> -1.3218994140625)
# wei value is            :         0.2578125        ( --> 0.2486572265625)
# stochastic mul value is :        -0.17578125       ( --> -0.32869982719421387)
# fixed mul value is      :    -0.341400146484375
# error is                :     16.5618896484375
# ------------------------------------------------------------------------------------------
# act value is            :        0.65234375        ( --> 0.66094970703125)
# wei value is            :           3.625          ( --> 3.623291015625)
# stochastic mul value is :        2.47265625        ( --> 2.394813060760498)
# fixed mul value is      :       2.36474609375
# error is                :       10.791015625
# ------------------------------------------------------------------------------------------
# act value is            :         1.0390625        ( --> 1.04974365234375)
# wei value is            :         0.8359375        ( --> 0.8525390625)
# stochastic mul value is :        1.05859375        ( --> 0.8949474692344666)
# fixed mul value is      :     0.86859130859375
# error is                :      19.000244140625
# ------------------------------------------------------------------------------------------
# act value is            :        0.88671875        ( --> 0.89422607421875)
# wei value is            :        2.12109375        ( --> 2.13134765625)
# stochastic mul value is :        2.12109375        ( --> 1.9059066772460938)
# fixed mul value is      :    1.8808135986328125
# error is                :     24.02801513671875
# ------------------------------------------------------------------------------------------
# act value is            :        -0.09765625       ( --> -0.0777587890625)
# wei value is            :        -0.26171875       ( --> -0.2486572265625)
# stochastic mul value is :        0.17578125        ( --> 0.01933528482913971)
# fixed mul value is      :    0.0255584716796875
# error is                :     15.02227783203125
# ------------------------------------------------------------------------------------------
# act value is            :         1.1171875        ( --> 1.12750244140625)
# wei value is            :        3.75390625        ( --> 3.765380859375)
# stochastic mul value is :        4.41796875        ( --> 4.245476245880127)
# fixed mul value is      :     4.193817138671875
# error is                :     22.4151611328125
# ------------------------------------------------------------------------------------------
# act value is            :            1.0           ( --> 1.0108642578125)
# wei value is            :            2.0           ( --> 1.9892578125)
# stochastic mul value is :        2.12109375        ( --> 2.0108695030212402)
# fixed mul value is      :            2.0
# error is                :         12.109375
# ------------------------------------------------------------------------------------------
# act value is            :        0.47265625        ( --> 0.466552734375)
# wei value is            :         -1.671875        ( --> -1.6695556640625)
# stochastic mul value is :        -0.52734375       ( --> -0.7789357900619507)
# fixed mul value is      :     -0.79022216796875
# error is                :      26.287841796875
# ------------------------------------------------------------------------------------------
# act value is            :         0.046875         ( --> 0.03887939453125)
# wei value is            :        -0.50390625       ( --> -0.497314453125)
# stochastic mul value is :            0.0           ( --> -0.01933528482913971)
# fixed mul value is      :     -0.02362060546875
# error is                :      2.362060546875
# ------------------------------------------------------------------------------------------
# act value is            :         -2.65625         ( --> -2.643798828125)
# wei value is            :         -0.578125        ( --> -0.568359375)
# stochastic mul value is :        1.58984375        ( --> 1.5026278495788574)
# fixed mul value is      :       1.53564453125
# error is                :        5.419921875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.1328125        ( --> -1.12750244140625)
# wei value is            :        1.42578125        ( --> 1.4208984375)
# stochastic mul value is :        -1.4140625        ( --> -1.6020665168762207)
# fixed mul value is      :    -1.615142822265625
# error is                :     20.1080322265625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.1796875        ( --> -0.155517578125)
# wei value is            :        0.98828125        ( --> 0.99462890625)
# stochastic mul value is :            0.0           ( --> -0.15468227863311768)
# fixed mul value is      :    -0.177581787109375
# error is                :     17.7581787109375
# ------------------------------------------------------------------------------------------
# act value is            :        1.02734375        ( --> 1.0108642578125)
# wei value is            :         2.3203125        ( --> 2.3089599609375)
# stochastic mul value is :        2.47265625        ( --> 2.334045171737671)
# fixed mul value is      :     2.383758544921875
# error is                :      8.8897705078125
# ------------------------------------------------------------------------------------------
# act value is            :         0.9609375        ( --> 0.97198486328125)
# wei value is            :         0.5234375        ( --> 0.5328369140625)
# stochastic mul value is :        0.70703125        ( --> 0.5179094076156616)
# fixed mul value is      :     0.50299072265625
# error is                :      20.404052734375
# ------------------------------------------------------------------------------------------
# act value is            :         3.203125         ( --> 3.1881103515625)
# wei value is            :        -0.6328125        ( --> -0.6038818359375)
# stochastic mul value is :         -1.765625        ( --> -1.9252419471740723)
# fixed mul value is      :     -2.0269775390625
# error is                :      26.13525390625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.10546875       ( --> -0.0777587890625)
# wei value is            :         0.6796875        ( --> 0.6749267578125)
# stochastic mul value is :            0.0           ( --> -0.05248148739337921)
# fixed mul value is      :    -0.071685791015625
# error is                :      7.1685791015625
# ------------------------------------------------------------------------------------------
# act value is            :        0.41796875        ( --> 0.42767333984375)
# wei value is            :        2.64453125        ( --> 2.6641845703125)
# stochastic mul value is :         1.4140625        ( --> 1.1394007205963135)
# fixed mul value is      :    1.1053314208984375
# error is                :     30.87310791015625
# ------------------------------------------------------------------------------------------
# act value is            :        1.27734375        ( --> 1.28302001953125)
# wei value is            :        -2.59765625       ( --> -2.5931396484375)
# stochastic mul value is :        -3.1796875        ( --> -3.327049970626831)
# fixed mul value is      :    -3.3180999755859375
# error is                :     13.84124755859375
# ------------------------------------------------------------------------------------------
# act value is            :        2.00390625        ( --> 2.021728515625)
# wei value is            :        2.65234375        ( --> 2.6641845703125)
# stochastic mul value is :          5.65625         ( --> 5.386258125305176)
# fixed mul value is      :    5.3150482177734375
# error is                :     34.12017822265625
# ------------------------------------------------------------------------------------------
# act value is            :        -3.91796875       ( --> -3.887939453125)
# wei value is            :        0.33984375        ( --> 0.355224609375)
# stochastic mul value is :         -1.234375        ( --> -1.381091833114624)
# fixed mul value is      :    -1.3314971923828125
# error is                :     9.71221923828125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.62890625       ( --> -1.59405517578125)
# wei value is            :        -2.1328125        ( --> -2.13134765625)
# stochastic mul value is :        3.53515625        ( --> 3.3974857330322266)
# fixed mul value is      :     3.474151611328125
# error is                :      6.1004638671875
# ------------------------------------------------------------------------------------------
# act value is            :         1.078125         ( --> 1.088623046875)
# wei value is            :        -2.5546875        ( --> -2.5220947265625)
# stochastic mul value is :        -2.47265625       ( --> -2.745610475540161)
# fixed mul value is      :     -2.7542724609375
# error is                :      28.16162109375
# ------------------------------------------------------------------------------------------
# act value is            :         -0.484375        ( --> -0.466552734375)
# wei value is            :         3.7421875        ( --> 3.7298583984375)
# stochastic mul value is :        -1.58984375       ( --> -1.7401756048202515)
# fixed mul value is      :     -1.8126220703125
# error is                :      22.27783203125
# ------------------------------------------------------------------------------------------
# act value is            :         1.6328125        ( --> 1.6329345703125)
# wei value is            :         3.2109375        ( --> 3.197021484375)
# stochastic mul value is :         5.4765625        ( --> 5.220526695251465)
# fixed mul value is      :     5.24285888671875
# error is                :      23.370361328125
# ------------------------------------------------------------------------------------------
# act value is            :        0.81640625        ( --> 0.81646728515625)
# wei value is            :          0.90625         ( --> 0.923583984375)
# stochastic mul value is :        1.05859375        ( --> 0.7540761232376099)
# fixed mul value is      :      0.7398681640625
# error is                :      31.87255859375
# ------------------------------------------------------------------------------------------
# act value is            :         0.2265625        ( --> 0.2332763671875)
# wei value is            :         0.140625         ( --> 0.14208984375)
# stochastic mul value is :        0.17578125        ( --> 0.0331462025642395)
# fixed mul value is      :      0.0318603515625
# error is                :      14.39208984375
# ------------------------------------------------------------------------------------------
# act value is            :        2.10546875        ( --> 2.0994873046875)
# wei value is            :        -3.20703125       ( --> -3.197021484375)
# stochastic mul value is :        -6.5390625        ( --> -6.712106227874756)
# fixed mul value is      :    -6.7523040771484375
# error is                :     21.32415771484375
# ------------------------------------------------------------------------------------------
# act value is            :        1.26171875        ( --> 1.244140625)
# wei value is            :        3.40234375        ( --> 3.41015625)
# stochastic mul value is :         4.2421875        ( --> 4.242713928222656)
# fixed mul value is      :    4.2928009033203125
# error is                :     5.06134033203125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.73046875       ( --> -0.6998291015625)
# wei value is            :         0.2890625        ( --> 0.2841796875)
# stochastic mul value is :        -0.17578125       ( --> -0.198877215385437)
# fixed mul value is      :    -0.211151123046875
# error is                :      3.5369873046875
# ------------------------------------------------------------------------------------------
# act value is            :         0.671875         ( --> 0.66094970703125)
# wei value is            :         4.546875         ( --> 0.0)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :      3.054931640625
# error is                :      305.4931640625
# ------------------------------------------------------------------------------------------
# act value is            :        0.06640625        ( --> 0.0777587890625)
# wei value is            :         3.3515625        ( --> 3.339111328125)
# stochastic mul value is :         0.3515625        ( --> 0.2596452534198761)
# fixed mul value is      :     0.222564697265625
# error is                :     12.8997802734375
# ------------------------------------------------------------------------------------------
# act value is            :          -1.875          ( --> -1.8662109375)
# wei value is            :        0.59765625        ( --> 0.6038818359375)
# stochastic mul value is :        -1.05859375       ( --> -1.126970887184143)
# fixed mul value is      :      -1.12060546875
# error is                :        6.201171875
# ------------------------------------------------------------------------------------------
# act value is            :        2.73046875        ( --> 2.7215576171875)
# wei value is            :        1.44921875        ( --> 1.4564208984375)
# stochastic mul value is :         4.2421875        ( --> 3.963733434677124)
# fixed mul value is      :    3.9570465087890625
# error is                :     28.51409912109375
# ------------------------------------------------------------------------------------------
# act value is            :        1.37109375        ( --> 1.36077880859375)
# wei value is            :        0.41796875        ( --> 0.42626953125)
# stochastic mul value is :        0.70703125        ( --> 0.5800585746765137)
# fixed mul value is      :    0.5730743408203125
# error is                :     13.39569091796875
# ------------------------------------------------------------------------------------------
# act value is            :          0.03125         ( --> 0.03887939453125)
# wei value is            :        0.67578125        ( --> 0.6749267578125)
# stochastic mul value is :        0.17578125        ( --> 0.026240743696689606)
# fixed mul value is      :      0.0211181640625
# error is                :      15.46630859375
# ------------------------------------------------------------------------------------------
# act value is            :         1.1171875        ( --> 1.12750244140625)
# wei value is            :        1.76171875        ( --> 1.776123046875)
# stochastic mul value is :         2.296875         ( --> 2.0025830268859863)
# fixed mul value is      :     1.968170166015625
# error is                :     32.8704833984375
# ------------------------------------------------------------------------------------------
# act value is            :        0.35546875        ( --> 0.34991455078125)
# wei value is            :        -2.6171875        ( --> -2.5931396484375)
# stochastic mul value is :        -0.70703125       ( --> -0.907377302646637)
# fixed mul value is      :    -0.930328369140625
# error is                :     22.3297119140625
# ------------------------------------------------------------------------------------------
# act value is            :        1.38671875        ( --> 1.399658203125)
# wei value is            :        -3.37109375       ( --> -3.3746337890625)
# stochastic mul value is :         -4.59375         ( --> -4.723333835601807)
# fixed mul value is      :    -4.6747589111328125
# error is                :     8.10089111328125
# ------------------------------------------------------------------------------------------
# act value is            :         0.984375         ( --> 0.97198486328125)
# wei value is            :        1.27734375        ( --> 1.27880859375)
# stochastic mul value is :         1.4140625        ( --> 1.2429826259613037)
# fixed mul value is      :     1.25738525390625
# error is                :      15.667724609375
# ------------------------------------------------------------------------------------------
# act value is            :         0.6171875        ( --> 0.6220703125)
# wei value is            :        -0.43359375       ( --> -0.42626953125)
# stochastic mul value is :        -0.17578125       ( --> -0.265169620513916)
# fixed mul value is      :    -0.267608642578125
# error is                :      9.1827392578125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.87890625       ( --> -0.8553466796875)
# wei value is            :        2.37890625        ( --> 2.3800048828125)
# stochastic mul value is :        -1.94140625       ( --> -2.035729169845581)
# fixed mul value is      :    -2.0908355712890625
# error is                :     14.94293212890625
# ------------------------------------------------------------------------------------------
# act value is            :        4.79296875        ( --> 4.78216552734375)
# wei value is            :        0.20703125        ( --> 0.213134765625)
# stochastic mul value is :        1.05859375        ( --> 1.0192457437515259)
# fixed mul value is      :    0.9922943115234375
# error is                :     6.62994384765625
# ------------------------------------------------------------------------------------------
# act value is            :         0.5546875        ( --> 0.5443115234375)
# wei value is            :        0.44140625        ( --> 0.4617919921875)
# stochastic mul value is :         0.3515625        ( --> 0.25135868787765503)
# fixed mul value is      :     0.244842529296875
# error is                :     10.6719970703125
# ------------------------------------------------------------------------------------------
# act value is            :        0.61328125        ( --> 0.6220703125)
# wei value is            :        -2.1953125        ( --> -2.1668701171875)
# stochastic mul value is :         -1.234375        ( --> -1.3479455709457397)
# fixed mul value is      :    -1.346343994140625
# error is                :     11.1968994140625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.98828125       ( --> -0.97198486328125)
# wei value is            :        -0.77734375       ( --> -0.7459716796875)
# stochastic mul value is :        1.05859375        ( --> 0.7250731587409973)
# fixed mul value is      :    0.7682342529296875
# error is                :     29.03594970703125
# ------------------------------------------------------------------------------------------
# act value is            :        -0.41015625       ( --> -0.3887939453125)
# wei value is            :         0.1796875        ( --> 0.1776123046875)
# stochastic mul value is :            0.0           ( --> -0.06905458867549896)
# fixed mul value is      :    -0.073699951171875
# error is                :      7.3699951171875
# ------------------------------------------------------------------------------------------
# act value is            :        -1.18359375       ( --> -1.1663818359375)
# wei value is            :        -3.28515625       ( --> -3.26806640625)
# stochastic mul value is :        3.88671875        ( --> 3.8118133544921875)
# fixed mul value is      :    3.8882904052734375
# error is                :     0.15716552734375
# ------------------------------------------------------------------------------------------
# act value is            :        -3.37109375       ( --> -3.3436279296875)
# wei value is            :        -0.96484375       ( --> -0.9591064453125)
# stochastic mul value is :        3.53515625        ( --> 3.206895112991333)
# fixed mul value is      :    3.2525787353515625
# error is                :     28.25775146484375
# ------------------------------------------------------------------------------------------
# act value is            :        -1.04296875       ( --> -1.0108642578125)
# wei value is            :        -1.38671875       ( --> -1.3853759765625)
# stochastic mul value is :        1.58984375        ( --> 1.4004271030426025)
# fixed mul value is      :    1.4463043212890625
# error is                :     14.35394287109375
# ------------------------------------------------------------------------------------------
# act value is            :         1.8984375        ( --> 1.90509033203125)
# wei value is            :           2.875          ( --> 2.8773193359375)
# stochastic mul value is :          5.65625         ( --> 5.481553077697754)
# fixed mul value is      :       5.4580078125
# error is                :        19.82421875
# ------------------------------------------------------------------------------------------
# act value is            :        1.69921875        ( --> 1.710693359375)
# wei value is            :         2.390625         ( --> 2.3800048828125)
# stochastic mul value is :         4.2421875        ( --> 4.071458339691162)
# fixed mul value is      :     4.06219482421875
# error is                :      17.999267578125
# ------------------------------------------------------------------------------------------
# act value is            :        0.46484375        ( --> 0.466552734375)
# wei value is            :        -0.5859375        ( --> -0.568359375)
# stochastic mul value is :        -0.17578125       ( --> -0.265169620513916)
# fixed mul value is      :    -0.272369384765625
# error is                :      9.6588134765625
# ------------------------------------------------------------------------------------------
# act value is            :         -1.421875        ( --> -1.399658203125)
# wei value is            :          3.09375         ( --> 3.0904541015625)
# stochastic mul value is :          -4.0625         ( --> -4.325579643249512)
# fixed mul value is      :      -4.39892578125
# error is                :       33.642578125
# ------------------------------------------------------------------------------------------
# act value is            :        1.66796875        ( --> 1.67181396484375)
# wei value is            :        -2.40234375       ( --> -2.3800048828125)
# stochastic mul value is :        -3.7109375        ( --> -3.9789254665374756)
# fixed mul value is      :    -4.0070343017578125
# error is                :     29.60968017578125
# ------------------------------------------------------------------------------------------
# act value is            :        0.00390625        ( --> 0.0)
# wei value is            :         0.9609375        ( --> 0.9591064453125)
# stochastic mul value is :            0.0           ( --> 0.0)
# fixed mul value is      :     0.003753662109375
# error is                :      0.3753662109375
# ------------------------------------------------------------------------------------------
# act value is            :        1.00390625        ( --> 1.0108642578125)
# wei value is            :         0.2578125        ( --> 0.2486572265625)
# stochastic mul value is :         0.3515625        ( --> 0.25135868787765503)
# fixed mul value is      :     0.258819580078125
# error is                :      9.2742919921875
# ------------------------------------------------------------------------------------------
# act value is            :          0.78125         ( --> 0.777587890625)
# wei value is            :            2.0           ( --> 1.9892578125)
# stochastic mul value is :        1.58984375        ( --> 1.5468227863311768)
# fixed mul value is      :          1.5625
# error is                :         2.734375
# ------------------------------------------------------------------------------------------
# act value is            :        0.59765625        ( --> 0.58319091796875)
# wei value is            :          -3.375          ( --> -3.3746337890625)
# stochastic mul value is :         -1.765625        ( --> -1.9680557250976562)
# fixed mul value is      :      -2.01708984375
# error is                :       25.146484375
# ------------------------------------------------------------------------------------------
# act value is            :         0.9140625        ( --> 0.93310546875)
# wei value is            :          1.90625         ( --> 1.918212890625)
# stochastic mul value is :        1.94140625        ( --> 1.789894938468933)
# fixed mul value is      :      1.742431640625
# error is                :       19.8974609375
# ------------------------------------------------------------------------------------------
# act value is            :        0.59765625        ( --> 0.58319091796875)
# wei value is            :        -0.82421875       ( --> -0.8170166015625)
# stochastic mul value is :        -0.17578125       ( --> -0.47647666931152344)
# fixed mul value is      :    -0.4925994873046875
# error is                :     31.68182373046875
# ------------------------------------------------------------------------------------------
# act value is            :        2.41796875        ( --> 2.4105224609375)
# wei value is            :        -0.48828125       ( --> -0.4617919921875)
# stochastic mul value is :        -0.8828125        ( --> -1.1131600141525269)
# fixed mul value is      :    -1.1806488037109375
# error is                :     29.78363037109375
# ------------------------------------------------------------------------------------------
# act value is            :          1.0625          ( --> 1.04974365234375)
# wei value is            :         -1.578125        ( --> -1.56298828125)
# stochastic mul value is :        -1.4140625        ( --> -1.6407370567321777)
# fixed mul value is      :       -1.6767578125
# error is                :        26.26953125
# ------------------------------------------------------------------------------------------
# act value is            :        -1.77734375       ( --> -1.74957275390625)
# wei value is            :        2.66015625        ( --> 2.6641845703125)
# stochastic mul value is :        -4.2421875        ( --> -4.661184787750244)
# fixed mul value is      :    -4.7280120849609375
# error is                :     48.58245849609375
# ------------------------------------------------------------------------------------------
# act value is            :        0.79296875        ( --> 0.777587890625)
# wei value is            :         0.4921875        ( --> 0.497314453125)
# stochastic mul value is :        0.52734375        ( --> 0.3867056965827942)
# fixed mul value is      :     0.390289306640625
# error is                :     13.7054443359375
# ------------------------------------------------------------------------------------------
# act value is            :        0.62890625        ( --> 0.6220703125)
# wei value is            :        -2.51953125       ( --> -2.5220947265625)
# stochastic mul value is :        -1.4140625        ( --> -1.5689202547073364)
# fixed mul value is      :    -1.5845489501953125
# error is                :     17.04864501953125
# ------------------------------------------------------------------------------------------
# act value is            :          -0.0625         ( --> -0.03887939453125)
# wei value is            :        -0.44921875       ( --> -0.42626953125)
# stochastic mul value is :        0.17578125        ( --> 0.01657310128211975)
# fixed mul value is      :      0.028076171875
# error is                :       14.7705078125
# ------------------------------------------------------------------------------------------
# act value is            :         2.2109375        ( --> 2.21612548828125)
# wei value is            :         4.2265625        ( --> 4.2271728515625)
# stochastic mul value is :        9.54296875        ( --> 9.367945671081543)
# fixed mul value is      :     9.34466552734375
# error is                :      19.830322265625
# ------------------------------------------------------------------------------------------
# act value is            :         0.6640625        ( --> 0.66094970703125)
# wei value is            :         4.2265625        ( --> 4.2271728515625)
# stochastic mul value is :         2.828125         ( --> 2.7939486503601074)
# fixed mul value is      :     2.80670166015625
# error is                :      2.142333984375
# ------------------------------------------------------------------------------------------
# act value is            :            3.5           ( --> 3.4991455078125)
# wei value is            :        4.21484375        ( --> 4.2271728515625)
# stochastic mul value is :        15.0234375        ( --> 14.791492462158203)
# fixed mul value is      :       14.751953125
# error is                :        27.1484375
# ------------------------------------------------------------------------------------------
# act value is            :        -2.83984375       ( --> -2.83819580078125)
# wei value is            :        0.26953125        ( --> 0.2841796875)
# stochastic mul value is :        -0.70703125       ( --> -0.8065575957298279)
# fixed mul value is      :    -0.7654266357421875
# error is                :     5.83953857421875
# ------------------------------------------------------------------------------------------
# act value is            :        -3.82421875       ( --> -3.8101806640625)
# wei value is            :         0.6796875        ( --> 0.6749267578125)
# stochastic mul value is :        -2.47265625       ( --> -2.5715928077697754)
# fixed mul value is      :    -2.599273681640625
# error is                :     12.6617431640625
# ------------------------------------------------------------------------------------------
# act value is            :        -0.33203125       ( --> -0.31103515625)
# wei value is            :          0.1875          ( --> 0.1776123046875)
# stochastic mul value is :            0.0           ( --> -0.05524367094039917)
# fixed mul value is      :      -0.062255859375
# error is                :       6.2255859375
# ------------------------------------------------------------------------------------------
# act value is            :        2.97265625        ( --> 2.954833984375)
# wei value is            :        0.62109375        ( --> 0.639404296875)
# stochastic mul value is :        2.12109375        ( --> 1.8893334865570068)
# fixed mul value is      :    1.8462982177734375
# error is                :     27.47955322265625
# ------------------------------------------------------------------------------------------
# act value is            :        0.23828125        ( --> 0.2332763671875)
# wei value is            :        2.35546875        ( --> 2.344482421875)
# stochastic mul value is :        0.70703125        ( --> 0.5469123125076294)
# fixed mul value is      :    0.5612640380859375
# error is                :     14.57672119140625
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## ERROR

# %%
def MSE(a,b):
    s = 0
    n = 0

    for i in range(10):
        for j in range(15):
            square = (((a[i][j])-b[i][j])**2).item()
            s += square
            n   += 1
    error = s/n
    return error

# %% [markdown]
# ## ERROR : 4bit LFSR

# %%
MSE(act_f*wei_f,cc)
# Out:
# 0.11837202747352421
