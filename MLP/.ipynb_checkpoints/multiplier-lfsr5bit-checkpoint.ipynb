# %% [markdown]
# # Multiplier TEST code

# %% [markdown]
# fixed number to stochastic conversion & multiply & stochastic to fixed number conversion

# %% [markdown]
# ## Import

# %%
import random, struct, math
import torch
import numpy as np
import torch.nn as nn 
import argparse
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Parser

# %%
parser = argparse.ArgumentParser(description='fixed_mac')
parser.add_argument('--full_bits', type=int, default=8, help='Number of Quantization Bits')
parser.add_argument('--frac_bits', type=int, default=5, help='Number of Quantization Bits')
parser.add_argument('--bBW', type=int, default=5, help='Number of bit width')
args = parser.parse_args(args=[])

# %% [markdown]
# ## Definition

# %% [markdown]
# ### int2bin : int number to binary number

# %%
def int2bin(iIn,iBW):
    iBW = iBW + 1
    if iIn >= 0:
        bOut = bin(iIn).replace('0b','').rjust(iBW,'0')
    else :
        bOut = bin(iIn & (pow(2,iBW)-1)).replace('0b','').rjust(iBW,'1')
    return bOut[1:]

# %% [markdown]
# ### XOR : xor gate with string

# %%
def XOR(iA,iB):
    if iA != iB :
        iOut = '1'
    else : 
        iOut = '0'
    return iOut

# %% [markdown]
# ### SNUM : sign number determination

# %%
def snum(a):
    if a >= 0 :
        return '0'
    else :
        return '1'

# %% [markdown]
# ### fxp & flp2fix : floating number to fixed number conversion

# %%
class fxp:
    def __init__(self, bIn, iBWF):
        self.iFullBW = len(bIn)
        self.iIntgBW = self.iFullBW - iBWF
        self.bSign = bIn[0]
        self.bIntg = bIn[:self.iIntgBW]
        self.bFrac = bIn[self.iIntgBW:]
        self.fFull = 0
        try:
            for idx, bit in enumerate(bIn):
                if idx == 0:
                    self.fFull = self.fFull + int(bit,2) * -pow(2, self.iIntgBW - 1)
                else:
                    self.fFull = self.fFull + int(bit,2) * pow(2, self.iIntgBW - 1 - idx)
        except:
            print(bIn)
        self.dispFull = self.bIntg +"."+ self.bFrac 
        return

# %%
class flp2fix:
    def __init__(self, fIn, iBW, iBWF):
        self.fMin = - 2 ** (iBW - iBWF - 1)
        self.fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
        self.fResol = 2 ** -iBWF
        if fIn < self.fMin or fIn > self.fMax:
            print(f'({fIn}): Out of input range ({self.fMax}/{self.fMin}) during flp -> fix converting ')
        self.iBW = iBW
        self.iBWI = iBW - iBWF
        self.iBWF = iBWF

        self.iFLP2INT = abs(int(fIn * 2 ** iBWF))
        if fIn < 0:
            self.iFLP2INT = 2 ** (iBW-1) - self.iFLP2INT

        if fIn >= 0:
            self.bFull = bin(self.iFLP2INT)[2:].rjust(iBW, '0')
        else:
            self.bFull = '1'+bin(self.iFLP2INT)[2:].rjust(iBW-1, '0')
            if len(self.bFull) > iBW:
                self.bFull = '0' * iBW

        self.cssFxp = fxp(self.bFull, self.iBWF)
        self.bSign = self.cssFxp.bSign
        self.bIntg = self.cssFxp.bIntg
        self.bFrac = self.cssFxp.bFrac
        self.fFull = self.cssFxp.fFull
        return

# %%
def flp2fixTensor(fIn, iBW, iBWF):
    fMin = - 2 ** (iBW - iBWF - 1)
    fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
    fList = []
    for aTensor in fIn.view(-1):
        fList.append(flp2fix(aTensor, iBW, iBWF).fFull)
    return torch.tensor(fList).view(fIn.size())

# %% [markdown]
# ### LFSR : make pseudorandom number bitstream

# %%
class LFSR5:
    def Random(self):
        self.b0 = eval(f'str(random.randint(0,1))')
        self.b1 = eval(f'str(random.randint(0,1))')
        self.b2 = eval(f'str(random.randint(0,1))')
        self.b3 = eval(f'str(random.randint(0,1))')
        self.b4 = eval(f'str(random.randint(0,1))')
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4
    
    def Normal(self,stream):
        self.b0 = XOR(int(stream[1]),int(stream[4]))
        self.b1 = stream[0]
        self.b2 = stream[1]
        self.b3 = stream[2]
        self.b4 = stream[3]
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4
    
    def Allzero(self):
        self.b0 = '0'
        self.b1 = '0'
        self.b2 = '0'
        self.b3 = '0'
        self.b4 = '0'
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4

# %% [markdown]
# ### LFSRlist : make pseudorandom number bitstream with 2**bBW cycle

# %%
def LFSRlist5():
    lfsr = LFSR5()
    lfsrlist = []
    for k in range(2**(5)-1): #lfsr number generating
        if k == 0:
            lfsrlist.append(lfsr.Random())
        else :
            lfsrlist.append(lfsr.Normal(lfsrlist[k-1]))
        if (k == 2**(5)-2):
            lfsrlist.append(lfsr.Allzero())
    
    if (args.bBW) != args.frac_bits :
        if args.bBW < args.frac_bits :
            for i in range(len(lfsrlist)):
                lfsrlist[i] = lfsrlist[i] + (args.frac_bits-args.bBW)*'0'
        else :
            print("it can't work")
            return 0
    
    return lfsrlist

# %% [markdown]
# ### Comp : Comparator in SNG

# %%
def Comp(a,lfsr,snum):
    for com in range(0,len(a)):
        oA = '0'
        if a[com]!=lfsr[com]:
            if(int(a[com]) > int(lfsr[com])):
                oA = '1'
            break
    return XOR(oA,snum)

# %% [markdown]
# ### Perm : module for permutation SNG

# %%
def perm(a):
    al = len(a)
    blist = []
    for i in range(al) :
        #print(al-i-1)
        blist.append(a[al-i-1])
    
    b = "".join(blist)
    
    return b

# %% [markdown]
# ### findMaxMin : find abs max value in act tensor

# %%
def findMaxMin(data):
    max = torch.max(data)
    min = torch.min(data)
    SF=torch.max(abs(max),abs(min)).item()
    return SF

# %% [markdown]
# ### SNG : stochastic number generator module

# %%
def SNG(iIN,lfsr):

    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        lNUM = lfsr[k]
        a = Comp(bIN[-(args.frac_bits):],lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if sNUM == '1' and bIN == args.full_bits*'0' :
        return '1'+(2**(args.bBW))*'0'
    else :
        return sA

# %% [markdown]
# ### SNG_P : permutation stochastic number generator module

# %%
def SNG_P(iIN,lfsr):
    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        if (args.bBW == args.frac_bits) :    
            lNUM = perm(lfsr[k])
        elif (args.bBW < args.frac_bits) :
            lNUM = perm(lfsr[k][:args.bBW])+(args.frac_bits-args.bBW)*"0"
        a = Comp(bIN[-(args.frac_bits):],lNUM,sNUM)
        oAlist.append(Comp(bIN[-(args.frac_bits):],lNUM,sNUM)) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if sNUM == '1' and bIN == args.full_bits*'0' :
        return '1'+(2**(args.bBW))*'0'
    else :
        return sA

# %% [markdown]
# ### SNGnumpy : SNG module with numpy

# %%
def SNGnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG(float(aNumpy),lfsr))
                     
    return np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### SNGpnumpy : permutation SNG module with numpy

# %%
def SNGpnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG_P(float(aNumpy),lfsr))
                     
    return  np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### CountOne : count 1 in stochastic number bit stream

# %%
def CountOne(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        n = 0
        for a in num:
            if a == '1' :
                n += 1
        if num[0] == '1' :
            nlist.append(n-1)
        else :
            nlist.append(n)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### defSign : sign determination in S2N

# %%
def defSign(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        if num[0] == '1' :
            nlist.append(-1)
        else :
            nlist.append(1)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### Multiplier

# %%
def mul(a,b):
    al = len(a)
    bl = len(b)
    
    outlist = []
    
    if al != bl :
        print("length of string is different")
        return 0
    
    outlist.append(XOR(a[0],b[0]))
    
    for i in range(al-1) :
        outlist.append(str(int(a[i+1]) & int(b[i+1])))
    
    #print(outlist)
    out = "".join(outlist)
    
    return out

# %%
def defSign1(nIn):
    if nIn[0] == '1' :
        return -1
    else :
        return 1

# %%
def CountOne1(nIn):
    n = 0
    for num in nIn:
        if num == '1' :
            n += 1
    if nIn[0] == '1' :
        return n-1
    else :
        return n

# %%
def S2None(sIn,SF):
    s = defSign(sIn)
    o = (CountOne(sIn)/(2**args.bBW))*SF*s
    return o

# %%
def mulNumpy(aIn,bIn,aSF,wSF):
    mList = []
    for i in range(aIn.shape[0]):
        for j in range(bIn.T.shape[1]):
            sum = 0
            for k in range(aIn.shape[1]):
                sum += S2None(mul((aIn[i][k].astype(str)),(bIn.T)[k][j].astype(str)),aSF*wSF)
            mList.append(sum)
    return torch.tensor(mList).view(aIn.shape[0],bIn.T.shape[1])

# %%
def FindError(a,b):
    error = 0
    for anum,bnum in zip(a.view(-1),b.view(-1)):
        e = (abs(bnum-anum)*100).item()
        error += e
    return error/(len(a.view(-1))+len(b.view(-1)))

# %% [markdown]
# # TEST : LFSR 5 bit

# %%
act = torch.rand((10,15))-torch.randint(2,(10,15))+torch.randint(2,(10,15))
wei = torch.rand((10,15))-torch.randint(2,(10,15))+torch.randint(2,(10,15))

# %%
act_f = flp2fixTensor(act,args.full_bits,args.frac_bits)
wei_f = flp2fixTensor(wei,args.full_bits,args.frac_bits)

# %% [markdown]
# ### number to stochastic conversion

# %%
aSF = findMaxMin(act_f)
wSF = findMaxMin(wei_f)

# %%
def N2S(act,wei,aSF,wSF):
    
    lfsrlist = LFSRlist5()
    
    a = SNGnumpy(act/aSF,lfsrlist)
    w = SNGpnumpy(wei/wSF,lfsrlist)
    
    return a,w

# %%
def N2Sone(data,SF):
    lfsrlist = LFSRlist5()
    
    o = SNGnumpy(data/SF,lfsrlist)
    
    return o

# %% [markdown]
# ### stochastic to number conversion

# %%
def S2N(a,w,aSF,wSF):
    
    sa = defSign(a)
    sw = defSign(w)

    ca = (CountOne(a)/(2**args.bBW)) * aSF *sa
    cw = (CountOne(w)/(2**args.bBW)) * wSF *sw

    return ca,cw

# %%
a,w = N2S(act,wei,aSF,wSF)

# %%
ca,cw = S2N(a,w,aSF,wSF)

# %%
def multest(aIn,wIn,aSF,wSF):
    mlist=[]
    out = 0
    for a,b in zip(aIn.reshape(-1),wIn.reshape(-1)) :
        out = mul(a,b)
        mlist.append(out)
    
    return np.array(mlist).reshape(aIn.shape)

# %%
c = multest(a,w,aSF,wSF)

# %%
cc = flp2fixTensor(S2None(c,aSF*wSF),args.full_bits,args.frac_bits)

# %%
print(aSF,wSF)
# Out:
# 1.96875 1.96875

# %%
for i in range(10):
    for j in range(15):
        print(f'act value is            : {act_f[i][j]:^25}(bin : {flp2fix(act[i][j],args.full_bits,args.frac_bits).bFull:^8}) --> {a[i][j]}')
        print(f'wei value is            : {wei_f[i][j]:^25}(bin : {flp2fix(wei[i][j],args.full_bits,args.frac_bits).bFull:^8}) --> {w[i][j]}')
        print(f'stochastic mul value is : {cc[i][j]:^25}(bin : {flp2fix(cc[i][j],args.full_bits,args.frac_bits).bFull:^8}) --> {c[i][j]}')
        print(f'fixed mul value is      : {act_f[i][j]*wei_f[i][j]:^25}(bin : {flp2fix(act[i][j]*wei[i][j],args.full_bits,args.frac_bits).bFull:^8}) --> {N2Sone(act[i][j]*wei[i][j],aSF*wSF)}')
        print(f'------------------------------------------------------------------------------------------')
# Out:
# act value is            :          1.09375         (bin : 00100011) --> 001110000011001011011111101000101
# wei value is            :          0.9375          (bin : 00011110) --> 000100110000001100101101111010101
# stochastic mul value is :          1.0625          (bin : 00100010) --> 000100000000001000001101101000101
# fixed mul value is      :        1.025390625       (bin : 00100001) --> 000001000001001110000000000011001
# ------------------------------------------------------------------------------------------
# act value is            :           0.625          (bin : 00010100) --> 000110000001000001011110100000001
# wei value is            :          1.5625          (bin : 00110010) --> 001111111000011101111111111111101
# stochastic mul value is :          1.0625          (bin : 00100010) --> 000110000000000001011110100000001
# fixed mul value is      :         0.9765625        (bin : 00011111) --> 000110000001000001001110000000001
# ------------------------------------------------------------------------------------------
# act value is            :          -0.375          (bin : 11110100) --> 110000011100000000000000000011000
# wei value is            :          1.96875         (bin : 00111111) --> 000000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :        -0.73828125       (bin : 11101000) --> 100110010000011100000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.9375          (bin : 00011110) --> 001110000001001011011110101000101
# wei value is            :          1.8125          (bin : 00111010) --> 011111111001111111111111111111101
# stochastic mul value is :          1.8125          (bin : 00111010) --> 001110000001001011011110101000101
# fixed mul value is      :        1.69921875        (bin : 00110110) --> 000000111000000100101101111010101
# ------------------------------------------------------------------------------------------
# act value is            :          -0.5625         (bin : 11101110) --> 110000111100010000000000000011010
# wei value is            :           0.625          (bin : 00010100) --> 000000110000001000101101110000001
# stochastic mul value is :         -0.21875         (bin : 11111001) --> 100000110000000000000000000000000
# fixed mul value is      :        -0.3515625        (bin : 11110101) --> 100000100000000011000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.1875          (bin : 00000110) --> 000000000000000000000110000000001
# wei value is            :          0.9375          (bin : 00011110) --> 000100110000001100101101111010101
# stochastic mul value is :          0.21875         (bin : 00000111) --> 000000000000000000000100000000001
# fixed mul value is      :        0.17578125        (bin : 00000110) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :            0.5           (bin : 00010000) --> 000110000001000001001110000000001
# wei value is            :           -0.5           (bin : 11110000) --> 110010000111100010000000000000010
# stochastic mul value is :         -0.21875         (bin : 11111001) --> 100010000001000000000000000000000
# fixed mul value is      :           -0.25          (bin : 11111000) --> 100000000000000011000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.0625          (bin : 00000010) --> 000000000000000000000000000000001
# wei value is            :          0.6875          (bin : 00010110) --> 000000110000001000101101111000001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :        0.04296875        (bin : 00000001) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.4375          (bin : 00001110) --> 000110000000000001001110000000001
# wei value is            :          1.71875         (bin : 00110111) --> 011111111000111111111111111111101
# stochastic mul value is :          0.84375         (bin : 00011011) --> 000110000000000001001110000000001
# fixed mul value is      :        0.751953125       (bin : 00011001) --> 011000000000000100000000000010011
# ------------------------------------------------------------------------------------------
# act value is            :          0.34375         (bin : 00001011) --> 000010000000000001001110000000001
# wei value is            :          1.90625         (bin : 00111101) --> 011111111011111111111111111111111
# stochastic mul value is :          0.71875         (bin : 00010111) --> 000010000000000001001110000000001
# fixed mul value is      :       0.6552734375       (bin : 00010111) --> 000000000001000000000000000111001
# ------------------------------------------------------------------------------------------
# act value is            :           0.875          (bin : 00011100) --> 001110000001001011011110101000001
# wei value is            :          0.90625         (bin : 00011101) --> 000100110000001100101101111010101
# stochastic mul value is :          0.84375         (bin : 00011011) --> 000100000000001000001100101000001
# fixed mul value is      :        0.79296875        (bin : 00011011) --> 001110000000000001000000000000101
# ------------------------------------------------------------------------------------------
# act value is            :         -0.71875         (bin : 11101001) --> 110000111100010100000000010111010
# wei value is            :          0.40625         (bin : 00001101) --> 000000100000000000001001110000001
# stochastic mul value is :         -0.21875         (bin : 11111001) --> 100000100000000000000000010000000
# fixed mul value is      :       -0.2919921875      (bin : 11110110) --> 100000000000001100000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.28125         (bin : 00001001) --> 000010000000000000000110000000001
# wei value is            :          1.9375          (bin : 00111110) --> 011111111011111111111111111111111
# stochastic mul value is :          0.46875         (bin : 00001111) --> 000010000000000000000110000000001
# fixed mul value is      :        0.544921875       (bin : 00010010) --> 000000000011000000000000100000001
# ------------------------------------------------------------------------------------------
# act value is            :          0.53125         (bin : 00010001) --> 000110000001000001001110100000001
# wei value is            :           0.375          (bin : 00001100) --> 000000100000000000001001110000001
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000001000100000001
# fixed mul value is      :        0.19921875        (bin : 00000110) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          0.71875         (bin : 00010111) --> 000110000001000011011110101000001
# wei value is            :          0.28125         (bin : 00001001) --> 000000100000000000001001100000001
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000001000100000001
# fixed mul value is      :       0.2021484375       (bin : 00000111) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          -0.6875         (bin : 11101010) --> 110000111100010100000000000111010
# wei value is            :          1.65625         (bin : 00110101) --> 001111111000111111111111111111101
# stochastic mul value is :         -0.96875         (bin : 11100001) --> 100000111000010100000000000111000
# fixed mul value is      :       -1.138671875       (bin : 11011011) --> 100010000000000000011011000011110
# ------------------------------------------------------------------------------------------
# act value is            :          0.4375          (bin : 00001110) --> 000110000000000001001110000000001
# wei value is            :          1.9375          (bin : 00111110) --> 011111111011111111111111111111111
# stochastic mul value is :          0.84375         (bin : 00011011) --> 000110000000000001001110000000001
# fixed mul value is      :        0.84765625        (bin : 00011011) --> 001100000000000010011100000000001
# ------------------------------------------------------------------------------------------
# act value is            :          1.09375         (bin : 00100011) --> 001111000011001011011111101000101
# wei value is            :          1.53125         (bin : 00110001) --> 001111111000011101111111111111101
# stochastic mul value is :          1.8125          (bin : 00111010) --> 001111000000001001011111101000101
# fixed mul value is      :       1.6748046875       (bin : 00110111) --> 000111000000100101101111010100001
# ------------------------------------------------------------------------------------------
# act value is            :           1.125          (bin : 00100100) --> 001111000011001011011111101000101
# wei value is            :          -0.8125         (bin : 11100110) --> 111010000111110011000000000101010
# stochastic mul value is :         -0.71875         (bin : 11101001) --> 101010000011000011000000000000000
# fixed mul value is      :        -0.9140625        (bin : 11100010) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          -0.0625         (bin : 11111110) --> 100000000100000000000000000000000
# wei value is            :          1.5625          (bin : 00110010) --> 001111111000011101111111111111101
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :        -0.09765625       (bin : 11111100) --> 100000000000000000000010000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.40625         (bin : 00001101) --> 000010000000000001001110000000001
# wei value is            :          0.3125          (bin : 00001010) --> 000000100000000000001001100000001
# stochastic mul value is :          0.21875         (bin : 00000111) --> 000000000000000000001000000000001
# fixed mul value is      :        0.126953125       (bin : 00000100) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :           1.625          (bin : 00110100) --> 001111100011111111111111111100111
# wei value is            :          0.21875         (bin : 00000111) --> 000000000000000000000001100000001
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000000001100000001
# fixed mul value is      :        0.35546875        (bin : 00001100) --> 000000000011000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          -0.0625         (bin : 11111110) --> 100000000100000000000000000000000
# wei value is            :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :           -0.0           (bin : 00000000) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          -0.1875         (bin : 11111010) --> 100000001100000000000000000001000
# wei value is            :          0.9375          (bin : 00011110) --> 000100110000001100101101111010101
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :        -0.17578125       (bin : 11111010) --> 100000000100000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          -0.8125         (bin : 11100110) --> 110000111100110100000000010111010
# wei value is            :          0.8125          (bin : 00011010) --> 000100110000001000101101111010001
# stochastic mul value is :         -0.46875         (bin : 11110001) --> 100000110000000000000000010010000
# fixed mul value is      :        -0.66015625       (bin : 11101010) --> 100000000000001001000001110000000
# ------------------------------------------------------------------------------------------
# act value is            :          -0.375          (bin : 11110100) --> 110000011100000000000000000011000
# wei value is            :          1.96875         (bin : 00111111) --> 000000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :        -0.73828125       (bin : 11101001) --> 100000000000011001000001110000000
# ------------------------------------------------------------------------------------------
# act value is            :         -0.34375         (bin : 11110101) --> 110000011100000000000000000011000
# wei value is            :           0.375          (bin : 00001100) --> 000000100000000000001001110000001
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :        -0.12890625       (bin : 11111100) --> 100000000000000000000000000000010
# ------------------------------------------------------------------------------------------
# act value is            :          0.53125         (bin : 00010001) --> 000110000001000001001110100000001
# wei value is            :         -0.96875         (bin : 11100001) --> 111011000111110011010000000101010
# stochastic mul value is :         -0.34375         (bin : 11110101) --> 100010000001000001000000000000000
# fixed mul value is      :       -0.5146484375      (bin : 11101111) --> 100000000100000000111000000000000
# ------------------------------------------------------------------------------------------
# act value is            :         -0.53125         (bin : 11101111) --> 110000111100010000000000000011000
# wei value is            :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :           -0.0           (bin : 00000000) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.1875          (bin : 00000110) --> 000000000000000000000110000000001
# wei value is            :          -0.1875         (bin : 11111010) --> 100000000110000000000000000000010
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :        -0.03515625       (bin : 11111111) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# wei value is            :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# fixed mul value is      :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# wei value is            :          0.65625         (bin : 00010101) --> 000000110000001000101101111000001
# stochastic mul value is :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# fixed mul value is      :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :           0.75           (bin : 00011000) --> 000110000001000011011110101000001
# wei value is            :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :         0.0703125        (bin : 00000010) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.15625         (bin : 00000101) --> 000000000000000000000010000000001
# wei value is            :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.65625         (bin : 00010101) --> 000110000001000001011110101000001
# wei value is            :          0.78125         (bin : 00011001) --> 000100110000001000101101111010001
# stochastic mul value is :          0.71875         (bin : 00010111) --> 000100000000000000001100101000001
# fixed mul value is      :       0.5126953125       (bin : 00010001) --> 000001100000000000010000000000001
# ------------------------------------------------------------------------------------------
# act value is            :           0.25           (bin : 00001000) --> 000010000000000000000110000000001
# wei value is            :          1.46875         (bin : 00101111) --> 001101111000011101111111111111101
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000000110000000001
# fixed mul value is      :         0.3671875        (bin : 00001100) --> 000000000000000000000000000001101
# ------------------------------------------------------------------------------------------
# act value is            :          -0.9375         (bin : 11100010) --> 110001111100110100100000010111010
# wei value is            :          0.90625         (bin : 00011101) --> 000100110000001100101101111010101
# stochastic mul value is :         -0.71875         (bin : 11101001) --> 100000110000000100100000010010000
# fixed mul value is      :       -0.849609375       (bin : 11100100) --> 100011001000001110001000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          1.6875          (bin : 00110110) --> 001111100011111111111111111110111
# wei value is            :          0.53125         (bin : 00010001) --> 000000110000001000001001110000001
# stochastic mul value is :          0.84375         (bin : 00011011) --> 000000100000001000001001110000001
# fixed mul value is      :        0.896484375       (bin : 00011100) --> 000011000000000000100111000000001
# ------------------------------------------------------------------------------------------
# act value is            :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# wei value is            :          0.65625         (bin : 00010101) --> 000000110000001000101101110000001
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.96875         (bin : 00011111) --> 001110000011001011011110101000101
# wei value is            :          1.34375         (bin : 00101011) --> 000101111000011101111111111010101
# stochastic mul value is :          1.3125          (bin : 00101010) --> 000100000000001001011110101000101
# fixed mul value is      :       1.3017578125       (bin : 00101010) --> 000001011110101000000011000000101
# ------------------------------------------------------------------------------------------
# act value is            :          1.9375          (bin : 00111110) --> 011111111011111111111111111111111
# wei value is            :          0.5625          (bin : 00010010) --> 000000110000001000001101110000001
# stochastic mul value is :          1.0625          (bin : 00100010) --> 000000110000001000001101110000001
# fixed mul value is      :        1.08984375        (bin : 00100011) --> 011000000100000100111010000000001
# ------------------------------------------------------------------------------------------
# act value is            :         -0.46875         (bin : 11110001) --> 110000011100010000000000000011000
# wei value is            :          0.9375          (bin : 00011110) --> 000100110000001100101101111010101
# stochastic mul value is :         -0.21875         (bin : 11111001) --> 100000010000000000000000000010000
# fixed mul value is      :       -0.439453125       (bin : 11110010) --> 100000011000000000000000000010000
# ------------------------------------------------------------------------------------------
# act value is            :          1.90625         (bin : 00111101) --> 011111111011111111111111111111111
# wei value is            :          1.90625         (bin : 00111101) --> 011111111011111111111111111111111
# stochastic mul value is :           3.75           (bin : 01111000) --> 011111111011111111111111111111111
# fixed mul value is      :       3.6337890625       (bin : 01110110) --> 011111111111111111111111111111111
# ------------------------------------------------------------------------------------------
# act value is            :            0.5           (bin : 00010000) --> 000110000001000001001110000000001
# wei value is            :         -0.09375         (bin : 11111101) --> 100000000100000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :         -0.046875        (bin : 11111111) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          1.53125         (bin : 00110001) --> 001111000011101111111111111100111
# wei value is            :          0.9375          (bin : 00011110) --> 000100110000001100101101111010101
# stochastic mul value is :          1.4375          (bin : 00101110) --> 000100000000001100101101111000101
# fixed mul value is      :        1.435546875       (bin : 00101110) --> 000000010000110111101010000000111
# ------------------------------------------------------------------------------------------
# act value is            :         -0.28125         (bin : 11110111) --> 100000011100000000000000000001000
# wei value is            :          1.21875         (bin : 00100111) --> 000101111000001100111111111010101
# stochastic mul value is :         -0.21875         (bin : 11111001) --> 100000011000000000000000000000000
# fixed mul value is      :       -0.3427734375      (bin : 11110101) --> 100000100000000011000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          -0.4375         (bin : 11110010) --> 110000011100010000000000000011000
# wei value is            :          0.90625         (bin : 00011101) --> 000100110000001100101101111010001
# stochastic mul value is :         -0.21875         (bin : 11111001) --> 100000010000000000000000000010000
# fixed mul value is      :       -0.396484375       (bin : 11110100) --> 100000010000000001100000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.53125         (bin : 00010001) --> 000110000001000001001110100000001
# wei value is            :          -0.1875         (bin : 11111010) --> 100000000110000000000000000000010
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :       -0.099609375       (bin : 11111101) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :           1.875          (bin : 00111100) --> 011111110011111111111111111111111
# wei value is            :          0.15625         (bin : 00000101) --> 000000000000000000000001000000001
# stochastic mul value is :          0.21875         (bin : 00000111) --> 000000000000000000000001000000001
# fixed mul value is      :        0.29296875        (bin : 00001010) --> 000001000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          -0.6875         (bin : 11101010) --> 110000111100010100000000000111010
# wei value is            :          0.03125         (bin : 00000001) --> 000000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :       -0.021484375       (bin : 11111111) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.8125          (bin : 00011010) --> 000110000001001011011110101000001
# wei value is            :          0.65625         (bin : 00010101) --> 000000110000001000101101110000001
# stochastic mul value is :          0.59375         (bin : 00010011) --> 000000000000001000001100100000001
# fixed mul value is      :        0.533203125       (bin : 00010001) --> 000000001100000000000010000000001
# ------------------------------------------------------------------------------------------
# act value is            :           0.25           (bin : 00001000) --> 000010000000000000000110000000001
# wei value is            :           0.25           (bin : 00001000) --> 000000100000000000000001100000001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :          0.0625          (bin : 00000010) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.9375          (bin : 00011110) --> 001110000001001011011110101000101
# wei value is            :          -0.375          (bin : 11110100) --> 110000000111000010000000000000010
# stochastic mul value is :         -0.21875         (bin : 11111001) --> 100000000001000010000000000000000
# fixed mul value is      :        -0.3515625        (bin : 11110101) --> 100000011000000000000000000010000
# ------------------------------------------------------------------------------------------
# act value is            :          0.03125         (bin : 00000001) --> 000000000000000000000000000000000
# wei value is            :          1.96875         (bin : 00111111) --> 000000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# fixed mul value is      :       0.0615234375       (bin : 00000010) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :           -0.75          (bin : 11101000) --> 110000111100010100000000010111010
# wei value is            :           0.625          (bin : 00010100) --> 000000110000001000101101110000001
# stochastic mul value is :         -0.34375         (bin : 11110101) --> 100000110000000000000000010000000
# fixed mul value is      :         -0.46875         (bin : 11110000) --> 100111000000000000000000010000000
# ------------------------------------------------------------------------------------------
# act value is            :          1.96875         (bin : 00111111) --> 000000000000000000000000000000000
# wei value is            :          0.03125         (bin : 00000001) --> 000000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# fixed mul value is      :       0.0615234375       (bin : 00000010) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :         -0.65625         (bin : 11101011) --> 110000111100010100000000000111010
# wei value is            :          -0.5625         (bin : 11101110) --> 110010000111100010000000000001010
# stochastic mul value is :          0.46875         (bin : 00001111) --> 010000000100000000000000000001010
# fixed mul value is      :        0.369140625       (bin : 00001100) --> 001100000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          0.21875         (bin : 00000111) --> 000010000000000000000110000000001
# wei value is            :           0.625          (bin : 00010100) --> 000000110000001000101101110000001
# stochastic mul value is :          0.21875         (bin : 00000111) --> 000000000000000000000100000000001
# fixed mul value is      :        0.13671875        (bin : 00000100) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :         -0.59375         (bin : 11101101) --> 110000111100010000000000000011010
# wei value is            :          0.65625         (bin : 00010101) --> 000000110000001000101101110000001
# stochastic mul value is :         -0.21875         (bin : 11111001) --> 100000110000000000000000000000000
# fixed mul value is      :       -0.3896484375      (bin : 11110011) --> 100000000100000000011000000000000
# ------------------------------------------------------------------------------------------
# act value is            :           1.625          (bin : 00110100) --> 001111100011111111111111111100111
# wei value is            :          0.96875         (bin : 00011111) --> 000100111000001100101101111010101
# stochastic mul value is :          1.5625          (bin : 00110010) --> 000100100000001100101101111000101
# fixed mul value is      :        1.57421875        (bin : 00110100) --> 000000110000001001011011110101001
# ------------------------------------------------------------------------------------------
# act value is            :          0.65625         (bin : 00010101) --> 000110000001000001011110101000001
# wei value is            :          0.6875          (bin : 00010110) --> 000000110000001000101101111000001
# stochastic mul value is :          0.59375         (bin : 00010011) --> 000000000000000000001100101000001
# fixed mul value is      :        0.451171875       (bin : 00001110) --> 011111111111111111111111111111111
# ------------------------------------------------------------------------------------------
# act value is            :          0.15625         (bin : 00000101) --> 000000000000000000000010000000001
# wei value is            :           0.875          (bin : 00011100) --> 000100110000001100101101111010001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :        0.13671875        (bin : 00000101) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :            1.5           (bin : 00110000) --> 001111000011101111111111111100111
# wei value is            :            1.5           (bin : 00110000) --> 001101111000011101111111111111101
# stochastic mul value is :          2.15625         (bin : 01000101) --> 001101000000001101111111111100101
# fixed mul value is      :           2.25           (bin : 01001001) --> 001111110100010011110000110010111
# ------------------------------------------------------------------------------------------
# act value is            :          -0.8125         (bin : 11100110) --> 110000111100110100000000010111010
# wei value is            :          1.84375         (bin : 00111011) --> 011111111001111111111111111111111
# stochastic mul value is :          -1.4375         (bin : 11010010) --> 110000111000110100000000010111010
# fixed mul value is      :       -1.498046875       (bin : 11001111) --> 111101100001111000101000000000100
# ------------------------------------------------------------------------------------------
# act value is            :          1.5625          (bin : 00110010) --> 001111100011101111111111111100111
# wei value is            :           0.125          (bin : 00000100) --> 000000000000000000000001000000001
# stochastic mul value is :          0.21875         (bin : 00000111) --> 000000000000000000000001000000001
# fixed mul value is      :         0.1953125        (bin : 00000111) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          0.15625         (bin : 00000101) --> 000000000000000000000010000000001
# wei value is            :          0.3125          (bin : 00001010) --> 000000100000000000001001100000001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :        0.048828125       (bin : 00000001) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :           0.75           (bin : 00011000) --> 000110000001000011011110101000001
# wei value is            :          -0.125          (bin : 11111100) --> 100000000110000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :         -0.09375         (bin : 11111101) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          1.21875         (bin : 00100111) --> 001111000011001011111111101000101
# wei value is            :           0.25           (bin : 00001000) --> 000000100000000000000001100000001
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000000001100000001
# fixed mul value is      :         0.3046875        (bin : 00001010) --> 000000000000000000000000000010001
# ------------------------------------------------------------------------------------------
# act value is            :          0.78125         (bin : 00011001) --> 000110000001000011011110101000001
# wei value is            :          1.84375         (bin : 00111011) --> 011111111001111111111111111111111
# stochastic mul value is :          1.4375          (bin : 00101110) --> 000110000001000011011110101000001
# fixed mul value is      :       1.4404296875       (bin : 00101110) --> 011101010000000110000001000011011
# ------------------------------------------------------------------------------------------
# act value is            :          0.3125          (bin : 00001010) --> 000010000000000000001110000000001
# wei value is            :          0.3125          (bin : 00001010) --> 000000100000000000001001100000001
# stochastic mul value is :          0.21875         (bin : 00000111) --> 000000000000000000001000000000001
# fixed mul value is      :        0.09765625        (bin : 00000011) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          1.96875         (bin : 00111111) --> 000000000000000000000000000000000
# wei value is            :          0.84375         (bin : 00011011) --> 000100110000001100101101111010001
# stochastic mul value is :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# fixed mul value is      :       1.6611328125       (bin : 00110111) --> 010000001110000001001011011110101
# ------------------------------------------------------------------------------------------
# act value is            :          -0.875          (bin : 11100100) --> 110000111100110100100000010111010
# wei value is            :          0.4375          (bin : 00001110) --> 000000100000001000001001110000001
# stochastic mul value is :         -0.21875         (bin : 11111001) --> 100000100000000000000000010000000
# fixed mul value is      :        -0.3828125        (bin : 11110100) --> 100001000000000110000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          1.5625          (bin : 00110010) --> 001111100011101111111111111100111
# wei value is            :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# fixed mul value is      :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# wei value is            :          0.8125          (bin : 00011010) --> 000100110000001000101101111010001
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.34375         (bin : 00001011) --> 000010000000000000001110000000001
# wei value is            :           0.75           (bin : 00011000) --> 000000110000001000101101111010001
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000001100000000001
# fixed mul value is      :         0.2578125        (bin : 00001000) --> 000000000000000000000000000010001
# ------------------------------------------------------------------------------------------
# act value is            :          0.21875         (bin : 00000111) --> 000000000000000000000110000000001
# wei value is            :           0.875          (bin : 00011100) --> 000100110000001100101101111010001
# stochastic mul value is :          0.21875         (bin : 00000111) --> 000000000000000000000100000000001
# fixed mul value is      :        0.19140625        (bin : 00000110) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :         -0.28125         (bin : 11110111) --> 100000011100000000000000000001000
# wei value is            :          0.59375         (bin : 00010011) --> 000000110000001000101101110000001
# stochastic mul value is :         -0.09375         (bin : 11111101) --> 100000010000000000000000000000000
# fixed mul value is      :       -0.1669921875      (bin : 11111011) --> 100000001000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.1875          (bin : 00000110) --> 000000000000000000000110000000001
# wei value is            :          0.65625         (bin : 00010101) --> 000000110000001000101101110000001
# stochastic mul value is :          0.21875         (bin : 00000111) --> 000000000000000000000100000000001
# fixed mul value is      :        0.123046875       (bin : 00000100) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          0.71875         (bin : 00010111) --> 000110000001000001011110101000001
# wei value is            :          1.46875         (bin : 00101111) --> 001101111000011101111111111110101
# stochastic mul value is :          1.0625          (bin : 00100010) --> 000100000000000001011110101000001
# fixed mul value is      :       1.0556640625       (bin : 00100001) --> 001110000000000011000000100000101
# ------------------------------------------------------------------------------------------
# act value is            :          0.71875         (bin : 00010111) --> 000110000001000011011110101000001
# wei value is            :          0.4375          (bin : 00001110) --> 000000100000001000001001110000001
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000001000100000001
# fixed mul value is      :        0.314453125       (bin : 00001011) --> 000010000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :           1.125          (bin : 00100100) --> 001111000011001011011111101000101
# wei value is            :           1.75           (bin : 00111000) --> 011111111000111111111111111111101
# stochastic mul value is :          1.9375          (bin : 00111110) --> 001111000000001011011111101000101
# fixed mul value is      :          1.96875         (bin : 01000000) --> 000011001011011110101000100111001
# ------------------------------------------------------------------------------------------
# act value is            :          0.8125          (bin : 00011010) --> 000110000001001011011110101000001
# wei value is            :          1.65625         (bin : 00110101) --> 001111111000111111111111111111101
# stochastic mul value is :          1.4375          (bin : 00101110) --> 000110000000001011011110101000001
# fixed mul value is      :        1.345703125       (bin : 00101101) --> 011000000100000101111010100000001
# ------------------------------------------------------------------------------------------
# act value is            :            1.0           (bin : 00100000) --> 001110000011001011011110101000101
# wei value is            :          0.21875         (bin : 00000111) --> 000000000000000000000001100000001
# stochastic mul value is :          0.21875         (bin : 00000111) --> 000000000000000000000000100000001
# fixed mul value is      :          0.21875         (bin : 00000111) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          1.3125          (bin : 00101010) --> 001111000011101011111111111000101
# wei value is            :          1.1875          (bin : 00100110) --> 000101111000001100111111111010101
# stochastic mul value is :          1.6875          (bin : 00110110) --> 000101000000001000111111111000101
# fixed mul value is      :        1.55859375        (bin : 00110010) --> 011111111111111111111111111111111
# ------------------------------------------------------------------------------------------
# act value is            :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# wei value is            :          1.5625          (bin : 00110010) --> 001111111000011101111111111111101
# stochastic mul value is :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# fixed mul value is      :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :           0.25           (bin : 00001000) --> 000010000000000000000110000000001
# wei value is            :          1.0625          (bin : 00100010) --> 000100111000001100101111111010101
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000000110000000001
# fixed mul value is      :         0.265625         (bin : 00001001) --> 000000000000000000000000000000011
# ------------------------------------------------------------------------------------------
# act value is            :          0.78125         (bin : 00011001) --> 000110000001000011011110101000001
# wei value is            :          0.21875         (bin : 00000111) --> 000000100000000000000001100000001
# stochastic mul value is :          0.21875         (bin : 00000111) --> 000000000000000000000000100000001
# fixed mul value is      :       0.1708984375       (bin : 00000110) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :           0.25           (bin : 00001000) --> 000010000000000000000110000000001
# wei value is            :          1.28125         (bin : 00101001) --> 000101111000011101111111111010101
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000000110000000001
# fixed mul value is      :         0.3203125        (bin : 00001011) --> 000000000000000000001000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          0.4375          (bin : 00001110) --> 000110000000000001001110000000001
# wei value is            :         -0.46875         (bin : 11110001) --> 110000000111100010000000000000010
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :       -0.205078125       (bin : 11111001) --> 100000010000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.9375          (bin : 00011110) --> 001110000001001011011110101000101
# wei value is            :           0.875          (bin : 00011100) --> 000100110000001100101101111010001
# stochastic mul value is :          0.84375         (bin : 00011011) --> 000100000000001000001100101000001
# fixed mul value is      :         0.8203125        (bin : 00011010) --> 011100000000000010000000000001001
# ------------------------------------------------------------------------------------------
# act value is            :          0.21875         (bin : 00000111) --> 000000000000000000000110000000001
# wei value is            :          0.15625         (bin : 00000101) --> 000000000000000000000001100000001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :       0.0341796875       (bin : 00000001) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.4375          (bin : 00001110) --> 000110000000000001001110000000001
# wei value is            :          -0.375          (bin : 11110100) --> 110000000111000010000000000000010
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :        -0.1640625        (bin : 11111011) --> 100000000001000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :           -0.25          (bin : 11111000) --> 100000011100000000000000000001000
# wei value is            :          -0.0625         (bin : 11111110) --> 100000000100000000000000000000000
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000100000000000000000000000
# fixed mul value is      :         0.015625         (bin : 00000000) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# ...
# act value is            :          0.6875          (bin : 00010110) --> 000110000001000001011110101000001
# wei value is            :          0.03125         (bin : 00000001) --> 000000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# fixed mul value is      :        0.021484375       (bin : 00000000) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.40625         (bin : 00001101) --> 000010000000000001001110000000001
# wei value is            :         -0.53125         (bin : 11101111) --> 110010000111100010000000000000010
# stochastic mul value is :         -0.09375         (bin : 11111101) --> 100010000000000000000000000000000
# fixed mul value is      :       -0.2158203125      (bin : 11111001) --> 110000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :         -0.09375         (bin : 11111101) --> 100000000100000000000000000000000
# wei value is            :          0.4375          (bin : 00001110) --> 000000100000001000001001110000001
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :       -0.041015625       (bin : 11111111) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :           -0.5           (bin : 11110000) --> 110000111100010000000000000011000
# wei value is            :          0.0625          (bin : 00000010) --> 000000000000000000000000000000001
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :         -0.03125         (bin : 11111111) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.21875         (bin : 00000111) --> 000010000000000000000110000000001
# wei value is            :          1.0625          (bin : 00100010) --> 000100111000001100101111111010101
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000000110000000001
# fixed mul value is      :        0.232421875       (bin : 00001000) --> 000000000000000000000000000000011
# ------------------------------------------------------------------------------------------
# act value is            :          0.28125         (bin : 00001001) --> 000010000000000000000110000000001
# wei value is            :           1.25           (bin : 00101000) --> 000101111000011100111111111010101
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000000110000000001
# fixed mul value is      :         0.3515625        (bin : 00001100) --> 000000000000001100000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          -0.9375         (bin : 11100010) --> 110001111100110100100000010111010
# wei value is            :          0.28125         (bin : 00001001) --> 000000100000000000000001100000001
# stochastic mul value is :         -0.09375         (bin : 11111101) --> 100000100000000000000000000000000
# fixed mul value is      :       -0.263671875       (bin : 11111000) --> 100000000000000000000001100000000
# ------------------------------------------------------------------------------------------
# act value is            :           0.25           (bin : 00001000) --> 000010000000000000000110000000001
# wei value is            :          0.46875         (bin : 00001111) --> 000000100000001000001001110000001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :         0.1171875        (bin : 00000100) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          1.53125         (bin : 00110001) --> 001111100011101111111111111100111
# wei value is            :            0.5           (bin : 00010000) --> 000000110000001000001001110000001
# stochastic mul value is :          0.84375         (bin : 00011011) --> 000000100000001000001001110000001
# fixed mul value is      :         0.765625         (bin : 00011001) --> 000000000100000000000010011100001
# ------------------------------------------------------------------------------------------
# act value is            :          0.46875         (bin : 00001111) --> 000110000000000001001110000000001
# wei value is            :          0.28125         (bin : 00001001) --> 000000100000000000000001100000001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :       0.1318359375       (bin : 00000100) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          0.6875          (bin : 00010110) --> 000110000001000001011110101000001
# wei value is            :          0.96875         (bin : 00011111) --> 000100111000001100101101111010101
# stochastic mul value is :          0.71875         (bin : 00010111) --> 000100000000000000001100101000001
# fixed mul value is      :        0.666015625       (bin : 00010110) --> 000000000000000111000000000000101
# ------------------------------------------------------------------------------------------
# act value is            :            0.5           (bin : 00010000) --> 000110000001000001001110000000001
# wei value is            :          0.71875         (bin : 00010111) --> 000000110000001000101101111010001
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000001100000000001
# fixed mul value is      :         0.359375         (bin : 00001100) --> 000000000000000000000000011000001
# ------------------------------------------------------------------------------------------
# act value is            :         -0.21875         (bin : 11111001) --> 100000011100000000000000000001000
# wei value is            :         -0.28125         (bin : 11110111) --> 100000000111000000000000000000010
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000100000000000000000000000
# fixed mul value is      :       0.0615234375       (bin : 00000010) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# wei value is            :          -0.5625         (bin : 11101110) --> 110010000111100010000000000001010
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :           -0.0           (bin : 00000000) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.65625         (bin : 00010101) --> 000110000001000001011110101000001
# wei value is            :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :       0.0615234375       (bin : 00000010) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :         -0.53125         (bin : 11101111) --> 110000111100010000000000000011010
# wei value is            :          1.1875          (bin : 00100110) --> 000101111000001100111111111010101
# stochastic mul value is :         -0.46875         (bin : 11110001) --> 100000111000000000000000000010000
# fixed mul value is      :       -0.630859375       (bin : 11101011) --> 100000000000000001001000001110000
# ------------------------------------------------------------------------------------------
# act value is            :          0.84375         (bin : 00011011) --> 001110000001001011011110101000001
# wei value is            :          1.21875         (bin : 00100111) --> 000101111000011100111111111010101
# stochastic mul value is :          1.0625          (bin : 00100010) --> 000100000000001000011110101000001
# fixed mul value is      :       1.0283203125       (bin : 00100010) --> 011100000000000110000001000001001
# ------------------------------------------------------------------------------------------
# act value is            :          1.03125         (bin : 00100001) --> 001110000011001011011111101000101
# wei value is            :          0.9375          (bin : 00011110) --> 000100110000001100101101111010101
# stochastic mul value is :          1.0625          (bin : 00100010) --> 000100000000001000001101101000101
# fixed mul value is      :        0.966796875       (bin : 00100000) --> 000010000010011100000000000110001
# ------------------------------------------------------------------------------------------
# act value is            :          1.84375         (bin : 00111011) --> 011111110011111111111111111111111
# wei value is            :          0.0625          (bin : 00000010) --> 000000000000000000000000000000001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :        0.115234375       (bin : 00000101) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :         -0.03125         (bin : 11111111) --> 100000000000000000000000000000000
# wei value is            :            0.0           (bin : 00000000) --> 000000000000000000000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :           -0.0           (bin : 00000000) --> 100000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.6875          (bin : 00010110) --> 000110000001000001011110101000001
# wei value is            :          0.40625         (bin : 00001101) --> 000000100000000000001001110000001
# stochastic mul value is :          0.34375         (bin : 00001011) --> 000000000000000000001000100000001
# fixed mul value is      :        0.279296875       (bin : 00001001) --> 000000001000000000000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :          1.8125          (bin : 00111010) --> 011111110011111111111111111110111
# wei value is            :           0.75           (bin : 00011000) --> 000000110000001000101101111010001
# stochastic mul value is :          1.4375          (bin : 00101110) --> 000000110000001000101101111010001
# fixed mul value is      :         1.359375         (bin : 00101011) --> 001000001011110101000000011000001
# ------------------------------------------------------------------------------------------
# act value is            :          0.84375         (bin : 00011011) --> 000110000001001011011110101000001
# wei value is            :          1.34375         (bin : 00101011) --> 000101111000011101111111111110101
# stochastic mul value is :          1.1875          (bin : 00100110) --> 000100000000001001011110101000001
# fixed mul value is      :       1.1337890625       (bin : 00100100) --> 000000011000000100000100111010001
# ------------------------------------------------------------------------------------------
# act value is            :         -0.28125         (bin : 11110111) --> 110000011100000000000000000001000
# wei value is            :          0.71875         (bin : 00010111) --> 000000110000001000101101111000001
# stochastic mul value is :         -0.09375         (bin : 11111101) --> 100000010000000000000000000000000
# fixed mul value is      :       -0.2021484375      (bin : 11111001) --> 100000000000000000000000000000100
# ------------------------------------------------------------------------------------------
# act value is            :         -0.46875         (bin : 11110001) --> 110000011100010000000000000011000
# wei value is            :           0.25           (bin : 00001000) --> 000000100000000000000001100000001
# stochastic mul value is :            0.0           (bin : 00000000) --> 100000000000000000000000000000000
# fixed mul value is      :        -0.1171875        (bin : 11111100) --> 100000000000000000000010000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.90625         (bin : 00011101) --> 001110000001001011011110101000001
# wei value is            :          0.84375         (bin : 00011011) --> 000100110000001000101101111010001
# stochastic mul value is :          0.84375         (bin : 00011011) --> 000100000000001000001100101000001
# fixed mul value is      :       0.7646484375       (bin : 00011000) --> 000000100000000000010011100000001
# ------------------------------------------------------------------------------------------
# act value is            :          1.84375         (bin : 00111011) --> 011111110011111111111111111111111
# wei value is            :          -0.625          (bin : 11101100) --> 111010000111100010000000000001010
# stochastic mul value is :          -1.0625         (bin : 11011110) --> 111010000011100010000000000001010
# fixed mul value is      :        -1.15234375       (bin : 11011010) --> 101111000100000000000000110110000
# ------------------------------------------------------------------------------------------
# act value is            :          -0.4375         (bin : 11110010) --> 110000011100010000000000000011000
# wei value is            :           -0.25          (bin : 11111000) --> 100000000111000000000000000000010
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000100000000000000000000000
# fixed mul value is      :         0.109375         (bin : 00000011) --> 000000000000000000000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :            0.5           (bin : 00010000) --> 000110000001000001001110000000001
# wei value is            :           -0.25          (bin : 11111000) --> 100000000111000000000000000000010
# stochastic mul value is :         -0.09375         (bin : 11111101) --> 100000000001000000000000000000000
# fixed mul value is      :          -0.125          (bin : 11111100) --> 100000000000000000000001000000000
# ------------------------------------------------------------------------------------------
# act value is            :           1.625          (bin : 00110100) --> 001111100011111111111111111100111
# wei value is            :          -0.4375         (bin : 11110010) --> 110000000111100010000000000000010
# stochastic mul value is :         -0.59375         (bin : 11101101) --> 100000000011100010000000000000010
# fixed mul value is      :        -0.7109375        (bin : 11101001) --> 100110010000011100000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :          0.53125         (bin : 00010001) --> 000110000001000001001110000000001
# wei value is            :          0.28125         (bin : 00001001) --> 000000100000000000000001100000001
# stochastic mul value is :          0.09375         (bin : 00000011) --> 000000000000000000000000000000001
# fixed mul value is      :       0.1494140625       (bin : 00000101) --> 000000000000000000000000000000001
# ------------------------------------------------------------------------------------------
