# %% [markdown]
# # Multiplier TEST code

# %% [markdown]
# fixed number to stochastic conversion & multiply & stochastic to fixed number conversion

# %% [markdown]
# ## Import

# %%
import random, struct, math
import torch
import numpy as np
import torch.nn as nn 
import argparse
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Parser

# %%
parser = argparse.ArgumentParser(description='fixed_mac')
parser.add_argument('--full_bits', type=int, default=8, help='Number of Quantization Bits')
parser.add_argument('--frac_bits', type=int, default=4, help='Number of Quantization Bits')
parser.add_argument('--bBW', type=int, default=4, help='Number of bit width')
args = parser.parse_args(args=[])

# %% [markdown]
# ## Definition

# %% [markdown]
# ### int2bin : int number to binary number

# %%
def int2bin(iIn,iBW):
    iBW = iBW + 1
    if iIn >= 0:
        bOut = bin(iIn).replace('0b','').rjust(iBW,'0')
    else :
        bOut = bin(iIn & (pow(2,iBW)-1)).replace('0b','').rjust(iBW,'1')
    return bOut[1:]

# %% [markdown]
# ### XOR : xor gate with string

# %%
def XOR(iA,iB):
    if iA != iB :
        iOut = '1'
    else : 
        iOut = '0'
    return iOut

# %% [markdown]
# ### SNUM : sign number determination

# %%
def snum(a):
    if a >= 0 :
        return '0'
    else :
        return '1'

# %% [markdown]
# ### fxp & flp2fix : floating number to fixed number conversion

# %%
class fxp:
    def __init__(self, bIn, iBWF):
        self.iFullBW = len(bIn)
        self.iIntgBW = self.iFullBW - iBWF
        self.bSign = bIn[0]
        self.bIntg = bIn[:self.iIntgBW]
        self.bFrac = bIn[self.iIntgBW:]
        self.fFull = 0
        try:
            for idx, bit in enumerate(bIn):
                if idx == 0:
                    self.fFull = self.fFull + int(bit,2) * -pow(2, self.iIntgBW - 1)
                else:
                    self.fFull = self.fFull + int(bit,2) * pow(2, self.iIntgBW - 1 - idx)
        except:
            print(bIn)
        self.dispFull = self.bIntg +"."+ self.bFrac 
        return

# %%
class flp2fix:
    def __init__(self, fIn, iBW, iBWF):
        self.fMin = - 2 ** (iBW - iBWF - 1)
        self.fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
        self.fResol = 2 ** -iBWF
        if fIn < self.fMin or fIn > self.fMax:
            print(f'({fIn}): Out of input range ({self.fMax}/{self.fMin}) during flp -> fix converting ')
        self.iBW = iBW
        self.iBWI = iBW - iBWF
        self.iBWF = iBWF

        self.iFLP2INT = abs(int(fIn * 2 ** iBWF))
        if fIn < 0:
            self.iFLP2INT = 2 ** (iBW-1) - self.iFLP2INT

        if fIn >= 0:
            self.bFull = bin(self.iFLP2INT)[2:].rjust(iBW, '0')
        else:
            self.bFull = '1'+bin(self.iFLP2INT)[2:].rjust(iBW-1, '0')
            if len(self.bFull) > iBW:
                self.bFull = '0' * iBW

        self.cssFxp = fxp(self.bFull, self.iBWF)
        self.bSign = self.cssFxp.bSign
        self.bIntg = self.cssFxp.bIntg
        self.bFrac = self.cssFxp.bFrac
        self.fFull = self.cssFxp.fFull
        return

# %% [markdown]
# ### LFSR : make pseudorandom number bitstream

# %%
class LFSR:
    def Random(self):
        self.b0 = eval(f'str(random.randint(0,1))')
        self.b1 = eval(f'str(random.randint(0,1))')
        self.b2 = eval(f'str(random.randint(0,1))')
        self.b3 = eval(f'str(random.randint(0,1))')
        
        return self.b0 + self.b1 + self.b2 + self.b3
    
    def Normal(self,stream):
        self.b0 = XOR(int(stream[2]),int(stream[3]))
        self.b1 = stream[0]
        self.b2 = stream[1]
        self.b3 = stream[2]
        
        return self.b0 + self.b1 + self.b2 + self.b3
    
    def Allzero(self):
        self.b0 = '0'
        self.b1 = '0'
        self.b2 = '0'
        self.b3 = '0'
        
        return self.b0 + self.b1 + self.b2 + self.b3

# %% [markdown]
# ### LFSRlist : make pseudorandom number bitstream with 2**bBW cycle

# %%
def LFSRlist():
    lfsr = LFSR()
    lfsrlist = []
    for k in range(2**(args.bBW)-1): #lfsr number generating
        if k == 0:
            lfsrlist.append(lfsr.Random())
        else :
            lfsrlist.append(lfsr.Normal(lfsrlist[k-1]))
        if (k == 2**(args.bBW)-2):
            lfsrlist.append(lfsr.Allzero())
    
    if (args.bBW) != args.frac_bits :
        if args.bBW < args.frac_bits :
            for i in range(len(lfsrlist)):
                lfsrlist[i] = lfsrlist[i] + (args.frac_bits-args.bBW)*'0'
        else :
            print("it can't work")
            return 0
    
    return lfsrlist

# %% [markdown]
# ### Comp : Comparator in SNG

# %%
def Comp(a,lfsr,snum):
    for com in range(0,len(a)):
        oA = '0'
        if a[com]!=lfsr[com]:
            if(int(a[com]) > int(lfsr[com])):
                oA = '1'
            break
    return XOR(oA,snum)

# %% [markdown]
# ### Perm : module for permutation SNG

# %%
def perm(a):
    al = len(a)
    blist = []
    for i in range(al) :
        #print(al-i-1)
        blist.append(a[al-i-1])
    
    b = "".join(blist)
    
    return b

# %% [markdown]
# ### findMaxMin : find abs max value in act tensor

# %%
def findMaxMin(data):
    max = torch.max(data)
    min = torch.min(data)
    SF=torch.max(abs(max),abs(min)).item()
    return SF

# %% [markdown]
# ### SNG : stochastic number generator module

# %%
def SNG(iIN,lfsr):

    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        lNUM = lfsr[k]
        a = Comp(bIN[-(args.frac_bits):],lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if sNUM == '1' and bIN == args.full_bits*'0' :
        return '10000000000000000'
    else :
        return sA

# %% [markdown]
# ### SNG_P : permutation stochastic number generator module

# %%
def SNG_P(iIN,lfsr):
    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        if (args.bBW == args.frac_bits) :    
            lNUM = perm(lfsr[k])
        elif (args.bBW < args.frac_bits) :
            lNUM = perm(lfsr[k][:args.bBW])+(args.frac_bits-args.bBW)*"0"
        a = Comp(bIN[-(args.frac_bits):],lNUM,sNUM)
        oAlist.append(Comp(bIN[-(args.frac_bits):],lNUM,sNUM)) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if sNUM == '1' and bIN == args.full_bits*'0' :
        return '10000000000000000'
    else :
        return sA

# %% [markdown]
# ### SNGnumpy : SNG module with numpy

# %%
def SNGnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG(float(aNumpy),lfsr))
                     
    return np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### SNGpnumpy : permutation SNG module with numpy

# %%
def SNGpnumpy(fIn,lfsr):
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG_P(float(aNumpy),lfsr))
                     
    return  np.array(sList).reshape(fIn.size())

# %% [markdown]
# ### CountOne : count 1 in stochastic number bit stream

# %%
def CountOne(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        n = 0
        for a in num:
            if a == '1' :
                n += 1
        if num[0] == '1' :
            nlist.append(n-1)
        else :
            nlist.append(n)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### defSign : sign determination in S2N

# %%
def defSign(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        if num[0] == '1' :
            nlist.append(-1)
        else :
            nlist.append(1)
    return torch.tensor(nlist).view(nIn.shape)

# %% [markdown]
# ### Multiplier

# %%
def mul(a,b):
    al = len(a)
    bl = len(b)
    
    outlist = []
    
    if al != bl :
        print("length of string is different")
        return 0
    
    outlist.append(XOR(a[0],b[0]))
    
    for i in range(al-1) :
        outlist.append(str(int(a[i+1]) & int(b[i+1])))
    
    #print(outlist)
    out = "".join(outlist)
    
    return out

# %%
def defSign1(nIn):
    if nIn[0] == '1' :
        return -1
    else :
        return 1

# %%
def CountOne1(nIn):
    n = 0
    for num in nIn:
        if num == '1' :
            n += 1
    if nIn[0] == '1' :
        return n-1
    else :
        return n

# %%
def S2None(sIn,SF):
    s = defSign(sIn)
    o = (CountOne(sIn)/(2**args.bBW))*SF*s
    return o

# %%
def mulNumpy(aIn,bIn,aSF,wSF):
    mList = []
    for i in range(aIn.shape[0]):
        for j in range(bIn.T.shape[1]):
            sum = 0
            for k in range(aIn.shape[1]):
                sum += S2None(mul((aIn[i][k].astype(str)),(bIn.T)[k][j].astype(str)),aSF*wSF)
            mList.append(sum)
    return torch.tensor(mList).view(aIn.shape[0],bIn.T.shape[1])

# %%
def FindError(a,b):
    error = 0
    for anum,bnum in zip(a.view(-1),b.view(-1)):
        e = (abs(bnum-anum)*100).item()
        error += e
    return error/(len(a.view(-1))+len(b.view(-1)))

# %% [markdown]
# # TEST : LFSR 4 bit

# %%
act = torch.rand((10,15))-torch.randint(4,(10,15))+torch.randint(4,(10,15))
wei = torch.rand((10,15))-torch.randint(4,(10,15))+torch.randint(4,(10,15))

# %% [markdown]
# ### number to stochastic conversion

# %%
aSF = findMaxMin(act)
wSF = findMaxMin(wei)

# %%
def N2S(act,wei,aSF,wSF):
    
    lfsrlist = LFSRlist()
    
    a = SNGnumpy(act/aSF,lfsrlist)
    w = SNGpnumpy(wei/wSF,lfsrlist)
    
    return a,w

# %%
def N2Sone(data,SF):
    lfsrlist = LFSRlist()
    
    o = SNGnumpy(data/SF,lfsrlist)
    
    return o

# %% [markdown]
# ### stochastic to number conversion

# %%
def S2N(a,w,aSF,wSF):
    
    sa = defSign(a)
    sw = defSign(w)

    ca = (CountOne(a)/(2**args.bBW)) * aSF *sa
    cw = (CountOne(w)/(2**args.bBW)) * wSF *sw

    return ca,cw

# %%
a,w = N2S(act,wei,aSF,wSF)

# %%
ca,cw = S2N(a,w,aSF,wSF)

# %%
def multest(aIn,wIn,aSF,wSF):
    mlist=[]
    out = 0
    for a,b in zip(aIn.reshape(-1),wIn.reshape(-1)) :
        out = mul(a,b)
        mlist.append(out)
    
    return np.array(mlist).reshape(aIn.shape)

# %%
c = multest(a,w,aSF,wSF)

# %%
cc = S2None(c,aSF*wSF)

# %%
print(aSF,wSF)
# Out:
# 3.9843709468841553 3.9465112686157227

# %%
for i in range(10):
    for j in range(15):
        print(f'act value is            : {act[i][j]:^25}(bin : {flp2fix(act[i][j],args.full_bits,args.frac_bits).bFull:^8}) --> {a[i][j]}')
        print(f'wei value is            : {wei[i][j]:^25}(bin : {flp2fix(wei[i][j],args.full_bits,args.frac_bits).bFull:^8}) --> {w[i][j]}')
        print(f'stochastic mul value is : {cc[i][j]:^25}(bin : {flp2fix(cc[i][j],args.full_bits,args.frac_bits).bFull:^8}) --> {c[i][j]}')
        print(f'fixed mul value is      : {act[i][j]*wei[i][j]:^25}(bin : {flp2fix(act[i][j]*wei[i][j],args.full_bits,args.frac_bits).bFull:^8}) --> {N2Sone(act[i][j]*wei[i][j],aSF*wSF)}')
        print(f'------------------------------------------------------------------------------------------')
# Out:
# act value is            :     1.371891975402832    (bin : 00010101) --> 00110000000000111
# wei value is            :    -1.9569910764694214   (bin : 11100001) --> 10001001101011100
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000000000000100
# fixed mul value is      :    -2.6847803592681885   (bin : 11010110) --> 10000001100000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.9570809006690979    (bin : 00001111) --> 00010000000000011
# wei value is            :    0.5123023986816406    (bin : 00001000) --> 01000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.4903148412704468    (bin : 00000111) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     2.545206308364868    (bin : 00101000) --> 01111010100001111
# wei value is            :   -0.04226994514465332   (bin : 00000000) --> 10000000000000000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.10758572816848755   (bin : 11111111) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     2.526609182357788    (bin : 00101000) --> 01111010100001111
# wei value is            :    -1.4078928232192993   (bin : 11101010) --> 10000001001011100
# stochastic mul value is :    -1.965545654296875    (bin : 11100001) --> 10000000000001100
# fixed mul value is      :    -3.557194948196411    (bin : 11001000) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -2.133173704147339    (bin : 11011110) --> 11001101011110000
# wei value is            :    0.3604271411895752    (bin : 00000101) --> 00000000000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.7688537240028381   (bin : 11110100) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.2649257183074951    (bin : 00010100) --> 00110000000000111
# wei value is            :    0.6006631255149841    (bin : 00001001) --> 01000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.7597942352294922    (bin : 00001100) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.9000805616378784    (bin : 00001110) --> 00010000000000011
# wei value is            :     1.625157117843628    (bin : 00011010) --> 01110100010000001
# stochastic mul value is :     1.965545654296875    (bin : 00011111) --> 00010000000000001
# fixed mul value is      :    1.4627723693847656    (bin : 00010111) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    -0.7334957122802734   (bin : 11110101) --> 10000000000110000
# wei value is            :     1.92836594581604     (bin : 00011110) --> 01110110010000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -1.4144481420516968   (bin : 11101010) --> 10000000000010000
# ------------------------------------------------------------------------------------------
# act value is            :    3.1228599548339844    (bin : 00110001) --> 01111011110001111
# wei value is            :    0.6423536539077759    (bin : 00001010) --> 01000000000000001
# stochastic mul value is :     1.965545654296875    (bin : 00011111) --> 01000000000000001
# fixed mul value is      :    2.0059804916381836    (bin : 00100000) --> 00000000000100001
# ------------------------------------------------------------------------------------------
# act value is            :    -2.085742473602295    (bin : 11011111) --> 11001101011110000
# wei value is            :    0.4349311590194702    (bin : 00000110) --> 00000000000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.907154381275177    (bin : 11110010) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -0.5026959180831909   (bin : 11111000) --> 10000000000110000
# wei value is            :    0.30742573738098145   (bin : 00000100) --> 00000000000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.15454165637493134   (bin : 11111110) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    3.2835171222686768    (bin : 00110100) --> 01111111110001111
# wei value is            :    -1.3289923667907715   (bin : 11101011) --> 10000001001011100
# stochastic mul value is :    -2.9483184814453125   (bin : 11010001) --> 10000001000001100
# fixed mul value is      :    -4.363769054412842    (bin : 10111011) --> 10100001110000000
# ------------------------------------------------------------------------------------------
# act value is            :   -0.34988903999328613   (bin : 11111011) --> 10000000000010000
# wei value is            :    -0.3831942081451416   (bin : 11111010) --> 10000000000010000
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000010000
# fixed mul value is      :    0.13407544791698456   (bin : 00000010) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.26603198051452637   (bin : 00000100) --> 00000000000000001
# wei value is            :     0.866159200668335    (bin : 00001101) --> 01100000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.23042604327201843   (bin : 00000011) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.2933025360107422    (bin : 00010100) --> 00110000000000111
# wei value is            :    -1.6162958145141602   (bin : 11100111) --> 10000001101011100
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000000000000100
# fixed mul value is      :    -2.0903594493865967   (bin : 11011111) --> 10000000000110000
# ------------------------------------------------------------------------------------------
# act value is            :    0.5245184898376465    (bin : 00001000) --> 00000000000000011
# wei value is            :     2.394648551940918    (bin : 00100110) --> 01110110010100011
# stochastic mul value is :     1.965545654296875    (bin : 00011111) --> 00000000000000011
# fixed mul value is      :    1.2560374736785889    (bin : 00010100) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    -1.4638035297393799   (bin : 11101001) --> 10000101001110000
# wei value is            :    1.5398585796356201    (bin : 00011000) --> 01110100010000001
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000100000000000
# fixed mul value is      :    -2.2540504932403564   (bin : 11011100) --> 11100000000000000
# ------------------------------------------------------------------------------------------
# act value is            :   0.0026597976684570312  (bin : 00000000) --> 00000000000000000
# wei value is            :    -2.7408528327941895   (bin : 11010101) --> 10001011111111110
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :  -0.0072901141829788685  (bin : 00000000) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.7552263140678406    (bin : 00001100) --> 00010000000000011
# wei value is            :    1.5932693481445312    (bin : 00011001) --> 01110100010000001
# stochastic mul value is :     1.965545654296875    (bin : 00011111) --> 00010000000000001
# fixed mul value is      :     1.20327889919281     (bin : 00010011) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :     2.285982131958008    (bin : 00100100) --> 01110010100001111
# wei value is            :    -1.2976257801055908   (bin : 11101100) --> 10000001001011100
# stochastic mul value is :    -1.965545654296875    (bin : 11100001) --> 10000000000001100
# fixed mul value is      :    -2.9663493633270264   (bin : 11010001) --> 10000000000001110
# ------------------------------------------------------------------------------------------
# act value is            :     2.809927225112915    (bin : 00101100) --> 01111010110001111
# wei value is            :    0.5082186460494995    (bin : 00001000) --> 01000000000000001
# stochastic mul value is :     1.965545654296875    (bin : 00011111) --> 01000000000000001
# fixed mul value is      :    1.4280574321746826    (bin : 00010110) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :     0.558937668800354    (bin : 00001000) --> 00000000000000011
# wei value is            :     1.919302225112915    (bin : 00011110) --> 01110110010000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :     1.072770357131958    (bin : 00010001) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    -1.1773390769958496   (bin : 11101110) --> 10000100001110000
# wei value is            :   -0.37164604663848877   (bin : 11111011) --> 10000000000010000
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000010000
# fixed mul value is      :    0.43755340576171875   (bin : 00000111) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.8593788146972656    (bin : 00011101) --> 00110010100000111
# wei value is            :    -0.5942327976226807   (bin : 11110111) --> 10000000000011000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -1.1049038171768188   (bin : 11101111) --> 10000000010000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.03739750385284424   (bin : 00000000) --> 00000000000000000
# wei value is            :    0.7658629417419434    (bin : 00001100) --> 01100000000000001
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :   0.028641361743211746   (bin : 00000000) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.4822940230369568    (bin : 00000111) --> 00000000000000001
# wei value is            :    0.7216238975524902    (bin : 00001011) --> 01000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.34803488850593567   (bin : 00000101) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     -2.53546142578125    (bin : 11011000) --> 11001111011111000
# wei value is            :    -2.980886459350586    (bin : 11010001) --> 10011011111111110
# stochastic mul value is :      7.8621826171875     (bin : 01111101) --> 00001011011111000
# fixed mul value is      :     7.557922840118408    (bin : 01111000) --> 00100000110110011
# ------------------------------------------------------------------------------------------
# act value is            :     0.255354642868042    (bin : 00000100) --> 00000000000000001
# wei value is            :     2.735611915588379    (bin : 00101011) --> 01111110110100011
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.6985511779785156    (bin : 00001011) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -1.8036885261535645   (bin : 11100100) --> 10001101011110000
# wei value is            :    1.2668023109436035    (bin : 00010100) --> 01110100000000001
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000100000000000
# fixed mul value is      :    -2.284916877746582    (bin : 11011100) --> 10000000000001100
# ------------------------------------------------------------------------------------------
# act value is            :    3.6892828941345215    (bin : 00111011) --> 01111111111001111
# wei value is            :     3.706887722015381    (bin : 00111011) --> 01111111111101111
# (13.758819580078125): Out of input range (7.9375/-8) during flp -> fix converting
# stochastic mul value is :    13.758819580078125    (bin : 11011100) --> 01111111111001111
# (13.67575740814209): Out of input range (7.9375/-8) during flp -> fix converting
# fixed mul value is      :     13.67575740814209    (bin : 11011010) --> 00111111111111001
# ------------------------------------------------------------------------------------------
# act value is            :    -0.5957112312316895   (bin : 11110111) --> 10000000000110000
# wei value is            :    -1.3134377002716064   (bin : 11101011) --> 10000001001011100
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000010000
# fixed mul value is      :     0.782429575920105    (bin : 00001100) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.09721541404724121   (bin : 00000001) --> 00000000000000000
# wei value is            :    -0.6080818772315979   (bin : 11110111) --> 10000000000011000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.059114933013916016  (bin : 00000000) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     0.622220516204834    (bin : 00001001) --> 00000000000000011
# wei value is            :    0.5690549612045288    (bin : 00001001) --> 01000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.35407766699790955   (bin : 00000101) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.0668625831604004    (bin : 00010001) --> 00010000000000111
# wei value is            :    0.31352782249450684   (bin : 00000101) --> 00000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :     0.334491103887558    (bin : 00000101) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -0.6649773120880127   (bin : 11110110) --> 10000000000110000
# wei value is            :    1.1168406009674072    (bin : 00010001) --> 01100100000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.7426736354827881   (bin : 11110101) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     2.139988660812378    (bin : 00100010) --> 00110010100001111
# wei value is            :    3.0659518241882324    (bin : 00110001) --> 01111110111100011
# stochastic mul value is :     5.896636962890625    (bin : 01011110) --> 00110010100000011
# fixed mul value is      :     6.561101913452148    (bin : 01101000) --> 01101100001000001
# ------------------------------------------------------------------------------------------
# act value is            :     3.332648515701294    (bin : 00110101) --> 01111111110001111
# wei value is            :    3.9465112686157227    (bin : 00111111) --> 00000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# (13.152335166931152): Out of input range (7.9375/-8) during flp -> fix converting
# fixed mul value is      :    13.152335166931152    (bin : 11010010) --> 01111111110001111
# ------------------------------------------------------------------------------------------
# act value is            :    3.6955747604370117    (bin : 00111011) --> 01111111111001111
# wei value is            :    0.20530182123184204   (bin : 00000011) --> 00000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :    0.7587082386016846    (bin : 00001100) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.4652507305145264    (bin : 00010111) --> 00110000000000111
# wei value is            :    -0.4262928366661072   (bin : 11111010) --> 10000000000010000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.6246258616447449   (bin : 11110111) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -2.574617862701416    (bin : 11010111) --> 11001111011111000
# wei value is            :     2.786525249481201    (bin : 00101100) --> 01111110110100011
# stochastic mul value is :    -5.896636962890625    (bin : 10100010) --> 11001110010100000
# fixed mul value is      :    -7.1742377281188965   (bin : 10001110) --> 10101111000000110
# ------------------------------------------------------------------------------------------
# act value is            :    0.8998417854309082    (bin : 00001110) --> 00010000000000011
# wei value is            :    0.20888042449951172   (bin : 00000011) --> 00000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :    0.18795932829380035   (bin : 00000011) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    2.5527427196502686    (bin : 00101000) --> 01111010100001111
# wei value is            :   -0.44187164306640625   (bin : 11111001) --> 10000000000010000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -1.127984642982483    (bin : 11101110) --> 10000000100000000
# ------------------------------------------------------------------------------------------
# act value is            :    -0.898950457572937    (bin : 11110010) --> 10000000001110000
# wei value is            :    0.3003849983215332    (bin : 00000100) --> 00000000000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.27003124356269836   (bin : 11111100) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :   0.010191917419433594   (bin : 00000000) --> 00000000000000000
# wei value is            :    1.4318766593933105    (bin : 00010110) --> 01110100000000001
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :   0.014593568630516529   (bin : 00000000) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    3.5457935333251953    (bin : 00111000) --> 01111111111001111
# wei value is            :    -0.2470264434814453   (bin : 11111101) --> 10000000000010000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.8759047389030457   (bin : 11110010) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -2.3916897773742676   (bin : 11011010) --> 11001101011111000
# wei value is            :    2.4755380153656006    (bin : 00100111) --> 01111110010100011
# stochastic mul value is :    -4.9138641357421875   (bin : 10110010) --> 11001100010100000
# fixed mul value is      :    -5.920719146728516    (bin : 10100010) --> 10000101011110000
# ------------------------------------------------------------------------------------------
# act value is            :     2.842559337615967    (bin : 00101101) --> 01111010110001111
# wei value is            :    -1.1063077449798584   (bin : 11101111) --> 10000001000011100
# stochastic mul value is :    -1.965545654296875    (bin : 11100001) --> 10000000000001100
# fixed mul value is      :    -3.144745349884033    (bin : 11001110) --> 10000000000001110
# ------------------------------------------------------------------------------------------
# act value is            :    1.7998725175857544    (bin : 00011100) --> 00110010100000111
# wei value is            :     3.283486843109131    (bin : 00110100) --> 01111110111100111
# stochastic mul value is :    6.8794097900390625    (bin : 01101110) --> 00110010100000111
# fixed mul value is      :     5.909857749938965    (bin : 01011110) --> 01101100001000001
# ------------------------------------------------------------------------------------------
# act value is            :    -1.207096815109253    (bin : 11101101) --> 10000100001110000
# wei value is            :    1.7915334701538086    (bin : 00011100) --> 01110110010000001
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000100000000000
# fixed mul value is      :    -2.1625542640686035   (bin : 11011110) --> 10000000001100000
# ------------------------------------------------------------------------------------------
# act value is            :    0.7773310542106628    (bin : 00001100) --> 00010000000000011
# wei value is            :    -0.545300304889679    (bin : 11111000) --> 10000000000011000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.42387884855270386   (bin : 11111010) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     2.470566511154175    (bin : 00100111) --> 01110010100001111
# wei value is            :    0.2000274658203125    (bin : 00000011) --> 00000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :    0.49418115615844727   (bin : 00000111) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.2538573741912842    (bin : 00000100) --> 00000000000000001
# wei value is            :   0.001310110092163086   (bin : 00000000) --> 00000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :   0.0003325811121612787  (bin : 00000000) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    3.9843709468841553    (bin : 00111111) --> 00000000000000000
# wei value is            :    1.2557638883590698    (bin : 00010100) --> 01110100000000001
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :     5.003428936004639    (bin : 01010000) --> 00000000000110111
# ------------------------------------------------------------------------------------------
# act value is            :    -1.978806972503662    (bin : 11100001) --> 10001101011110000
# wei value is            :     2.033141851425171    (bin : 00100000) --> 01110110010100001
# stochastic mul value is :    -2.9483184814453125   (bin : 11010001) --> 10000100010100000
# fixed mul value is      :    -4.023195266723633    (bin : 11000000) --> 10000111000000010
# ------------------------------------------------------------------------------------------
# act value is            :    2.0262064933776855    (bin : 00100000) --> 00110010100001111
# wei value is            :    0.3003583550453186    (bin : 00000100) --> 00000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.6085880398750305    (bin : 00001001) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :   -0.15844982862472534   (bin : 11111110) --> 10000000000000000
# wei value is            :    3.5501391887664795    (bin : 00111000) --> 01111111111100111
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.5625189542770386   (bin : 11110111) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.7806394100189209    (bin : 00001100) --> 00010000000000011
# wei value is            :    0.17412471771240234   (bin : 00000010) --> 00000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :    0.13592861592769623   (bin : 00000010) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.5154569149017334    (bin : 00001000) --> 00000000000000011
# wei value is            :    2.3862507343292236    (bin : 00100110) --> 01110110010100011
# stochastic mul value is :     1.965545654296875    (bin : 00011111) --> 00000000000000011
# fixed mul value is      :    1.2300094366073608    (bin : 00010011) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    1.0685653686523438    (bin : 00010001) --> 00010000000000111
# wei value is            :    0.1918439269065857    (bin : 00000011) --> 00000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :    0.20499777793884277   (bin : 00000011) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -0.682655930519104    (bin : 11110110) --> 10000000000110000
# wei value is            :     1.754607081413269    (bin : 00011100) --> 01110110010000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -1.197792887687683    (bin : 11101101) --> 10000000000000100
# ------------------------------------------------------------------------------------------
# act value is            :    -2.323945999145508    (bin : 11011011) --> 11001101011111000
# wei value is            :    0.7718569040298462    (bin : 00001100) --> 01100000000000001
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 11000000000000000
# fixed mul value is      :    -1.793753743171692    (bin : 11100100) --> 11000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     0.64376300573349     (bin : 00001010) --> 00000000000000011
# wei value is            :     2.02134108543396     (bin : 00100000) --> 01110110010100001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    1.3012646436691284    (bin : 00010100) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :   -0.18407511711120605   (bin : 11111110) --> 10000000000000000
# wei value is            :   -0.005341768264770508  (bin : 00000000) --> 10000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :   0.0009832866489887238  (bin : 00000000) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.6637732982635498    (bin : 00011010) --> 00110000100000111
# wei value is            :    0.5059266090393066    (bin : 00001000) --> 01000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.8417471647262573    (bin : 00001101) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -0.8686315417289734   (bin : 11110011) --> 10000000001110000
# wei value is            :    -0.6079949736595154   (bin : 11110111) --> 10000000000011000
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000010000
# fixed mul value is      :    0.5281236171722412    (bin : 00001000) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.02891230583190918   (bin : 00000000) --> 00000000000000000
# wei value is            :    -0.6359879970550537   (bin : 11110110) --> 10000000000011000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.01838788017630577   (bin : 00000000) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    3.9007182121276855    (bin : 00111110) --> 01111111111101111
# wei value is            :     1.053173303604126    (bin : 00010000) --> 01100100000000001
# stochastic mul value is :     3.93109130859375     (bin : 00111110) --> 01100100000000001
# fixed mul value is      :     4.108132362365723    (bin : 01000001) --> 00011001000000001
# ------------------------------------------------------------------------------------------
# act value is            :     2.748307466506958    (bin : 00101011) --> 01111010110001111
# wei value is            :    -0.5429732799530029   (bin : 11111000) --> 10000000000011000
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000000000001000
# fixed mul value is      :    -1.4922574758529663   (bin : 11101001) --> 10000000000100000
# ------------------------------------------------------------------------------------------
# act value is            :    1.8002080917358398    (bin : 00011100) --> 00110010100000111
# wei value is            :    0.5237636566162109    (bin : 00001000) --> 01000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.9428835511207581    (bin : 00001111) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.5115754008293152    (bin : 00001000) --> 00000000000000011
# wei value is            :   -0.47179508209228516   (bin : 11111001) --> 10000000000010000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.24135875701904297   (bin : 11111101) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -0.4066653251647949   (bin : 11111010) --> 10000000000010000
# wei value is            :    0.7734915018081665    (bin : 00001100) --> 01100000000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.3145521879196167   (bin : 11111011) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -1.308690071105957    (bin : 11101100) --> 10000101001110000
# wei value is            :    0.6378406882286072    (bin : 00001010) --> 01000000000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.8347357511520386   (bin : 11110011) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.7989916801452637    (bin : 00011100) --> 00110010100000111
# wei value is            :    3.0827324390411377    (bin : 00110001) --> 01111110111100011
# stochastic mul value is :     5.896636962890625    (bin : 01011110) --> 00110010100000011
# fixed mul value is      :     5.545810222625732    (bin : 01011000) --> 00001101100000001
# ------------------------------------------------------------------------------------------
# act value is            :   -0.09957528114318848   (bin : 11111111) --> 10000000000000000
# wei value is            :    -1.2147154808044434   (bin : 11101101) --> 10000001000011100
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :    0.12095563858747482   (bin : 00000001) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.13380008935928345   (bin : 00000010) --> 00000000000000000
# wei value is            :    -2.5338189601898193   (bin : 11011000) --> 10001011101111110
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.33902519941329956   (bin : 11111011) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.4562416076660156    (bin : 00010111) --> 00110000000000111
# wei value is            :    -1.2898509502410889   (bin : 11101100) --> 10000001001011100
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000000000000100
# fixed mul value is      :    -1.878334641456604    (bin : 11100010) --> 10000000000000100
# ------------------------------------------------------------------------------------------
# act value is            :    -1.0238430500030518   (bin : 11110000) --> 10000100001110000
# wei value is            :    0.8407041430473328    (bin : 00001101) --> 01100000000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.8607490658760071   (bin : 11110011) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -0.9196609258651733   (bin : 11110010) --> 10000000001110000
# wei value is            :    0.43329131603240967   (bin : 00000110) --> 00000000000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.3984811007976532   (bin : 11111010) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     2.665720224380493    (bin : 00101010) --> 01111010100001111
# wei value is            :    1.5534958839416504    (bin : 00011000) --> 01110100010000001
# stochastic mul value is :     3.93109130859375     (bin : 00111110) --> 01110000000000001
# fixed mul value is      :     4.141185283660889    (bin : 01000010) --> 00000110010000001
# ------------------------------------------------------------------------------------------
# act value is            :   -0.24898111820220947   (bin : 11111101) --> 10000000000000000
# wei value is            :    1.7939419746398926    (bin : 00011100) --> 01110110010000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.4466576874256134   (bin : 11111001) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.12518715858459473   (bin : 00000010) --> 00000000000000000
# wei value is            :    -2.2285780906677246   (bin : 11011101) --> 10001001101111110
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.27898934483528137   (bin : 11111100) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -0.3204166889190674   (bin : 11111011) --> 10000000000010000
# wei value is            :   -0.01578700542449951   (bin : 00000000) --> 10000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :   0.005058419890701771   (bin : 00000000) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    2.2674124240875244    (bin : 00100100) --> 01110010100001111
# wei value is            :    1.5789388418197632    (bin : 00011001) --> 01110100010000001
# stochastic mul value is :     3.93109130859375     (bin : 00111110) --> 01110000000000001
# fixed mul value is      :    3.5801055431365967    (bin : 00111001) --> 01001000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    0.9557911157608032    (bin : 00001111) --> 00010000000000011
# wei value is            :    1.5181361436843872    (bin : 00011000) --> 01110100010000001
# stochastic mul value is :     1.965545654296875    (bin : 00011111) --> 00010000000000001
# fixed mul value is      :    1.4510210752487183    (bin : 00010111) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    1.3960869312286377    (bin : 00010110) --> 00110000000000111
# wei value is            :    0.6403070688247681    (bin : 00001010) --> 01000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :     0.893924355506897    (bin : 00001110) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :   -0.025290250778198242  (bin : 00000000) --> 10000000000000000
# wei value is            :   0.008643746376037598   (bin : 00000000) --> 00000000000000000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :  -0.00021860250853933394 (bin : 00000000) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     2.99440598487854     (bin : 00101111) --> 01111011110001111
# wei value is            :    -0.7315165996551514   (bin : 11110101) --> 10000000000011000
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000000000001000
# fixed mul value is      :    -2.190457582473755    (bin : 11011101) --> 10000000110000000
# ------------------------------------------------------------------------------------------
# act value is            :    2.7932724952697754    (bin : 00101100) --> 01111010110001111
# wei value is            :    1.3115315437316895    (bin : 00010100) --> 01110100000000001
# stochastic mul value is :     3.93109130859375     (bin : 00111110) --> 01110000000000001
# fixed mul value is      :    3.6634650230407715    (bin : 00111010) --> 00000000000010011
# ------------------------------------------------------------------------------------------
# act value is            :     2.942063808441162    (bin : 00101111) --> 01111010110001111
# wei value is            :     -1.88486647605896    (bin : 11100010) --> 10001001101011100
# stochastic mul value is :     -3.93109130859375    (bin : 11000010) --> 10001000100001100
# fixed mul value is      :    -5.5453972816467285   (bin : 10101000) --> 10000001010011100
# ------------------------------------------------------------------------------------------
# act value is            :    0.9748548269271851    (bin : 00001111) --> 00010000000000011
# wei value is            :    -0.5942362546920776   (bin : 11110111) --> 10000000000011000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.5792940855026245   (bin : 11110111) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.14570707082748413   (bin : 00000010) --> 00000000000000000
# wei value is            :     3.499335765838623    (bin : 00110111) --> 01111111111100111
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :    0.5098779797554016    (bin : 00001000) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -0.6062929630279541   (bin : 11110111) --> 10000000000110000
# wei value is            :    -2.395855665206909    (bin : 11011010) --> 10001001101111110
# stochastic mul value is :     1.965545654296875    (bin : 00011111) --> 00000000000110000
# fixed mul value is      :    1.4525904655456543    (bin : 00010111) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    2.8686723709106445    (bin : 00101101) --> 01111010110001111
# wei value is            :    0.3932833671569824    (bin : 00000110) --> 00000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    1.1282011270523071    (bin : 00010010) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    2.8618621826171875    (bin : 00101101) --> 01111010110001111
# wei value is            :    2.0609426498413086    (bin : 00100000) --> 01110110010100001
# stochastic mul value is :     5.896636962890625    (bin : 01011110) --> 01110010010000001
# fixed mul value is      :     5.898133754730225    (bin : 01011110) --> 00000100000110111
# ------------------------------------------------------------------------------------------
# act value is            :    0.35061556100845337   (bin : 00000101) --> 00000000000000001
# wei value is            :    0.1589275598526001    (bin : 00000010) --> 00000000000000000
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :    0.05572247505187988   (bin : 00000000) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.1389832496643066    (bin : 00010010) --> 00010000000000111
# wei value is            :    3.1734719276428223    (bin : 00110010) --> 01111110111100011
# stochastic mul value is :    2.9483184814453125    (bin : 00101111) --> 00010000000000011
# fixed mul value is      :    3.6145312786102295    (bin : 00111001) --> 01000000000001001
# ------------------------------------------------------------------------------------------
# act value is            :    2.6533823013305664    (bin : 00101010) --> 01111010100001111
# wei value is            :    0.8394151329994202    (bin : 00001101) --> 01100000000000001
# stochastic mul value is :    2.9483184814453125    (bin : 00101111) --> 01100000000000001
# fixed mul value is      :    2.2272891998291016    (bin : 00100011) --> 01111111111111111
# ------------------------------------------------------------------------------------------
# act value is            :     0.595128059387207    (bin : 00001001) --> 00000000000000011
# wei value is            :    0.5899367332458496    (bin : 00001001) --> 01000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.35108789801597595   (bin : 00000101) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    3.4031295776367188    (bin : 00110110) --> 01111111110001111
# wei value is            :    -1.6672639846801758   (bin : 11100110) --> 10000001101011100
# stochastic mul value is :     -3.93109130859375    (bin : 11000010) --> 10000001100001100
# fixed mul value is      :    -5.673915386199951    (bin : 10100110) --> 11001110000000100
# ------------------------------------------------------------------------------------------
# act value is            :    -0.5062839388847351   (bin : 11111000) --> 10000000000110000
# wei value is            :    -2.0975687503814697   (bin : 11011111) --> 10001001101011110
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000010000
# fixed mul value is      :    1.0619653463363647    (bin : 00010000) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    2.3956806659698486    (bin : 00100110) --> 01110010100001111
# wei value is            :    1.5314152240753174    (bin : 00011000) --> 01110100010000001
# stochastic mul value is :     3.93109130859375     (bin : 00111110) --> 01110000000000001
# fixed mul value is      :    3.6687817573547363    (bin : 00111010) --> 00000000000010011
# ------------------------------------------------------------------------------------------
# act value is            :    -1.5729436874389648   (bin : 11100111) --> 10000101011110000
# wei value is            :     0.712945282459259    (bin : 00001011) --> 01000000000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -1.1214227676391602   (bin : 11101111) --> 10000000100000000
# ------------------------------------------------------------------------------------------
# act value is            :     2.742556095123291    (bin : 00101011) --> 01111010110001111
# wei value is            :    0.36172229051589966   (bin : 00000101) --> 00000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :     0.992043673992157    (bin : 00001111) --> 01111111111111111
# ------------------------------------------------------------------------------------------
# act value is            :    -0.6605589389801025   (bin : 11110110) --> 10000000000110000
# wei value is            :    1.7104582786560059    (bin : 00011011) --> 01110100010000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -1.1298584938049316   (bin : 11101110) --> 10000001000000000
# ------------------------------------------------------------------------------------------
# act value is            :     2.83162522315979     (bin : 00101101) --> 01111010110001111
# wei value is            :    0.24667668342590332   (bin : 00000011) --> 00000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.6984959244728088    (bin : 00001011) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.6691560745239258    (bin : 00001010) --> 00000000000000011
# wei value is            :    -0.9788055419921875   (bin : 11110001) --> 10000001000011000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.6549736857414246   (bin : 11110110) --> 10000000000000000
# ...
# fixed mul value is      :    1.3700578212738037    (bin : 00010101) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :     1.497593879699707    (bin : 00010111) --> 00110000100000111
# wei value is            :    1.9950618743896484    (bin : 00011111) --> 01110110010100001
# stochastic mul value is :    2.9483184814453125    (bin : 00101111) --> 00110000000000001
# fixed mul value is      :     2.987792491912842    (bin : 00101111) --> 01111111111111111
# ------------------------------------------------------------------------------------------
# act value is            :    0.5304417610168457    (bin : 00001000) --> 00000000000000011
# wei value is            :    1.0321142673492432    (bin : 00010000) --> 01100100000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.5474765300750732    (bin : 00001000) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    2.5231618881225586    (bin : 00101000) --> 01111010100001111
# wei value is            :    2.2464442253112793    (bin : 00100011) --> 01110110010100011
# stochastic mul value is :     5.896636962890625    (bin : 01011110) --> 01110010000000011
# fixed mul value is      :     5.668142318725586    (bin : 01011010) --> 00000000000110111
# ------------------------------------------------------------------------------------------
# act value is            :     -1.7425537109375     (bin : 11100101) --> 10000101011110000
# wei value is            :    -0.6109530925750732   (bin : 11110111) --> 10000000000011000
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000010000
# fixed mul value is      :    1.0646185874938965    (bin : 00010001) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    0.6941664218902588    (bin : 00001011) --> 00000000000000011
# wei value is            :    -0.3059925436973572   (bin : 11111100) --> 10000000000010000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.21240974962711334   (bin : 11111101) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     1.434739589691162    (bin : 00010110) --> 00110000000000111
# wei value is            :    -1.6552550792694092   (bin : 11100110) --> 10000001101011100
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000000000000100
# fixed mul value is      :    -2.3748600482940674   (bin : 11011011) --> 10000000000000110
# ------------------------------------------------------------------------------------------
# act value is            :    -0.4216909408569336   (bin : 11111010) --> 10000000000010000
# wei value is            :    0.28971362113952637   (bin : 00000100) --> 00000000000000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.1221696063876152   (bin : 11111111) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.4944666624069214    (bin : 00000111) --> 00000000000000001
# wei value is            :     2.798827886581421    (bin : 00101100) --> 01111110110100011
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    1.3839271068572998    (bin : 00010110) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    -1.3655202388763428   (bin : 11101011) --> 10000101001110000
# wei value is            :    -0.2635934352874756   (bin : 11111100) --> 10000000000010000
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000010000
# fixed mul value is      :    0.35994216799736023   (bin : 00000101) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.7710442543029785    (bin : 00011100) --> 00110010100000111
# wei value is            :    1.0906338691711426    (bin : 00010001) --> 01100100000000001
# stochastic mul value is :     1.965545654296875    (bin : 00011111) --> 00100000000000001
# fixed mul value is      :    1.9315608739852905    (bin : 00011110) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    2.8911805152893066    (bin : 00101110) --> 01111010110001111
# wei value is            :    1.2684354782104492    (bin : 00010100) --> 01110100000000001
# stochastic mul value is :     3.93109130859375     (bin : 00111110) --> 01110000000000001
# fixed mul value is      :     3.667275905609131    (bin : 00111010) --> 00000000000010011
# ------------------------------------------------------------------------------------------
# act value is            :     2.605074167251587    (bin : 00101001) --> 01111010100001111
# wei value is            :    -1.549165964126587    (bin : 11101000) --> 10000001101011100
# stochastic mul value is :    -2.9483184814453125   (bin : 11010001) --> 10000000100001100
# fixed mul value is      :     -4.03569221496582    (bin : 11000000) --> 11110000000100000
# ------------------------------------------------------------------------------------------
# act value is            :    0.2686889171600342    (bin : 00000100) --> 00000000000000001
# wei value is            :    1.2660375833511353    (bin : 00010100) --> 01110100000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.3401702642440796    (bin : 00000101) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.6422309875488281    (bin : 00001010) --> 00000000000000011
# wei value is            :    1.0865750312805176    (bin : 00010001) --> 01100100000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.6978321671485901    (bin : 00001011) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :   -0.23423254489898682   (bin : 11111101) --> 10000000000000000
# wei value is            :    1.7450019121170044    (bin : 00011011) --> 01110110010000001
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -0.4087362289428711   (bin : 11111010) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.1653282642364502    (bin : 00010010) --> 00010000000000111
# wei value is            :    -1.9138967990875244   (bin : 11100010) --> 10001001101011100
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000000000000100
# fixed mul value is      :    -2.230318069458008    (bin : 11011101) --> 11100000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.7707473039627075    (bin : 00011100) --> 00110010100000111
# wei value is            :    2.2853965759277344    (bin : 00100100) --> 01110110010100011
# stochastic mul value is :    4.9138641357421875    (bin : 01001110) --> 00110010000000011
# fixed mul value is      :    4.0468597412109375    (bin : 01000000) --> 00000000110010001
# ------------------------------------------------------------------------------------------
# act value is            :    -0.9709365367889404   (bin : 11110001) --> 10000000001110000
# wei value is            :    -1.545612096786499    (bin : 11101000) --> 10000001101011100
# stochastic mul value is :     1.965545654296875    (bin : 00011111) --> 00000000001010000
# fixed mul value is      :     1.500691294670105    (bin : 00011000) --> 00000000000000001
# ------------------------------------------------------------------------------------------
# act value is            :    0.4047519564628601    (bin : 00000110) --> 00000000000000001
# wei value is            :    0.3675401210784912    (bin : 00000101) --> 00000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.14876258373260498   (bin : 00000010) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.23856306076049805   (bin : 00000011) --> 00000000000000000
# wei value is            :     3.485750913619995    (bin : 00110111) --> 01111111111100111
# stochastic mul value is :            0.0           (bin : 00000000) --> 00000000000000000
# fixed mul value is      :    0.8315714001655579    (bin : 00001101) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -1.7433247566223145   (bin : 11100101) --> 10001101011110000
# wei value is            :    1.9665075540542603    (bin : 00011111) --> 01110110010000001
# stochastic mul value is :    -1.965545654296875    (bin : 11100001) --> 10000100010000000
# fixed mul value is      :    -3.4282612800598145   (bin : 11001010) --> 11110000000000000
# ------------------------------------------------------------------------------------------
# act value is            :   -0.40950024127960205   (bin : 11111010) --> 10000000000010000
# wei value is            :     3.692314386367798    (bin : 00111011) --> 01111111111100111
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :    -1.5120036602020264   (bin : 11101000) --> 10001000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     2.957034111022949    (bin : 00101111) --> 01111010110001111
# wei value is            :     2.378309965133667    (bin : 00100110) --> 01110110010100011
# stochastic mul value is :    6.8794097900390625    (bin : 01101110) --> 01110010010000011
# fixed mul value is      :     7.03274393081665     (bin : 01110000) --> 00100000110110011
# ------------------------------------------------------------------------------------------
# act value is            :    -1.716792106628418    (bin : 11100101) --> 10000101011110000
# wei value is            :    2.1175663471221924    (bin : 00100001) --> 01110110010100001
# stochastic mul value is :    -2.9483184814453125   (bin : 11010001) --> 10000100010100000
# fixed mul value is      :    -3.6354212760925293   (bin : 11000110) --> 11000000000000110
# ------------------------------------------------------------------------------------------
# act value is            :    0.9705926179885864    (bin : 00001111) --> 00010000000000011
# wei value is            :   -0.22002029418945312   (bin : 11111101) --> 10000000000000000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.21355007588863373   (bin : 11111101) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -1.4075700044631958   (bin : 11101010) --> 10000101001110000
# wei value is            :    1.5457720756530762    (bin : 00011000) --> 01110100010000001
# stochastic mul value is :    -0.9827728271484375   (bin : 11110001) --> 10000100000000000
# fixed mul value is      :    -2.1757824420928955   (bin : 11011110) --> 10001100000000000
# ------------------------------------------------------------------------------------------
# act value is            :   0.041435956954956055   (bin : 00000000) --> 00000000000000000
# wei value is            :    -1.4820665121078491   (bin : 11101001) --> 10000001101011100
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.06141084432601929   (bin : 00000000) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.3217524290084839    (bin : 00000101) --> 00000000000000001
# wei value is            :    1.3053956031799316    (bin : 00010100) --> 01110100000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :    0.4200142025947571    (bin : 00000110) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    0.5161144733428955    (bin : 00001000) --> 00000000000000011
# wei value is            :   -0.02785181999206543   (bin : 00000000) --> 10000000000000000
# stochastic mul value is :           -0.0           (bin : 00000000) --> 10000000000000000
# fixed mul value is      :   -0.014374727383255959  (bin : 00000000) --> 10000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :     1.149043321609497    (bin : 00010010) --> 00010000000000111
# wei value is            :    0.6986944079399109    (bin : 00001011) --> 01000000000000001
# stochastic mul value is :    0.9827728271484375    (bin : 00001111) --> 00000000000000001
# fixed mul value is      :     0.802830159664154    (bin : 00001100) --> 00000000000000000
# ------------------------------------------------------------------------------------------
# act value is            :    -2.8417599201202393   (bin : 11010011) --> 11001111111111000
# wei value is            :    0.9915786981582642    (bin : 00001111) --> 01100100000000001
# stochastic mul value is :    -1.965545654296875    (bin : 11100001) --> 11000100000000000
# fixed mul value is      :     -2.81782865524292    (bin : 11010011) --> 10000000110000000
# ------------------------------------------------------------------------------------------
# act value is            :    -1.9907636642456055   (bin : 11100001) --> 10001101011110000
# wei value is            :    -2.981405735015869    (bin : 11010001) --> 10011011111111110
# stochastic mul value is :     5.896636962890625    (bin : 01011110) --> 00001001011110000
# fixed mul value is      :     5.935274124145508    (bin : 01011110) --> 00011011000010001
# ------------------------------------------------------------------------------------------
# act value is            :    1.7237396240234375    (bin : 00011011) --> 00110000100000111
# wei value is            :    -2.5837831497192383   (bin : 11010111) --> 10001011101111110
# stochastic mul value is :    -2.9483184814453125   (bin : 11010001) --> 10000000100000110
# fixed mul value is      :    -4.453769207000732    (bin : 10111001) --> 10010000111000000
# ------------------------------------------------------------------------------------------
# act value is            :     2.809753894805908    (bin : 00101100) --> 01111010110001111
# wei value is            :    -2.5505592823028564   (bin : 11011000) --> 10001011101111110
# stochastic mul value is :    -5.896636962890625    (bin : 10100010) --> 10001010100001110
# fixed mul value is      :    -7.166443824768066    (bin : 10001110) --> 11101011110000000
# ------------------------------------------------------------------------------------------
# act value is            :    1.6142523288726807    (bin : 00011001) --> 00110000100000111
# wei value is            :    -2.0766689777374268   (bin : 11011111) --> 10001001101011110
# stochastic mul value is :    -2.9483184814453125   (bin : 11010001) --> 10000000100000110
# fixed mul value is      :    -3.3522677421569824   (bin : 11001011) --> 10000111000000000
# ------------------------------------------------------------------------------------------

# %% [markdown]
# # TEST : LFSR 5 bit

# %%
class LFSR5:
    def Random(self):
        self.b0 = eval(f'str(random.randint(0,1))')
        self.b1 = eval(f'str(random.randint(0,1))')
        self.b2 = eval(f'str(random.randint(0,1))')
        self.b3 = eval(f'str(random.randint(0,1))')
        self.b4 = eval(f'str(random.randint(0,1))')
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4
    
    def Normal(self,stream):
        self.b0 = XOR(int(stream[1]),int(stream[4]))
        self.b1 = stream[0]
        self.b2 = stream[1]
        self.b3 = stream[2]
        self.b4 = stream[3]
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4
    
    def Allzero(self):
        self.b0 = '0'
        self.b1 = '0'
        self.b2 = '0'
        self.b3 = '0'
        self.b4 = '0'
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4

# %%
def LFSRlist5():
    lfsr = LFSR5()
    lfsrlist = []
    for k in range(2**(5)-1): #lfsr number generating
        if k == 0:
            lfsrlist.append(lfsr.Random())
        else :
            lfsrlist.append(lfsr.Normal(lfsrlist[k-1]))
        if (k == 2**(5)-2):
            lfsrlist.append(lfsr.Allzero())
    
    if (args.bBW) != args.frac_bits :
        if args.bBW < args.frac_bits :
            for i in range(len(lfsrlist)):
                lfsrlist[i] = lfsrlist[i] + (args.frac_bits-args.bBW)*'0'
        else :
            print("it can't work")
            return 0
    
    return lfsrlist

# %%
lfsr = LFSRlist5()

# %%
for i in lfsr :
    print(i)
# Out:
# 00001
# 10000
# 01000
# 10100
# 01010
# 10101
# 11010
# 11101
# 01110
# 10111
# 11011
# 01101
# 00110
# 00011
# 10001
# 11000
# 11100
# 11110
# 11111
# 01111
# 00111
# 10011
# 11001
# 01100
# 10110
# 01011
# 00101
# 10010
# 01001
# 00100
# 00010
# 00000
