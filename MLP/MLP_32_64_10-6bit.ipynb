# %% [markdown]
# # Module

# %%
import argparse
from tqdm import tqdm_notebook as tq
import tqdm
import os, time, math, copy
import numpy as np
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from collections import namedtuple
import matplotlib.pyplot as plt
import random
import time
import datetime

torch.set_printoptions(precision=8, linewidth=50000)
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # Print Colors

# %%
BLACK	= '\033[30m'
RED		= '\033[31m'
GREEN	= '\033[32m'
YELLOW	= '\033[33m'
BLUE	= '\033[34m'
MAGENTA	= '\033[35m'
CYAN	= '\033[36m'
RESET	= '\033[0m'
SEL		= '\033[7m'

# %%
def int2bin(iIn,iBW):
    iBW = iBW + 1
    if iIn >= 0:
        bOut = bin(iIn).replace('0b','').rjust(iBW,'0')
    else :
        bOut = bin(iIn & (pow(2,iBW)-1)).replace('0b','').rjust(iBW,'1')
    return bOut[1:]

# %%
def XOR(iA,iB):
    if iA != iB :
        iOut = '1'
    else : 
        iOut = '0'
    return iOut

# %%
def snum(a):
    if a >= 0 :
        return '0'
    else :
        return '1'

# %%
class fxp:
    def __init__(self, bIn, iBWF):
        self.iFullBW = len(bIn)
        self.iIntgBW = self.iFullBW - iBWF
        self.bSign = bIn[0]
        self.bIntg = bIn[:self.iIntgBW]
        self.bFrac = bIn[self.iIntgBW:]
        self.fFull = 0
        try:
            for idx, bit in enumerate(bIn):
                if idx == 0:
                    self.fFull = self.fFull + int(bit,2) * -pow(2, self.iIntgBW - 1)
                else:
                    self.fFull = self.fFull + int(bit,2) * pow(2, self.iIntgBW - 1 - idx)
        except:
            print(bIn)
        self.dispFull = self.bIntg +"."+ self.bFrac 
        return

# %%
class flp2fix:
    def __init__(self, fIn, iBW, iBWF):
        self.fMin = - 2 ** (iBW - iBWF - 1)
        self.fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
        self.fResol = 2 ** -iBWF
        #if fIn < self.fMin or fIn > self.fMax:
            #print(f'({fIn}): Out of input range ({self.fMax}/{self.fMin}) during flp -> fix converting ')
        self.iBW = iBW
        self.iBWI = iBW - iBWF
        self.iBWF = iBWF

        self.iFLP2INT = abs(int(fIn * 2 ** iBWF))
        if fIn < 0:
            self.iFLP2INT = 2 ** (iBW-1) - self.iFLP2INT

        if fIn >= 0:
            self.bFull = bin(self.iFLP2INT)[2:].rjust(iBW, '0')
        else:
            self.bFull = '1'+bin(self.iFLP2INT)[2:].rjust(iBW-1, '0')
            if len(self.bFull) > iBW:
                self.bFull = '0' * iBW

        self.cssFxp = fxp(self.bFull, self.iBWF)
        self.bSign = self.cssFxp.bSign
        self.bIntg = self.cssFxp.bIntg
        self.bFrac = self.cssFxp.bFrac
        self.fFull = self.cssFxp.fFull
        return

# %%
def flp2fixTensor(fIn, iBW, iBWF):
    fMin = - 2 ** (iBW - iBWF - 1)
    fMax = (2 ** (iBW-1) - 1) * (2 ** -iBWF)
    fList = []
    for aTensor in fIn.view(-1):
        fList.append(flp2fix(aTensor, iBW, iBWF).fFull)
    return torch.tensor(fList).view(fIn.size())

# %% [markdown]
# # User Define Variables

# %%
data_path = '~/dataset'

# %%
parser = argparse.ArgumentParser(description='PyTorch for MNIST dataset')
parser.add_argument('--device', type=str, default='cpu', help='Device')
parser.add_argument('--shuffle', action='store_true', default=False, help='enables data shuffle')
parser.add_argument('--dataset', type=str, default='mnist', help='training dataset')
parser.add_argument('--data_path', type=str, default=data_path, help='path to MNIST')
parser.add_argument('--batch_size', type=int, default=64, help='batch size')
parser.add_argument('--epochs', type=int, default=10, help='number of epochs to train')
parser.add_argument('--lr', type=float, default=0.001, help='learning rate')
parser.add_argument('--optimizer', type=str, default='adam', help='optimizer')
parser.add_argument('--loss_func', type=str, default='cel', help='optimizer')
parser.add_argument('--quant_opt', type=str, default='asym', help='Type of Quantization')
parser.add_argument('--full_bits', type=int, default=16, help='Number of Quantization Bits')
parser.add_argument('--frac_bits', type=int, default=8, help='Number of Quantization Bits')
#parser.add_argument('--pretrained', type=bool, default=True, help='Pretrained Model')
parser.add_argument('--act_quant', type=bool, default=False, help='Activation Quantization')
parser.add_argument('--disp', type=bool, default=False, help='Display Model Information')
parser.add_argument('--bBW',type=int,default=6,help='bit number')
args = parser.parse_args(args=[])

# %% [markdown]
# # Preparing Data

# %%
kwargs = {'num_workers': 1, 'pin_memory': True} if args.device == 'cuda' else {}
if args.dataset == 'mnist':
	train_loader = torch.utils.data.DataLoader(
		dataset=datasets.MNIST(
			root=args.data_path,
			train=True,
			download=True,
			transform=transforms.ToTensor()
		),
		batch_size=args.batch_size,
		shuffle=args.shuffle,
		**kwargs
	)

	test_loader = torch.utils.data.DataLoader(
		dataset=datasets.MNIST(
			root=args.data_path,
			train=False,
			download=True,
			transform=transforms.ToTensor()
		),
		batch_size=args.batch_size,
		shuffle=args.shuffle,
		**kwargs
	)

# %% [markdown]
# # Build Model

# %%
class MLP(nn.Module):
	def __init__(self):
		super(MLP, self).__init__()
		self.flatten = nn.Flatten()
		self.fc1 = nn.Linear(28*28, 32)
		self.relu1 = nn.ReLU()
		self.fc2 = nn.Linear(32, 64)
		self.relu2 = nn.ReLU()
		self.fc3 = nn.Linear(64, 10)
		
	def forward(self, x):
		x = self.flatten(x)
		x = self.fc1(x)
		x = self.relu1(x)
		x = self.fc2(x)
		x = self.relu2(x)
		logits = self.fc3(x)
		return logits

# %%
def genOptimizer(model, args):
	if args.optimizer == 'sgd':
		optimizer = torch.optim.SGD(model.parameters(), lr=args.lr)
	if args.optimizer == 'adam':
		optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)
	return optimizer

def genLossFunc(args):
	if args.loss_func == 'cel':
		loss_func = nn.CrossEntropyLoss()
	return loss_func

# %%
def train(train_loader, model, epoch, args):
	model.train()
	loss_func = genLossFunc(args)
	optimizer = genOptimizer(model, args)
	max_batch_index = int(np.floor(len(train_loader.dataset)/args.batch_size))
	running_loss = 0
	for batch_index, (image, label) in enumerate(tq(train_loader, desc='Train', leave=False)):
		image, label = image.to(args.device), label.to(args.device)
		pred = model(image)
		loss = loss_func(pred, label)
		running_loss += loss.item()#*image.size(0)

		optimizer.zero_grad()
		loss.backward()
		optimizer.step()
				
	print(f'Epoch {epoch+1:<3d}: Avg. Loss: {running_loss/len(train_loader.dataset):.4f}', end = '\t')

# %%
def test(test_loader, model, args):
	model.eval()
	with torch.no_grad():
		loss_func = genLossFunc(args)
		loss, correct = 0, 0
# 		for batch_index, (image, label) in enumerate(tq(test_loader, desc='Test', leave=False)):
		for batch_index, (image, label) in enumerate(test_loader):
			image, label = image.to(args.device), label.to(args.device)
			pred = model(image)
			loss += loss_func(pred, label).item()#*image.size(0)
			correct += (pred.argmax(1) == label).type(torch.int).sum().item()
	loss /= len(test_loader.dataset)
	correct_rate = 100 * correct / len(test_loader.dataset)
	print(f'Accuracy: {correct}/{len(test_loader.dataset)} ({correct_rate:>.1f}%)')

# %%
def main(model):
	for epoch in range(args.epochs):
		train(train_loader, model, epoch, args)
		test(test_loader, model, args)
	print("Done!")
	return model

# %%
#if args.pretrained:
#    if os.path.isfile('preTrainedModel.pth'):
#        model = MLP().to(args.device)
#        model.load_state_dict(torch.load('preTrainedModel.pth'))
#        test(test_loader, model, args)
#    else:
#        model = main(MLP().to(args.device))
#        torch.save(model.state_dict(), 'preTrainedModel.pth')
#else:
model = main(MLP().to(args.device))
torch.save(model.state_dict(), 'preTrainedModel.pth')
# Out:
# Train:   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 1  : Avg. Loss: 0.0069	Accuracy: 9278/10000 (92.8%)
# Train:   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 2  : Avg. Loss: 0.0033	Accuracy: 9434/10000 (94.3%)
# Train:   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 3  : Avg. Loss: 0.0024	Accuracy: 9537/10000 (95.4%)
# Train:   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 4  : Avg. Loss: 0.0020	Accuracy: 9572/10000 (95.7%)
# Train:   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 5  : Avg. Loss: 0.0017	Accuracy: 9619/10000 (96.2%)
# Train:   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 6  : Avg. Loss: 0.0014	Accuracy: 9640/10000 (96.4%)
# Train:   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 7  : Avg. Loss: 0.0013	Accuracy: 9643/10000 (96.4%)
# Train:   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 8  : Avg. Loss: 0.0011	Accuracy: 9662/10000 (96.6%)
# Train:   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 9  : Avg. Loss: 0.0010	Accuracy: 9673/10000 (96.7%)
# Train:   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 10 : Avg. Loss: 0.0009	Accuracy: 9673/10000 (96.7%)
# Done!

# %%
print(model.fc1.weight)
# Out:
# Parameter containing:
# tensor([[ 2.27456279e-02, -2.50127669e-02,  3.36687230e-02,  ..., -1.50927650e-02, -8.86419881e-03, -3.06686256e-02],
#         [-4.47343104e-03,  3.23692746e-02,  3.00943311e-02,  ..., -5.51010063e-03, -8.84023774e-03, -5.42833563e-03],
#         [-7.52190221e-03,  1.85453855e-02, -9.47671288e-05,  ..., -1.41537916e-02,  3.15114409e-02, -2.47127432e-02],
#         ...,
#         [-2.75546759e-02, -9.54158045e-03,  1.24212978e-02,  ..., -2.45343111e-02,  1.83019731e-02,  3.50744724e-02],
#         [ 8.12484976e-03, -2.42062230e-02, -2.43803281e-02,  ..., -2.09148843e-02, -2.66197342e-02,  2.07835492e-02],
#         [ 1.84579976e-02,  3.46053727e-02,  2.14001592e-02,  ..., -3.04318336e-03,  2.07831189e-02,  9.83890519e-03]], requires_grad=True)

# %% [markdown]
# # SNG

# %%
def Comp(a,lfsr,snum):
    for com in range(0,len(a)):
        oA = '0'
        if a[com]!=lfsr[com]:
            if(int(a[com]) > int(lfsr[com])):
                oA = '1'
            break
    return XOR(oA,snum)

# %%
def perm(a):
    al = len(a)
    blist = []
    for i in range(al) :
        #print(al-i-1)
        blist.append(a[al-i-1])
    
    b = "".join(blist)
    
    return b

# %%
class LFSR6:
    def Random(self):
        self.b0 = eval(f'str(random.randint(0,1))')
        self.b1 = eval(f'str(random.randint(0,1))')
        self.b2 = eval(f'str(random.randint(0,1))')
        self.b3 = eval(f'str(random.randint(0,1))')
        self.b4 = eval(f'str(random.randint(0,1))')
        self.b5 = eval(f'str(random.randint(0,1))')
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5
    
    def Normal(self,stream):
        self.b0 = XOR(int(stream[4]),int(stream[5]))
        self.b1 = stream[0]
        self.b2 = stream[1]
        self.b3 = stream[2]
        self.b4 = stream[3]
        self.b5 = stream[4]
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5
    
    def Allzero(self):
        self.b0 = '0'
        self.b1 = '0'
        self.b2 = '0'
        self.b3 = '0'
        self.b4 = '0'
        self.b5 = '0'
        
        return self.b0 + self.b1 + self.b2 + self.b3 + self.b4 + self.b5

# %%
def LFSRlist6():
    lfsr = LFSR6()
    lfsrlist = []
    for k in range(2**(args.bBW)-1): #lfsr number generating
        if k == 0:
            lfsrlist.append(lfsr.Random())
        else :
            lfsrlist.append(lfsr.Normal(lfsrlist[k-1]))
        if (k == 2**(args.bBW)-2):
            lfsrlist.append(lfsr.Allzero())
    
    if (args.bBW) != args.frac_bits :
        if args.bBW < args.frac_bits :
            for i in range(len(lfsrlist)):
                lfsrlist[i] = lfsrlist[i] + (args.frac_bits-args.bBW)*'0'
        else :
            print("it can't work")
            return 0
    
    return lfsrlist

# %%
def SNG(iIN,lfsr):

    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        lNUM = lfsr[k]
        a = Comp(bIN[-(args.frac_bits):],lNUM,sNUM)
        oAlist.append(a) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if sNUM == '1' and bIN == args.full_bits*'0' :
        return '1'+(2**(args.bBW))*'0'
    else :
        return sA

# %%
def SNG_P(iIN,lfsr):
    sNUM = snum(iIN)
    
    bIN = flp2fix(iIN,args.full_bits,args.frac_bits).bFull
    oAlist = []
    
    for k in range(2**(args.bBW)): #lfsr number generating
        if (args.bBW == args.frac_bits) :    
            lNUM = perm(lfsr[k])
        elif (args.bBW < args.frac_bits) :
            lNUM = perm(lfsr[k][:args.bBW])+(args.frac_bits-args.bBW)*"0"
        a = Comp(bIN[-(args.frac_bits):],lNUM,sNUM)
        oAlist.append(Comp(bIN[-(args.frac_bits):],lNUM,sNUM)) #comparator of input a
    
    oAlist.insert(0,sNUM)
    sA = "".join(oAlist)
    if sNUM == '1' and bIN == args.full_bits*'0' :
        return '1'+(2**(args.bBW))*'0'
    else :
        return sA

# %%
def SNGnumpy(fIn,lfsr):
    start = time.time()
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG(float(aNumpy),lfsr))
    end = time.time()
    sec = (end-start)
    result_list = str(datetime.timedelta(seconds=sec)).split(".")
    print(f'SNGnumpy : {result_list[0]}')                 
    return np.array(sList).reshape(fIn.size())

# %%
def SNGpnumpy(fIn,lfsr):
    start = time.time()
    sList = []
    for aNumpy in fIn.view(-1):
        sList.append(SNG_P(float(aNumpy),lfsr))
    end = time.time()
    sec = (end-start)
    result_list = str(datetime.timedelta(seconds=sec)).split(".")
    print(f'SNGpnumpy : {result_list[0]}')                   
    return  np.array(sList).reshape(fIn.size())

# %%
def CountOne(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        n = 0
        for a in num:
            if a == '1' :
                n += 1
        if a[0] == '1' :
            nlist.append(n-1)
        else :
            nlist.append(n)
    return torch.tensor(nlist).view(nIn.shape)

# %%
def defSign(nIn):
    nlist = []
    for num in nIn.reshape(-1):
        if num[0] == '1' :
            nlist.append(-1)
        else :
            nlist.append(1)
    return torch.tensor(nlist).view(nIn.shape)

# %%
def mul(a,b):
    al = len(a)
    bl = len(b)
    
    outlist = []
    
    if al != bl :
        print("length of string is different")
        return 0
    
    outlist.append(XOR(a[0],b[0]))
    
    for i in range(al-1) :
        outlist.append(str(int(a[i+1]) & int(b[i+1])))
    
    #print(outlist)
    out = "".join(outlist)
    return out

# %%
def defSign1(nIn):
    if nIn[0] == '1' :
        return -1
    else :
        return 1

# %%
def CountOne1(nIn):
    n = 0
    for num in nIn:
        if num == '1' :
            n += 1
    if nIn[0] == '1' :
        return n-1
    else :
        return n

# %%
def S2None(sIn,SF):
    s = defSign1(sIn)
    o = (CountOne1(sIn)/(2**args.bBW))*SF*s
    end = time.time()
    return o

# %%
def mulNumpy(aIn,bIn,aSF,wSF):
    start = time.time()
    mList = []
    for i in range(aIn.shape[0]):
        for j in range(bIn.T.shape[1]):
            sum = 0
            for k in range(aIn.shape[1]):
                sum += S2None(mul((aIn[i][k].astype(str)),(bIn.T)[k][j].astype(str)),aSF*wSF)
            mList.append(sum)
    end = time.time()
    sec = (end-start)
    result_list = str(datetime.timedelta(seconds=sec)).split(".")
    print(f'mulNumpy : {result_list[0]}')
    return torch.tensor(mList).view(aIn.shape[0],bIn.T.shape[1])

# %% [markdown]
# ## Find max, min

# %%
def findMaxMin(data):
    start = time.time()
    
    max = torch.max(data)
    min = torch.min(data)
    SF=torch.max(abs(max),abs(min)).item()
    
    end = time.time()
    sec = (end-start)
    result_list = str(datetime.timedelta(seconds=sec)).split(".")
    print(f'findMaxMin : {result_list[0]}')
    
    return SF

# %% [markdown]
# ## Checking time

# %% [markdown]
# ## Fixed model

# %%
def model2fix(model, args):
	for name, _ in model.named_parameters():
		exec(f'model.{name}.data = flp2fixTensor(model.{name}.data, {args.full_bits}, {args.frac_bits})')
	return model

# %%
def N2S2N(model, iX, iW, iB, args):
    lfsr = LFSRlist6()
    
    xSF = findMaxMin(iX)
    wSF = findMaxMin(iW)
    
    x = SNGnumpy(iX/xSF,lfsr)
    w = SNGpnumpy(iW/wSF,lfsr)
    
    sout = mulNumpy(x,w,xSF,wSF) + iB
    
    return sout

# %%
def quantFixForward(model, x, args):
    cmodel = copy.deepcopy(model).to(args.device)
    
    with torch.no_grad():
        i0 = cmodel.flatten(x)
        act0 = N2S2N(cmodel,i0,cmodel.fc1.weight,cmodel.fc1.bias,args)
        print("act0 successed")
        
        i1 = model.relu1(act0)
        act1 = N2S2N(cmodel,i1,cmodel.fc2.weight,cmodel.fc2.bias,args)
        print("act1 successed")
        
        i2 = cmodel.relu2(act1)
        act2 = N2S2N(cmodel,i2,cmodel.fc3.weight,cmodel.fc3.bias,args)
        print("act2 successed")
        
        act3 = flp2fixTensor(act2, args.full_bits, args.frac_bits)
        print("act3 successed")
    return cmodel, act0, act1, act2, act3

# %%
def testQuant(model, test_loader, args):
    
    start = time.time()
    
    qmodel = copy.deepcopy(model).to(args.device)
    qmodel = model2fix(qmodel, args)
    qmodel.eval()
    
    with torch.no_grad():
        loss_func = genLossFunc(args)
        loss, correct = 0, 0
        for batch_index, (image, label) in enumerate(tq(test_loader,desc='Test',leave=False)):
            start = time.time()
            image, label = image.to(args.device), label.to(args.device)
            qmodel, act0, act1, act2, act3  = quantFixForward(qmodel, image, args)
            y = act3
            loss += loss_func(y, label).item()#*image.size(0)
            correct += (y.argmax(1) == label).type(torch.int).sum().item()
            end = time.time()
            sec = end - start
            result_list = str(datetime.timedelta(seconds=sec)).split(".")
            print(f'image {batch_index} time  : {result_list[0]}')
    correct_rate = 100 * correct / len(test_loader.dataset)
    print(f'Accuracy: {correct}/{len(test_loader.dataset)} ({correct_rate:>.1f}%) Loss: {loss/len(test_loader.dataset):.2f}')
    
    end = time.time()
    sec = (end-start)
    result_list = str(datetime.timedelta(seconds=sec)).split(".")
    print(f'Total time is : {result_list}')
    return qmodel, act0, act1, act2, act3

# %%
qmodel, act0, act1, act2, act3 = testQuant(model, test_loader, args)
# Out:
# Test:   0%|          | 0/157 [00:00<?, ?it/s]
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 0 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 1 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 2 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 3 time  : 0:01:03
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 4 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 5 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 6 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 7 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 8 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 9 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 10 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 11 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 12 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 13 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 14 time  : 0:01:03
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 15 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 16 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 17 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# 10b1010011000000
# 1b11001001110001
# 1b10001101100100
# 1b11000111101101
# 1000000b10100010
# 1b11011101100100
# 10b1010001101110
# 10b1111010100110
# 10b1111001010100
# 1b11101111010011
# 10b1111001110001
# 1b11011011100000
# act3 successed
# image 18 time  : 0:01:03
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 19 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 20 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 21 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 22 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 23 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 24 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 25 time  : 0:01:03
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 26 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 27 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# 1b10011011010010
# 100b101100000010
# 10b1011000100010
# 1b11000111110001
# 1b11110011011111
# 1b10110001100010
# 1b11110100101110
# 1b10011010100000
# act3 successed
# image 28 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# 1b11101100000000
# 1b10111101010000
# 1b11010011110110
# 1b11101100000000
# 1b10001110011111
# 1b11101101010010
# 10b1110111000111
# 1b11101100000000
# 100b110000111110
# 10b1011110111100
# act3 successed
# image 29 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 30 time  : 0:01:03
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 31 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 32 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 33 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 34 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 35 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 36 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 37 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 38 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 39 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 40 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 41 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 42 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 43 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 44 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 45 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 46 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 47 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 48 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 49 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 50 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 51 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 52 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 53 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 54 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 55 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 56 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 57 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 58 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 59 time  : 0:01:03
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 60 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 61 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 62 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 63 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 64 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 65 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 66 time  : 0:01:03
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 67 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 68 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 69 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 70 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 71 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 72 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 73 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 74 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 75 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 76 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 77 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 78 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 79 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 80 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 81 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 82 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 83 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 84 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 85 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 86 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 87 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 88 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 89 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 90 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 91 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 92 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 93 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 94 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 95 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 96 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 97 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 98 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 99 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 100 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 101 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 102 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 103 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 104 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 105 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 106 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 107 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 108 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 109 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 110 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 111 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 112 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 113 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 114 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 115 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 116 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 117 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 118 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 119 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 120 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 121 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 122 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 123 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 124 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# 1b11000110001100
# 1b11011100100101
# 10b1100011000111
# 1000b11001110000
# 100b110010101010
# 100b110001011011
# 1b11110101000010
# 10b1111010110001
# act3 successed
# image 125 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 126 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 127 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 128 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 129 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 130 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 131 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 132 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 133 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 134 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 135 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 136 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 137 time  : 0:01:03
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 138 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 139 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 140 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 141 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 142 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 143 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:04
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 144 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 145 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# 1b11110101101010
# 1b11110101101010
# 1b11110110011100
# 100b111001001111
# 10b1110010111110
# 1b11100011011110
# 1b10000101111011
# 1b11110110011100
# 1b10101001110011
# 1b10010111100111
# 10000000b1001011
# 1000b10010110111
# 1b10101010100101
# 1b11010000111101
# 1b10101011110111
# 1b10000011110111
# act3 successed
# image 146 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 147 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:49
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 148 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 149 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 150 time  : 0:01:01
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 151 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:48
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# 10b1011001001000
# 1b11111000010111
# 10b1111000110100
# 1b11001000110100
# 10000b1001111010
# 1000b11010100010
# 1b10011000100000
# 10000b1001111010
# 1b11001000000010
# 1b10111010010000
# 10b1001010000100
# 10b1001010000100
# 100b111010101011
# 1b11001000000010
# 1b11101001110011
# 1b10011001101111
# 1b10111000001100
# 10b1011001111010
# 10b1001001010010
# 1b10101000010110
# 1b11001000000010
# 1b11001001010001
# 1b10101001001000
# act3 successed
# image 152 time  : 0:01:02
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 153 time  : 0:01:00
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:46
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 154 time  : 0:01:00
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:03
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:47
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:03
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:01
# act2 successed
# act3 successed
# image 155 time  : 0:01:00
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:04
# mulNumpy : 0:00:11
# act0 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:00
# act1 successed
# findMaxMin : 0:00:00
# findMaxMin : 0:00:00
# SNGnumpy : 0:00:00
# SNGpnumpy : 0:00:00
# mulNumpy : 0:00:00
# act2 successed
# act3 successed
# image 156 time  : 0:00:18
# Accuracy: 6653/10000 (66.5%) Loss: 0.09
# Total time is : ['0:00:18', '990533']
