# %%
import random, struct,math

# %% [markdown]
# ## Integer -> Two's Complemenet Binary

# %%
def int2bin(iIn,iBW):
    iBW = iBW + 1
    if iIn >= 0:
        bOut = bin(iIn).replace('0b','').rjust(iBW,'0')
    else :
        bOut = bin(iIn & (pow(2,iBW)-1)).replace('0b','').rjust(iBW,'1')
    return bOut[1:]

# %% [markdown]
# ## XOR gate

# %%
def XOR(iA,iB):
    if iA != iB :
        iOut = '1'
    else : 
        iOut = '0'
    return iOut

# %% [markdown]
# ## LFSR funnction

# %%
def olfsr(seed,flag,taps):
    sr, xor = seed, 0
    for t in taps :
        xor += int(sr[t-1])
        #print(xor)
    if xor%2 == 0:
        xor = 0
    else :
        xor = 1
    sr, xor = str(xor) + sr[:-1], 0
    num = int(sr,2)
    if sr == flag[0]:
        return len(seed)*"0"
    else :
        return sr

# %% [markdown]
# ## SNG

# %%
def SNG(a,bBW):
    iB = int2bin(a,bBW) 
    sNUM = iB[0] #signed number
    oAlist = []
    lfsrlist = []
    ran = random.randint(1,math.pow(2,bBW-1)-1)
    ranZP = bBW-1-len(bin(ran)[2:])
    num = ranZP*'0'+bin(ran)[2:] #lfsr start number generate
    for k in range(2**(bBW-1)): #lfsr number generating
        if not lfsrlist:
            lfsrlist.append(num)
        else :
            lfsrlist.append(olfsr(lfsrlist[k-1],lfsrlist,(0,1)))
        blNUM = lfsrlist[k]
        for com in range(0,len(blNUM)): #	comparator
            oA = '0'
            if iB[com+1] != blNUM[com]:
                if int(iB[com+1]) > int(blNUM[com]) :
                    oA = '1'
                break
        oAlist.append(XOR(oA,sNUM))	#XOR gating & appending
    Onum = oAlist.count('1')
    oAlist.insert(0,sNUM)
    stochastic = "".join(oAlist)
    return stochastic

# %% [markdown]
# ## MAC

# %% [markdown]
# ### mult

# %%
def mul(a,b):
    al = len(a)
    bl = len(b)
    
    outlist = []
    
    if al != bl :
        print("length of string is different")
        return 0
    
    for i in range(al) :
        outlist.append(str(int(a[i]) & int(b[i])))
    
    #print(outlist)
    out = "".join(outlist)
    
    return out

# %%
def count1(sto):
    n = 0
    for i in range(len(sto)):
        if sto[i] == '1' :
                   n += 1
    
    return n

# %% [markdown]
# ## TEST

# %%
a = 8
b = 12
bBW = 5
result = a*b

print(result)
# Out:
# 96

# %%
Sa = SNG(a,bBW)
Sb = SNG(b,bBW)
print(Sa)
print(Sb)
# Out:
# 00100110111000011
# 01100011110111111

# %%
Sout = mul(Sa,Sb)
print(Sout)
# Out:
# 00100010110000011

# %%
print(count1(Sout))
# Out:
# 6

# %%
Sresult = Sout[1:]*len(Sa[1:])

# %%
print(Sresult)
# Out:
# 

# %%
NumOne = count1(Sresult)

# %%
if (NumOne == result ) :
    print("Success!")
else :
    print("fail")
# Out:
# Success!

# %% [markdown]
# ## Random test

# %%
Ra = random.randint(0,2**(bBW-1))
Rb = random.randint(0,2**(bBW-1))

# %%
print(Ra)
print(Rb)
# Out:
# 9
# 10

# %%
for i in range (100) :
    
    n = 0

    Ra = random.randint(0,2**(bBW-1))
    Rb = random.randint(0,2**(bBW-1))
    Rresult = Ra * Rb
    
    Sa = SNG(a,bBW)
    Sb = SNG(b,bBW) 
    
    Sout = mul(Sa,Sb)
    
    Sresult = Sout[1:]*len(Sa[1:])
    
    NumOne = count1(Sresult)
    
    print(f'Ra : {Ra}')
    print(f'Rb : {Rb}')
    print(f'result : {Rresult}')
    print(f'multiplier stohastic number is : {Sout}')
    print(f'NumOne is : {NumOne}')
          
    if (NumOne == result ) :
        n += 1
# Out:
# Ra : 14
# Rb : 5
# result : 70
# multiplier stohastic number is : 00010000110101001
# NumOne is : 96
# Ra : 8
# Rb : 4
# result : 32
# multiplier stohastic number is : 00010100000111001
# NumOne is : 96
# Ra : 8
# Rb : 5
# result : 40
# multiplier stohastic number is : 00000101001100011
# NumOne is : 96
# Ra : 5
# Rb : 13
# result : 65
# multiplier stohastic number is : 00000001001001111
# NumOne is : 96
# Ra : 8
# Rb : 11
# result : 88
# multiplier stohastic number is : 00111000000100011
# NumOne is : 96
# Ra : 11
# Rb : 14
# result : 154
# multiplier stohastic number is : 00110110000010001
# NumOne is : 96
# Ra : 13
# Rb : 13
# result : 169
# multiplier stohastic number is : 00000100010111001
# NumOne is : 96
# Ra : 3
# Rb : 6
# result : 18
# multiplier stohastic number is : 01000011011000001
# NumOne is : 96
# Ra : 4
# Rb : 10
# result : 40
# multiplier stohastic number is : 00011100001010001
# NumOne is : 96
# Ra : 3
# Rb : 14
# result : 42
# multiplier stohastic number is : 00110111000010101
# NumOne is : 128
# Ra : 16
# Rb : 1
# result : 16
# multiplier stohastic number is : 00000101001101111
# NumOne is : 128
# Ra : 2
# Rb : 2
# result : 4
# multiplier stohastic number is : 01001000110000101
# NumOne is : 96
# Ra : 4
# Rb : 3
# result : 12
# multiplier stohastic number is : 01100001010011011
# NumOne is : 128
# Ra : 6
# Rb : 9
# result : 54
# multiplier stohastic number is : 01000011001100001
# NumOne is : 96
# Ra : 15
# Rb : 10
# result : 150
# multiplier stohastic number is : 00101001101110001
# NumOne is : 128
# Ra : 14
# Rb : 3
# result : 42
# multiplier stohastic number is : 00111000010100111
# NumOne is : 128
# Ra : 5
# Rb : 4
# result : 20
# multiplier stohastic number is : 01110000000001101
# NumOne is : 96
# Ra : 5
# Rb : 13
# result : 65
# multiplier stohastic number is : 00000100001101011
# NumOne is : 96
# Ra : 5
# Rb : 3
# result : 15
# multiplier stohastic number is : 00101001000110001
# NumOne is : 96
# Ra : 15
# Rb : 12
# result : 180
# multiplier stohastic number is : 00110001000010101
# NumOne is : 96
# Ra : 5
# Rb : 8
# result : 40
# multiplier stohastic number is : 01001101110000101
# NumOne is : 128
# Ra : 13
# Rb : 5
# result : 65
# multiplier stohastic number is : 00000110011000011
# NumOne is : 96
# Ra : 10
# Rb : 6
# result : 60
# multiplier stohastic number is : 00001100001010011
# NumOne is : 96
# Ra : 3
# Rb : 4
# result : 12
# multiplier stohastic number is : 00010000110110001
# NumOne is : 96
# Ra : 16
# Rb : 4
# result : 64
# multiplier stohastic number is : 00010100000111001
# NumOne is : 96
# Ra : 15
# Rb : 9
# result : 135
# multiplier stohastic number is : 01010011010000001
# NumOne is : 96
# Ra : 10
# Rb : 8
# result : 80
# multiplier stohastic number is : 01000000101001101
# NumOne is : 96
# Ra : 4
# Rb : 9
# result : 36
# multiplier stohastic number is : 00000110110000011
# NumOne is : 96
# Ra : 12
# Rb : 9
# result : 108
# multiplier stohastic number is : 00000010100010111
# NumOne is : 96
# Ra : 6
# Rb : 8
# result : 48
# multiplier stohastic number is : 00001010010001101
# NumOne is : 96
# Ra : 11
# Rb : 14
# result : 154
# multiplier stohastic number is : 01011100001010011
# NumOne is : 128
# Ra : 1
# Rb : 14
# result : 14
# multiplier stohastic number is : 00100110111000011
# NumOne is : 128
# Ra : 14
# Rb : 6
# result : 84
# multiplier stohastic number is : 01001101110000101
# NumOne is : 128
# Ra : 9
# Rb : 10
# result : 90
# multiplier stohastic number is : 00010011000000001
# NumOne is : 64
# Ra : 3
# Rb : 15
# result : 45
# multiplier stohastic number is : 00011011100000001
# NumOne is : 96
# Ra : 7
# Rb : 1
# result : 7
# multiplier stohastic number is : 01000101100000101
# NumOne is : 96
# Ra : 10
# Rb : 15
# result : 150
# multiplier stohastic number is : 00000111000010101
# NumOne is : 96
# Ra : 11
# Rb : 6
# result : 66
# multiplier stohastic number is : 00001001001110001
# NumOne is : 96
# Ra : 7
# Rb : 10
# result : 70
# multiplier stohastic number is : 00001010000011101
# NumOne is : 96
# Ra : 8
# Rb : 4
# result : 32
# multiplier stohastic number is : 01000001110000101
# NumOne is : 96
# Ra : 15
# Rb : 0
# result : 0
# multiplier stohastic number is : 01100001000011001
# NumOne is : 96
# Ra : 16
# Rb : 9
# result : 144
# multiplier stohastic number is : 01101100000100001
# NumOne is : 96
# Ra : 15
# Rb : 9
# result : 135
# multiplier stohastic number is : 01000110000101001
# NumOne is : 96
# Ra : 3
# Rb : 7
# result : 21
# multiplier stohastic number is : 00100001100110001
# NumOne is : 96
# Ra : 12
# Rb : 4
# result : 48
# multiplier stohastic number is : 01010010001100001
# NumOne is : 96
# Ra : 0
# Rb : 16
# result : 0
# multiplier stohastic number is : 00001101110000001
# NumOne is : 96
# Ra : 5
# Rb : 5
# result : 25
# multiplier stohastic number is : 00010100100011001
# NumOne is : 96
# Ra : 4
# Rb : 8
# result : 32
# multiplier stohastic number is : 01101110000000001
# NumOne is : 96
# Ra : 12
# Rb : 13
# result : 156
# multiplier stohastic number is : 00001101010000101
# NumOne is : 96
# Ra : 15
# Rb : 11
# result : 165
# multiplier stohastic number is : 00101001000110001
# NumOne is : 96
# Ra : 15
# Rb : 13
# result : 195
# multiplier stohastic number is : 00000011100001011
# NumOne is : 96
# Ra : 7
# Rb : 9
# result : 63
# multiplier stohastic number is : 01000101100000101
# NumOne is : 96
# Ra : 12
# Rb : 6
# result : 72
# multiplier stohastic number is : 00010100000111001
# NumOne is : 96
# Ra : 12
# Rb : 15
# result : 180
# multiplier stohastic number is : 00000100110000001
# NumOne is : 64
# Ra : 6
# Rb : 16
# result : 96
# multiplier stohastic number is : 01101000000101001
# NumOne is : 96
# Ra : 5
# Rb : 3
# result : 15
# multiplier stohastic number is : 00110000010100011
# NumOne is : 96
# Ra : 0
# Rb : 16
# result : 0
# multiplier stohastic number is : 00000000010011001
# NumOne is : 64
# Ra : 14
# Rb : 1
# result : 14
# multiplier stohastic number is : 01001110000001001
# NumOne is : 96
# Ra : 2
# Rb : 13
# result : 26
# multiplier stohastic number is : 00011000100001011
# NumOne is : 96
# Ra : 0
# Rb : 5
# result : 0
# multiplier stohastic number is : 00101110000001001
# NumOne is : 96
# Ra : 5
# Rb : 10
# result : 50
# multiplier stohastic number is : 00100110100000011
# NumOne is : 96
# Ra : 16
# Rb : 10
# result : 160
# multiplier stohastic number is : 00110001000010101
# NumOne is : 96
# Ra : 2
# Rb : 9
# result : 18
# multiplier stohastic number is : 00100110111000011
# NumOne is : 128
# Ra : 4
# Rb : 14
# result : 56
# multiplier stohastic number is : 00000010000110111
# NumOne is : 96
# Ra : 0
# Rb : 11
# result : 0
# multiplier stohastic number is : 01011100001010011
# NumOne is : 128
# Ra : 5
# Rb : 5
# result : 25
# multiplier stohastic number is : 01000110000101001
# NumOne is : 96
# Ra : 16
# Rb : 13
# result : 208
# multiplier stohastic number is : 01000101110000001
# NumOne is : 96
# Ra : 10
# Rb : 6
# result : 60
# multiplier stohastic number is : 00100000010100111
# NumOne is : 96
# Ra : 0
# Rb : 5
# result : 0
# multiplier stohastic number is : 00001011100000011
# NumOne is : 96
# Ra : 3
# Rb : 15
# result : 45
# multiplier stohastic number is : 00000100001101011
# NumOne is : 96
# Ra : 13
# Rb : 16
# result : 208
# multiplier stohastic number is : 01000000100100111
# NumOne is : 96
# Ra : 14
# Rb : 7
# result : 98
# multiplier stohastic number is : 01000011011000001
# NumOne is : 96
# Ra : 12
# Rb : 6
# result : 72
# multiplier stohastic number is : 01100001000011001
# NumOne is : 96
# Ra : 10
# Rb : 8
# result : 80
# multiplier stohastic number is : 00000111000010101
# NumOne is : 96
# Ra : 0
# Rb : 1
# result : 0
# multiplier stohastic number is : 01000000000110111
# NumOne is : 96
# Ra : 12
# Rb : 3
# result : 36
# multiplier stohastic number is : 01010011011100001
# NumOne is : 128
# Ra : 6
# Rb : 15
# result : 90
# multiplier stohastic number is : 01100000000001001
# NumOne is : 64
# Ra : 5
# Rb : 3
# result : 15
# multiplier stohastic number is : 01001100010000101
# NumOne is : 96
# Ra : 7
# Rb : 8
# result : 56
# multiplier stohastic number is : 00000011100001011
# NumOne is : 96
# Ra : 14
# Rb : 3
# result : 42
# multiplier stohastic number is : 01100000000001001
# NumOne is : 64
# Ra : 7
# Rb : 1
# result : 7
# multiplier stohastic number is : 01110000101000001
# NumOne is : 96
# Ra : 8
# Rb : 7
# result : 56
# multiplier stohastic number is : 01000010100000111
# NumOne is : 96
# Ra : 16
# Rb : 4
# result : 64
# multiplier stohastic number is : 00110000010100011
# NumOne is : 96
# Ra : 13
# Rb : 9
# result : 117
# multiplier stohastic number is : 01000010100110111
# NumOne is : 128
# Ra : 14
# Rb : 4
# result : 56
# multiplier stohastic number is : 00110000010100011
# NumOne is : 96
# Ra : 2
# Rb : 14
# result : 28
# multiplier stohastic number is : 00101001101110001
# NumOne is : 128
# Ra : 0
# Rb : 16
# result : 0
# multiplier stohastic number is : 00101000010000111
# NumOne is : 96
# Ra : 6
# Rb : 16
# result : 96
# multiplier stohastic number is : 00110000000000101
# NumOne is : 64
# Ra : 16
# Rb : 3
# result : 48
# multiplier stohastic number is : 00101000010000111
# NumOne is : 96
# Ra : 10
# Rb : 5
# result : 50
# multiplier stohastic number is : 01110000101001101
# NumOne is : 128
# Ra : 7
# Rb : 6
# result : 42
# multiplier stohastic number is : 00000100001100111
# NumOne is : 96
# Ra : 3
# Rb : 15
# result : 45
# multiplier stohastic number is : 00000011100001011
# NumOne is : 96
# Ra : 13
# Rb : 5
# result : 65
# multiplier stohastic number is : 00000100001101011
# NumOne is : 96
# Ra : 14
# Rb : 11
# result : 154
# multiplier stohastic number is : 01110000101001101
# NumOne is : 128
# Ra : 15
# Rb : 8
# result : 120
# multiplier stohastic number is : 01010000100001101
# NumOne is : 96
# Ra : 16
# Rb : 14
# result : 224
# multiplier stohastic number is : 00100100111000001
# NumOne is : 96
# Ra : 6
# Rb : 0
# result : 0
# multiplier stohastic number is : 00100010110000011
# NumOne is : 96
# Ra : 16
# Rb : 16
# result : 256
# multiplier stohastic number is : 01010000001010011
# NumOne is : 96
# Ra : 5
# Rb : 16
# result : 80
# multiplier stohastic number is : 00000001001100001
# NumOne is : 64
# Ra : 7
# Rb : 3
# result : 21
# multiplier stohastic number is : 01010000100001101
# NumOne is : 96

# %%
print(f' Succes is : {n}/{100}')
# Out:
#  Succes is : 1/100
